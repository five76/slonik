# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import re
from glob import glob

# %%
df_amo= pd.read_csv(r'C:\Users\Admin\rasp.csv', sep = ';').to_dict()


# file = r'C:\Users\Admin\rasp.csv'
# with open(file) as f:
#     reader = csv.DictReader(f, delimiter=';')

# for row in reader:
#     print(row)

# %% [markdown]
# df_amo

# %%
df_amo
# Out:
# {'prep': {0: 100,
#   1: 100,
#   2: 107,
#   3: 107,
#   4: 104,
#   5: 104,
#   6: 104,
#   7: 103,
#   8: 101,
#   9: 101,
#   10: 105,
#   11: 105,
#   12: 107,
#   13: 106,
#   14: 106,
#   15: 107,
#   16: 101,
#   17: 102,
#   18: 103,
#   19: 103,
#   20: 101,
#   21: 101,
#   22: 101,
#   23: 101,
#   24: 101,
#   25: 101,
#   26: 100,
#   27: 101,
#   28: 101,
#   29: 104,
#   30: 105,
#   31: 106,
#   32: 107,
#   33: 107},
#  'gr': {0: 2011,
#   1: 2012,
#   2: 2011,
#   3: 2012,
#   4: 2012,
#   5: 2011,
#   6: 201,
#   7: 201,
#   8: 2011,
#   9: 2012,
#   10: 2011,
#   11: 2012,
#   12: 2011,
#   13: 2011,
#   14: 2012,
#   15: 2012,
#   16: 201,
#   17: 201,
#   18: 2011,
#   19: 2012,
#   20: 2011,
#   21: 2012,
#   22: 2011,
#   23: 2012,
#   24: 2012,
#   25: 2011,
#   26: 201,
#   27: 201,
#   28: 201,
#   29: 201,
#   30: 201,
#   31: 201,
#   32: 201,
#   33: 201},
#  'disc': {0: 100,
#   1: 100,
#   2: 110,
#   3: 110,
#   4: 107,
#   5: 107,
#   6: 104,
# ...

# %%
rr = {}
for i in range(34):
    p = []
    for j in range(34):
        if df_amo['prep'][i] == df_amo['prep'][j]:
                #p.append({'gr':df_amo['gr'][j], 'disc':df_amo['disc'][j], 'hwo':df_amo['hwo'][j]})
                p.append([df_amo['gr'][j], df_amo['disc'][j],df_amo['hwo'][j]])
                
    if df_amo['prep'][i] not in rr:
        rr[df_amo['prep'][i]] = p

# %% [raw]
# rr

# %%
rr
# Out:
# {100: [[2011, 100, '6,00'], [2012, 100, '6,00'], [201, 100, '0,00']],
#  107: [[2011, 110, '6,00'],
#   [2012, 110, '6,00'],
#   [2011, 111, '2,00'],
#   [2012, 111, '2,00'],
#   [201, 110, '0,00'],
#   [201, 111, '0,00']],
#  104: [[2012, 107, '4,00'],
#   [2011, 107, '4,00'],
#   [201, 104, '4,00'],
#   [201, 107, '0,00']],
#  103: [[201, 106, '2,00'], [2011, 106, '2,00'], [2012, 106, '2,00']],
#  101: [[2011, 104, '2,00'],
#   [2012, 104, '2,00'],
#   [201, 101, '2,00'],
#   [2011, 102, '0,00'],
#   [2012, 102, '0,00'],
#   [2011, 101, '0,00'],
#   [2012, 101, '0,00'],
#   [2012, 103, '0,00'],
#   [2011, 103, '0,00'],
#   [201, 102, '0,00'],
#   [201, 103, '0,00']],
#  105: [[2011, 108, '2,00'], [2012, 108, '2,00'], [201, 108, '0,00']],
#  106: [[2011, 109, '2,00'], [2012, 109, '2,00'], [201, 109, '0,00']],
#  102: [[201, 105, '2,00']]}
