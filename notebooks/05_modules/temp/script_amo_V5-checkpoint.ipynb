# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import re
from glob import glob

# %% [markdown]
# ## Чтение данных

# %%
#file_amo = 'df_amocrm_sample_export_2019_01_01_2024-02-20.csv'

# %%
file_amo = glob('df_amocrm_sample_export_*.csv')[0]

# %%
file_amo
# Out:
# 'df_amocrm_sample_export_2019_01_01_2024-02-26.csv'

# %%
date_int = re.search(r'_\d+[_-]\d+[_-]\d+[_-]\d+[_-]\d+[_-]\d+',file_amo).group(0)

# %%
date_int
# Out:
# '_2019_01_01_2024-02-26'

# %%
df_amo= pd.read_csv(file_amo, encoding='utf-8')

# %%
df_values= pd.read_csv('df_list_of_values_2023_12_13.csv', encoding='utf-8')

# %%
df_sample= pd.read_csv('df_certificates_list_sample.csv', encoding='utf-8')

# %%
df_archive= pd.read_excel('df_codes_archieve_2024_02_20.xlsx')

# %%
#Вывод таблицы во всю ширину
pd.set_option('display.max_columns', None)
df_amo.head(5)
# Out:
#          ID          Этап сделки  Бюджет  Дата создания сделки  \
# 0  26975611  Успешно реализовано     4500  26.02.2024 12:36:08
# 1  26972451  Успешно реализовано     6000  26.02.2024 10:00:59
# 2  26963357  Успешно реализовано     4300  25.02.2024 11:56:47
# 3  26960863  Успешно реализовано     5500  25.02.2024 00:26:07
# 4  26960249  Успешно реализовано    10000  24.02.2024 21:50:08
#
#          Дата закрытия  DELIVERY_PRICE Стоимость доставки  \
# 0  26.02.2024 12:52:00             0.0                NaN
# 1  26.02.2024 10:35:00             NaN                NaN
# 2  26.02.2024 11:09:00           700.0                NaN
# 3  25.02.2024 09:08:00             0.0                NaN
# 4  24.02.2024 22:04:00             0.0                NaN
#
#                                             PRODUCTS    PRICE  SUBTOTAL  \
# 0  Заезд на Дрифт Трайке (Варианты: Заезд 30 мину...   4500.0    4500.0
# 1  Бигфуты (Варианты: 40 мин. для 1 с пассажиром,...   6000.0    6000.0
# 2  Скалодром (Варианты: Start Up для двоих, Бумаж...   4300.0    3600.0
# 3  Снегоходы (Варианты: 1 снежик на 1 час, Бумажн...   5500.0    5500.0
# 4  Искусственная волна Flow Moscow (Варианты: 1 ч...  10000.0   10000.0
#
#   Выручка от клиента Направление (вид сертификата) Номер сертификата  \
# 0               4500              Мото Дрифт-трайк   VDT30 101669122
# 1               6000           Квадроциклы Бигфуты   VBF40 901660887
# 2               4300                     Скалодром     GC2 900263473
# 3               5500                     Снегоходы   VSN1X 101635025
# 4              10000           Искусственная волна    VCW2 601640748
#
#   КОРНЕВАЯ СДЕЛКА Номер 2-го сертификата Номер 3-го сертификата  \
# 0             NaN                    NaN                    NaN
# 1             NaN                    NaN                    NaN
# 2             NaN                    NaN                    NaN
# 3             NaN                    NaN                    NaN
# 4             NaN                    NaN                    NaN
#
#   Номер 4-го сертификата Номер 5-го сертификата Сертификат на тренера  \
# 0                    NaN                    NaN                   NaN
# 1                    NaN                    NaN                   NaN
# 2                    NaN                    NaN                   NaN
# 3                    NaN                    NaN                   NaN
# 4                    NaN                    NaN                   NaN
#
#   Статус погашения Дата получения услуги Стоимость закупки
# 0              NaN                   NaN              4050
# 1              NaN                   NaN              4500
# 2              NaN                   NaN              3000
# 3              NaN                   NaN              4000
# 4              NaN                   NaN              8000

# %% [markdown]
# ## Предобработка архивных префиксов

# %%
df_archive.head()
# Out:
#   Префикс
# 0   2SU24
# 1   2SU60
# 2   2WP24
# 3      MT
# 4     MTT

# %%
df_archive['Префикс'] = df_archive['Префикс'].str.upper()

# %%
df_archive = df_archive.dropna(subset=['Префикс'])

# %%
df_archive = df_archive.reset_index(drop=True)

# %%
df_archive.rename(columns = {'Префикс':'prefix'}, inplace = True )

# %%
df_archive.head()
# Out:
#   prefix
# 0  2SU24
# 1  2SU60
# 2  2WP24
# 3     MT
# 4    MTT

# %%
print(sorted(list(df_archive['prefix'].unique())))
# Out:
# ['2SU24', '2SU60', '2WP24', 'AC2', 'AC30', 'AC60', 'AT10', 'AT15', 'AT30', 'AT4', 'AT4K', 'AT6', 'AT60', 'AT6K', 'BC1', 'BC2', 'BCR', 'BF180', 'BF40', 'BF90', 'BG', 'BGH', 'BGK', 'BGKH', 'CS20', 'CS30', 'CS40', 'CS60', 'CSR60', 'CW1', 'CW2', 'CWH', 'DRC2H', 'DT230', 'DT240', 'DT260', 'DT30', 'DT32', 'DT40', 'DT60', 'DTM', 'EB1X', 'EB1X1', 'EB2X', 'EB4X', 'ED3H', 'EDC', 'EF30', 'EF60', 'EFL30', 'EFL60', 'ES130', 'ES160', 'ES230', 'ES260', 'ESG1', 'ESG2', 'ESG4', 'F1', 'F1K', 'F2', 'FD', 'FDK', 'FJ30', 'FM30', 'FM45', 'FM60', 'FMCS30', 'FMCS45', 'FMCS45R', 'FMCS60', 'FMP15', 'FMP30', 'FMS30', 'FMS45', 'FMS60', 'FR', 'FR2', 'FROG1', 'FROG3', 'FROGM', 'GC1', 'GC2', 'GR1', 'GR1X1', 'GR2', 'GR2X1', 'GU', 'GU2', 'HB20', 'HB30', 'HY30', 'HY60', 'ICE1', 'ICE2', 'ID', 'KA2', 'KA4', 'KA6', 'KAT', 'KAT2', 'KAT4', 'KR1', 'KR2', 'KR3', 'KR4', 'KR6', 'KS', 'KS2', 'KV1X1', 'KV2X1', 'KVP1X1', 'KVP2X1', 'KVS', 'KW', 'KW2', 'KYT', 'KYT2', 'LB1X', 'LB2X', 'LB4X', 'LL1H', 'LL1HP', 'LL2H', 'LL2HP', 'LL3H', 'MB', 'MB2', 'MB2X', 'MF20', 'MF30', 'MF60', 'MT', 'MT10', 'MT10B', 'MT2', 'MT2B', 'MT5', 'MT5B', 'MTT', 'OW2', 'OWG', 'OWI', 'P1', 'P1G', 'P1P', 'P2', 'P2G', 'P2P', 'PB', 'PB2', 'PB2X', 'PH', 'PP', 'PP2', 'PPP', 'PPT', 'PR20', 'PR30', 'PR40', 'PR60', 'PS', 'RB15', 'RB20', 'RB30', 'RB40', 'RB60', 'RC', 'RCV', 'RJ', 'RJ1X', 'RJ2', 'RJ2X', 'RJXX', 'RS', 'RT', 'RTV', 'RX', 'RXV', 'S', 'S2', 'SC', 'SG10', 'SG7', 'SH', 'SH2', 'SHH', 'SK2', 'SKI20', 'SKI40', 'SKI60', 'SKT1', 'SKT10', 'SKT2', 'SKT4', 'SKT6', 'SKV', 'SN1X', 'SN1X1', 'SN2X', 'SN2X1', 'SP', 'SP2', 'ST', 'SU24', 'SU60', 'TR', 'TR1', 'TR1K', 'TR2', 'TR2K', 'TX', 'UC', 'UN', 'UNI', 'VD', 'W&F', 'WP15', 'WP2H', 'WP30', 'WP60', 'WS20', 'WS30', 'WS40', 'WS60', 'WSN40', 'WSN60', 'WTF2', 'WTF3', 'YAS', 'YEP', 'YHD']

# %% [markdown]
# При сортировке обнаружилась кириллица в префиксах

# %%
alf_ciril = 'Е Т О Р А Н К Х С В М'.split()
alf_latin = 'E T O P A H K X C B M'.split()

# %%
def replace_cirillic_latin(x):
    try:
        v = x
        new_v = ''
        for i in range(len(v)):
            simv = v[i]
            if simv in alf_ciril:
                pos = alf_ciril.index(simv)
                simv = alf_latin[pos]
            new_v += simv
    except:
        pass
    return new_v

# %%
df_archive['prefix'] = df_archive.apply(lambda x: replace_cirillic_latin(x['prefix']),axis=1)

# %% [markdown]
# Удаление OLD из префикса

# %%
df1 = df_archive[df_archive['prefix'].str.contains('OLD')]

# %%
df1
# Out:
# Empty DataFrame
# Columns: [prefix]
# Index: []

# %%
df1.shape
# Out:
# (0, 1)

# %%
#df_archive.replace(r' (OLD)|(OLD) ',r'',regex=True,inplace=True)
df_archive.replace(r'( *OLD *)',r'',regex=True,inplace=True)

# %%
df1.head()
# Out:
# Empty DataFrame
# Columns: [prefix]
# Index: []

# %%
#df_archive.iloc[246]['prefix']

# %%
df1.shape
# Out:
# (0, 1)

# %% [markdown]
# Удаление **+ Карта Тренер**, **+T**

# %%
df_archive.replace(r'( *\+ *\S* *[Т|T]\S*)',r'T',regex=True,inplace=True)

# %%
print(sorted(list(df_archive['prefix'].unique())))
# Out:
# ['2SU24', '2SU60', '2WP24', 'AC2', 'AC30', 'AC60', 'AT10', 'AT15', 'AT30', 'AT4', 'AT4K', 'AT6', 'AT60', 'AT6K', 'BC1', 'BC2', 'BCR', 'BF180', 'BF40', 'BF90', 'BG', 'BGH', 'BGK', 'BGKH', 'CS20', 'CS30', 'CS40', 'CS60', 'CSR60', 'CW1', 'CW2', 'CWH', 'DRC2H', 'DT230', 'DT240', 'DT260', 'DT30', 'DT32', 'DT40', 'DT60', 'DTM', 'EB1X', 'EB1X1', 'EB2X', 'EB4X', 'ED3H', 'EDC', 'EF30', 'EF60', 'EFL30', 'EFL60', 'ES130', 'ES160', 'ES230', 'ES260', 'ESG1', 'ESG2', 'ESG4', 'F1', 'F1K', 'F2', 'FD', 'FDK', 'FJ30', 'FM30', 'FM45', 'FM60', 'FMCS30', 'FMCS45', 'FMCS45R', 'FMCS60', 'FMP15', 'FMP30', 'FMS30', 'FMS45', 'FMS60', 'FR', 'FR2', 'FROG1', 'FROG3', 'FROGM', 'GC1', 'GC2', 'GR1', 'GR1X1', 'GR2', 'GR2X1', 'GU', 'GU2', 'HB20', 'HB30', 'HY30', 'HY60', 'ICE1', 'ICE2', 'ID', 'KA2', 'KA4', 'KA6', 'KAT', 'KAT2', 'KAT4', 'KR1', 'KR2', 'KR3', 'KR4', 'KR6', 'KS', 'KS2', 'KV1X1', 'KV2X1', 'KVP1X1', 'KVP2X1', 'KVS', 'KW', 'KW2', 'KYT', 'KYT2', 'LB1X', 'LB2X', 'LB4X', 'LL1H', 'LL1HP', 'LL2H', 'LL2HP', 'LL3H', 'MB', 'MB2', 'MB2X', 'MF20', 'MF30', 'MF60', 'MT', 'MT10', 'MT10B', 'MT2', 'MT2B', 'MT5', 'MT5B', 'MTT', 'OW2', 'OWG', 'OWI', 'P1', 'P1G', 'P1P', 'P2', 'P2G', 'P2P', 'PB', 'PB2', 'PB2X', 'PH', 'PP', 'PP2', 'PPP', 'PPT', 'PR20', 'PR30', 'PR40', 'PR60', 'PS', 'RB15', 'RB20', 'RB30', 'RB40', 'RB60', 'RC', 'RCV', 'RJ', 'RJ1X', 'RJ2', 'RJ2X', 'RJXX', 'RS', 'RT', 'RTV', 'RX', 'RXV', 'S', 'S2', 'SC', 'SG10', 'SG7', 'SH', 'SH2', 'SHH', 'SK2', 'SKI20', 'SKI40', 'SKI60', 'SKT1', 'SKT10', 'SKT2', 'SKT4', 'SKT6', 'SKV', 'SN1X', 'SN1X1', 'SN2X', 'SN2X1', 'SP', 'SP2', 'ST', 'SU24', 'SU60', 'TR', 'TR1', 'TR1K', 'TR2', 'TR2K', 'TX', 'UC', 'UN', 'UNI', 'VD', 'W&F', 'WP15', 'WP2H', 'WP30', 'WP60', 'WS20', 'WS30', 'WS40', 'WS60', 'WSN40', 'WSN60', 'WTF2', 'WTF3', 'YAS', 'YEP', 'YHD']

# %% [markdown]
# Имеются двойные префиксы MT/MT2 и MT10/MT10B

# %%
archive_prefix = list(df_archive['prefix'].unique())

# %% [markdown]
# ## Предобработка активных префиксов

# %%
df_values.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              198 non-null    int64
#  1   Activity Name   198 non-null    object
#  2   Value           196 non-null    object
#  3   Status          198 non-null    object
#  4   Prefix          198 non-null    object
#  5   Purchase Price  167 non-null    float64
#  6   Sale Price      196 non-null    float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 11.0+ KB

# %%
df_values.columns = df_values.columns.str.lower()

# %%
df_values.columns = df_values.columns.str.strip()

# %%
df_values.columns = df_values.columns.map(lambda x: re.sub( '(?<!^)(?=[ ])', '_', x ).lower())
df_values.columns = df_values.columns.map(lambda x: re.sub( ' ', '', x ))

# %%
df_values.head(5)
# Out:
#    id        activity_name                                              value  \
# 0   1  Вейксёрф и вейкборд  2 часа вейксерфинга или вейкбординга\nна волне...
# 1   2  Вейксёрф и вейкборд  1 час вейксерфинга или вейкбординга\nна волне ...
# 2   3  Вейксёрф и вейкборд  40 минут вейксерфинга или вейкбординга\nна вол...
# 3   4  Вейксёрф и вейкборд  30 минут вейксерфинга или вейкбординга\nна вол...
# 4   5  Вейксёрф и вейкборд  25 минут вейксерфинга или вейкбординга\nна вол...
#
#    status prefix  purchase_price  sale_price
# 0  on_air    WS2             NaN     22500.0
# 1  on_air    WS1             NaN     11000.0
# 2  on_air   WS40             NaN      7500.0
# 3  on_air   WS30             NaN      5500.0
# 4  on_air   WS25             NaN      5000.0

# %%
df_values.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              198 non-null    int64
#  1   activity_name   198 non-null    object
#  2   value           196 non-null    object
#  3   status          198 non-null    object
#  4   prefix          198 non-null    object
#  5   purchase_price  167 non-null    float64
#  6   sale_price      196 non-null    float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 11.0+ KB

# %%
print(sorted(list(df_values['prefix'].unique())))
# Out:
# ['2MWP24', '2WP24', 'AB', 'AB4', 'AB4G', 'ABG', 'AC2', 'AC30', 'AC60', 'AT10', 'AT15', 'AT30', 'AT4', 'AT4K', 'AT6', 'AT60', 'AT6K', 'BF180', 'BF40', 'BF90', 'BG', 'BGH', 'BGK', 'BGKH', 'CS20', 'CS30', 'CS40', 'CS60', 'CSR60', 'CW1', 'CW1T', 'CW2', 'CW2T', 'CWH', 'DRC2H', 'DRCH', 'DT30', 'DT32', 'DT40', 'DT42', 'DT60', 'DT62', 'DTM', 'EB1x', 'EB2x', 'EB4x', 'ED3H', 'EDС', 'EFL30', 'EFL60', 'FR', 'FR2,', 'FRK', 'FRT', 'FRTK', 'GC1', 'GC2', 'GR1', 'GR2', 'GU', 'GU2', 'HB30', 'HB60', 'HY30', 'HY60', 'KA2', 'KA4', 'KA6', 'KAT', 'KAT2', 'KAT4', 'KS', 'KS2', 'KV1X1', 'KV2X1', 'KVP1X1', 'KVP2X1', 'KW', 'KW2', 'KYT', 'KYT2', 'LL1H', 'LL1HP', 'LL2H', 'LL2HP', 'LL3H', 'MB', 'MB2', 'MB2X', 'MEFL30', 'MEFL60', 'MF20', 'MF30', 'MF60', 'MHB60', 'MHY30', 'MHY60', 'MMF20', 'MMF30', 'MMF60', 'MSKI40', 'MSKI60', 'MSU24', 'MSU60', 'MT10', 'MW&F', 'MWP15', 'MWP2H', 'MWP60', 'MWS1', 'MWS2', 'MWS25', 'MWS30', 'MWS40', 'MWSN1', 'MWSN2', 'MWSN25', 'MWSN40', 'OW2', 'OWG', 'OWI', 'PL15', 'PL20', 'PL30', 'PP', 'PP2', 'PP2P', 'PP2S', 'PPP', 'PPS', 'PPT', 'PR20', 'PR30', 'PR40', 'PR60', 'RB15', 'RB20', 'RB30', 'RB40', 'RB60', 'RC', 'RCV', 'RJ', 'RJ2', 'RT', 'RTV', 'RX', 'RXV', 'SG10', 'SG5', 'SH', 'SH2', 'SHH', 'SK', 'SK2', 'SK2V', 'SKI40', 'SKI60', 'SKT', 'SKT1', 'SKT10', 'SKT2', 'SKT4', 'SKT6', 'SKV', 'SN1X', 'SN2X', 'SU24', 'SU60', 'SUT', 'TB', 'TB2', 'TB4', 'W&F', 'WP15', 'WP2H', 'WP60', 'WS1', 'WS2', 'WS25', 'WS30', 'WS40', 'WSN1', 'WSN2', 'WSN25', 'WSN40', 'WTF2', 'WTF3', 'YAS', 'YEР', 'YHD', 'МТ', 'МТ5', 'МТТ', 'РB', 'РB2', 'РB2X']

# %% [markdown]
# Все prefix прописные. Имеется кириллица в префиксах

# %%
df_values['prefix'] = df_values['prefix'].str.upper()

# %%
df_values['prefix'] = df_values.apply(lambda x: replace_cirillic_latin(x['prefix']),axis=1)

# %%
prefix_values = list(df_values['prefix'].unique())

# %%
print(sorted((prefix_values)))
# Out:
# ['2MWP24', '2WP24', 'AB', 'AB4', 'AB4G', 'ABG', 'AC2', 'AC30', 'AC60', 'AT10', 'AT15', 'AT30', 'AT4', 'AT4K', 'AT6', 'AT60', 'AT6K', 'BF180', 'BF40', 'BF90', 'BG', 'BGH', 'BGK', 'BGKH', 'CS20', 'CS30', 'CS40', 'CS60', 'CSR60', 'CW1', 'CW1T', 'CW2', 'CW2T', 'CWH', 'DRC2H', 'DRCH', 'DT30', 'DT32', 'DT40', 'DT42', 'DT60', 'DT62', 'DTM', 'EB1X', 'EB2X', 'EB4X', 'ED3H', 'EDC', 'EFL30', 'EFL60', 'FR', 'FR2,', 'FRK', 'FRT', 'FRTK', 'GC1', 'GC2', 'GR1', 'GR2', 'GU', 'GU2', 'HB30', 'HB60', 'HY30', 'HY60', 'KA2', 'KA4', 'KA6', 'KAT', 'KAT2', 'KAT4', 'KS', 'KS2', 'KV1X1', 'KV2X1', 'KVP1X1', 'KVP2X1', 'KW', 'KW2', 'KYT', 'KYT2', 'LL1H', 'LL1HP', 'LL2H', 'LL2HP', 'LL3H', 'MB', 'MB2', 'MB2X', 'MEFL30', 'MEFL60', 'MF20', 'MF30', 'MF60', 'MHB60', 'MHY30', 'MHY60', 'MMF20', 'MMF30', 'MMF60', 'MSKI40', 'MSKI60', 'MSU24', 'MSU60', 'MT', 'MT10', 'MT5', 'MTT', 'MW&F', 'MWP15', 'MWP2H', 'MWP60', 'MWS1', 'MWS2', 'MWS25', 'MWS30', 'MWS40', 'MWSN1', 'MWSN2', 'MWSN25', 'MWSN40', 'OW2', 'OWG', 'OWI', 'PB', 'PB2', 'PB2X', 'PL15', 'PL20', 'PL30', 'PP', 'PP2', 'PP2P', 'PP2S', 'PPP', 'PPS', 'PPT', 'PR20', 'PR30', 'PR40', 'PR60', 'RB15', 'RB20', 'RB30', 'RB40', 'RB60', 'RC', 'RCV', 'RJ', 'RJ2', 'RT', 'RTV', 'RX', 'RXV', 'SG10', 'SG5', 'SH', 'SH2', 'SHH', 'SK', 'SK2', 'SK2V', 'SKI40', 'SKI60', 'SKT', 'SKT1', 'SKT10', 'SKT2', 'SKT4', 'SKT6', 'SKV', 'SN1X', 'SN2X', 'SU24', 'SU60', 'SUT', 'TB', 'TB2', 'TB4', 'W&F', 'WP15', 'WP2H', 'WP60', 'WS1', 'WS2', 'WS25', 'WS30', 'WS40', 'WSN1', 'WSN2', 'WSN25', 'WSN40', 'WTF2', 'WTF3', 'YAS', 'YEP', 'YHD']

# %%
len(prefix_values)
# Out:
# 197

# %% [markdown]
# #### Объединенный список префиксов

# %%
all_prefix = list(set(prefix_values).union(set(archive_prefix)))

# %%
all_prefix.sort()

# %%
print(all_prefix)
# Out:
# ['2MWP24', '2SU24', '2SU60', '2WP24', 'AB', 'AB4', 'AB4G', 'ABG', 'AC2', 'AC30', 'AC60', 'AT10', 'AT15', 'AT30', 'AT4', 'AT4K', 'AT6', 'AT60', 'AT6K', 'BC1', 'BC2', 'BCR', 'BF180', 'BF40', 'BF90', 'BG', 'BGH', 'BGK', 'BGKH', 'CS20', 'CS30', 'CS40', 'CS60', 'CSR60', 'CW1', 'CW1T', 'CW2', 'CW2T', 'CWH', 'DRC2H', 'DRCH', 'DT230', 'DT240', 'DT260', 'DT30', 'DT32', 'DT40', 'DT42', 'DT60', 'DT62', 'DTM', 'EB1X', 'EB1X1', 'EB2X', 'EB4X', 'ED3H', 'EDC', 'EF30', 'EF60', 'EFL30', 'EFL60', 'ES130', 'ES160', 'ES230', 'ES260', 'ESG1', 'ESG2', 'ESG4', 'F1', 'F1K', 'F2', 'FD', 'FDK', 'FJ30', 'FM30', 'FM45', 'FM60', 'FMCS30', 'FMCS45', 'FMCS45R', 'FMCS60', 'FMP15', 'FMP30', 'FMS30', 'FMS45', 'FMS60', 'FR', 'FR2', 'FR2,', 'FRK', 'FROG1', 'FROG3', 'FROGM', 'FRT', 'FRTK', 'GC1', 'GC2', 'GR1', 'GR1X1', 'GR2', 'GR2X1', 'GU', 'GU2', 'HB20', 'HB30', 'HB60', 'HY30', 'HY60', 'ICE1', 'ICE2', 'ID', 'KA2', 'KA4', 'KA6', 'KAT', 'KAT2', 'KAT4', 'KR1', 'KR2', 'KR3', 'KR4', 'KR6', 'KS', 'KS2', 'KV1X1', 'KV2X1', 'KVP1X1', 'KVP2X1', 'KVS', 'KW', 'KW2', 'KYT', 'KYT2', 'LB1X', 'LB2X', 'LB4X', 'LL1H', 'LL1HP', 'LL2H', 'LL2HP', 'LL3H', 'MB', 'MB2', 'MB2X', 'MEFL30', 'MEFL60', 'MF20', 'MF30', 'MF60', 'MHB60', 'MHY30', 'MHY60', 'MMF20', 'MMF30', 'MMF60', 'MSKI40', 'MSKI60', 'MSU24', 'MSU60', 'MT', 'MT10', 'MT10B', 'MT2', 'MT2B', 'MT5', 'MT5B', 'MTT', 'MW&F', 'MWP15', 'MWP2H', 'MWP60', 'MWS1', 'MWS2', 'MWS25', 'MWS30', 'MWS40', 'MWSN1', 'MWSN2', 'MWSN25', 'MWSN40', 'OW2', 'OWG', 'OWI', 'P1', 'P1G', 'P1P', 'P2', 'P2G', 'P2P', 'PB', 'PB2', 'PB2X', 'PH', 'PL15', 'PL20', 'PL30', 'PP', 'PP2', 'PP2P', 'PP2S', 'PPP', 'PPS', 'PPT', 'PR20', 'PR30', 'PR40', 'PR60', 'PS', 'RB15', 'RB20', 'RB30', 'RB40', 'RB60', 'RC', 'RCV', 'RJ', 'RJ1X', 'RJ2', 'RJ2X', 'RJXX', 'RS', 'RT', 'RTV', 'RX', 'RXV', 'S', 'S2', 'SC', 'SG10', 'SG5', 'SG7', 'SH', 'SH2', 'SHH', 'SK', 'SK2', 'SK2V', 'SKI20', 'SKI40', 'SKI60', 'SKT', 'SKT1', 'SKT10', 'SKT2', 'SKT4', 'SKT6', 'SKV', 'SN1X', 'SN1X1', 'SN2X', 'SN2X1', 'SP', 'SP2', 'ST', 'SU24', 'SU60', 'SUT', 'TB', 'TB2', 'TB4', 'TR', 'TR1', 'TR1K', 'TR2', 'TR2K', 'TX', 'UC', 'UN', 'UNI', 'VD', 'W&F', 'WP15', 'WP2H', 'WP30', 'WP60', 'WS1', 'WS2', 'WS20', 'WS25', 'WS30', 'WS40', 'WS60', 'WSN1', 'WSN2', 'WSN25', 'WSN40', 'WSN60', 'WTF2', 'WTF3', 'YAS', 'YEP', 'YHD']

# %%
len(all_prefix)
# Out:
# 292

# %%
archive_prefix = list(set(archive_prefix) - set(prefix_values))

# %%
archive_prefix.sort()

# %% [markdown]
# Измененный **archive_prefix**

# %%
print(archive_prefix)
# Out:
# ['2SU24', '2SU60', 'BC1', 'BC2', 'BCR', 'DT230', 'DT240', 'DT260', 'EB1X1', 'EF30', 'EF60', 'ES130', 'ES160', 'ES230', 'ES260', 'ESG1', 'ESG2', 'ESG4', 'F1', 'F1K', 'F2', 'FD', 'FDK', 'FJ30', 'FM30', 'FM45', 'FM60', 'FMCS30', 'FMCS45', 'FMCS45R', 'FMCS60', 'FMP15', 'FMP30', 'FMS30', 'FMS45', 'FMS60', 'FR2', 'FROG1', 'FROG3', 'FROGM', 'GR1X1', 'GR2X1', 'HB20', 'ICE1', 'ICE2', 'ID', 'KR1', 'KR2', 'KR3', 'KR4', 'KR6', 'KVS', 'LB1X', 'LB2X', 'LB4X', 'MT10B', 'MT2', 'MT2B', 'MT5B', 'P1', 'P1G', 'P1P', 'P2', 'P2G', 'P2P', 'PH', 'PS', 'RJ1X', 'RJ2X', 'RJXX', 'RS', 'S', 'S2', 'SC', 'SG7', 'SKI20', 'SN1X1', 'SN2X1', 'SP', 'SP2', 'ST', 'TR', 'TR1', 'TR1K', 'TR2', 'TR2K', 'TX', 'UC', 'UN', 'UNI', 'VD', 'WP30', 'WS20', 'WS60', 'WSN60']

# %%
len(archive_prefix)
# Out:
# 95

# %%
df_amo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8368 entries, 0 to 8367
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ID                             8368 non-null   int64
#  1   Этап сделки                    8368 non-null   object
#  2   Бюджет                         8368 non-null   int64
#  3   Дата создания сделки           8368 non-null   object
#  4   Дата закрытия                  8368 non-null   object
#  5   DELIVERY_PRICE                 5614 non-null   float64
#  6   Стоимость доставки             504 non-null    object
#  7   PRODUCTS                       7449 non-null   object
#  8   PRICE                          7449 non-null   float64
#  9   SUBTOTAL                       7405 non-null   float64
#  10  Выручка от клиента             8162 non-null   object
#  11  Направление (вид сертификата)  8246 non-null   object
#  12  Номер сертификата              8368 non-null   object
#  13  КОРНЕВАЯ СДЕЛКА                159 non-null    object
#  14  Номер 2-го сертификата         714 non-null    object
#  15  Номер 3-го сертификата         10 non-null     object
#  16  Номер 4-го сертификата         4 non-null      object
#  17  Номер 5-го сертификата         27 non-null     object
#  18  Сертификат на тренера          112 non-null    object
#  19  Статус погашения               3288 non-null   object
#  20  Дата получения услуги          3259 non-null   object
#  21  Стоимость закупки              2715 non-null   object
# dtypes: float64(3), int64(2), object(17)
# memory usage: 1.4+ MB

# %%
df_values.head(10)
# Out:
#    id        activity_name                                              value  \
# 0   1  Вейксёрф и вейкборд  2 часа вейксерфинга или вейкбординга\nна волне...
# 1   2  Вейксёрф и вейкборд  1 час вейксерфинга или вейкбординга\nна волне ...
# 2   3  Вейксёрф и вейкборд  40 минут вейксерфинга или вейкбординга\nна вол...
# 3   4  Вейксёрф и вейкборд  30 минут вейксерфинга или вейкбординга\nна вол...
# 4   5  Вейксёрф и вейкборд  25 минут вейксерфинга или вейкбординга\nна вол...
# 5   6  Вейксёрф и вейкборд  2 часа вейксерфинга или вейкбординга\nна любой...
# 6   7  Вейксёрф и вейкборд  1 час вейксерфинга или вейкбординга на любой в...
# 7   8  Вейксёрф и вейкборд  40 минут вейксерфинга или вейкбординга на любо...
# 8   9  Вейксёрф и вейкборд  25 минут вейксерфинга или вейкбординга на любо...
# 9  10            Флайборд                          1 час полёта на флайборде
#
#    status prefix  purchase_price  sale_price
# 0  on_air    WS2             NaN     22500.0
# 1  on_air    WS1             NaN     11000.0
# 2  on_air   WS40             NaN      7500.0
# 3  on_air   WS30             NaN      5500.0
# 4  on_air   WS25             NaN      5000.0
# 5  on_air   WSN2             NaN     26500.0
# 6  on_air   WSN1             NaN     13500.0
# 7  on_air  WSN40             NaN      8500.0
# 8  on_air  WSN25             NaN      6000.0
# 9  on_air   MF60             NaN     12500.0

# %% [markdown]
# ## Предобработка базы AMO

# %% [markdown]
# ### Имена столбцов

# %% [markdown]
# Столбцы в нижний регистр и удаление пробелов

# %%
df_amo.columns = df_amo.columns.str.lower()

# %%
df_amo.columns = df_amo.columns.str.strip()

# %%
df_amo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8368 entries, 0 to 8367
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             8368 non-null   int64
#  1   этап сделки                    8368 non-null   object
#  2   бюджет                         8368 non-null   int64
#  3   дата создания сделки           8368 non-null   object
#  4   дата закрытия                  8368 non-null   object
#  5   delivery_price                 5614 non-null   float64
#  6   стоимость доставки             504 non-null    object
#  7   products                       7449 non-null   object
#  8   price                          7449 non-null   float64
#  9   subtotal                       7405 non-null   float64
#  10  выручка от клиента             8162 non-null   object
#  11  направление (вид сертификата)  8246 non-null   object
#  12  номер сертификата              8368 non-null   object
#  13  корневая сделка                159 non-null    object
#  14  номер 2-го сертификата         714 non-null    object
#  15  номер 3-го сертификата         10 non-null     object
#  16  номер 4-го сертификата         4 non-null      object
#  17  номер 5-го сертификата         27 non-null     object
#  18  сертификат на тренера          112 non-null    object
#  19  статус погашения               3288 non-null   object
#  20  дата получения услуги          3259 non-null   object
#  21  стоимость закупки              2715 non-null   object
# dtypes: float64(3), int64(2), object(17)
# memory usage: 1.4+ MB

# %% [markdown]
# Удаление пробелов и вставка символа "_"

# %%
df_amo.columns = df_amo.columns.map(lambda x: re.sub( '(?<!^)(?=[ ])', '_', x ).lower())
df_amo.columns = df_amo.columns.map(lambda x: re.sub( ' ', '', x ))

# %% [markdown]
# Копирование исходной базы

# %%
df_amo_temp = df_amo.copy()

# %% [markdown]
# Переименование столбцов

# %%
df_amo_temp.rename(columns = {'номер_сертификата':'code', 'id':'amo_id','дата_закрытия':'sale_date','дата_получения_услуги':'card_used_date'}, inplace = True )

# %%
df_values.rename(columns = {'id':'activity_value_id' }, inplace = True )

# %%
df_amo_temp['code'] = df_amo_temp['code'].str.upper()

# %%
df_amo_temp['номер_2-го_сертификата'] = df_amo_temp['номер_2-го_сертификата'].str.upper()

# %%
df_amo_temp['номер_3-го_сертификата'] = df_amo_temp['номер_3-го_сертификата'].str.upper()

# %%
df_amo_temp['номер_4-го_сертификата'] = df_amo_temp['номер_4-го_сертификата'].str.upper()

# %%
df_amo_temp['номер_5-го_сертификата'] = df_amo_temp['номер_5-го_сертификата'].str.upper()

# %%
#df_amo_temp['сертификат_на_фотографа'] = df_amo_temp['сертификат_на_фотографа'].str.upper()

# %%
df_amo_temp['сертификат_на_тренера'] = df_amo_temp['сертификат_на_тренера'].str.upper()

# %%
df_amo_temp['дата_создания_сделки'] = pd.to_datetime(df_amo_temp['дата_создания_сделки'] )

# %%
df_amo_temp['sale_date'] = pd.to_datetime(df_amo_temp['sale_date'])

# %%
df_amo_temp['card_used_date'] = pd.to_datetime(df_amo_temp['card_used_date'],errors='coerce')
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23.02.2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24.02.2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22.02.2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25.02.2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17.02.2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28.01.2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26.01.2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19.07.2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27.01.2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24.01.2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20.01.2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18.02.2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19.01.2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13.02.2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21.01.2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14.01.2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13.01.2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23.12.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30.12.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28.12.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16.12.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17.12.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29.01.2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20.02.2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22.01.2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16.11.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18.01.2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29.12.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25.11.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18.11.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26.11.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13.12.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27.10.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25.01.2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16.01.2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31.01.2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29.10.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18.10.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14.10.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28.10.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24.10.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30.09.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28.09.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19.10.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14.08.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15.10.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17.09.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21.10.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30.10.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20.09.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23.09.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15.09.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24.09.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27.12.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16.09.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27.09.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23.01.2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13.11.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29.09.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26.08.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14.09.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27.08.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21.11.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24.08.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28.08.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21.08.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25.08.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20.08.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31.08.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20.10.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19.08.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18.08.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16.08.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15.08.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13.10.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13.08.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30.08.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30.07.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28.07.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17.08.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22.08.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19.09.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22.07.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13.09.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21.07.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14.07.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28.02.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18.07.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16.07.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17.10.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23.07.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25.09.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22.10.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13.07.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29.07.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25.06.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24.06.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26.06.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18.12.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23.06.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16.06.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20.06.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17.06.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29.06.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14.06.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15.07.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17.07.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15.06.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30.05.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21.09.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22.09.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28.05.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20.07.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31.05.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24.05.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19.06.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22.05.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27.05.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20.05.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21.05.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17.11.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31.07.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18.06.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27.06.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13.05.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14.05.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23.05.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21.06.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29.04.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17.05.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22.04.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25.04.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15.12.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25.07.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17.04.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28.03.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30.03.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17.03.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29.03.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15.04.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21.04.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13.04.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25.02.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13.02.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31.01.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23.01.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18.02.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25.01.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26.05.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14.02.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17.01.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15.01.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14.01.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24.01.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29.01.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16.02.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27.12.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20.02.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15.02.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18.12.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30.11.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14.11.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17.11.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16.11.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30.04.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18.09.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23.12.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22.11.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24.11.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25.11.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28.11.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26.01.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26.09.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24.08.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16.09.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27.09.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23.09.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13.09.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31.08.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19.09.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29.07.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29.08.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20.08.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23.08.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30.08.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22.08.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25.08.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18.08.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15.08.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19.08.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27.07.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21.08.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21.09.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26.07.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13.08.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25.07.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17.08.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15.07.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18.07.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27.06.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24.06.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28.07.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21.06.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)

# %%
df_amo_temp = df_amo_temp.sort_values(by=["дата_создания_сделки"], ascending=True)

# %%
#df_amo_temp['supplier_payment_date'] = df_amo_temp['card_used_date']

# %%
df_amo_temp = df_amo_temp.reset_index(drop=True)

# %%
df_amo_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8368 entries, 0 to 8367
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   amo_id                         8368 non-null   int64
#  1   этап_сделки                    8368 non-null   object
#  2   бюджет                         8368 non-null   int64
#  3   дата_создания_сделки           8368 non-null   datetime64[ns]
#  4   sale_date                      8368 non-null   datetime64[ns]
#  5   delivery_price                 5614 non-null   float64
#  6   стоимость_доставки             504 non-null    object
#  7   products                       7449 non-null   object
#  8   price                          7449 non-null   float64
#  9   subtotal                       7405 non-null   float64
#  10  выручка_от_клиента             8162 non-null   object
#  11  направление_(вид_сертификата)  8246 non-null   object
#  12  code                           8368 non-null   object
#  13  корневая_сделка                159 non-null    object
#  14  номер_2-го_сертификата         714 non-null    object
#  15  номер_3-го_сертификата         10 non-null     object
#  16  номер_4-го_сертификата         4 non-null      object
#  17  номер_5-го_сертификата         27 non-null     object
#  18  сертификат_на_тренера          112 non-null    object
#  19  статус_погашения               3288 non-null   object
#  20  card_used_date                 3259 non-null   datetime64[ns]
#  21  стоимость_закупки              2715 non-null   object
# dtypes: datetime64[ns](3), float64(3), int64(2), object(14)
# memory usage: 1.4+ MB

# %%
df_amo_temp.head()
# Out:
#     amo_id          этап_сделки  бюджет дата_создания_сделки  \
# 0  7721733  Успешно реализовано    7550  2020-01-06 10:45:48
# 1  7731389  Успешно реализовано    2400  2020-01-06 13:28:31
# 2  8884277  Успешно реализовано    2600  2020-01-07 12:02:41
# 3  8885245  Успешно реализовано   12695  2020-01-07 12:23:45
# 4  8891643  Успешно реализовано    3600  2020-01-07 15:14:42
#
#             sale_date  delivery_price стоимость_доставки products  price  \
# 0 2020-10-07 18:16:00             NaN                615      NaN    NaN
# 1 2020-10-07 18:13:00             NaN                NaN      NaN    NaN
# 2 2020-10-07 18:01:00             NaN                NaN      NaN    NaN
# 3 2020-10-07 18:01:00             NaN                NaN      NaN    NaN
# 4 2020-10-07 18:01:00             NaN                NaN      NaN    NaN
#
#    subtotal выручка_от_клиента направление_(вид_сертификата)          code  \
# 0       NaN             7550.0    Вейксёрф и вейк за катером    WS60 86373
# 1       NaN             2200.0  Флайборд / Ховерборд / Ранец    MF20 49719
# 2       NaN               2600  Флайборд / Ховерборд / Ранец  MF2001394966
# 3       NaN              12695   Универсальный Мосвейк 12345      WF 43009
# 4       NaN               3600    Вейксёрф и вейк за катером   WS30 143693
#
#   корневая_сделка номер_2-го_сертификата номер_3-го_сертификата  \
# 0             NaN                    NaN                    NaN
# 1             NaN                    NaN                    NaN
# 2             NaN                    NaN                    NaN
# 3             NaN                    NaN                    NaN
# 4             NaN                    NaN                    NaN
#
#   номер_4-го_сертификата номер_5-го_сертификата сертификат_на_тренера  \
# 0                    NaN                    NaN                   NaN
# 1                    NaN                    NaN                   NaN
# 2                    NaN                    NaN                   NaN
# 3                    NaN                    NaN                   NaN
# 4                    NaN                    NaN                   NaN
#
#   статус_погашения card_used_date стоимость_закупки
# 0          Погашен     2020-12-07               NaN
# 1          Погашен     2020-09-09               NaN
# 2          Погашен     2020-01-07               NaN
# 3              NaN            NaT               NaN
# 4              NaN            NaT               NaN

# %% [markdown]
# Определение разделителей в поле **code**

# %%
cc = df_amo_temp['code'].unique()

# %%
set_cc = set()

# %%
for el in cc:
    set_cc.update(el)

# %%
print(set_cc)
# Out:
# {'Х', 'W', 'К', '3', 'M', '6', '1', 'T', '8', 'V', 'С', 'О', 'X', 'K', '0', 'Р', ' ', 'E', 'N', 'Н', 'И', 'B', '\xa0', '2', 'G', ')', 'А', 'P', 'R', 'J', 'H', '_', 'C', 'Е', 'L', '?', '(', 'I', '9', 'D', 'В', 'У', '5', 'A', 'М', 'Т', 'Б', 'S', 'F', '&', 'U', 'Y', '-', '7', '4'}

# %% [markdown]
# В качестве разделителей используются символы ' ', '_', '\xa0' и их комбинации

# %% [markdown]
# В значениях поля code имеются символы кириллицы

# %% [markdown]
# Замена кириллицы на латинские символы

# %%
#df_amo_temp['code'] = df_amo_temp.apply(replace_cirillic_latin,axis=1)
df_amo_temp['code'] = df_amo_temp.apply(lambda x: replace_cirillic_latin(x['code']),axis=1)

# %%
#df_amo_temp['номер_2-го_сертификата'] = df_amo_temp.apply(lambda x: replace_cirillic_latin(x['номер_2-го_сертификата']),axis=1)

# %%
#df_amo_temp['номер_3-го_сертификата'] = df_amo_temp.apply(lambda x: replace_cirillic_latin(x['номер_3-го_сертификата']),axis=1)

# %%
#df_amo_temp['номер_4-го_сертификата'] = df_amo_temp.apply(lambda x: replace_cirillic_latin(x['номер_4-го_сертификата']),axis=1)

# %%
#df_amo_temp['номер_5-го_сертификата'] = df_amo_temp.apply(lambda x: replace_cirillic_latin(x['номер_5-го_сертификата']),axis=1)

# %% [markdown]
# Замена всех возможных разделителей на '_'

# %%
#df_amo_temp['code'] = df_amo_temp['code'].str.replace('[^_ \xa0]+([ _\xa0]+)\d+','_',regex=True)
df_amo_temp.replace(r'([ _\xa0]+)',r'_',regex=True,inplace=True)

# %%
df_amo_temp.head(100)
# Out:
#      amo_id          этап_сделки  бюджет дата_создания_сделки  \
# 0   7721733  Успешно_реализовано    7550  2020-01-06 10:45:48
# 1   7731389  Успешно_реализовано    2400  2020-01-06 13:28:31
# 2   8884277  Успешно_реализовано    2600  2020-01-07 12:02:41
# 3   8885245  Успешно_реализовано   12695  2020-01-07 12:23:45
# 4   8891643  Успешно_реализовано    3600  2020-01-07 15:14:42
# ..      ...                  ...     ...                  ...
# 95  9018133  Успешно_реализовано    5550  2020-04-07 12:21:46
# 96  9019375  Успешно_реализовано    4400  2020-04-07 13:09:51
# 97  9021283  Успешно_реализовано    4500  2020-04-07 14:39:07
# 98  9025795  Успешно_реализовано    4500  2020-04-07 17:53:04
# 99  9028613  Успешно_реализовано    3000  2020-04-07 20:46:10
#
#              sale_date  delivery_price стоимость_доставки  \
# 0  2020-10-07 18:16:00             NaN                615
# 1  2020-10-07 18:13:00             NaN                NaN
# 2  2020-10-07 18:01:00             NaN                NaN
# 3  2020-10-07 18:01:00             NaN                NaN
# 4  2020-10-07 18:01:00             NaN                NaN
# ..                 ...             ...                ...
# 95 2020-10-07 18:01:00             NaN                316
# 96 2020-10-07 18:01:00             NaN                NaN
# 97 2020-10-07 18:01:00             NaN                NaN
# 98 2020-10-07 18:00:00             NaN                NaN
# 99 2020-10-07 18:00:00             NaN                NaN
#
#                                              products   price  subtotal  \
# 0                                                 NaN     NaN       NaN
# 1                                                 NaN     NaN       NaN
# 2                                                 NaN     NaN       NaN
# 3                                                 NaN     NaN       NaN
# 4                                                 NaN     NaN       NaN
# ..                                                ...     ...       ...
# 95                                                NaN     NaN       NaN
# 96                                                NaN     NaN       NaN
# 97  Подарочный_сертификатна_Флайборд_(Выберите_тип...  4500.0    4500.0
# 98                                                NaN     NaN       NaN
# 99  Подарочный_сертификатна_Флайборд_(Выберите_тип...  3000.0    3000.0
#
#    выручка_от_клиента направление_(вид_сертификата)            code  \
# 0              7550.0    Вейксёрф_и_вейк_за_катером      WS60_86373
# 1              2200.0  Флайборд_/_Ховерборд_/_Ранец      MF20_49719
# 2                2600  Флайборд_/_Ховерборд_/_Ранец    MF2001394966
# 3               12695   Универсальный_Мосвейк_12345        WF_43009
# 4                3600    Вейксёрф_и_вейк_за_катером     WS30_143693
# ..                ...                           ...             ...
# 95               5550    Вейксёрф_и_вейк_за_катером      WS40_15420
# 96               4400                      САП-сёрф      SU24_78531
# 97               4500  Флайборд_/_Ховерборд_/_Ранец  VMF30_01056812
# 98               4500  Флайборд_/_Ховерборд_/_Ранец  VMF30_02026976
# 99               3000  Флайборд_/_Ховерборд_/_Ранец  VMF30_03072271
#
#    корневая_сделка номер_2-го_сертификата номер_3-го_сертификата  \
# 0              NaN                    NaN                    NaN
# 1              NaN                    NaN                    NaN
# 2              NaN                    NaN                    NaN
# 3              NaN                    NaN                    NaN
# 4              NaN                    NaN                    NaN
# ..             ...                    ...                    ...
# 95             NaN                    NaN                    NaN
# 96             NaN                    NaN                    NaN
# 97             NaN                    NaN                    NaN
# 98             NaN                    NaN                    NaN
# 99             NaN                    NaN                    NaN
#
#    номер_4-го_сертификата номер_5-го_сертификата сертификат_на_тренера  \
# 0                     NaN                    NaN                   NaN
# 1                     NaN                    NaN                   NaN
# 2                     NaN                    NaN                   NaN
# 3                     NaN                    NaN                   NaN
# 4                     NaN                    NaN                   NaN
# ..                    ...                    ...                   ...
# 95                    NaN                    NaN                   NaN
# 96                    NaN                    NaN                   NaN
# 97                    NaN                    NaN                   NaN
# 98                    NaN                    NaN                   NaN
# 99                    NaN                    NaN                   NaN
#
#    статус_погашения card_used_date стоимость_закупки
# 0           Погашен     2020-12-07               NaN
# 1           Погашен     2020-09-09               NaN
# 2           Погашен     2020-01-07               NaN
# 3               NaN            NaT               NaN
# 4               NaN            NaT               NaN
# ..              ...            ...               ...
# 95              NaN            NaT               NaN
# 96          Погашен     2020-07-25               NaN
# 97              NaN            NaT               NaN
# 98          Погашен     2020-08-15               NaN
# 99              NaN            NaT               NaN
#
# [100 rows x 22 columns]

# %% [markdown]
# ## Создание отдельных строк для дополнительных сертификатов

# %% [markdown]
# Кол-во строк до вставки

# %%
df_amo_temp.shape
# Out:
# (8368, 22)

# %%
def insert_row_for_sert(row):
    global field
    df_amo_temp.loc[len(df_amo_temp.index)] = [row['amo_id'],
                                           np.NaN,
                                          np.NaN,
                                           row['дата_создания_сделки'],
                                           row['sale_date'],
                                          np.NaN,
                                          np.NaN,
                                          np.NaN,
                                          np.NaN,
                                          0,
                                          np.NaN,
                                          '',
                                          row[field],
                                          np.NaN,
                                          np.NaN,
                                          np.NaN,
                                          np.NaN,
                                          np.NaN,
                                          np.NaN,
                                          np.NaN,
                                               np.NaN,
                                               np.NaN
                                              ]
    return 1

# %%
dop_sert = ['номер_2-го_сертификата',
            'номер_3-го_сертификата',
            'номер_4-го_сертификата',
            'номер_5-го_сертификата',
            'сертификат_на_тренера']

# %%
for field in dop_sert:
    #Выборка строк для конкретного вида сертификата
    df_dop_sert = df_amo_temp.loc[(df_amo_temp[field].notna())] 
    print(f'Обнаружено строк для {field} {df_dop_sert.shape[0]}')
    #Удаление из выборки DISABLED сертификатов
    df_dop_sert = df_dop_sert.loc[~df_dop_sert[field].str.contains('DI')]
    df_dop_sert['qq']= df_dop_sert.apply(insert_row_for_sert,axis=1)
# Out:
# Обнаружено строк для номер_2-го_сертификата 714
# Обнаружено строк для номер_3-го_сертификата 10
# Обнаружено строк для номер_4-го_сертификата 4
# Обнаружено строк для номер_5-го_сертификата 27
# Обнаружено строк для сертификат_на_тренера 112

# %% [markdown]
# В базу AMO добавлены строки для дополнительных сертификатов

# %% [markdown]
# Кол-во строк после вставки

# %%
df_amo_temp.shape
# Out:
# (9176, 22)

# %% [markdown]
# ### Формирование новых столбцов в базе АМО

# %%
df_amo_temp['id'] = ''

# %% [markdown]
# #### prefix and number

# %%
df_amo_temp['prefix'] = df_amo_temp['code'].apply(lambda x: re.split('[ _]',x)[0] if ' ' in x or '_' in x else '')

# %%
df_amo_temp['number'] = df_amo_temp['code'].apply(lambda x: re.split('[ _]',x)[1] if ' ' in x or '_' in x else '')

# %%
df_amo_temp.head(10)
# Out:
#     amo_id          этап_сделки   бюджет дата_создания_сделки  \
# 0  7721733  Успешно_реализовано   7550.0  2020-01-06 10:45:48
# 1  7731389  Успешно_реализовано   2400.0  2020-01-06 13:28:31
# 2  8884277  Успешно_реализовано   2600.0  2020-01-07 12:02:41
# 3  8885245  Успешно_реализовано  12695.0  2020-01-07 12:23:45
# 4  8891643  Успешно_реализовано   3600.0  2020-01-07 15:14:42
# 5  8900351  Успешно_реализовано   3600.0  2020-01-07 17:49:48
# 6  8907645  Успешно_реализовано   4400.0  2020-01-07 23:05:00
# 7  9973679  Успешно_реализовано   1600.0  2020-01-08 01:13:35
# 8  9977557  Успешно_реализовано   4900.0  2020-01-08 10:37:09
# 9  9979317  Успешно_реализовано   3000.0  2020-01-08 12:07:43
#
#             sale_date  delivery_price стоимость_доставки  \
# 0 2020-10-07 18:16:00             NaN                615
# 1 2020-10-07 18:13:00             NaN                NaN
# 2 2020-10-07 18:01:00             NaN                NaN
# 3 2020-10-07 18:01:00             NaN                NaN
# 4 2020-10-07 18:01:00             NaN                NaN
# 5 2020-10-07 18:01:00             NaN                NaN
# 6 2020-10-07 11:41:00             NaN                492
# 7 2020-01-08 12:13:00             NaN                NaN
# 8 2020-04-08 09:28:00             NaN                730
# 9 2020-04-08 09:29:00             NaN                NaN
#
#                                             products   price  subtotal  \
# 0                                                NaN     NaN       NaN
# 1                                                NaN     NaN       NaN
# 2                                                NaN     NaN       NaN
# 3                                                NaN     NaN       NaN
# 4                                                NaN     NaN       NaN
# 5                                                NaN     NaN       NaN
# 6                                                NaN     NaN       NaN
# 7  Подарочный_сертификатна_Сап-Сёрфинг_(Выберите_...  1600.0    1600.0
# 8                                                NaN     NaN       NaN
# 9  Подарочный_сертификатна_Флайборд_(Выберите_тип...  3000.0    3000.0
#
#   выручка_от_клиента направление_(вид_сертификата)            code  \
# 0             7550.0    Вейксёрф_и_вейк_за_катером      WS60_86373
# 1             2200.0  Флайборд_/_Ховерборд_/_Ранец      MF20_49719
# 2               2600  Флайборд_/_Ховерборд_/_Ранец    MF2001394966
# 3              12695   Универсальный_Мосвейк_12345        WF_43009
# 4               3600    Вейксёрф_и_вейк_за_катером     WS30_143693
# 5               3600    Вейксёрф_и_вейк_за_катером   WS30_03015337
# 6               4400  Флайборд_/_Ховерборд_/_Ранец      MF30_21861
# 7               1600                      САП-сёрф  V2SU6078082417
# 8               4900  Флайборд_/_Ховерборд_/_Ранец    MF3004074082
# 9               3000  Флайборд_/_Ховерборд_/_Ранец    MF2004230327
#
#   корневая_сделка номер_2-го_сертификата номер_3-го_сертификата  \
# 0             NaN                    NaN                    NaN
# 1             NaN                    NaN                    NaN
# 2             NaN                    NaN                    NaN
# 3             NaN                    NaN                    NaN
# 4             NaN                    NaN                    NaN
# 5             NaN                    NaN                    NaN
# 6             NaN                    NaN                    NaN
# 7             NaN                    NaN                    NaN
# 8             NaN                    NaN                    NaN
# 9             NaN                    NaN                    NaN
#
#   номер_4-го_сертификата номер_5-го_сертификата сертификат_на_тренера  \
# 0                    NaN                    NaN                   NaN
# 1                    NaN                    NaN                   NaN
# 2                    NaN                    NaN                   NaN
# 3                    NaN                    NaN                   NaN
# 4                    NaN                    NaN                   NaN
# 5                    NaN                    NaN                   NaN
# 6                    NaN                    NaN                   NaN
# 7                    NaN                    NaN                   NaN
# 8                    NaN                    NaN                   NaN
# 9                    NaN                    NaN                   NaN
#
#   статус_погашения card_used_date стоимость_закупки id prefix    number
# 0          Погашен     2020-12-07               NaN      WS60     86373
# 1          Погашен     2020-09-09               NaN      MF20     49719
# 2          Погашен     2020-01-07               NaN
# 3              NaN            NaT               NaN        WF     43009
# 4              NaN            NaT               NaN      WS30    143693
# 5          Погашен     2020-08-29               NaN      WS30  03015337
# 6              NaN            NaT               NaN      MF30     21861
# 7              NaN            NaT               NaN
# 8          Погашен     2020-09-13               NaN
# 9              NaN            NaT               NaN

# %%
prefix_amo = list(df_amo_temp['prefix'].unique())
prefix_amo.sort()
prefix_amo = prefix_amo[1:]

# %%
prefix_amo.sort(key=lambda x: len(x),reverse=True)

# %%
print(prefix_amo)
# Out:
# ['VMF306120784', 'MF30134139', 'VHY60T30', 'FMCS45R', 'VFMCS30', 'VKVP1X1', 'VKVP2X1', 'VMWSN40', 'VSKI40T', 'VSKI60T', 'VWS20TR', 'VWSN40T', 'VWSN60T', '60WAKE', 'FMCS30', 'KVP1X1', 'KVP1X2', 'KVP2X1', 'MWSN40', 'V2SU24', 'V2SU60', 'V2WP24', 'VBF180', 'VDRC2H', 'VEFL30', 'VES130', 'VES160', 'VES230', 'VGR1X1', 'VHY30T', 'VKV1X1', 'VKV2X1', 'VKVP1X', 'VMMF20', 'VMMF30', 'VMSU60', 'VMWP15', 'VMWS25', 'VMWS40', 'VSKI20', 'VSKI40', 'VSKI60', 'VSN1X1', 'VSN2X1', 'VSN2X4', 'VWS20T', 'VWS30T', 'VWS40T', 'VWS60T', 'VWSN25', 'VWSN40', 'VWSN60', '2SU60', '2WP24', 'BF180', 'DRC2H', 'DT230', 'DT240', 'DT260', 'EB1X1', 'EFL30', 'EFL60', 'ES130', 'ES160', 'ES230', 'FMP30', 'GR1X1', 'GR2X1', 'KV1X1', 'KV2X1', 'LL1HP', 'MMF60', 'MWS25', 'SKI40', 'SKI60', 'SN1X1', 'SN2X1', 'VAC30', 'VAC60', 'VAT10', 'VAT15', 'VAT30', 'VAT4K', 'VAT6K', 'VBF40', 'VBF90', 'VBGKH', 'VCS20', 'VCS30', 'VCS40', 'VCS60', 'VCW1T', 'VCW2T', 'VDRCH', 'VDT30', 'VDT32', 'VDT40', 'VDT42', 'VDT60', 'VDT62', 'VEB1X', 'VEB2X', 'VED3H', 'VEF30', 'VEF60', 'VESG1', 'VESG2', 'VFJ30', 'VFM30', 'VFM45', 'VHB20', 'VHB30', 'VHB60', 'VHY30', 'VHY60', 'VJT4A', 'VKAT2', 'VKAT4', 'VKV1X', 'VLB1X', 'VLL1H', 'VLL2H', 'VLL3H', 'VMB2X', 'VMF20', 'VMF30', 'VMF60', 'VMT10', 'VMT2B', 'VMW&F', 'VMWS1', 'VPB2X', 'VPH20', 'VPP2P', 'VPP2S', 'VPR20', 'VPR30', 'VPR40', 'VPR60', 'VRB15', 'VRB20', 'VRB30', 'VRB40', 'VRJ1X', 'VRJ2X', 'VSG10', 'VSK2V', 'VSKT1', 'VSKT2', 'VSKT4', 'VSN1X', 'VSN2X', 'VSN60', 'VSU24', 'VSU60', 'VTR1K', 'VTR2K', 'VTR30', 'VWP15', 'VWP2H', 'VWP60', 'VWS20', 'VWS25', 'VWS30', 'VWS40', 'VWS60', 'VWTF2', 'WS30T', 'WSN40', 'WSN60', 'AC30', 'AC60', 'AT10', 'AT15', 'AT30', 'AT4K', 'AT6K', 'BF40', 'BF90', 'BGKH', 'CS20', 'CS30', 'CS40', 'CS60', 'DRCH', 'DT30', 'DT40', 'DT60', 'EB1X', 'EB2X', 'ED3H', 'EF30', 'EF60', 'ESG1', 'ESG2', 'FJ30', 'FM30', 'FM45', 'FM60', 'HB20', 'HB30', 'HY30', 'HY60', 'KAT2', 'KAT4', 'LL1H', 'LL2H', 'MB2X', 'MF20', 'MF30', 'MF60', 'MT2B', 'MWS2', 'PB2X', 'PL15', 'PL20', 'PR20', 'PR30', 'PR40', 'PR60', 'RB15', 'RB20', 'RB30', 'RJ2X', 'SG10', 'SKT1', 'SKT2', 'SKT4', 'SN1X', 'SN2X', 'SU24', 'SU60', 'TR1K', 'TR1К', 'TR2K', 'VAC2', 'VAT4', 'VAT6', 'VAWP', 'VBGH', 'VBGK', 'VCW1', 'VCW2', 'VCWH', 'VDTM', 'VEDC', 'VEFL', 'VFR2', 'VFRT', 'VGC1', 'VGC2', 'VGR1', 'VGR2', 'VGU2', 'VJT2', 'VKA2', 'VKA4', 'VKA6', 'VKAT', 'VKR1', 'VKR3', 'VKVS', 'VMB2', 'VMT2', 'VMT5', 'VMTT', 'VP1G', 'VPB2', 'VPP2', 'VPPP', 'VPPS', 'VPPT', 'VRCV', 'VRJ2', 'VRTV', 'VSG5', 'VSG7', 'VSH2', 'VSK2', 'VSKT', 'VSKV', 'VSUT', 'VSVH', 'VTB2', 'VTR1', 'VTR2', 'VW&F', 'VWPA', 'VWS1', 'VWS6', 'VWTF', 'VYAS', 'VYEP', 'WP15', 'WP24', 'WP2H', 'WP30', 'WP60', 'WS20', 'WS25', 'WS30', 'WS40', 'WS60', 'WTF2', 'WTF3', 'ЕВ1Х', 'AT4', 'AT6', 'BGH', 'CW1', 'CW2', 'EDC', 'GC1', 'GC2', 'GR1', 'GR2', 'GRT', 'GU2', 'JT2', 'KA2', 'KA4', 'KA6', 'KAT', 'KR1', 'KR2', 'KR4', 'KS2', 'KVC', 'KVS', 'MB2', 'MT2', 'MT5', 'MTT', 'P1G', 'P1P', 'P2G', 'PB2', 'PP2', 'PPP', 'RCV', 'RJ2', 'RTV', 'RXV', 'SG7', 'SH2', 'SHH', 'SK2', 'SKV', 'SP2', 'TR1', 'TR2', 'VBG', 'VFR', 'VGU', 'VMB', 'VMT', 'VP1', 'VPB', 'VPH', 'VPP', 'VRC', 'VRJ', 'VRS', 'VS2', 'VSH', 'VSK', 'VSP', 'VST', 'VTR', 'VUN', 'VWF', 'VWS', 'W&F', 'YEP', 'КА2', 'AT', 'BG', 'F1', 'GU', 'KS', 'MB', 'MF', 'MT', 'P1', 'P2', 'PB', 'PH', 'PS', 'RC', 'RJ', 'RS', 'RX', 'S2', 'SH', 'SP', 'ST', 'TR', 'UN', 'VS', 'WF', 'S']

# %% [markdown]
# Некоторые значения в code без разделителей, потому не выделились prefix и number

# %% [markdown]
# Отделение prefix от number

# %%
all_prefix_sort = all_prefix

# %%
all_prefix_sort.sort(key=lambda x: len(x),reverse=True)

# %%
all_prefix_sort
# Out:
# ['FMCS45R',
#  '2MWP24',
#  'FMCS30',
#  'FMCS45',
#  'FMCS60',
#  'KVP1X1',
#  'KVP2X1',
#  'MEFL30',
#  'MEFL60',
#  'MSKI40',
#  'MSKI60',
#  'MWSN25',
#  'MWSN40',
#  '2SU24',
#  '2SU60',
#  '2WP24',
#  'BF180',
#  'CSR60',
#  'DRC2H',
#  'DT230',
#  'DT240',
#  'DT260',
#  'EB1X1',
#  'EFL30',
#  'EFL60',
#  'ES130',
#  'ES160',
#  'ES230',
#  'ES260',
#  'FMP15',
#  'FMP30',
#  'FMS30',
#  'FMS45',
#  'FMS60',
#  'FROG1',
#  'FROG3',
#  'FROGM',
#  'GR1X1',
#  'GR2X1',
#  'KV1X1',
#  'KV2X1',
#  'LL1HP',
#  'LL2HP',
#  'MHB60',
#  'MHY30',
#  'MHY60',
#  'MMF20',
#  'MMF30',
#  'MMF60',
#  'MSU24',
#  'MSU60',
#  'MT10B',
#  'MWP15',
#  'MWP2H',
#  'MWP60',
#  'MWS25',
#  'MWS30',
#  'MWS40',
#  'MWSN1',
#  'MWSN2',
#  'SKI20',
#  'SKI40',
#  'SKI60',
#  'SKT10',
#  'SN1X1',
#  'SN2X1',
#  'WSN25',
#  'WSN40',
#  'WSN60',
#  'AB4G',
#  'AC30',
#  'AC60',
#  'AT10',
#  'AT15',
#  'AT30',
#  'AT4K',
#  'AT60',
#  'AT6K',
#  'BF40',
#  'BF90',
#  'BGKH',
#  'CS20',
#  'CS30',
#  'CS40',
#  'CS60',
#  'CW1T',
#  'CW2T',
#  'DRCH',
#  'DT30',
#  'DT32',
#  'DT40',
#  'DT42',
#  'DT60',
#  'DT62',
#  'EB1X',
#  'EB2X',
#  'EB4X',
#  'ED3H',
#  'EF30',
#  'EF60',
#  'ESG1',
#  'ESG2',
#  'ESG4',
#  'FJ30',
#  'FM30',
#  'FM45',
#  'FM60',
#  'FR2,',
#  'FRTK',
#  'HB20',
#  'HB30',
#  'HB60',
#  'HY30',
#  'HY60',
#  'ICE1',
#  'ICE2',
#  'KAT2',
#  'KAT4',
#  'KYT2',
#  'LB1X',
#  'LB2X',
#  'LB4X',
#  'LL1H',
#  'LL2H',
#  'LL3H',
#  'MB2X',
#  'MF20',
#  'MF30',
#  'MF60',
#  'MT10',
#  'MT2B',
#  'MT5B',
#  'MW&F',
#  'MWS1',
#  'MWS2',
#  'PB2X',
#  'PL15',
#  'PL20',
#  'PL30',
#  'PP2P',
#  'PP2S',
#  'PR20',
#  'PR30',
#  'PR40',
#  'PR60',
#  'RB15',
#  'RB20',
#  'RB30',
#  'RB40',
#  'RB60',
#  'RJ1X',
#  'RJ2X',
#  'RJXX',
#  'SG10',
#  'SK2V',
#  'SKT1',
#  'SKT2',
#  'SKT4',
#  'SKT6',
#  'SN1X',
#  'SN2X',
#  'SU24',
#  'SU60',
#  'TR1K',
#  'TR2K',
#  'WP15',
#  'WP2H',
#  'WP30',
#  'WP60',
#  'WS20',
#  'WS25',
#  'WS30',
#  'WS40',
#  'WS60',
#  'WSN1',
#  'WSN2',
#  'WTF2',
#  'WTF3',
#  'AB4',
#  'ABG',
#  'AC2',
#  'AT4',
#  'AT6',
#  'BC1',
#  'BC2',
#  'BCR',
#  'BGH',
#  'BGK',
#  'CW1',
#  'CW2',
#  'CWH',
#  'DTM',
#  'EDC',
#  'F1K',
#  'FDK',
#  'FR2',
#  'FRK',
#  'FRT',
#  'GC1',
#  'GC2',
#  'GR1',
#  'GR2',
#  'GU2',
#  'KA2',
#  'KA4',
#  'KA6',
#  'KAT',
#  'KR1',
#  'KR2',
#  'KR3',
#  'KR4',
#  'KR6',
#  'KS2',
#  'KVS',
#  'KW2',
#  'KYT',
#  'MB2',
#  'MT2',
#  'MT5',
#  'MTT',
#  'OW2',
#  'OWG',
#  'OWI',
#  'P1G',
#  'P1P',
#  'P2G',
#  'P2P',
#  'PB2',
#  'PP2',
#  'PPP',
#  'PPS',
#  'PPT',
#  'RCV',
#  'RJ2',
#  'RTV',
#  'RXV',
#  'SG5',
#  'SG7',
#  'SH2',
#  'SHH',
#  'SK2',
#  'SKT',
#  'SKV',
#  'SP2',
#  'SUT',
#  'TB2',
#  'TB4',
#  'TR1',
#  'TR2',
#  'UNI',
#  'W&F',
#  'WS1',
#  'WS2',
#  'YAS',
#  'YEP',
#  'YHD',
#  'AB',
#  'BG',
#  'F1',
#  'F2',
#  'FD',
#  'FR',
#  'GU',
#  'ID',
#  'KS',
#  'KW',
#  'MB',
#  'MT',
#  'P1',
#  'P2',
#  'PB',
#  'PH',
#  'PP',
#  'PS',
#  'RC',
#  'RJ',
#  'RS',
#  'RT',
#  'RX',
#  'S2',
#  'SC',
#  'SH',
#  'SK',
#  'SP',
#  'ST',
#  'TB',
#  'TR',
#  'TX',
#  'UC',
#  'UN',
#  'VD',
#  'S']

# %%
def separate_prefix_number(row):
    
    pl = all_prefix_sort
    #print(pl)
    v = row['code']
    if row['prefix'] == '':
        not_find = True
        amo_id = row['amo_id']
        
        for el in pl:
            if el == row['code'][0:len(el)]:
#                 print(el, row['code'][0:len(el)], row['code'])
            #if el in row['code']:
                try:
                    v = el + '_' + row['code'][len(el):]
#                     not_find = False
                except:
                    pass
                finally:
                    return v
#         if not_find:
        pl = prefix_amo   
        #print(pl)
        for el in pl:
            #print(el,row['code'][0:len(el)])
            if el == row['code'][0:len(el)]:
                #print(el, row['code'][0:len(el)+1], row['code'])
            #if el in row['code']:
                try:
                    v = el + '_' + row['code'][len(el):]
                except:
                    pass
                finally:
                    return v
    return v

# %%
df_amo_temp['code'] = df_amo_temp.apply(separate_prefix_number,axis=1)

# %%
df_amo_temp.head(5)
# Out:
#     amo_id          этап_сделки   бюджет дата_создания_сделки  \
# 0  7721733  Успешно_реализовано   7550.0  2020-01-06 10:45:48
# 1  7731389  Успешно_реализовано   2400.0  2020-01-06 13:28:31
# 2  8884277  Успешно_реализовано   2600.0  2020-01-07 12:02:41
# 3  8885245  Успешно_реализовано  12695.0  2020-01-07 12:23:45
# 4  8891643  Успешно_реализовано   3600.0  2020-01-07 15:14:42
#
#             sale_date  delivery_price стоимость_доставки products  price  \
# 0 2020-10-07 18:16:00             NaN                615      NaN    NaN
# 1 2020-10-07 18:13:00             NaN                NaN      NaN    NaN
# 2 2020-10-07 18:01:00             NaN                NaN      NaN    NaN
# 3 2020-10-07 18:01:00             NaN                NaN      NaN    NaN
# 4 2020-10-07 18:01:00             NaN                NaN      NaN    NaN
#
#    subtotal выручка_от_клиента направление_(вид_сертификата)           code  \
# 0       NaN             7550.0    Вейксёрф_и_вейк_за_катером     WS60_86373
# 1       NaN             2200.0  Флайборд_/_Ховерборд_/_Ранец     MF20_49719
# 2       NaN               2600  Флайборд_/_Ховерборд_/_Ранец  MF20_01394966
# 3       NaN              12695   Универсальный_Мосвейк_12345       WF_43009
# 4       NaN               3600    Вейксёрф_и_вейк_за_катером    WS30_143693
#
#   корневая_сделка номер_2-го_сертификата номер_3-го_сертификата  \
# 0             NaN                    NaN                    NaN
# 1             NaN                    NaN                    NaN
# 2             NaN                    NaN                    NaN
# 3             NaN                    NaN                    NaN
# 4             NaN                    NaN                    NaN
#
#   номер_4-го_сертификата номер_5-го_сертификата сертификат_на_тренера  \
# 0                    NaN                    NaN                   NaN
# 1                    NaN                    NaN                   NaN
# 2                    NaN                    NaN                   NaN
# 3                    NaN                    NaN                   NaN
# 4                    NaN                    NaN                   NaN
#
#   статус_погашения card_used_date стоимость_закупки id prefix  number
# 0          Погашен     2020-12-07               NaN      WS60   86373
# 1          Погашен     2020-09-09               NaN      MF20   49719
# 2          Погашен     2020-01-07               NaN
# 3              NaN            NaT               NaN        WF   43009
# 4              NaN            NaT               NaN      WS30  143693

# %%
df_amo_temp.loc[df_amo_temp['prefix'] == '','prefix'] = \
df_amo_temp['code'].apply(lambda x: re.split('[_]',x)[0] if ' ' in x or '_' in x else '')

# %%
df_amo_temp.loc[df_amo_temp['number'] == '','number'] = \
df_amo_temp['code'].apply(lambda x: re.split('[_]',x)[1] if ' ' in x or '_' in x else '')

# %%
df_amo_temp.head(5)
# Out:
#     amo_id          этап_сделки   бюджет дата_создания_сделки  \
# 0  7721733  Успешно_реализовано   7550.0  2020-01-06 10:45:48
# 1  7731389  Успешно_реализовано   2400.0  2020-01-06 13:28:31
# 2  8884277  Успешно_реализовано   2600.0  2020-01-07 12:02:41
# 3  8885245  Успешно_реализовано  12695.0  2020-01-07 12:23:45
# 4  8891643  Успешно_реализовано   3600.0  2020-01-07 15:14:42
#
#             sale_date  delivery_price стоимость_доставки products  price  \
# 0 2020-10-07 18:16:00             NaN                615      NaN    NaN
# 1 2020-10-07 18:13:00             NaN                NaN      NaN    NaN
# 2 2020-10-07 18:01:00             NaN                NaN      NaN    NaN
# 3 2020-10-07 18:01:00             NaN                NaN      NaN    NaN
# 4 2020-10-07 18:01:00             NaN                NaN      NaN    NaN
#
#    subtotal выручка_от_клиента направление_(вид_сертификата)           code  \
# 0       NaN             7550.0    Вейксёрф_и_вейк_за_катером     WS60_86373
# 1       NaN             2200.0  Флайборд_/_Ховерборд_/_Ранец     MF20_49719
# 2       NaN               2600  Флайборд_/_Ховерборд_/_Ранец  MF20_01394966
# 3       NaN              12695   Универсальный_Мосвейк_12345       WF_43009
# 4       NaN               3600    Вейксёрф_и_вейк_за_катером    WS30_143693
#
#   корневая_сделка номер_2-го_сертификата номер_3-го_сертификата  \
# 0             NaN                    NaN                    NaN
# 1             NaN                    NaN                    NaN
# 2             NaN                    NaN                    NaN
# 3             NaN                    NaN                    NaN
# 4             NaN                    NaN                    NaN
#
#   номер_4-го_сертификата номер_5-го_сертификата сертификат_на_тренера  \
# 0                    NaN                    NaN                   NaN
# 1                    NaN                    NaN                   NaN
# 2                    NaN                    NaN                   NaN
# 3                    NaN                    NaN                   NaN
# 4                    NaN                    NaN                   NaN
#
#   статус_погашения card_used_date стоимость_закупки id prefix    number
# 0          Погашен     2020-12-07               NaN      WS60     86373
# 1          Погашен     2020-09-09               NaN      MF20     49719
# 2          Погашен     2020-01-07               NaN      MF20  01394966
# 3              NaN            NaT               NaN        WF     43009
# 4              NaN            NaT               NaN      WS30    143693

# %%
df_not_separate_prefix = df_amo_temp.loc[~df_amo_temp['code'].str.contains('_')]

# %%
df_not_separate_prefix.shape
# Out:
# (34, 25)

# %%
df_not_separate_prefix
# Out:
#         amo_id          этап_сделки    бюджет дата_создания_сделки  \
# 67     2966455  Успешно_реализовано    9350.0  2020-03-19 12:57:22
# 84     4036001  Успешно_реализовано    4850.0  2020-03-27 12:13:24
# 210    8516711  Успешно_реализовано    3600.0  2020-06-20 16:28:47
# 221    8600581  Успешно_реализовано    8400.0  2020-06-23 12:40:41
# 338    9540233  Успешно_реализовано    3000.0  2020-07-18 19:33:14
# 413    9963485  Успешно_реализовано    4000.0  2020-07-31 14:47:26
# 538   11748177  Успешно_реализовано    4200.0  2020-09-22 22:52:46
# 549    8122189  Успешно_реализовано    4350.0  2020-10-06 20:27:13
# 587    8142557  Успешно_реализовано   12345.0  2020-11-06 11:52:11
# 766   18637653  Успешно_реализовано    4400.0  2021-01-06 11:11:08
# 815   15334621  Успешно_реализовано   16000.0  2021-01-16 11:34:50
# 818   15350229  Успешно_реализовано    8000.0  2021-01-17 13:10:49
# 1019  16313257  Успешно_реализовано   10000.0  2021-02-23 12:40:20
# 1049  15781389  Успешно_реализовано    4290.0  2021-03-02 12:26:25
# 1104  16808755  Успешно_реализовано   11500.0  2021-03-16 16:32:03
# 1291  17947779  Успешно_реализовано    6000.0  2021-04-29 14:25:13
# 1330  19199281  Успешно_реализовано    4000.0  2021-05-07 19:28:04
# 1443  18581471  Успешно_реализовано    1600.0  2021-05-28 19:00:37
# 1563  18978659  Успешно_реализовано    8200.0  2021-06-17 20:54:36
# 1768  20301050  Успешно_реализовано    3000.0  2021-07-11 10:52:02
# 1819  19333746  Успешно_реализовано    7500.0  2021-07-15 16:02:04
# 2037  17354135  Успешно_реализовано    7400.0  2021-08-04 10:30:27
# 2066  19237733  Успешно_реализовано    4400.0  2021-08-07 13:24:09
# 2269  19864137  Успешно_реализовано   12000.0  2021-09-17 13:59:03
# 2382  18859675  Успешно_реализовано    4000.0  2021-11-06 16:25:28
# 2460  16712559  Успешно_реализовано  242900.0  2021-12-03 14:18:19
# 2870  21311499  Успешно_реализовано    3500.0  2022-02-03 16:15:37
# 2963  21140213  Успешно_реализовано    4500.0  2022-02-16 14:59:06
# 3919  22078429  Успешно_реализовано    4000.0  2022-06-28 11:49:00
# 5734  24084549  Успешно_реализовано    5700.0  2023-04-15 21:38:45
# 8150  26872373  Успешно_реализовано       0.0  2024-02-15 21:33:58
# 8465  16097677                  NaN       NaN  2021-02-14 21:01:38
# 8470  16202345                  NaN       NaN  2021-02-18 11:16:15
# 8860  21051299                  NaN       NaN  2022-08-02 10:30:03
#
#                sale_date  delivery_price стоимость_доставки  \
# 67   2020-10-07 18:33:00             NaN                NaN
# 84   2020-10-07 18:26:00             NaN                390
# 210  2020-10-07 18:04:00             NaN                NaN
# 221  2020-10-07 18:04:00             NaN                NaN
# 338  2020-07-18 22:03:00             NaN                NaN
# 413  2020-07-31 16:09:00             NaN                NaN
# 538  2020-09-24 22:36:00             NaN                NaN
# 549  2020-06-15 11:14:00             NaN                NaN
# 587  2020-12-06 13:11:00             NaN                NaN
# 766  2021-06-06 22:31:00           400.0                350
# 815  2021-01-24 14:21:00             NaN                NaN
# 818  2021-01-17 20:02:00             NaN                NaN
# 1019 2021-02-23 12:58:00             0.0                NaN
# 1049 2021-08-02 22:12:00           290.0                NaN
# 1104 2021-03-16 17:09:00             0.0                NaN
# 1291 2021-06-05 11:52:00             0.0                NaN
# 1330 2021-06-07 16:02:00             0.0                NaN
# 1443 2021-05-28 19:16:00             0.0                NaN
# 1563 2021-06-27 11:50:00           290.0                480
# 1768 2021-07-11 11:50:00             0.0                NaN
# 1819 2021-07-20 15:58:00             0.0                NaN
# 2037 2021-08-04 21:55:00           400.0                NaN
# 2066 2021-09-07 00:58:00           400.0                527
# 2269 2021-09-17 15:09:00             0.0                NaN
# 2382 2021-11-06 16:51:00             NaN                NaN
# 2460 2021-12-03 15:51:00             NaN                NaN
# 2870 2022-04-03 21:23:00             0.0                NaN
# 2963 2022-02-16 16:01:00             0.0                NaN
# 3919 2022-06-28 20:02:00           400.0                NaN
# 5734 2023-01-05 16:47:00           500.0                NaN
# 8150 2024-02-16 10:33:00             NaN                NaN
# 8465 2021-02-18 16:25:00             NaN                NaN
# 8470 2021-02-22 21:50:00             NaN                NaN
# 8860 2022-09-02 21:42:00             NaN                NaN
#
#                                                products    price  subtotal  \
# 67                                                  NaN      NaN       NaN
# 84    Подарочный_сертификатна_Искусственную_Волну_(В...   4850.0    4500.0
# 210                                                 NaN      NaN       NaN
# 221                                                 NaN      NaN       NaN
# 338                                                 NaN      NaN       NaN
# 413                                                 NaN      NaN       NaN
# 538                                                 NaN      NaN       NaN
# 549                                                 NaN      NaN       NaN
# 587                                                 NaN      NaN       NaN
# 766   Подарочный_сертификатна_Квадроциклы_(Выберите_...   4400.0    4000.0
# 815                                                 NaN      NaN       NaN
# 818                                                 NaN      NaN       NaN
# 1019  Подарочный_сертификатна_пилотаж_на_спортивном_...  10000.0   10000.0
# 1049  Подарочный_сертификат_на_квадроциклы_(Выберите...   4290.0    4000.0
# 1104  Подарочный_сертификатна_прогулку_на_самолёте_C...  11500.0   11500.0
# 1291  Подарочный_сертификатна_Электробайк_(Выберите_...   6000.0    6000.0
# 1330  Подарочный_сертификатна_Квадроциклы_(Выберите_...   4000.0    4000.0
# 1443  Подарочный_сертификатна_Сап-Сёрфинг_(Выберите_...   1600.0    1600.0
# 1563  Подарочный_сертификатна_вейк_за_катером_(Выбер...   8090.0    7800.0
# 1768  Подарочный_сертификатна_Электробайк_(Выберите_...   3000.0    3000.0
# 1819  Подарочный_сертификатна_прогулку_на_самолёте_C...   7500.0    7500.0
# 2037  Подарочный_сертификатна_Ховерборд_(Выберите_ти...   7400.0    7000.0
# 2066  Подарочный_сертификат_на_квадроциклы_(Выберите...   4400.0    4000.0
# 2269  Подарочный_сертификатна_полёт_на_самолёте_(Выб...  12000.0   12000.0
# 2382  Подарочный_сертификатна_сап-сёрфинг_(Выберите_...   4000.0       NaN
# 2460                                                NaN      NaN       NaN
# 2870  Подарочный_сертификатна_ховерборд_(Выберите_ти...   3500.0    3500.0
# 2963  Подарочный_сертификат_на_Флайборд_(Выберите_ти...   4500.0    4500.0
# 3919  Подарочный_сертификат_в_Вейк-парк_(Выберите_ти...   2400.0    2000.0
# 5734  катание_на_картинге_(Варианты:_40_минут_катани...   5700.0    5200.0
# 8150                                                NaN      NaN       NaN
# 8465                                                NaN      NaN       0.0
# 8470                                                NaN      NaN       0.0
# 8860                                                NaN      NaN       0.0
#
#      выручка_от_клиента направление_(вид_сертификата)                code  \
# 67               8500.0    Вейксёрф_и_вейк_за_катером               42064
# 84               4850.0           Искусственная_волна               43220
# 210              3600.0    Вейксёрф_и_вейк_за_катером            01213577
# 221                 NaN    Вейксёрф_и_вейк_за_катером               25579
# 338                2700  Флайборд_/_Ховерборд_/_Ранец              M94336
# 413                4000                      САП-сёрф      W2SU2476076555
# 538                4200                     Вейк-парк         60PARK97598
# 549              4350.0                      САП-сёрф               81826
# 587             12345.0   Универсальный_Мосвейк_12345            M&F23085
# 766                4400                   Квадроциклы     KV1P1X102044120
# 815               16000                     Снегоходы               79934
# 818                8000                     Снегоходы               98173
# 1019              10000                 Авиа_Самолёты     VFMP30365043415
# 1049               4290                   Квадроциклы       KVP1102024295
# 1104              11500                 Авиа_Самолёты    VFMCS45425046055
# 1291               6000              Мото_Электробайк               12931
# 1330               4000                   Квадроциклы  KV1P1X102099687459
# 1443               1600                      САП-сёрф               79532
# 1563               8200    Вейксёрф_и_вейк_за_катером               66064
# 1768               3000              Мото_Электробайк               32580
# 1819                NaN                 Авиа_Самолёты               36528
# 2037               7400  Флайборд_/_Ховерборд_/_Ранец              H42255
# 2066               4400                   Квадроциклы     KV1P1X102167289
# 2269              12000                 Авиа_Самолёты       VFMCS45037727
# 2382               4000                      САП-сёрф               62127
# 2460             242900                           NaN               90855
# 2870               3500  Флайборд_/_Ховерборд_/_Ранец              H54470
# 2963               4500  Флайборд_/_Ховерборд_/_Ранец               98915
# 3919               4000                     Вейк-парк          WP19045770
# 5734               5700                       Картинг               52950
# 8150                NaN                           NaN               19652
# 8465                NaN                                             РН009
# 8470                NaN                                             РН007
# 8860                NaN                                             РН002
#
#      корневая_сделка номер_2-го_сертификата номер_3-го_сертификата  \
# 67               NaN                    NaN                    NaN
# 84               NaN                    NaN                    NaN
# 210              NaN                    NaN                    NaN
# 221              NaN                    NaN                    NaN
# 338              NaN                    NaN                    NaN
# 413              NaN                    NaN                    NaN
# 538              NaN                    NaN                    NaN
# 549              NaN                    NaN                    NaN
# 587              NaN                    NaN                    NaN
# 766              NaN                    NaN                    NaN
# 815              NaN                    NaN                    NaN
# 818              NaN                    NaN                    NaN
# 1019             NaN                    NaN                    NaN
# 1049             NaN                    NaN                    NaN
# 1104             NaN                    NaN                    NaN
# 1291             NaN                    NaN                    NaN
# 1330             NaN                    NaN                    NaN
# 1443             NaN                    NaN                    NaN
# 1563             NaN                    NaN                    NaN
# 1768             NaN                    NaN                    NaN
# 1819             NaN                    NaN                    NaN
# 2037             NaN                HB20305                    NaN
# 2066             NaN                    NaN                    NaN
# 2269             NaN                    NaN                    NaN
# 2382             NaN                    NaN                    NaN
# 2460             NaN                    NaN                    NaN
# 2870             NaN                    NaN                    NaN
# 2963             NaN                    NaN                    NaN
# 3919             NaN             SU60190183                    NaN
# 5734             NaN                    NaN                    NaN
# 8150             NaN                    NaN                    NaN
# 8465             NaN                    NaN                    NaN
# 8470             NaN                    NaN                    NaN
# 8860             NaN                    NaN                    NaN
#
#      номер_4-го_сертификата номер_5-го_сертификата сертификат_на_тренера  \
# 67                      NaN                    NaN                   NaN
# 84                      NaN                    NaN                   NaN
# 210                     NaN                    NaN                   NaN
# 221                     NaN                    NaN                   NaN
# 338                     NaN                    NaN                   NaN
# 413                     NaN                    NaN                   NaN
# 538                     NaN                    NaN                   NaN
# 549                     NaN                    NaN                   NaN
# 587                     NaN                    NaN                   NaN
# 766                     NaN                    NaN                   NaN
# 815                     NaN                    NaN                   NaN
# 818                     NaN                    NaN                   NaN
# 1019                    NaN                    NaN                   NaN
# 1049                    NaN                    NaN                   NaN
# 1104                    NaN                    NaN                   NaN
# 1291                    NaN                    NaN                   NaN
# 1330                    NaN                    NaN                   NaN
# 1443                    NaN                    NaN                   NaN
# 1563                    NaN                    NaN                   NaN
# 1768                    NaN                    NaN                   NaN
# 1819                    NaN                    NaN                   NaN
# 2037                    NaN                    NaN                   NaN
# 2066                    NaN                    NaN                   NaN
# 2269                    NaN                    NaN                   NaN
# 2382                    NaN                    NaN                   NaN
# 2460                    NaN                    NaN                   NaN
# 2870                    NaN                    NaN                   NaN
# 2963                    NaN                    NaN                   NaN
# 3919                    NaN                    NaN                   NaN
# 5734                    NaN                    NaN                   NaN
# 8150                    NaN                    NaN                   NaN
# 8465                    NaN                    NaN                   NaN
# 8470                    NaN                    NaN                   NaN
# 8860                    NaN                    NaN                   NaN
#
#      статус_погашения card_used_date стоимость_закупки id prefix number
# 67                NaN            NaT               NaN
# 84                NaN            NaT               NaN
# 210               NaN            NaT               NaN
# 221               NaN            NaT               NaN
# 338               NaN            NaT               NaN
# 413               NaN            NaT               NaN
# 538           Погашен     2020-09-26               NaN
# 549               NaN            NaT               NaN
# 587               NaN            NaT               NaN
# 766           Погашен     2022-01-20               NaN
# 815               NaN            NaT               NaN
# 818               NaN            NaT               NaN
# 1019              NaN            NaT               NaN
# 1049          Погашен     2022-01-03               NaN
# 1104              NaN            NaT               NaN
# 1291              NaN            NaT               NaN
# 1330              NaN            NaT               NaN
# 1443              NaN            NaT               NaN
# 1563              NaN            NaT               NaN
# 1768              NaN            NaT               NaN
# 1819              NaN            NaT               NaN
# 2037              NaN            NaT               NaN
# 2066              NaN            NaT               NaN
# 2269              NaN            NaT               NaN
# 2382              NaN            NaT               NaN
# 2460              NaN            NaT               NaN
# 2870              NaN            NaT               NaN
# 2963              NaN            NaT               NaN
# 3919          Погашен     2022-10-07               NaN
# 5734              NaN            NaT              4400
# 8150              NaN            NaT               NaN
# 8465              NaN            NaT               NaN
# 8470              NaN            NaT               NaN
# 8860              NaN            NaT               NaN

# %%
df_amo_temp['code'] = df_amo_temp.apply(lambda x: re.sub(r'(W)(F)', r'\1&\2', x['code']),axis=1)

# %% [markdown]
# #### Дополнительное поле prefix_V для "чистых префиксов" (без V)

# %%
df_amo_temp['prefix'] = df_amo_temp.apply(lambda x: replace_cirillic_latin(x['prefix']),axis=1)

# %%
df_amo_temp['prefix_V'] = df_amo_temp['prefix']

# %%
df_amo_temp.loc[(df_amo_temp['prefix'].str[0] == 'V'),'prefix_V'] = df_amo_temp['prefix'].str[1:]

# %%
df_amo_temp.head()
# Out:
#     amo_id          этап_сделки   бюджет дата_создания_сделки  \
# 0  7721733  Успешно_реализовано   7550.0  2020-01-06 10:45:48
# 1  7731389  Успешно_реализовано   2400.0  2020-01-06 13:28:31
# 2  8884277  Успешно_реализовано   2600.0  2020-01-07 12:02:41
# 3  8885245  Успешно_реализовано  12695.0  2020-01-07 12:23:45
# 4  8891643  Успешно_реализовано   3600.0  2020-01-07 15:14:42
#
#             sale_date  delivery_price стоимость_доставки products  price  \
# 0 2020-10-07 18:16:00             NaN                615      NaN    NaN
# 1 2020-10-07 18:13:00             NaN                NaN      NaN    NaN
# 2 2020-10-07 18:01:00             NaN                NaN      NaN    NaN
# 3 2020-10-07 18:01:00             NaN                NaN      NaN    NaN
# 4 2020-10-07 18:01:00             NaN                NaN      NaN    NaN
#
#    subtotal выручка_от_клиента направление_(вид_сертификата)           code  \
# 0       NaN             7550.0    Вейксёрф_и_вейк_за_катером     WS60_86373
# 1       NaN             2200.0  Флайборд_/_Ховерборд_/_Ранец     MF20_49719
# 2       NaN               2600  Флайборд_/_Ховерборд_/_Ранец  MF20_01394966
# 3       NaN              12695   Универсальный_Мосвейк_12345      W&F_43009
# 4       NaN               3600    Вейксёрф_и_вейк_за_катером    WS30_143693
#
#   корневая_сделка номер_2-го_сертификата номер_3-го_сертификата  \
# 0             NaN                    NaN                    NaN
# 1             NaN                    NaN                    NaN
# 2             NaN                    NaN                    NaN
# 3             NaN                    NaN                    NaN
# 4             NaN                    NaN                    NaN
#
#   номер_4-го_сертификата номер_5-го_сертификата сертификат_на_тренера  \
# 0                    NaN                    NaN                   NaN
# 1                    NaN                    NaN                   NaN
# 2                    NaN                    NaN                   NaN
# 3                    NaN                    NaN                   NaN
# 4                    NaN                    NaN                   NaN
#
#   статус_погашения card_used_date стоимость_закупки id prefix    number  \
# 0          Погашен     2020-12-07               NaN      WS60     86373
# 1          Погашен     2020-09-09               NaN      MF20     49719
# 2          Погашен     2020-01-07               NaN      MF20  01394966
# 3              NaN            NaT               NaN        WF     43009
# 4              NaN            NaT               NaN      WS30    143693
#
#   prefix_V
# 0     WS60
# 1     MF20
# 2     MF20
# 3       WF
# 4     WS30

# %% [markdown]
# #### Отсутствующие префиксы

# %%
prefix_amo = list(df_amo_temp['prefix_V'].unique())
prefix_amo.sort()
#prefix_amo = prefix_amo[1:]

# %% [markdown]
# ##### Префиксы в AMO

# %%
print(prefix_amo)
# Out:
# ['', '2SU24', '2SU60', '2WP24', '60WAKE', 'AC2', 'AC30', 'AC60', 'AT', 'AT10', 'AT15', 'AT30', 'AT4', 'AT4K', 'AT6', 'AT60', 'AT6K', 'AWP', 'BF180', 'BF40', 'BF90', 'BG', 'BGH', 'BGK', 'BGKH', 'CS20', 'CS30', 'CS40', 'CS60', 'CW1', 'CW1T', 'CW2', 'CW2T', 'CWH', 'D', 'DRC2H', 'DRCH', 'DT230', 'DT240', 'DT260', 'DT30', 'DT32', 'DT40', 'DT42', 'DT60', 'DT62', 'DTM', 'EB1X', 'EB1X1', 'EB2X', 'ED3H', 'EDC', 'EF30', 'EF60', 'EFL', 'EFL30', 'EFL60', 'ES130', 'ES160', 'ES230', 'ES260', 'ESG1', 'ESG2', 'F1', 'FJ30', 'FM30', 'FM45', 'FM60', 'FMCS30', 'FMCS45R', 'FMP30', 'FR', 'FR2', 'FRT', 'GC1', 'GC2', 'GR1', 'GR1X1', 'GR2', 'GR2X1', 'GRT', 'GU', 'GU2', 'HB20', 'HB30', 'HB60', 'HY30', 'HY30T', 'HY60', 'HY60T30', 'JT2', 'JT4A', 'KA2', 'KA4', 'KA6', 'KAT', 'KAT2', 'KAT4', 'KR1', 'KR2', 'KR3', 'KR4', 'KS', 'KS2', 'KV1X', 'KV1X1', 'KV2X1', 'KVC', 'KVP1X', 'KVP1X1', 'KVP1X2', 'KVP2X1', 'KVS', 'LB1X', 'LL1H', 'LL1HP', 'LL2H', 'LL3H', 'MB', 'MB2', 'MB2X', 'MF', 'MF20', 'MF30', 'MF30134139', 'MF306120784', 'MF60', 'MMF20', 'MMF30', 'MMF60', 'MSU60', 'MT', 'MT10', 'MT2', 'MT2B', 'MT5', 'MTT', 'MW&F', 'MWP15', 'MWS1', 'MWS2', 'MWS25', 'MWS40', 'MWSN40', 'P1', 'P1G', 'P1P', 'P2', 'P2G', 'PB', 'PB2', 'PB2X', 'PH', 'PH20', 'PL15', 'PL20', 'PP', 'PP2', 'PP2P', 'PP2S', 'PPP', 'PPS', 'PPT', 'PR20', 'PR30', 'PR40', 'PR60', 'PS', 'RB15', 'RB20', 'RB30', 'RB40', 'RC', 'RCV', 'RJ', 'RJ1X', 'RJ2', 'RJ2X', 'RS', 'RTV', 'RX', 'RXV', 'S', 'S2', 'SG10', 'SG5', 'SG7', 'SH', 'SH2', 'SHH', 'SK', 'SK2', 'SK2V', 'SKI20', 'SKI40', 'SKI40T', 'SKI60', 'SKI60T', 'SKT', 'SKT1', 'SKT2', 'SKT4', 'SKV', 'SN1X', 'SN1X1', 'SN2X', 'SN2X1', 'SN2X4', 'SN60', 'SP', 'SP2', 'ST', 'SU24', 'SU60', 'SUT', 'SVH', 'TB2', 'TR', 'TR1', 'TR1K', 'TR2', 'TR2K', 'TR30', 'UN', 'W&F', 'WF', 'WP15', 'WP24', 'WP2H', 'WP30', 'WP60', 'WPA', 'WS', 'WS1', 'WS20', 'WS20T', 'WS20TR', 'WS25', 'WS30', 'WS30T', 'WS40', 'WS40T', 'WS6', 'WS60', 'WS60T', 'WSN25', 'WSN40', 'WSN40T', 'WSN60', 'WSN60T', 'WTF', 'WTF2', 'WTF3', 'YAS', 'YEP']

# %% [markdown]
# ##### Префиксы, отсутсвующие в общем списке

# %%
#missing_prefix = set(prefix_value).difference(set(prefix_amo))
missing_prefix = list(set(prefix_amo)-(set(all_prefix)))
missing_prefix.sort()

# %%
print(missing_prefix)
# Out:
# ['', '60WAKE', 'AT', 'AWP', 'D', 'EFL', 'GRT', 'HY30T', 'HY60T30', 'JT2', 'JT4A', 'KV1X', 'KVC', 'KVP1X', 'KVP1X2', 'MF', 'MF30134139', 'MF306120784', 'PH20', 'SKI40T', 'SKI60T', 'SN2X4', 'SN60', 'SVH', 'TR30', 'WF', 'WP24', 'WPA', 'WS', 'WS20T', 'WS20TR', 'WS30T', 'WS40T', 'WS6', 'WS60T', 'WSN40T', 'WSN60T', 'WTF']

# %%
len(missing_prefix)
# Out:
# 38

# %%
print('AT'=='AT')
# Out:
# True

# %% [markdown]
# #### Товары, префиксы которых отсутствуют в списке категорий

# %%
df_amo_missing_prefix = df_amo_temp.query('prefix in @missing_prefix')

# %%
df_amo_missing_prefix.head()
# Out:
#      amo_id          этап_сделки   бюджет дата_создания_сделки  \
# 3   8885245  Успешно_реализовано  12695.0  2020-01-07 12:23:45
# 12  9985725  Успешно_реализовано  12345.0  2020-01-08 17:37:52
# 37  9996671  Успешно_реализовано  12745.0  2020-02-08 14:47:26
# 46  8977113  Успешно_реализовано  16845.0  2020-03-07 11:15:03
# 67  2966455  Успешно_реализовано   9350.0  2020-03-19 12:57:22
#
#              sale_date  delivery_price стоимость_доставки  \
# 3  2020-10-07 18:01:00             NaN                NaN
# 12 2020-01-08 18:50:00             NaN                NaN
# 37 2020-06-08 19:53:00             NaN                NaN
# 46 2020-07-27 12:34:00             NaN                NaN
# 67 2020-10-07 18:33:00             NaN                NaN
#
#                                       products    price  subtotal  \
# 3                                          NaN      NaN       NaN
# 12  Универсальный_сертификат_-_1x12345_=_12345  12345.0   12345.0
# 37                                         NaN      NaN       NaN
# 46                                         NaN      NaN       NaN
# 67                                         NaN      NaN       NaN
#
#    выручка_от_клиента направление_(вид_сертификата)          code  \
# 3               12695   Универсальный_Мосвейк_12345     W&F_43009
# 12              12345                           NaN     W&F_25644
# 37              12745   Универсальный_Мосвейк_12345  W&F_04283556
# 46              16845   Универсальный_Мосвейк_12345  W&F_04046503
# 67             8500.0    Вейксёрф_и_вейк_за_катером         42064
#
#    корневая_сделка номер_2-го_сертификата номер_3-го_сертификата  \
# 3              NaN                    NaN                    NaN
# 12             NaN                    NaN                    NaN
# 37             NaN                    NaN                    NaN
# 46             NaN            MF30_040769                    NaN
# 67             NaN                    NaN                    NaN
#
#    номер_4-го_сертификата номер_5-го_сертификата сертификат_на_тренера  \
# 3                     NaN                    NaN                   NaN
# 12                    NaN                    NaN                   NaN
# 37                    NaN                    NaN                   NaN
# 46                    NaN                    NaN                   NaN
# 67                    NaN                    NaN                   NaN
#
#    статус_погашения card_used_date стоимость_закупки id prefix    number  \
# 3               NaN            NaT               NaN        WF     43009
# 12              NaN            NaT               NaN        WF     25644
# 37          Погашен     2020-08-30               NaN        WF  04283556
# 46          Погашен     2020-05-09               NaN        WF  04046503
# 67              NaN            NaT               NaN
#
#    prefix_V
# 3        WF
# 12       WF
# 37       WF
# 46       WF
# 67

# %%
df_amo_missing_prefix.shape
# Out:
# (231, 26)

# %% [markdown]
# Количество записей для префиксов, отсутствующих в общей базе

# %%
df_amo_missing_prefix.groupby(['prefix'])['prefix'].count()
# Out:
# prefix
#                34
# 60WAKE          6
# AT              1
# GRT             2
# JT2             1
# KVC             1
# KVP1X2          1
# MF              1
# MF30134139      1
# WF            181
# WP24            1
# WS30T           1
# Name: prefix, dtype: int64

# %%
df111 = df_amo_temp.query('prefix == "MF"')

# %%
df111.head(10)
# Out:
#         amo_id          этап_сделки  бюджет дата_создания_сделки  \
# 7535  24790553  Успешно_реализовано     0.0  2023-11-07 21:16:07
#
#                sale_date  delivery_price стоимость_доставки products  price  \
# 7535 2023-07-14 10:52:00             NaN                NaN      NaN    NaN
#
#       subtotal выручка_от_клиента направление_(вид_сертификата)        code  \
# 7535       NaN                  0  Флайборд_/_Ховерборд_/_Ранец  MF_2521379
#
#      корневая_сделка номер_2-го_сертификата номер_3-го_сертификата  \
# 7535       #24790463                    NaN                    NaN
#
#      номер_4-го_сертификата номер_5-го_сертификата сертификат_на_тренера  \
# 7535                    NaN                    NaN                   NaN
#
#      статус_погашения card_used_date стоимость_закупки id prefix   number  \
# 7535              NaN            NaT              5525        MF  2521379
#
#      prefix_V
# 7535       MF

# %% [markdown]
# Префиксу WF соответствует W&F

# %%
df_amo_temp.loc[df_amo_temp['prefix_V'] == 'WF','prefix_V'] = 'W&F'

# %%
df_amo_temp.loc[df_amo_temp['prefix'] == 'WF','prefix'] = 'W&F'

# %%
df_amo_temp.loc[df_amo_temp['prefix'] == 'VWF','prefix'] = 'VW&F'

# %% [markdown]
# #### База АМО без prefix

# %%
df_amo_without_prefix = df_amo_temp.loc[df_amo_temp['prefix'] == '']

# %%
df_amo_without_prefix.shape
# Out:
# (34, 26)

# %%
df_amo_without_prefix.head()
# Out:
#       amo_id          этап_сделки  бюджет дата_создания_сделки  \
# 67   2966455  Успешно_реализовано  9350.0  2020-03-19 12:57:22
# 84   4036001  Успешно_реализовано  4850.0  2020-03-27 12:13:24
# 210  8516711  Успешно_реализовано  3600.0  2020-06-20 16:28:47
# 221  8600581  Успешно_реализовано  8400.0  2020-06-23 12:40:41
# 338  9540233  Успешно_реализовано  3000.0  2020-07-18 19:33:14
#
#               sale_date  delivery_price стоимость_доставки  \
# 67  2020-10-07 18:33:00             NaN                NaN
# 84  2020-10-07 18:26:00             NaN                390
# 210 2020-10-07 18:04:00             NaN                NaN
# 221 2020-10-07 18:04:00             NaN                NaN
# 338 2020-07-18 22:03:00             NaN                NaN
#
#                                               products   price  subtotal  \
# 67                                                 NaN     NaN       NaN
# 84   Подарочный_сертификатна_Искусственную_Волну_(В...  4850.0    4500.0
# 210                                                NaN     NaN       NaN
# 221                                                NaN     NaN       NaN
# 338                                                NaN     NaN       NaN
#
#     выручка_от_клиента направление_(вид_сертификата)      code  \
# 67              8500.0    Вейксёрф_и_вейк_за_катером     42064
# 84              4850.0           Искусственная_волна     43220
# 210             3600.0    Вейксёрф_и_вейк_за_катером  01213577
# 221                NaN    Вейксёрф_и_вейк_за_катером     25579
# 338               2700  Флайборд_/_Ховерборд_/_Ранец    M94336
#
#     корневая_сделка номер_2-го_сертификата номер_3-го_сертификата  \
# 67              NaN                    NaN                    NaN
# 84              NaN                    NaN                    NaN
# 210             NaN                    NaN                    NaN
# 221             NaN                    NaN                    NaN
# 338             NaN                    NaN                    NaN
#
#     номер_4-го_сертификата номер_5-го_сертификата сертификат_на_тренера  \
# 67                     NaN                    NaN                   NaN
# 84                     NaN                    NaN                   NaN
# 210                    NaN                    NaN                   NaN
# 221                    NaN                    NaN                   NaN
# 338                    NaN                    NaN                   NaN
#
#     статус_погашения card_used_date стоимость_закупки id prefix number  \
# 67               NaN            NaT               NaN
# 84               NaN            NaT               NaN
# 210              NaN            NaT               NaN
# 221              NaN            NaT               NaN
# 338              NaN            NaT               NaN
#
#     prefix_V
# 67
# 84
# 210
# 221
# 338

# %%
#df_amo_temp = df_amo_temp.loc[df_amo_temp['prefix'] != '']

# %%
df_amo_temp['card_type'] ='paper'

# %%
#df_amo_temp['series'] =''

# %%
df_amo_temp['design_type'] = 'design1'

# %%
df_amo_temp['status'] = ''

# %%
#df_amo_temp['stock_status'] = ''

# %%
df_amo_temp['sale_price'] = 0

# %%
df_amo_temp['expiry_date'] = ''

# %%
df_amo_temp['created_at'] = ''

# %%
df_amo_temp['updated_at'] = ''

# %%
df_amo_temp['deleted_at'] = ''

# %%
df_amo_temp.loc[(df_amo_temp['card_used_date'].notna()) |  (df_amo_temp['статус_погашения'] == 'Погашен'),'status'] = 'sold_used'

# %%
df_amo_temp['supplier_payment_date'] = df_amo_temp['card_used_date']

# %%
df_amo_temp.query('status=="sold_used"').head()
# Out:
#     amo_id          этап_сделки  бюджет дата_создания_сделки  \
# 0  7721733  Успешно_реализовано  7550.0  2020-01-06 10:45:48
# 1  7731389  Успешно_реализовано  2400.0  2020-01-06 13:28:31
# 2  8884277  Успешно_реализовано  2600.0  2020-01-07 12:02:41
# 5  8900351  Успешно_реализовано  3600.0  2020-01-07 17:49:48
# 8  9977557  Успешно_реализовано  4900.0  2020-01-08 10:37:09
#
#             sale_date  delivery_price стоимость_доставки products  price  \
# 0 2020-10-07 18:16:00             NaN                615      NaN    NaN
# 1 2020-10-07 18:13:00             NaN                NaN      NaN    NaN
# 2 2020-10-07 18:01:00             NaN                NaN      NaN    NaN
# 5 2020-10-07 18:01:00             NaN                NaN      NaN    NaN
# 8 2020-04-08 09:28:00             NaN                730      NaN    NaN
#
#    subtotal выручка_от_клиента направление_(вид_сертификата)           code  \
# 0       NaN             7550.0    Вейксёрф_и_вейк_за_катером     WS60_86373
# 1       NaN             2200.0  Флайборд_/_Ховерборд_/_Ранец     MF20_49719
# 2       NaN               2600  Флайборд_/_Ховерборд_/_Ранец  MF20_01394966
# 5       NaN               3600    Вейксёрф_и_вейк_за_катером  WS30_03015337
# 8       NaN               4900  Флайборд_/_Ховерборд_/_Ранец  MF30_04074082
#
#   корневая_сделка номер_2-го_сертификата номер_3-го_сертификата  \
# 0             NaN                    NaN                    NaN
# 1             NaN                    NaN                    NaN
# 2             NaN                    NaN                    NaN
# 5             NaN                    NaN                    NaN
# 8             NaN                    NaN                    NaN
#
#   номер_4-го_сертификата номер_5-го_сертификата сертификат_на_тренера  \
# 0                    NaN                    NaN                   NaN
# 1                    NaN                    NaN                   NaN
# 2                    NaN                    NaN                   NaN
# 5                    NaN                    NaN                   NaN
# 8                    NaN                    NaN                   NaN
#
#   статус_погашения card_used_date стоимость_закупки id prefix    number  \
# 0          Погашен     2020-12-07               NaN      WS60     86373
# 1          Погашен     2020-09-09               NaN      MF20     49719
# 2          Погашен     2020-01-07               NaN      MF20  01394966
# 5          Погашен     2020-08-29               NaN      WS30  03015337
# 8          Погашен     2020-09-13               NaN      MF30  04074082
#
#   prefix_V card_type design_type     status  sale_price expiry_date  \
# 0     WS60     paper     design1  sold_used           0
# 1     MF20     paper     design1  sold_used           0
# 2     MF20     paper     design1  sold_used           0
# 5     WS30     paper     design1  sold_used           0
# 8     MF30     paper     design1  sold_used           0
#
#   created_at updated_at deleted_at supplier_payment_date
# 0                                             2020-12-07
# 1                                             2020-09-09
# 2                                             2020-01-07
# 5                                             2020-08-29
# 8                                             2020-09-13

# %%
df_amo_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9176 entries, 0 to 9175
# Data columns (total 35 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   amo_id                         9176 non-null   int64
#  1   этап_сделки                    8368 non-null   object
#  2   бюджет                         8368 non-null   float64
#  3   дата_создания_сделки           9176 non-null   datetime64[ns]
#  4   sale_date                      9176 non-null   datetime64[ns]
#  5   delivery_price                 5614 non-null   float64
#  6   стоимость_доставки             504 non-null    object
#  7   products                       7449 non-null   object
#  8   price                          7449 non-null   float64
#  9   subtotal                       8213 non-null   float64
#  10  выручка_от_клиента             8162 non-null   object
#  11  направление_(вид_сертификата)  9054 non-null   object
#  12  code                           9176 non-null   object
#  13  корневая_сделка                159 non-null    object
#  14  номер_2-го_сертификата         714 non-null    object
#  15  номер_3-го_сертификата         10 non-null     object
#  16  номер_4-го_сертификата         4 non-null      object
#  17  номер_5-го_сертификата         27 non-null     object
#  18  сертификат_на_тренера          112 non-null    object
#  19  статус_погашения               3288 non-null   object
#  20  card_used_date                 3259 non-null   datetime64[ns]
#  21  стоимость_закупки              2715 non-null   object
#  22  id                             9176 non-null   object
#  23  prefix                         9176 non-null   object
#  24  number                         9176 non-null   object
#  25  prefix_V                       9176 non-null   object
#  26  card_type                      9176 non-null   object
#  27  design_type                    9176 non-null   object
#  28  status                         9176 non-null   object
#  29  sale_price                     9176 non-null   int64
#  30  expiry_date                    9176 non-null   object
#  31  created_at                     9176 non-null   object
#  32  updated_at                     9176 non-null   object
#  33  deleted_at                     9176 non-null   object
#  34  supplier_payment_date          3259 non-null   datetime64[ns]
# dtypes: datetime64[ns](4), float64(4), int64(2), object(25)
# memory usage: 2.8+ MB

# %% [markdown]
# ### Обработка поля **status**

# %%
df_amo_temp.loc[(df_amo_temp['card_used_date'].notna()) |  \
                (df_amo_temp['статус_погашения'] == 'Погашен'),'status'] = 'sold_used'

# %% [markdown]
# ### Обработка **sale_price**

# %% [markdown]
# #### Строки, являющиеся корневыми сделками

# %%
lst_root_deal = list(df_amo_temp.query('корневая_сделка.notna()')['корневая_сделка'])

# %%
print(lst_root_deal)
# Out:
# ['VMT2_2416017', '#23245257', '#23018371', '#23041919', '#23045841', '23285275', '#23287451', '#23307809', '23320675', '23371033', '#23379527', '#23381609', '#23769895', '#24693067', '#24964891', '#26171801', '#23459729', '1715029001', '#23586703', '#23514709', '#24696037', '#24696037', '#24975785', '#23681147', '#23681147', '#23705733', '#23703937', '#23710155', '#23716727', '#23716727', '#23716727', '23717485', '23718601', '23718601', '23718601', '#23724197', '#23723181', '23727459', '#23728823', '#23729565', '#23729565', '#23729565', '23732757', '#23720975', '#23748665', '#23756947', '#24204699', '#24715547', '#25885733', '#23906061', '#23918309', '#23918309', '23923847', '23923847', '#23931737', '23963847', '#23968933', '#23965909', '#23772175', '24214499', '24723003', '24992009', '#25228541', '#25538207', '#25538207', '#24072407', '#24083997', '#24098553', '#24103527', '24108151', '#24122097', 'КR2_230212', '#24177302', '#23787591', '#24996157', '24292405', '#24294657', '#24308743', '24349847', '24378991', '#24386001', '24402725', '24403171', '24403285', '24432999', '24434571', '24436793', '24437073', '#23624295', '#23624295', '#23624295', '24740295', '24548805', '#24579543', '#24579543', '#24579543', '#24579543', '#24586559', '#24606011', '#24621605', '#24646105', '#24651727', '24669423', '24676465', '#24678867', '#24029505', '24030407', '#25010665', '#25010665', '#25010665', '#25011851', '25022279', '#24815607', '#24817501', '#24818493', '24819955', '24864753', '#24873289', '24906299', '24930467', '24930467', '#24935145', '#24955825', '24757173', '24757173', '25027311', '25256899', '25256899', '#25070099', '25084249', '25084249', '25141043', '25156349', '25156349', '24526869', '#25269385', '#25938825', '#24770321', '24996969', '24996969', '#25693371', '24733567', '#24790463', '#25988183', '#26042871', '#26139623', '#23760001', '#24543987', '#26287915', '#26322051', '#26357639', '#26365001', '#26365511', '#26386633', '#26405057', '#26406417', '26432777', '26432777', '26459569']

# %%
len(lst_root_deal)
# Out:
# 159

# %%
def clear_num(num):
    """
    Очистка id корневой сделки и перевод ео в int
    """
    if num.isdigit():
        return int(num)
    else:
        l = len(num)-1
        while l>0:
            if num[l].isdigit():
                l -= 1
            else:
                break
        return int(num[l+1:])

# %% [markdown]
# Проверка:

# %%
print(clear_num('КR2_230212'))
# Out:
# 230212

# %%
lst_root_deal = list(map(clear_num,lst_root_deal))

# %% [markdown]
# Список id строк, являющимися корневыми сделками

# %%
print(lst_root_deal)
# Out:
# [2416017, 23245257, 23018371, 23041919, 23045841, 23285275, 23287451, 23307809, 23320675, 23371033, 23379527, 23381609, 23769895, 24693067, 24964891, 26171801, 23459729, 1715029001, 23586703, 23514709, 24696037, 24696037, 24975785, 23681147, 23681147, 23705733, 23703937, 23710155, 23716727, 23716727, 23716727, 23717485, 23718601, 23718601, 23718601, 23724197, 23723181, 23727459, 23728823, 23729565, 23729565, 23729565, 23732757, 23720975, 23748665, 23756947, 24204699, 24715547, 25885733, 23906061, 23918309, 23918309, 23923847, 23923847, 23931737, 23963847, 23968933, 23965909, 23772175, 24214499, 24723003, 24992009, 25228541, 25538207, 25538207, 24072407, 24083997, 24098553, 24103527, 24108151, 24122097, 230212, 24177302, 23787591, 24996157, 24292405, 24294657, 24308743, 24349847, 24378991, 24386001, 24402725, 24403171, 24403285, 24432999, 24434571, 24436793, 24437073, 23624295, 23624295, 23624295, 24740295, 24548805, 24579543, 24579543, 24579543, 24579543, 24586559, 24606011, 24621605, 24646105, 24651727, 24669423, 24676465, 24678867, 24029505, 24030407, 25010665, 25010665, 25010665, 25011851, 25022279, 24815607, 24817501, 24818493, 24819955, 24864753, 24873289, 24906299, 24930467, 24930467, 24935145, 24955825, 24757173, 24757173, 25027311, 25256899, 25256899, 25070099, 25084249, 25084249, 25141043, 25156349, 25156349, 24526869, 25269385, 25938825, 24770321, 24996969, 24996969, 25693371, 24733567, 24790463, 25988183, 26042871, 26139623, 23760001, 24543987, 26287915, 26322051, 26357639, 26365001, 26365511, 26386633, 26405057, 26406417, 26432777, 26432777, 26459569]

# %%
df_amo_temp.query('amo_id in @lst_root_deal').head()
# Out:
#         amo_id          этап_сделки   бюджет дата_создания_сделки  \
# 3669  23245257  Успешно_реализовано   9900.0  2022-06-12 11:29:01
# 4026  23018371  Успешно_реализовано  10350.0  2022-07-11 12:40:42
# 4658  23041919  Успешно_реализовано   8000.0  2022-10-11 14:37:31
# 4760  23045841  Успешно_реализовано  16900.0  2022-11-11 09:18:21
# 4853  23285275  Успешно_реализовано  18000.0  2022-12-12 13:17:25
#
#                sale_date  delivery_price стоимость_доставки  \
# 3669 2022-07-12 20:38:00           400.0                207
# 4026 2022-08-11 19:32:00           350.0                NaN
# 4658 2022-10-11 20:29:00             NaN                NaN
# 4760 2022-11-11 16:41:00           400.0                NaN
# 4853 2022-12-15 13:47:00             0.0                NaN
#
#                                                products    price  subtotal  \
# 3669  Квадроциклы_(Варианты:_1_квадрик_1_час_без_пас...   9900.0    9500.0
# 4026  Мотокросс_и_Эндуро_(Варианты:_2_часа_с_тренеро...  10350.0   10000.0
# 4658  Электробайк_(Варианты:_1,5_ч_катания_для_1_чел...   8000.0    8000.0
# 4760  Полет_на_параплане_(Варианты:_2_полета_с_инстр...  16900.0   16500.0
# 4853  Снегоходы_(Варианты:_1_снежик_на_2_часа,_Бумаж...  18000.0   18000.0
#
#      выручка_от_клиента направление_(вид_сертификата)             code  \
# 3669               9900                     Снегоходы    SN1X_19054346
# 4026              10350                Мото_Мотокросс    MT2B_20013189
# 4658               8000              Мото_Электробайк  VEB1X_221430938
# 4760              16900                      Параплан      P2_22088724
# 4853              18000                     Снегоходы   SN2X1_17024919
#
#      корневая_сделка номер_2-го_сертификата номер_3-го_сертификата  \
# 3669             NaN                    NaN                    NaN
# 4026             NaN                    NaN                    NaN
# 4658             NaN                    NaN                    NaN
# 4760             NaN                    NaN                    NaN
# 4853             NaN                    NaN                    NaN
#
#      номер_4-го_сертификата номер_5-го_сертификата сертификат_на_тренера  \
# 3669                    NaN                    NaN                   NaN
# 4026                    NaN                    NaN                   NaN
# 4658                    NaN                    NaN                   NaN
# 4760                    NaN                    NaN                   NaN
# 4853                    NaN                    NaN                   NaN
#
#      статус_погашения card_used_date стоимость_закупки id prefix     number  \
# 3669          Погашен     2023-02-18              4000      SN1X   19054346
# 4026              NaN            NaT              4000      MT2B   20013189
# 4658          Погашен     2023-09-04              3200     VEB1X  221430938
# 4760              NaN            NaT              5500        P2   22088724
# 4853          Погашен     2023-02-20             16000     SN2X1   17024919
#
#      prefix_V card_type design_type     status  sale_price expiry_date  \
# 3669     SN1X     paper     design1  sold_used           0
# 4026     MT2B     paper     design1                      0
# 4658     EB1X     paper     design1  sold_used           0
# 4760       P2     paper     design1                      0
# 4853    SN2X1     paper     design1  sold_used           0
#
#      created_at updated_at deleted_at supplier_payment_date
# 3669                                             2023-02-18
# 4026                                                    NaT
# 4658                                             2023-09-04
# 4760                                                    NaT
# 4853                                             2023-02-20

# %% [markdown]
# Если в сделке 1 товар и сделка не имеет производных сделок, то использовать значение поля SUBTOTAL

# %% [markdown]
# #### Расчет sale_price для обычных товаров

# %%
df_amo_temp.loc[(df_amo_temp['номер_2-го_сертификата'].isna()) & \
                (df_amo_temp['номер_3-го_сертификата'].isna()) & \
                (df_amo_temp['номер_4-го_сертификата'].isna()) & \
                (df_amo_temp['номер_5-го_сертификата'].isna()) & \
                (df_amo_temp['сертификат_на_тренера'].isna()) &\
                (~df_amo_temp['amo_id'].isin(lst_root_deal)) &\
                (df_amo_temp['корневая_сделка'].isna()),\
                'sale_price'] = df_amo_temp['subtotal']

# %% [markdown]
# Проверка

# %% [markdown]
# Сумма поля sale_price для сделок, являющихся корневыми

# %%
df_amo_temp.query('amo_id in @lst_root_deal')['sale_price'].sum()
# Out:
# 0.0

# %% [markdown]
# Сумма поля sale_pricaae для сделок, не являющихся корневыми, не имеющих дополнительных серт

# %%
df_amo_temp.query('amo_id in @lst_root_deal')['subtotal'].sum()
# Out:
# 1632329.0

# %%
df_amo_temp.head()
# Out:
#     amo_id          этап_сделки   бюджет дата_создания_сделки  \
# 0  7721733  Успешно_реализовано   7550.0  2020-01-06 10:45:48
# 1  7731389  Успешно_реализовано   2400.0  2020-01-06 13:28:31
# 2  8884277  Успешно_реализовано   2600.0  2020-01-07 12:02:41
# 3  8885245  Успешно_реализовано  12695.0  2020-01-07 12:23:45
# 4  8891643  Успешно_реализовано   3600.0  2020-01-07 15:14:42
#
#             sale_date  delivery_price стоимость_доставки products  price  \
# 0 2020-10-07 18:16:00             NaN                615      NaN    NaN
# 1 2020-10-07 18:13:00             NaN                NaN      NaN    NaN
# 2 2020-10-07 18:01:00             NaN                NaN      NaN    NaN
# 3 2020-10-07 18:01:00             NaN                NaN      NaN    NaN
# 4 2020-10-07 18:01:00             NaN                NaN      NaN    NaN
#
#    subtotal выручка_от_клиента направление_(вид_сертификата)           code  \
# 0       NaN             7550.0    Вейксёрф_и_вейк_за_катером     WS60_86373
# 1       NaN             2200.0  Флайборд_/_Ховерборд_/_Ранец     MF20_49719
# 2       NaN               2600  Флайборд_/_Ховерборд_/_Ранец  MF20_01394966
# 3       NaN              12695   Универсальный_Мосвейк_12345      W&F_43009
# 4       NaN               3600    Вейксёрф_и_вейк_за_катером    WS30_143693
#
#   корневая_сделка номер_2-го_сертификата номер_3-го_сертификата  \
# 0             NaN                    NaN                    NaN
# 1             NaN                    NaN                    NaN
# 2             NaN                    NaN                    NaN
# 3             NaN                    NaN                    NaN
# 4             NaN                    NaN                    NaN
#
#   номер_4-го_сертификата номер_5-го_сертификата сертификат_на_тренера  \
# 0                    NaN                    NaN                   NaN
# 1                    NaN                    NaN                   NaN
# 2                    NaN                    NaN                   NaN
# 3                    NaN                    NaN                   NaN
# 4                    NaN                    NaN                   NaN
#
#   статус_погашения card_used_date стоимость_закупки id prefix    number  \
# 0          Погашен     2020-12-07               NaN      WS60     86373
# 1          Погашен     2020-09-09               NaN      MF20     49719
# 2          Погашен     2020-01-07               NaN      MF20  01394966
# 3              NaN            NaT               NaN       W&F     43009
# 4              NaN            NaT               NaN      WS30    143693
#
#   prefix_V card_type design_type     status  sale_price expiry_date  \
# 0     WS60     paper     design1  sold_used         NaN
# 1     MF20     paper     design1  sold_used         NaN
# 2     MF20     paper     design1  sold_used         NaN
# 3      W&F     paper     design1                    NaN
# 4     WS30     paper     design1                    NaN
#
#   created_at updated_at deleted_at supplier_payment_date
# 0                                             2020-12-07
# 1                                             2020-09-09
# 2                                             2020-01-07
# 3                                                    NaT
# 4                                                    NaT

# %% [markdown]
# База АМО c prefix

# %%
df_amo_temp = df_amo_temp.loc[df_amo_temp['prefix'] != '']

# %%
df_amo_temp.shape
# Out:
# (9142, 35)

# %%
df_amo_temp['card_type'] = df_amo_temp['prefix'].apply(lambda x: 'electronic' if x[0] == 'V' else 'paper')

# %%
df_amo_temp.query('amo_id==26139623').head()
# Out:
#         amo_id          этап_сделки   бюджет дата_создания_сделки  \
# 7635  26139623  Успешно_реализовано  11450.0  2023-11-28 13:06:38
# 8984  26139623                  NaN      NaN  2023-11-28 13:06:38
#
#                sale_date  delivery_price стоимость_доставки  \
# 7635 2023-02-12 22:29:00           450.0                NaN
# 8984 2023-02-12 22:29:00             NaN                NaN
#
#                                                products    price  subtotal  \
# 7635  Снегоходы_(Варианты:_1_снежик_на_1_час,_Бумажн...  11450.0   11000.0
# 8984                                                NaN      NaN       0.0
#
#      выручка_от_клиента направление_(вид_сертификата)           code  \
# 7635              11450                     Снегоходы  SN1X_19010652
# 8984                NaN                                  SN1X_191480
#
#      корневая_сделка номер_2-го_сертификата номер_3-го_сертификата  \
# 7635             NaN            SN1X_191480                    NaN
# 8984             NaN                    NaN                    NaN
#
#      номер_4-го_сертификата номер_5-го_сертификата сертификат_на_тренера  \
# 7635                    NaN                    NaN                   NaN
# 8984                    NaN                    NaN                   NaN
#
#      статус_погашения card_used_date стоимость_закупки id prefix    number  \
# 7635          Погашен     2024-11-02              4000      SN1X  19010652
# 8984              NaN            NaT               NaN      SN1X    191480
#
#      prefix_V card_type design_type     status  sale_price expiry_date  \
# 7635     SN1X     paper     design1  sold_used         0.0
# 8984     SN1X     paper     design1                    0.0
#
#      created_at updated_at deleted_at supplier_payment_date
# 7635                                             2024-11-02
# 8984                                                    NaT

# %%
#df_amo_temp.query('корневая_сделка.notna()')

# %% [markdown]
# #Проверка:

# %%
#pp = df_amo_temp.query('amo_id == 26139797')

# %%
#pp

# %% [markdown]
# #### Расчет sale_price для корневых, имеющих дополнительный сертификат

# %%
df_amo_temp['sale_price'].fillna(0, inplace=True)

# %%
df_amo_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9142 entries, 0 to 9175
# Data columns (total 35 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   amo_id                         9142 non-null   int64
#  1   этап_сделки                    8337 non-null   object
#  2   бюджет                         8337 non-null   float64
#  3   дата_создания_сделки           9142 non-null   datetime64[ns]
#  4   sale_date                      9142 non-null   datetime64[ns]
#  5   delivery_price                 5597 non-null   float64
#  6   стоимость_доставки             500 non-null    object
#  7   products                       7430 non-null   object
#  8   price                          7430 non-null   float64
#  9   subtotal                       8192 non-null   float64
#  10  выручка_от_клиента             8134 non-null   object
#  11  направление_(вид_сертификата)  9022 non-null   object
#  12  code                           9142 non-null   object
#  13  корневая_сделка                159 non-null    object
#  14  номер_2-го_сертификата         712 non-null    object
#  15  номер_3-го_сертификата         10 non-null     object
#  16  номер_4-го_сертификата         4 non-null      object
#  17  номер_5-го_сертификата         27 non-null     object
#  18  сертификат_на_тренера          112 non-null    object
#  19  статус_погашения               3284 non-null   object
#  20  card_used_date                 3255 non-null   datetime64[ns]
#  21  стоимость_закупки              2714 non-null   object
#  22  id                             9142 non-null   object
#  23  prefix                         9142 non-null   object
#  24  number                         9142 non-null   object
#  25  prefix_V                       9142 non-null   object
#  26  card_type                      9142 non-null   object
#  27  design_type                    9142 non-null   object
#  28  status                         9142 non-null   object
#  29  sale_price                     9142 non-null   float64
#  30  expiry_date                    9142 non-null   object
#  31  created_at                     9142 non-null   object
#  32  updated_at                     9142 non-null   object
#  33  deleted_at                     9142 non-null   object
#  34  supplier_payment_date          3255 non-null   datetime64[ns]
# dtypes: datetime64[ns](4), float64(5), int64(1), object(25)
# memory usage: 2.5+ MB

# %% [markdown]
# Функция для определения sale_price для

# %%
iis = 0
iisv = 0

# %%
def insert_sale111(row):    
    v = row['sale_price']
    if row['sale_price'] == 0:
        amo_id = row['amo_id']
        pr = row['prefix']
        v = 0
        str1 = f'sale_price != 0 & prefix == "{pr}"'
        try:
            v = df_amo_temp.query(str1).iloc[-1]['sale_price']
        except:
            pass
        finally:
            return v
    return v

# %%
def insert_sale(row):    
    v = row['sale_price']
    #print(v)
    if row['sale_price'] == 0:
        d = row['дата_создания_сделки']
        amo_id = row['amo_id']
        pr = row['prefix']
        #v = 0
        str1 = f'sale_price != 0 & prefix == "{pr}"'
        try:
            #v = df_amo_temp.query(str1).iloc[-1]['sale_price']
            arr = df_amo_temp.query(str1)    
            arr['diff_date'] = arr['дата_создания_сделки'] - d
            arr = arr.sort_values(by='diff_date',ascending=True)
            arr.reset_index(drop= True , inplace= True)
            v = arr.iloc[0]['sale_price']
            iis += 1
        except:
            pass
        finally:
            return v
    return v

# %%
def insert_saleV(row):    
    v = row['sale_price']
    #print(v)
    if row['sale_price'] == 0:
        d = row['дата_создания_сделки']
        amo_id = row['amo_id']
        pr = row['prefix_V']
        #v = 0
        str1 = f'sale_price != 0 & prefix_V == "{pr}"'
        try:
            #v = df_amo_temp.query(str1).iloc[-1]['sale_price']
            arr = df_amo_temp.query(str1)    
            arr['diff_date'] = arr['дата_создания_сделки'] - d
            arr = arr.sort_values(by='diff_date',ascending=True)
            arr.reset_index(drop= True , inplace= True)
            v = arr.iloc[0]['sale_price']
            iisv += 1
        except:
            pass
        finally:
            return v
    return v

# %%
df_amo_temp['sale_price'] = df_amo_temp.apply(insert_sale,axis=1)

# %%
df_amo_temp['sale_price'] = df_amo_temp.apply(insert_saleV,axis=1)

# %%
print(f'iis - {iis} iisv - {iisv}')
# Out:
# iis - 0 iisv - 0

# %% [markdown]
# Проверка:

# %%
pp = df_amo_temp.query('amo_id == 26139623')

# %%
pp
# Out:
#         amo_id          этап_сделки   бюджет дата_создания_сделки  \
# 7635  26139623  Успешно_реализовано  11450.0  2023-11-28 13:06:38
# 8984  26139623                  NaN      NaN  2023-11-28 13:06:38
#
#                sale_date  delivery_price стоимость_доставки  \
# 7635 2023-02-12 22:29:00           450.0                NaN
# 8984 2023-02-12 22:29:00             NaN                NaN
#
#                                                products    price  subtotal  \
# 7635  Снегоходы_(Варианты:_1_снежик_на_1_час,_Бумажн...  11450.0   11000.0
# 8984                                                NaN      NaN       0.0
#
#      выручка_от_клиента направление_(вид_сертификата)           code  \
# 7635              11450                     Снегоходы  SN1X_19010652
# 8984                NaN                                  SN1X_191480
#
#      корневая_сделка номер_2-го_сертификата номер_3-го_сертификата  \
# 7635             NaN            SN1X_191480                    NaN
# 8984             NaN                    NaN                    NaN
#
#      номер_4-го_сертификата номер_5-го_сертификата сертификат_на_тренера  \
# 7635                    NaN                    NaN                   NaN
# 8984                    NaN                    NaN                   NaN
#
#      статус_погашения card_used_date стоимость_закупки id prefix    number  \
# 7635          Погашен     2024-11-02              4000      SN1X  19010652
# 8984              NaN            NaT               NaN      SN1X    191480
#
#      prefix_V card_type design_type     status  sale_price expiry_date  \
# 7635     SN1X     paper     design1  sold_used      5000.0
# 8984     SN1X     paper     design1                 5000.0
#
#      created_at updated_at deleted_at supplier_payment_date
# 7635                                             2024-11-02
# 8984                                                    NaT

# %% [markdown]
# sale_price появился

# %% [markdown]
# #### Строки, оставшиеся без sale_price

# %%
dd0 = df_amo_temp.query('sale_price == 0')

# %%
dd0.shape
# Out:
# (326, 35)

# %%
dd0.head(10)
# Out:
#         amo_id          этап_сделки   бюджет дата_создания_сделки  \
# 186   11187459  Успешно_реализовано      1.0  2020-06-09 22:09:43
# 187   11187473  Успешно_реализовано      1.0  2020-06-09 22:11:22
# 224    8633971  Успешно_реализовано   5350.0  2020-06-23 16:04:00
# 489   10821667  Успешно_реализовано   4000.0  2020-08-26 10:58:02
# 634    2043485  Успешно_реализовано   8000.0  2020-12-03 16:42:41
# 830   15499835  Успешно_реализовано  12000.0  2021-01-20 14:37:07
# 1059  18695607  Успешно_реализовано   7500.0  2021-03-06 22:11:29
# 1737  18769077  Успешно_реализовано   4500.0  2021-07-06 19:26:54
# 2832  20910305  Успешно_реализовано   5000.0  2022-01-23 11:58:15
# 3641  22125805  Успешно_реализовано  10900.0  2022-06-07 15:32:30
#
#                sale_date  delivery_price стоимость_доставки  \
# 186  2020-06-09 22:15:00             NaN                NaN
# 187  2020-06-09 22:15:00             NaN                NaN
# 224  2020-10-07 18:03:00             NaN                NaN
# 489  2020-08-26 11:15:00             NaN                NaN
# 634  2020-12-03 16:45:00             NaN                NaN
# 830  2021-01-23 07:40:00             NaN                NaN
# 1059 2021-04-06 07:33:00             NaN                NaN
# 1737 2021-07-06 19:56:00             0.0                NaN
# 2832 2022-01-23 11:58:00             NaN                NaN
# 3641 2022-07-07 19:51:00             NaN                NaN
#
#                                                products    price  subtotal  \
# 186                                                 NaN      NaN       NaN
# 187                                                 NaN      NaN       NaN
# 224                                                 NaN      NaN       NaN
# 489                                                 NaN      NaN       NaN
# 634                                                 NaN      NaN       NaN
# 830                                                 NaN      NaN       NaN
# 1059  Подарочный_сертификатна_вейксёрфинг_(Выберите_...   7500.0       NaN
# 1737  Подарочный_сертификатна_Флайборд_(Выберите_тип...   4500.0    4500.0
# 2832                                                NaN      NaN       NaN
# 3641  Подарочный_сертификатна_вейкборд_(Выберите_тип...  10900.0   10900.0
#
#      выручка_от_клиента направление_(вид_сертификата)                code  \
# 186                   1                     Вейк-парк       WP30_04071533
# 187                   1                     Вейк-парк       WP30_04092000
# 224              5350.0                     Вейк-парк          WP24_46355
# 489                4000                        Тренер     VTR2K_138066338
# 634              8000.0                   Квадроциклы     KVP1X2_???96384
# 830               12000                     Аэротруба       AT_1007189075
# 1059               7500    Вейксёрф_и_вейк_за_катером     VWS6_0584073507
# 1737               4500  Флайборд_/_Ховерборд_/_Ранец  VMF306120784_13063
# 2832               5000               Моржевание+баня        KR1_17014148
# 3641              10900    Вейксёрф_и_вейк_за_катером        TR2_15247945
#
#      корневая_сделка номер_2-го_сертификата номер_3-го_сертификата  \
# 186              NaN                    NaN                    NaN
# 187              NaN                    NaN                    NaN
# 224              NaN                    NaN                    NaN
# 489              NaN           VTR2K1390277                    NaN
# 634              NaN                    NaN                    NaN
# 830              NaN                  PH027                    NaN
# 1059             NaN                    NaN                    NaN
# 1737             NaN           VKA4_3828822                    NaN
# 2832             NaN                    NaN                    NaN
# 3641             NaN            WS60_210757                    NaN
#
#      номер_4-го_сертификата номер_5-го_сертификата сертификат_на_тренера  \
# 186                     NaN                    NaN                   NaN
# 187                     NaN                    NaN                   NaN
# 224                     NaN                    NaN                   NaN
# 489                     NaN                    NaN                   NaN
# 634                     NaN                    NaN                   NaN
# 830                     NaN                    NaN                   NaN
# 1059                    NaN                    NaN                   NaN
# 1737                    NaN                    NaN                   NaN
# 2832                    NaN                    NaN                   NaN
# 3641                    NaN                    NaN                   NaN
#
#      статус_погашения card_used_date стоимость_закупки id        prefix  \
# 186               NaN            NaT               NaN             WP30
# 187               NaN            NaT               NaN             WP30
# 224           Погашен     2022-04-08               NaN             WP24
# 489           Погашен     2021-04-11               NaN            VTR2K
# 634               NaN            NaT               NaN           KVP1X2
# 830               NaN            NaT               NaN               AT
# 1059          Погашен     2021-11-24               NaN             VWS6
# 1737              NaN            NaT               NaN     VMF306120784
# 2832              NaN            NaT               NaN              KR1
# 3641          Погашен     2022-07-28               NaN              TR2
#
#           number     prefix_V   card_type design_type     status  sale_price  \
# 186     04071533         WP30       paper     design1                    0.0
# 187     04092000         WP30       paper     design1                    0.0
# 224        46355         WP24       paper     design1  sold_used         0.0
# 489    138066338         TR2K  electronic     design1  sold_used         0.0
# 634     ???96384       KVP1X2       paper     design1                    0.0
# 830   1007189075           AT       paper     design1                    0.0
# 1059  0584073507          WS6  electronic     design1  sold_used         0.0
# 1737       13063  MF306120784  electronic     design1                    0.0
# 2832    17014148          KR1       paper     design1                    0.0
# 3641    15247945          TR2       paper     design1  sold_used         0.0
#
#      expiry_date created_at updated_at deleted_at supplier_payment_date
# 186                                                                 NaT
# 187                                                                 NaT
# 224                                                          2022-04-08
# 489                                                          2021-04-11
# 634                                                                 NaT
# 830                                                                 NaT
# 1059                                                         2021-11-24
# 1737                                                                NaT
# 2832                                                                NaT
# 3641                                                         2022-07-28

# %%
dd0 = df_amo_temp.query('sale_price.isna()')

# %%
dd0.shape
# Out:
# (0, 35)

# %%
dd0.head()
# Out:
# Empty DataFrame
# Columns: [amo_id, этап_сделки, бюджет, дата_создания_сделки, sale_date, delivery_price, стоимость_доставки, products, price, subtotal, выручка_от_клиента, направление_(вид_сертификата), code, корневая_сделка, номер_2-го_сертификата, номер_3-го_сертификата, номер_4-го_сертификата, номер_5-го_сертификата, сертификат_на_тренера, статус_погашения, card_used_date, стоимость_закупки, id, prefix, number, prefix_V, card_type, design_type, status, sale_price, expiry_date, created_at, updated_at, deleted_at, supplier_payment_date]
# Index: []

# %% [markdown]
# Несколько записей так и не получили sale_price

# %%
df_amo_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9142 entries, 0 to 9175
# Data columns (total 35 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   amo_id                         9142 non-null   int64
#  1   этап_сделки                    8337 non-null   object
#  2   бюджет                         8337 non-null   float64
#  3   дата_создания_сделки           9142 non-null   datetime64[ns]
#  4   sale_date                      9142 non-null   datetime64[ns]
#  5   delivery_price                 5597 non-null   float64
#  6   стоимость_доставки             500 non-null    object
#  7   products                       7430 non-null   object
#  8   price                          7430 non-null   float64
#  9   subtotal                       8192 non-null   float64
#  10  выручка_от_клиента             8134 non-null   object
#  11  направление_(вид_сертификата)  9022 non-null   object
#  12  code                           9142 non-null   object
#  13  корневая_сделка                159 non-null    object
#  14  номер_2-го_сертификата         712 non-null    object
#  15  номер_3-го_сертификата         10 non-null     object
#  16  номер_4-го_сертификата         4 non-null      object
#  17  номер_5-го_сертификата         27 non-null     object
#  18  сертификат_на_тренера          112 non-null    object
#  19  статус_погашения               3284 non-null   object
#  20  card_used_date                 3255 non-null   datetime64[ns]
#  21  стоимость_закупки              2714 non-null   object
#  22  id                             9142 non-null   object
#  23  prefix                         9142 non-null   object
#  24  number                         9142 non-null   object
#  25  prefix_V                       9142 non-null   object
#  26  card_type                      9142 non-null   object
#  27  design_type                    9142 non-null   object
#  28  status                         9142 non-null   object
#  29  sale_price                     9142 non-null   float64
#  30  expiry_date                    9142 non-null   object
#  31  created_at                     9142 non-null   object
#  32  updated_at                     9142 non-null   object
#  33  deleted_at                     9142 non-null   object
#  34  supplier_payment_date          3255 non-null   datetime64[ns]
# dtypes: datetime64[ns](4), float64(5), int64(1), object(25)
# memory usage: 2.5+ MB

# %% [markdown]
# ## Запись в файлы

# %% [markdown]
# ### Объединение датафреймов без префиксов и с отсутствующими в базах префиксами и запись в файл

# %%
df_amo_missing_prefix = df_amo_temp.query('prefix in @missing_prefix')

# %%
df_amo_missing_prefix.shape
# Out:
# (16, 35)

# %%
frames = [df_amo_without_prefix, df_amo_missing_prefix]

# %%
cert_w_missing_prefix = pd.concat(frames)

# %%
cert_w_missing_prefix.shape
# Out:
# (50, 35)

# %%
cert_w_missing_prefix.to_csv('r_cert_w_missing_prefix' + date_int + '.csv')

# %% [markdown]
# ### Запись отсутствующих в Списке подкатегорий prefix в файл

# %%
df_missing_prefix = pd.DataFrame({'prefix':missing_prefix})

# %%
df_missing_prefix.shape
# Out:
# (38, 1)

# %%
df_missing_prefix.head()
# Out:
#    prefix
# 0
# 1  60WAKE
# 2      AT
# 3     AWP
# 4       D

# %%
df_missing_prefix.to_csv('r_missing_prefix' + date_int + '.csv')

# %% [markdown]
# ### (п.10) Запись товаров, необходимые поля которого заполнены

# %%
df_amo_temp['amo_lead_id'] = df_amo_temp['amo_id']

# %%
df_amo_temp['amo_id'] = ''

# %% [markdown]
# Итоговые столбцы из АМО

# %%
lst_afm = ['id', 
           'amo_id',
           'amo_lead_id',
           'prefix',
           'prefix_V',
           'code',
           'card_type',
           'design_type',
           'status',
           'supplier_payment_date',
           'sale_price',
           'sale_date',
           'expiry_date',
           'card_used_date',
           'created_at',
           'updated_at',
           'deleted_at',
           'number',
]

# %% [markdown]
# Итоговые столбцы из Реестра

# %%
df_values['prefix_V'] = df_values['prefix']

# %%
lst_val = ['activity_value_id','prefix_V']

# %% [markdown]
# Датафреймы для объединения

# %%
df_amo_for_merge = df_amo_temp.query('prefix_V in @prefix_values')

# %%
df_amo_for_merge = df_amo_for_merge[lst_afm]

# %%
df_amo_for_merge.head()
# Out:
#   id amo_id  amo_lead_id prefix prefix_V           code card_type design_type  \
# 1                7731389   MF20     MF20     MF20_49719     paper     design1
# 2                8884277   MF20     MF20  MF20_01394966     paper     design1
# 3                8885245    W&F      W&F      W&F_43009     paper     design1
# 4                8891643   WS30     WS30    WS30_143693     paper     design1
# 5                8900351   WS30     WS30  WS30_03015337     paper     design1
#
#       status supplier_payment_date  sale_price           sale_date  \
# 1  sold_used            2020-09-09      3000.0 2020-10-07 18:13:00
# 2  sold_used            2020-01-07      3000.0 2020-10-07 18:01:00
# 3                              NaT     12345.0 2020-10-07 18:01:00
# 4                              NaT      3900.0 2020-10-07 18:01:00
# 5  sold_used            2020-08-29      3900.0 2020-10-07 18:01:00
#
#   expiry_date card_used_date created_at updated_at deleted_at    number
# 1                 2020-09-09                                      49719
# 2                 2020-01-07                                   01394966
# 3                        NaT                                      43009
# 4                        NaT                                     143693
# 5                 2020-08-29                                   03015337

# %%
df_value_for_merge = df_values[lst_val]

# %% [markdown]
# Объединение датафреймов

# %%
df_list = pd.merge(df_amo_for_merge, df_value_for_merge,how="inner",on='prefix_V')

# %%
df_list.head()
# Out:
#   id amo_id  amo_lead_id prefix prefix_V            code   card_type  \
# 0                7731389   MF20     MF20      MF20_49719       paper
# 1                8884277   MF20     MF20   MF20_01394966       paper
# 2                9979317   MF20     MF20   MF20_04230327       paper
# 3                9988677  VMF20     MF20  VMF20_80030727  electronic
# 4                 667573   MF20     MF20      MF20_95425       paper
#
#   design_type     status supplier_payment_date  sale_price  \
# 0     design1  sold_used            2020-09-09      3000.0
# 1     design1  sold_used            2020-01-07      3000.0
# 2     design1                              NaT      3000.0
# 3     design1                              NaT      3000.0
# 4     design1  sold_used            2020-01-07      2600.0
#
#             sale_date expiry_date card_used_date created_at updated_at  \
# 0 2020-10-07 18:13:00                 2020-09-09
# 1 2020-10-07 18:01:00                 2020-01-07
# 2 2020-04-08 09:29:00                        NaT
# 3 2020-01-08 22:17:00                        NaT
# 4 2020-10-07 10:40:00                 2020-01-07
#
#   deleted_at    number  activity_value_id
# 0                49719                 12
# 1             01394966                 12
# 2             04230327                 12
# 3             80030727                 12
# 4                95425                 12

# %%
df_list = df_list.drop('prefix_V', axis=1)

# %%
df_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6755 entries, 0 to 6754
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     6755 non-null   object
#  1   amo_id                 6755 non-null   object
#  2   amo_lead_id            6755 non-null   int64
#  3   prefix                 6755 non-null   object
#  4   code                   6755 non-null   object
#  5   card_type              6755 non-null   object
#  6   design_type            6755 non-null   object
#  7   status                 6755 non-null   object
#  8   supplier_payment_date  2379 non-null   datetime64[ns]
#  9   sale_price             6755 non-null   float64
#  10  sale_date              6755 non-null   datetime64[ns]
#  11  expiry_date            6755 non-null   object
#  12  card_used_date         2379 non-null   datetime64[ns]
#  13  created_at             6755 non-null   object
#  14  updated_at             6755 non-null   object
#  15  deleted_at             6755 non-null   object
#  16  number                 6755 non-null   object
#  17  activity_value_id      6755 non-null   int64
# dtypes: datetime64[ns](3), float64(1), int64(2), object(12)
# memory usage: 1002.7+ KB

# %% [markdown]
# Запись в файл

# %%
df_list.to_csv('r_certs_to_import' + date_int +'.csv')

# %% [markdown]
# ### (п.11) Список товаров, чьи префиксы не обнаружены в list_of_values.csv, но есть в codes_archieve

# %%
df_amo_temp = df_amo_temp.query('prefix_V in @archive_prefix')

# %%
df_amo_for_write = df_amo_temp[lst_afm]

# %%
df_amo_for_write = df_amo_for_write.drop('prefix_V', axis=1)

# %%
df_amo_for_write.head()
# Out:
#    id amo_id  amo_lead_id  prefix             code   card_type design_type  \
# 0                 7721733    WS60       WS60_86373       paper     design1
# 7                 9973679  V2SU60  V2SU60_78082417  electronic     design1
# 10                9983981   2SU60   2SU60_03022869       paper     design1
# 18               11023407   VWS20  VWS20_152014539  electronic     design1
# 25                8924333   VWS20   VWS20_01449377  electronic     design1
#
#        status supplier_payment_date  sale_price           sale_date  \
# 0   sold_used            2020-12-07      7500.0 2020-10-07 18:16:00
# 7                               NaT      1600.0 2020-01-08 12:13:00
# 10  sold_used            2020-11-08      1600.0 2020-04-08 09:31:00
# 18                              NaT      2600.0 2020-01-09 19:04:00
# 25                              NaT      2600.0 2020-02-07 11:15:00
#
#    expiry_date card_used_date created_at updated_at deleted_at     number
# 0                  2020-12-07                                       86373
# 7                         NaT                                    78082417
# 10                 2020-11-08                                    03022869
# 18                        NaT                                   152014539
# 25                        NaT                                    01449377

# %%
df_amo_for_write.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1991 entries, 0 to 9175
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     1991 non-null   object
#  1   amo_id                 1991 non-null   object
#  2   amo_lead_id            1991 non-null   int64
#  3   prefix                 1991 non-null   object
#  4   code                   1991 non-null   object
#  5   card_type              1991 non-null   object
#  6   design_type            1991 non-null   object
#  7   status                 1991 non-null   object
#  8   supplier_payment_date  694 non-null    datetime64[ns]
#  9   sale_price             1991 non-null   float64
#  10  sale_date              1991 non-null   datetime64[ns]
#  11  expiry_date            1991 non-null   object
#  12  card_used_date         694 non-null    datetime64[ns]
#  13  created_at             1991 non-null   object
#  14  updated_at             1991 non-null   object
#  15  deleted_at             1991 non-null   object
#  16  number                 1991 non-null   object
# dtypes: datetime64[ns](3), float64(1), int64(1), object(12)
# memory usage: 280.0+ KB

# %%
df_amo_for_write.to_csv('r_certs_to_import_archieve_prefix' + date_int +'.csv')
