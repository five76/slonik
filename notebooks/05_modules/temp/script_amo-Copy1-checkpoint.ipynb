# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import re

# %% [markdown]
# ## Чтение данных

# %%
df_amo= pd.read_csv('amocrm_sample_export.csv', encoding='utf-8')

# %%
df_values= pd.read_csv('list_of_values.csv', encoding='utf-8')

# %%
df_sample= pd.read_csv('certificates_list_sample.csv', encoding='utf-8')

# %%
#Вывод таблицы во всю ширину
pd.set_option('display.max_columns', None)
df_amo.head(5)
# Out:
#          ID          Этап сделки  Бюджет  Дата создания сделки  \
# 0  26165303  Успешно реализовано     5500  30.11.2023 17:43:20
# 1  26163311  Успешно реализовано     8000  30.11.2023 14:58:27
# 2  26162989  Успешно реализовано     5450  30.11.2023 14:33:51
# 3  26160427  Успешно реализовано    34567  30.11.2023 11:37:23
# 4  26158865  Успешно реализовано     9000  30.11.2023 09:39:04
#
#          Дата закрытия  DELIVERY_PRICE  Стоимость доставки  \
# 0  30.11.2023 18:00:00             0.0                 NaN
# 1  01.12.2023 15:09:00             NaN                 NaN
# 2  01.12.2023 15:20:00           450.0                 NaN
# 3  02.12.2023 16:01:00             NaN                 NaN
# 4  30.11.2023 09:47:00             NaN                 NaN
#
#                                             PRODUCTS    PRICE  SUBTOTAL  \
# 0  катание на картинге (Варианты: 40 минут катани...   5500.0    5500.0
# 1  Мотокросс и Эндуро (Варианты: Персональная тре...   8000.0    8000.0
# 2  Стрельба из боевого оружия (Варианты: Курс «на...   5450.0    5000.0
# 3  Универсальный 23456 (Варианты: 34 567 руб., Бу...  34567.0   34567.0
# 4  Аэротруба (Варианты: 10 минут полёта (для 1-2 ...   9000.0    9000.0
#
#   Выручка от клиента    Направление (вид сертификата) Номер сертификата  \
# 0               5500                          Картинг      VKA4_4314611
# 1               8000                   Мото Мотокросс         MT 273176
# 2               5450  Тир. Стрельба из боевого оружия         GU2 21041
# 3              34567         Универс. 23.456 и 34.567       WTF3 269703
# 4               9000                        Аэротруба     VAT10 4353286
#
#   КОРНЕВАЯ СДЕЛКА Номер 2-го сертификата Сертификат на фотографа  \
# 0             NaN                    NaN                     NaN
# 1             NaN                    NaN                     NaN
# 2             NaN                    NaN                     NaN
# 3             NaN                    NaN                     NaN
# 4             NaN                    NaN                     NaN
#
#   Сертификат на тренера Статус погашения Дата оплаты подрядчику
# 0                   NaN              NaN                    NaN
# 1                   NaN              NaN                    NaN
# 2                   NaN              NaN                    NaN
# 3                   NaN              NaN                    NaN
# 4                   NaN              NaN                    NaN

# %%
df_amo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2622 entries, 0 to 2621
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ID                             2622 non-null   int64
#  1   Этап сделки                    2622 non-null   object
#  2   Бюджет                         2622 non-null   int64
#  3   Дата создания сделки           2622 non-null   object
#  4   Дата закрытия                  2622 non-null   object
#  5   DELIVERY_PRICE                 1647 non-null   float64
#  6   Стоимость доставки             9 non-null      float64
#  7   PRODUCTS                       2452 non-null   object
#  8   PRICE                          2452 non-null   float64
#  9   SUBTOTAL                       2452 non-null   float64
#  10  Выручка от клиента             2498 non-null   object
#  11  Направление (вид сертификата)  2622 non-null   object
#  12  Номер сертификата              2622 non-null   object
#  13  КОРНЕВАЯ СДЕЛКА                135 non-null    object
#  14  Номер 2-го сертификата         82 non-null     object
#  15  Сертификат на фотографа        16 non-null     object
#  16  Сертификат на тренера          97 non-null     object
#  17  Статус погашения               1048 non-null   object
#  18  Дата оплаты подрядчику         1052 non-null   object
# dtypes: float64(4), int64(2), object(13)
# memory usage: 389.3+ KB

# %%
df_values.head(10)
# Out:
#    Id        Activity Name                                              Value  \
# 0   1  Вейксёрф и вейкборд  2 часа вейксерфинга или вейкбординга\nна волне...
# 1   2  Вейксёрф и вейкборд  1 час вейксерфинга или вейкбординга\nна волне ...
# 2   3  Вейксёрф и вейкборд  40 минут вейксерфинга или вейкбординга\nна вол...
# 3   4  Вейксёрф и вейкборд  30 минут вейксерфинга или вейкбординга\nна вол...
# 4   5  Вейксёрф и вейкборд  25 минут вейксерфинга или вейкбординга\nна вол...
# 5   6  Вейксёрф и вейкборд  2 часа вейксерфинга или вейкбординга\nна любой...
# 6   7  Вейксёрф и вейкборд  1 час вейксерфинга или вейкбординга на любой в...
# 7   8  Вейксёрф и вейкборд  40 минут вейксерфинга или вейкбординга на любо...
# 8   9  Вейксёрф и вейкборд  25 минут вейксерфинга или вейкбординга на любо...
# 9  10            Флайборд                          1 час полёта на флайборде
#
#    Status Prefix  Purchase Price  Sale Price
# 0  on_air    WS2             NaN     22500.0
# 1  on_air    WS1             NaN     11000.0
# 2  on_air   WS40             NaN      7500.0
# 3  on_air   WS30             NaN      5500.0
# 4  on_air   WS25             NaN      5000.0
# 5  on_air   WSN2             NaN     26500.0
# 6  on_air   WSN1             NaN     13500.0
# 7  on_air  WSN40             NaN      8500.0
# 8  on_air  WSN25             NaN      6000.0
# 9  on_air   MF60             NaN     12500.0

# %%
df_values.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              198 non-null    int64
#  1   Activity Name   198 non-null    object
#  2   Value           196 non-null    object
#  3   Status          198 non-null    object
#  4   Prefix          198 non-null    object
#  5   Purchase Price  167 non-null    float64
#  6   Sale Price      196 non-null    float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 11.0+ KB

# %% [markdown]
# Столбцы в нижний регистр и удаление пробелов

# %%
df_amo.columns = df_amo.columns.str.lower()
df_values.columns = df_values.columns.str.lower()

# %%
df_amo.columns = df_amo.columns.str.strip()
df_values.columns = df_values.columns.str.strip()

# %%
df_amo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2622 entries, 0 to 2621
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             2622 non-null   int64
#  1   этап сделки                    2622 non-null   object
#  2   бюджет                         2622 non-null   int64
#  3   дата создания сделки           2622 non-null   object
#  4   дата закрытия                  2622 non-null   object
#  5   delivery_price                 1647 non-null   float64
#  6   стоимость доставки             9 non-null      float64
#  7   products                       2452 non-null   object
#  8   price                          2452 non-null   float64
#  9   subtotal                       2452 non-null   float64
#  10  выручка от клиента             2498 non-null   object
#  11  направление (вид сертификата)  2622 non-null   object
#  12  номер сертификата              2622 non-null   object
#  13  корневая сделка                135 non-null    object
#  14  номер 2-го сертификата         82 non-null     object
#  15  сертификат на фотографа        16 non-null     object
#  16  сертификат на тренера          97 non-null     object
#  17  статус погашения               1048 non-null   object
#  18  дата оплаты подрядчику         1052 non-null   object
# dtypes: float64(4), int64(2), object(13)
# memory usage: 389.3+ KB

# %% [markdown]
# Удаление пробелов и вставка символа "_"

# %%
df_amo.columns = df_amo.columns.map(lambda x: re.sub( '(?<!^)(?=[ ])', '_', x ).lower())
df_amo.columns = df_amo.columns.map(lambda x: re.sub( ' ', '', x ))

# %%
df_values.columns = df_values.columns.map(lambda x: re.sub( '(?<!^)(?=[ ])', '_', x ).lower())
df_values.columns = df_values.columns.map(lambda x: re.sub( ' ', '', x ))

# %%
df_values.head(5)
# Out:
#    id        activity_name                                              value  \
# 0   1  Вейксёрф и вейкборд  2 часа вейксерфинга или вейкбординга\nна волне...
# 1   2  Вейксёрф и вейкборд  1 час вейксерфинга или вейкбординга\nна волне ...
# 2   3  Вейксёрф и вейкборд  40 минут вейксерфинга или вейкбординга\nна вол...
# 3   4  Вейксёрф и вейкборд  30 минут вейксерфинга или вейкбординга\nна вол...
# 4   5  Вейксёрф и вейкборд  25 минут вейксерфинга или вейкбординга\nна вол...
#
#    status prefix  purchase_price  sale_price
# 0  on_air    WS2             NaN     22500.0
# 1  on_air    WS1             NaN     11000.0
# 2  on_air   WS40             NaN      7500.0
# 3  on_air   WS30             NaN      5500.0
# 4  on_air   WS25             NaN      5000.0

# %%
df_values.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              198 non-null    int64
#  1   activity_name   198 non-null    object
#  2   value           196 non-null    object
#  3   status          198 non-null    object
#  4   prefix          198 non-null    object
#  5   purchase_price  167 non-null    float64
#  6   sale_price      196 non-null    float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 11.0+ KB

# %%
prefix_values = df_values['prefix'].unique()

# %%
prefix_values
# Out:
# array(['WS2', 'WS1', 'WS40', 'WS30', 'WS25', 'WSN2', 'WSN1', 'WSN40',
#        'WSN25', 'MF60', 'MF30', 'MF20', 'HB60', 'HB30', 'HY60', 'HY30',
#        '2WP24', 'WP2H', 'WP60', 'WP15', 'SU24', 'SU60', 'SUT', 'EFL30',
#        'EFL60', 'SKI60', 'SKI40', 'W&F', 'MWS2', 'MWS1', 'MWS40', 'MWS30',
#        'MWS25', 'MWSN2', 'MWSN1', 'MWSN40', 'MWSN25', 'MMF60', 'MMF30',
#        'MMF20', 'MHB60', 'MHY60', 'MHY30', '2MWP24', 'MWP2H', 'MWP60',
#        'MWP15', 'MSU24', 'MSU60', 'MEFL30', 'MEFL60', 'MSKI60', 'MSKI40',
#        'AC2', 'AC60', 'AC30', 'RB60', 'RB40', 'RB30', 'RB20', 'RB15',
#        'CSR60', 'CS60', 'CS40', 'CS30', 'CS20', 'PR60', 'PR40', 'PR30',
#        'PR20', 'RT', 'RTV', 'RC', 'RCV', 'RX', 'RXV', 'DRCH', 'DRC2H',
#        'ED3H', 'EDС', 'AT4', 'AT6', 'AT10', 'AT15', 'AT30', 'AT4K',
#        'AT6K', 'AT60', 'BG', 'BGH', 'BGK', 'BGKH', 'GR1', 'GR2', 'OWG',
#        'OWI', 'OW2', 'CW1', 'CW2', 'CWH', 'CW1T', 'CW2T', 'KA2', 'KA4',
#        'KA6', 'KAT', 'KAT2', 'KAT4', 'LL1H', 'LL1HP', 'LL2H', 'LL2HP',
#        'LL3H', 'KW', 'KW2', 'KS', 'KS2', 'KYT', 'KYT2', 'KV1X1', 'KVP1X1',
#        'KV2X1', 'KVP2X1', 'BF40', 'BF90', 'BF180', 'YEР', 'YHD', 'YAS',
#        'DT30', 'DT32', 'DT40', 'DT42', 'DT60', 'DT62', 'DTM', 'МТ', 'МТТ',
#        'МТ5', 'MT10', 'РB', 'РB2', 'РB2X', 'EB1x', 'EB2x', 'EB4x', 'MB',
#        'MB2', 'MB2X', 'PL15', 'PL20', 'PL30', 'PP', 'PP2', 'PPP', 'PP2P',
#        'PPS', 'PP2S', 'PPT', 'SK', 'SK2', 'SKV', 'SK2V', 'SKT', 'RJ',
#        'RJ2', 'GC1', 'GC2', 'SN1X', 'SN2X', 'SKT1', 'SKT2', 'SKT4',
#        'SKT6', 'SKT10', 'SG5', 'SG10', 'GU', 'GU2', 'MW&F', 'WTF2',
#        'WTF3', 'SH', 'SH2', 'SHH', 'FR', 'FR2,', 'FRT', 'FRK', 'FRTK',
#        'TB', 'TB2', 'TB4', 'ABG', 'AB4G', 'AB', 'AB4'], dtype=object)

# %%
len(prefix_values)
# Out:
# 197

# %% [markdown]
# Все prefix прописные

# %% [markdown]
# Копирование исходной базы

# %%
df_amo_temp = df_amo.copy()

# %% [markdown]
# Переименование столбцов

# %%
df_amo_temp.rename(columns = {'номер_сертификата':'code', 'id':'amo_id','дата_закрытия':'sale_date','дата_оплаты_подрядчику':'card_used_date'}, inplace = True )

# %%
df_values.rename(columns = {'id':'activity_value_id' }, inplace = True )

# %%
df_amo_temp['code'] = df_amo_temp['code'].str.upper()

# %%
df_amo_temp['дата_создания_сделки'] = pd.to_datetime(df_amo_temp['дата_создания_сделки'] )
# Out:
# C:\Users\fiv_e\AppData\Local\Temp\ipykernel_13484\1868446354.py:1: UserWarning: Parsing dates in %d.%m.%Y %H:%M:%S format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_amo_temp['дата_создания_сделки'] = pd.to_datetime(df_amo_temp['дата_создания_сделки'] )

# %%
df_amo_temp['sale_date'] = pd.to_datetime(df_amo_temp['sale_date'])
# Out:
# C:\Users\fiv_e\AppData\Local\Temp\ipykernel_13484\3706027285.py:1: UserWarning: Parsing dates in %d.%m.%Y %H:%M:%S format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_amo_temp['sale_date'] = pd.to_datetime(df_amo_temp['sale_date'])

# %%
df_amo_temp['card_used_date'] = pd.to_datetime(df_amo_temp['card_used_date'],errors='coerce')

# %%
df_amo_temp = df_amo_temp.sort_values(by=["дата_создания_сделки"], ascending=True)

# %%
df_amo_temp = df_amo_temp.reset_index(drop=True)

# %%
df_amo_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2622 entries, 0 to 2621
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   amo_id                         2622 non-null   int64
#  1   этап_сделки                    2622 non-null   object
#  2   бюджет                         2622 non-null   int64
#  3   дата_создания_сделки           2622 non-null   datetime64[ns]
#  4   sale_date                      2622 non-null   datetime64[ns]
#  5   delivery_price                 1647 non-null   float64
#  6   стоимость_доставки             9 non-null      float64
#  7   products                       2452 non-null   object
#  8   price                          2452 non-null   float64
#  9   subtotal                       2452 non-null   float64
#  10  выручка_от_клиента             2498 non-null   object
#  11  направление_(вид_сертификата)  2622 non-null   object
#  12  code                           2622 non-null   object
#  13  корневая_сделка                135 non-null    object
#  14  номер_2-го_сертификата         82 non-null     object
#  15  сертификат_на_фотографа        16 non-null     object
#  16  сертификат_на_тренера          97 non-null     object
#  17  статус_погашения               1048 non-null   object
#  18  card_used_date                 441 non-null    datetime64[ns]
# dtypes: datetime64[ns](3), float64(4), int64(2), object(10)
# memory usage: 389.3+ KB

# %%
df_amo_temp.head()
# Out:
#      amo_id          этап_сделки  бюджет дата_создания_сделки  \
# 0  23400119  Успешно реализовано    5000  2023-01-02 16:00:55
# 1  23400461  Успешно реализовано    4500  2023-01-02 18:01:25
# 2  23400807  Успешно реализовано    9000  2023-01-02 20:48:09
# 3  23401947  Успешно реализовано   12345  2023-01-03 11:35:11
# 4  23403789  Успешно реализовано    5000  2023-01-03 21:56:43
#
#             sale_date  delivery_price  стоимость_доставки  \
# 0 2023-01-02 16:08:00             0.0                 NaN
# 1 2023-01-02 18:10:00             NaN                 NaN
# 2 2023-01-03 10:18:00             0.0                 NaN
# 3 2023-01-03 12:19:00             0.0                 NaN
# 4 2023-01-04 15:19:00             NaN                 NaN
#
#                                             products    price  subtotal  \
# 0  Снегоходы (Варианты: 1 снежик на 1 час, Бумажн...   5000.0    5000.0
# 1  Полет на параплане (Варианты: 1 полет с инстру...   4500.0    4500.0
# 2  Снегоходы (Варианты: 2 снежика на 1 час, Бумаж...   9000.0    9000.0
# 3  Подарочный сертификат на 12 345 рублей - 1x123...  12345.0   12345.0
# 4  Квадроциклы (Варианты: 2 квадрика на 1 час без...   9000.0    9000.0
#
#   выручка_от_клиента направление_(вид_сертификата)           code  \
# 0               5000                     Снегоходы  VSN1X 2438352
# 1               4500                      Параплан     P1G 251473
# 2               9000                     Снегоходы  VSN2X 2497270
# 3              12345   Универсальный Мосвейк 12345   VW&F_2421026
# 4               5000                   Квадроциклы  KVP1X1 138834
#
#   корневая_сделка номер_2-го_сертификата сертификат_на_фотографа  \
# 0             NaN                    NaN                     NaN
# 1             NaN                    NaN                     NaN
# 2             NaN                    NaN                     NaN
# 3             NaN                    NaN                     NaN
# 4             NaN      VKV2X1_2415531DIZ                     NaN
#
#   сертификат_на_тренера статус_погашения card_used_date
# 0                   NaN          Погашен     2023-06-02
# 1                   NaN              NaN            NaT
# 2                   NaN          Погашен     2023-11-02
# 3                   NaN          Погашен            NaT
# 4                   NaN          Погашен            NaT

# %% [markdown]
# Определение разделителей в поле **code**

# %%
cc = df_amo_temp['code'].unique()

# %%
set_cc = set()

# %%
for el in cc:
    set_cc.update(el)

# %%
print(set_cc)
# Out:
# {'V', '4', ')', 'P', '&', 'А', '_', 'D', 'Y', 'М', 'W', 'И', 'K', 'N', 'C', 'B', 'Т', '8', 'U', '5', '7', 'M', '3', '(', 'E', 'I', '\xa0', '1', 'В', '9', '0', 'G', 'H', 'Н', 'S', 'F', 'Р', 'R', ' ', 'A', 'X', 'T', 'L', 'J', 'С', '6', 'К', '2'}

# %% [markdown]
# В качестве разделителей используются символы ' ', '_', '\xa0' и их комбинации

# %% [markdown]
# В значениях поля code имеются символы кириллицы

# %% [markdown]
# Замена кириллицы на латинские символы

# %%
alf_ciril = 'Е Т О Р А Н К Х С В М'.split()
alf_latin = 'E T O P A H K X C B M'.split()

# %%
alf_ciril
# Out:
# ['Е', 'Т', 'О', 'Р', 'А', 'Н', 'К', 'Х', 'С', 'В', 'М']

# %%
def replace_cirillic_latin(row):
    v = row['code']
    new_v = ''
    for i in range(len(v)):
        simv = v[i]
        if simv in alf_ciril:
            pos = alf_ciril.index(simv)
            simv = alf_latin[pos]
        new_v += simv
    return new_v

# %%
df_amo_temp['code'] = df_amo_temp.apply(replace_cirillic_latin,axis=1)

# %% [markdown]
# Замена всех возможных разделителей на '_'

# %%
#df_amo_temp['code'] = df_amo_temp['code'].str.replace('[^_ \xa0]+([ _\xa0]+)\d+','_',regex=True)
df_amo_temp.replace(r'([ _\xa0]+)',r'_',regex=True,inplace=True)

# %%
df_amo_temp.head()
# Out:
#      amo_id          этап_сделки  бюджет дата_создания_сделки  \
# 0  23400119  Успешно_реализовано    5000  2023-01-02 16:00:55
# 1  23400461  Успешно_реализовано    4500  2023-01-02 18:01:25
# 2  23400807  Успешно_реализовано    9000  2023-01-02 20:48:09
# 3  23401947  Успешно_реализовано   12345  2023-01-03 11:35:11
# 4  23403789  Успешно_реализовано    5000  2023-01-03 21:56:43
#
#             sale_date  delivery_price  стоимость_доставки  \
# 0 2023-01-02 16:08:00             0.0                 NaN
# 1 2023-01-02 18:10:00             NaN                 NaN
# 2 2023-01-03 10:18:00             0.0                 NaN
# 3 2023-01-03 12:19:00             0.0                 NaN
# 4 2023-01-04 15:19:00             NaN                 NaN
#
#                                             products    price  subtotal  \
# 0  Снегоходы_(Варианты:_1_снежик_на_1_час,_Бумажн...   5000.0    5000.0
# 1  Полет_на_параплане_(Варианты:_1_полет_с_инстру...   4500.0    4500.0
# 2  Снегоходы_(Варианты:_2_снежика_на_1_час,_Бумаж...   9000.0    9000.0
# 3  Подарочный_сертификат_на_12_345_рублей_-_1x123...  12345.0   12345.0
# 4  Квадроциклы_(Варианты:_2_квадрика_на_1_час_без...   9000.0    9000.0
#
#   выручка_от_клиента направление_(вид_сертификата)           code  \
# 0               5000                     Снегоходы  VSN1X_2438352
# 1               4500                      Параплан     P1G_251473
# 2               9000                     Снегоходы  VSN2X_2497270
# 3              12345   Универсальный_Мосвейк_12345   VW&F_2421026
# 4               5000                   Квадроциклы  KVP1X1_138834
#
#   корневая_сделка номер_2-го_сертификата сертификат_на_фотографа  \
# 0             NaN                    NaN                     NaN
# 1             NaN                    NaN                     NaN
# 2             NaN                    NaN                     NaN
# 3             NaN                    NaN                     NaN
# 4             NaN      VKV2X1_2415531DIZ                     NaN
#
#   сертификат_на_тренера статус_погашения card_used_date
# 0                   NaN          Погашен     2023-06-02
# 1                   NaN              NaN            NaT
# 2                   NaN          Погашен     2023-11-02
# 3                   NaN          Погашен            NaT
# 4                   NaN          Погашен            NaT

# %% [markdown]
# Формирование новых столбцов в базе АМО

# %%
df_amo_temp['id'] = ''

# %%
df_amo_temp['prefix'] = df_amo_temp['code'].apply(lambda x: re.split('[ _]',x)[0] if ' ' in x or '_' in x else '')

# %%
df_amo_temp['number'] = df_amo_temp['code'].apply(lambda x: re.split('[ _]',x)[1] if ' ' in x or '_' in x else '')

# %%
df_amo_temp.head(10)
# Out:
#      amo_id          этап_сделки  бюджет дата_создания_сделки  \
# 0  23400119  Успешно_реализовано    5000  2023-01-02 16:00:55
# 1  23400461  Успешно_реализовано    4500  2023-01-02 18:01:25
# 2  23400807  Успешно_реализовано    9000  2023-01-02 20:48:09
# 3  23401947  Успешно_реализовано   12345  2023-01-03 11:35:11
# 4  23403789  Успешно_реализовано    5000  2023-01-03 21:56:43
# 5  23408953  Успешно_реализовано   27000  2023-01-05 10:02:22
# 6  23409993  Успешно_реализовано    3500  2023-01-05 13:43:49
# 7  23409837  Успешно_реализовано    7000  2023-01-05 13:57:46
# 8  23410089  Успешно_реализовано   15500  2023-01-05 14:17:46
# 9  23411393  Успешно_реализовано    8300  2023-01-05 19:46:14
#
#             sale_date  delivery_price  стоимость_доставки  \
# 0 2023-01-02 16:08:00             0.0                 NaN
# 1 2023-01-02 18:10:00             NaN                 NaN
# 2 2023-01-03 10:18:00             0.0                 NaN
# 3 2023-01-03 12:19:00             0.0                 NaN
# 4 2023-01-04 15:19:00             NaN                 NaN
# 5 2023-01-05 11:31:00             NaN                 NaN
# 6 2023-01-06 08:06:00             NaN                 NaN
# 7 2023-01-05 14:41:00             NaN                 NaN
# 8 2023-01-12 13:33:00           500.0                 NaN
# 9 2023-01-15 17:28:00           500.0                 NaN
#
#                                             products    price  subtotal  \
# 0  Снегоходы_(Варианты:_1_снежик_на_1_час,_Бумажн...   5000.0    5000.0
# 1  Полет_на_параплане_(Варианты:_1_полет_с_инстру...   4500.0    4500.0
# 2  Снегоходы_(Варианты:_2_снежика_на_1_час,_Бумаж...   9000.0    9000.0
# 3  Подарочный_сертификат_на_12_345_рублей_-_1x123...  12345.0   12345.0
# 4  Квадроциклы_(Варианты:_2_квадрика_на_1_час_без...   9000.0    9000.0
# 5  Заезд_на_спорткаре_по_гоночной_трассе_(Вариант...  27000.0   27000.0
# 6  Вейк_в_бассейне_(Варианты:_Start_Up,_Бумажный_...   3500.0    3500.0
# 7  Зимний_кайтинг_(Варианты:_2_часа_для_одного,_Б...   7000.0    7000.0
# 8  Вертолет_Robinson_R44_(Варианты:_20_минут_полё...  15500.0   15000.0
# 9  Аэротруба_(Варианты:_4_минуты_полёта_(для_1_че...   8300.0    7800.0
#
#   выручка_от_клиента направление_(вид_сертификата)           code  \
# 0               5000                     Снегоходы  VSN1X_2438352
# 1               4500                      Параплан     P1G_251473
# 2               9000                     Снегоходы  VSN2X_2497270
# 3              12345   Универсальный_Мосвейк_12345   VW&F_2421026
# 4               5000                   Квадроциклы  KVP1X1_138834
# 5              27000       Авто_Заезд_на_спорткаре   VRCV_2477875
# 6               3500              Вейк-парк_крытый   VGR1_2480017
# 7               7000                   Сноукайтинг  VSKT1_2426359
# 8              15500                 Авиа_Вертолет    RB20_155687
# 9               8300                     Аэротруба     AT4_127813
#
#   корневая_сделка номер_2-го_сертификата сертификат_на_фотографа  \
# 0             NaN                    NaN                     NaN
# 1             NaN                    NaN                     NaN
# 2             NaN                    NaN                     NaN
# 3             NaN                    NaN                     NaN
# 4             NaN      VKV2X1_2415531DIZ                     NaN
# 5             NaN                    NaN                     NaN
# 6             NaN                    NaN                     NaN
# 7             NaN                    NaN                     NaN
# 8             NaN                    NaN                     NaN
# 9             NaN                    NaN                     NaN
#
#   сертификат_на_тренера статус_погашения card_used_date id  prefix   number
# 0                   NaN          Погашен     2023-06-02      VSN1X  2438352
# 1                   NaN              NaN            NaT        P1G   251473
# 2                   NaN          Погашен     2023-11-02      VSN2X  2497270
# 3                   NaN          Погашен            NaT       VW&F  2421026
# 4                   NaN          Погашен            NaT     KVP1X1   138834
# 5                   NaN              NaN            NaT       VRCV  2477875
# 6                   NaN              NaN            NaT       VGR1  2480017
# 7                   NaN              NaN            NaT      VSKT1  2426359
# 8                   NaN          Погашен     2023-03-07       RB20   155687
# 9                   NaN          Погашен     2023-08-10        AT4   127813

# %%
prefix_amo = list(df_amo_temp['prefix'].unique())
prefix_amo.sort()
prefix_amo = prefix_amo[1:]

# %%
print(prefix_amo)
# Out:
# ['AC60', 'AT10', 'AT15', 'AT4', 'AT4K', 'AT6', 'AT6K', 'BF180', 'BF40', 'BF90', 'BG', 'BGH', 'CS20', 'CS30', 'CS40', 'CS60', 'CW1', 'CW2', 'DRC2H', 'DT230', 'DT240', 'DT30', 'DT40', 'DT60', 'EB1X', 'EB2X', 'ED3H', 'EDC', 'EF30', 'EFL30', 'EFL60', 'ES130', 'F1', 'GC1', 'GC2', 'GR1', 'GR1X1', 'GR2', 'GU', 'GU2', 'HB20', 'HB30', 'KA2', 'KA4', 'KA6', 'KAT', 'KAT2', 'KR2', 'KR4', 'KS', 'KS2', 'KV1X1', 'KV2X1', 'KVP1X1', 'KVP2X1', 'LL1H', 'LL2H', 'MF', 'MF20', 'MF30', 'MF60', 'MT', 'MT2', 'MT5', 'MTT', 'P1', 'P1G', 'P1P', 'P2', 'P2G', 'PB', 'PB2', 'PB2X', 'PPP', 'PR20', 'PR30', 'PR40', 'PR60', 'PS', 'RB15', 'RB20', 'RB30', 'RC', 'RCV', 'RJ', 'RJ2', 'RTV', 'RXV', 'S', 'S2', 'SC', 'SC7', 'SG7', 'SH', 'SH2', 'SHH', 'SKI40', 'SKIN60', 'SKT1', 'SKT2', 'SKV', 'SN1X', 'SN1X1', 'SN2X', 'SN2X1', 'SP', 'SP2', 'ST', 'SU24', 'SU60', 'UN', 'VAC30', 'VAC60', 'VAT10', 'VAT15', 'VAT30', 'VAT4', 'VAT4K', 'VAT6', 'VAT6K', 'VBF180', 'VBF40', 'VBF90', 'VBG', 'VBGH', 'VBGK', 'VBGKH', 'VCS20', 'VCS30', 'VCS40', 'VCS60', 'VCW1', 'VCW1T', 'VCW2', 'VCW2T', 'VDRC2H', 'VDT30', 'VDT40', 'VDT60', 'VDT62', 'VDTM', 'VEB1X', 'VEB2X', 'VED3H', 'VEF30', 'VEF60', 'VEFL', 'VEFL30', 'VFR', 'VFR2', 'VGC1', 'VGC2', 'VGR1', 'VGR2', 'VGU', 'VGU2', 'VHB20', 'VHB30', 'VHY30', 'VHY30T', 'VHY60', 'VHY60T30', 'VKA2', 'VKA4', 'VKA6', 'VKAT', 'VKAT2', 'VKAT4', 'VKV1X', 'VKV1X1', 'VKV2X1', 'VKVP1X', 'VKVP1X1', 'VKVP2X1', 'VLB1X', 'VLL1H', 'VLL2H', 'VLL3H', 'VMB', 'VMB2', 'VMB2X', 'VMF20', 'VMF30', 'VMF60', 'VMT', 'VMT2', 'VMT5', 'VMTT', 'VPB', 'VPP', 'VPP2', 'VPP2P', 'VPPP', 'VPPS', 'VPR20', 'VPR30', 'VPR60', 'VRC', 'VRCV', 'VRJ', 'VRJ1X', 'VRJ2', 'VRJ2X', 'VRTV', 'VS', 'VS2', 'VSC10', 'VSC7', 'VSG7', 'VSH', 'VSH2', 'VSK', 'VSK2', 'VSK2V', 'VSKI40', 'VSKI60', 'VSKT', 'VSKT1', 'VSKV', 'VSN1X', 'VSN2X', 'VSN2X1', 'VSP', 'VSP2', 'VST', 'VSU24', 'VSU60', 'VSUT', 'VSVH', 'VUN', 'VW&F', 'VWF', 'VWP15', 'VWP60', 'VWPA', 'VWS20', 'VWS20T', 'VWS30', 'VWS30T', 'VWS40', 'VWS40T', 'VWS60', 'VWS60T', 'VWSN40', 'VWSN40T', 'VWSN60', 'VWSN60T', 'VWTF', 'VWTF2', 'VYAS', 'VYEP', 'W&F', 'WF', 'WP15', 'WP2H', 'WP60', 'WS20', 'WS30', 'WS30T', 'WS40', 'WS60', 'WSN40', 'WSN60', 'WTF2', 'WTF3', 'WVS30', 'YEP']

# %% [markdown]
# Некоторые значения в code без разделителей, потому не выделились prefix и number

# %% [markdown]
# Отделение prefix от number

# %%
def separate_prefix_number(row):
    pl = prefix_amo
    v = row['code']
    if row['prefix'] == '':
        amo_id = row['amo_id']
        
        for el in pl:
            if el in row['code']:
                try:
                    v = el + '_' + row['code'][len(el):] 
                except:
                    pass
                finally:
                    return v
    return v

# %%
df_amo_temp['code'] = df_amo_temp.apply(separate_prefix_number,axis=1)

# %%
df_amo_temp.head(5)
# Out:
#      amo_id          этап_сделки  бюджет дата_создания_сделки  \
# 0  23400119  Успешно_реализовано    5000  2023-01-02 16:00:55
# 1  23400461  Успешно_реализовано    4500  2023-01-02 18:01:25
# 2  23400807  Успешно_реализовано    9000  2023-01-02 20:48:09
# 3  23401947  Успешно_реализовано   12345  2023-01-03 11:35:11
# 4  23403789  Успешно_реализовано    5000  2023-01-03 21:56:43
#
#             sale_date  delivery_price  стоимость_доставки  \
# 0 2023-01-02 16:08:00             0.0                 NaN
# 1 2023-01-02 18:10:00             NaN                 NaN
# 2 2023-01-03 10:18:00             0.0                 NaN
# 3 2023-01-03 12:19:00             0.0                 NaN
# 4 2023-01-04 15:19:00             NaN                 NaN
#
#                                             products    price  subtotal  \
# 0  Снегоходы_(Варианты:_1_снежик_на_1_час,_Бумажн...   5000.0    5000.0
# 1  Полет_на_параплане_(Варианты:_1_полет_с_инстру...   4500.0    4500.0
# 2  Снегоходы_(Варианты:_2_снежика_на_1_час,_Бумаж...   9000.0    9000.0
# 3  Подарочный_сертификат_на_12_345_рублей_-_1x123...  12345.0   12345.0
# 4  Квадроциклы_(Варианты:_2_квадрика_на_1_час_без...   9000.0    9000.0
#
#   выручка_от_клиента направление_(вид_сертификата)           code  \
# 0               5000                     Снегоходы  VSN1X_2438352
# 1               4500                      Параплан     P1G_251473
# 2               9000                     Снегоходы  VSN2X_2497270
# 3              12345   Универсальный_Мосвейк_12345   VW&F_2421026
# 4               5000                   Квадроциклы  KVP1X1_138834
#
#   корневая_сделка номер_2-го_сертификата сертификат_на_фотографа  \
# 0             NaN                    NaN                     NaN
# 1             NaN                    NaN                     NaN
# 2             NaN                    NaN                     NaN
# 3             NaN                    NaN                     NaN
# 4             NaN      VKV2X1_2415531DIZ                     NaN
#
#   сертификат_на_тренера статус_погашения card_used_date id  prefix   number
# 0                   NaN          Погашен     2023-06-02      VSN1X  2438352
# 1                   NaN              NaN            NaT        P1G   251473
# 2                   NaN          Погашен     2023-11-02      VSN2X  2497270
# 3                   NaN          Погашен            NaT       VW&F  2421026
# 4                   NaN          Погашен            NaT     KVP1X1   138834

# %%
df_amo_temp.loc[df_amo_temp['prefix'] == '','prefix'] = \
df_amo_temp['code'].apply(lambda x: re.split('[_]',x)[0] if ' ' in x or '_' in x else '')

# %%
df_amo_temp.loc[df_amo_temp['number'] == '','number'] = \
df_amo_temp['code'].apply(lambda x: re.split('[_]',x)[1] if ' ' in x or '_' in x else '')

# %%
df_amo_temp.head(5)
# Out:
#      amo_id          этап_сделки  бюджет дата_создания_сделки  \
# 0  23400119  Успешно_реализовано    5000  2023-01-02 16:00:55
# 1  23400461  Успешно_реализовано    4500  2023-01-02 18:01:25
# 2  23400807  Успешно_реализовано    9000  2023-01-02 20:48:09
# 3  23401947  Успешно_реализовано   12345  2023-01-03 11:35:11
# 4  23403789  Успешно_реализовано    5000  2023-01-03 21:56:43
#
#             sale_date  delivery_price  стоимость_доставки  \
# 0 2023-01-02 16:08:00             0.0                 NaN
# 1 2023-01-02 18:10:00             NaN                 NaN
# 2 2023-01-03 10:18:00             0.0                 NaN
# 3 2023-01-03 12:19:00             0.0                 NaN
# 4 2023-01-04 15:19:00             NaN                 NaN
#
#                                             products    price  subtotal  \
# 0  Снегоходы_(Варианты:_1_снежик_на_1_час,_Бумажн...   5000.0    5000.0
# 1  Полет_на_параплане_(Варианты:_1_полет_с_инстру...   4500.0    4500.0
# 2  Снегоходы_(Варианты:_2_снежика_на_1_час,_Бумаж...   9000.0    9000.0
# 3  Подарочный_сертификат_на_12_345_рублей_-_1x123...  12345.0   12345.0
# 4  Квадроциклы_(Варианты:_2_квадрика_на_1_час_без...   9000.0    9000.0
#
#   выручка_от_клиента направление_(вид_сертификата)           code  \
# 0               5000                     Снегоходы  VSN1X_2438352
# 1               4500                      Параплан     P1G_251473
# 2               9000                     Снегоходы  VSN2X_2497270
# 3              12345   Универсальный_Мосвейк_12345   VW&F_2421026
# 4               5000                   Квадроциклы  KVP1X1_138834
#
#   корневая_сделка номер_2-го_сертификата сертификат_на_фотографа  \
# 0             NaN                    NaN                     NaN
# 1             NaN                    NaN                     NaN
# 2             NaN                    NaN                     NaN
# 3             NaN                    NaN                     NaN
# 4             NaN      VKV2X1_2415531DIZ                     NaN
#
#   сертификат_на_тренера статус_погашения card_used_date id  prefix   number
# 0                   NaN          Погашен     2023-06-02      VSN1X  2438352
# 1                   NaN              NaN            NaT        P1G   251473
# 2                   NaN          Погашен     2023-11-02      VSN2X  2497270
# 3                   NaN          Погашен            NaT       VW&F  2421026
# 4                   NaN          Погашен            NaT     KVP1X1   138834

# %%
#df_amo_temp = df_amo_temp.loc[df_amo_temp['prefix'] != '']

# %%
df_amo_temp['card_type'] ='paper'

# %%
df_amo_temp['series'] =''

# %%
df_amo_temp['design_type'] = 'design1'

# %%
df_amo_temp['status'] = ''

# %%
df_amo_temp['stock_status'] = ''

# %%
df_amo_temp['sale_price'] = 0

# %%
df_amo_temp['expiry_date'] = ''

# %%
df_amo_temp['created_at'] = ''

# %%
df_amo_temp['updated_at'] = ''

# %%
df_amo_temp['deleted_at'] = ''

# %%
df_amo_temp.loc[(df_amo_temp['card_used_date'].notna()) |  (df_amo_temp['статус_погашения'] == 'Погашен'),'status'] = 'sold_used'

# %%
df_amo_temp.query('status=="sold_used"').head()
# Out:
#      amo_id          этап_сделки  бюджет дата_создания_сделки  \
# 0  23400119  Успешно_реализовано    5000  2023-01-02 16:00:55
# 2  23400807  Успешно_реализовано    9000  2023-01-02 20:48:09
# 3  23401947  Успешно_реализовано   12345  2023-01-03 11:35:11
# 4  23403789  Успешно_реализовано    5000  2023-01-03 21:56:43
# 8  23410089  Успешно_реализовано   15500  2023-01-05 14:17:46
#
#             sale_date  delivery_price  стоимость_доставки  \
# 0 2023-01-02 16:08:00             0.0                 NaN
# 2 2023-01-03 10:18:00             0.0                 NaN
# 3 2023-01-03 12:19:00             0.0                 NaN
# 4 2023-01-04 15:19:00             NaN                 NaN
# 8 2023-01-12 13:33:00           500.0                 NaN
#
#                                             products    price  subtotal  \
# 0  Снегоходы_(Варианты:_1_снежик_на_1_час,_Бумажн...   5000.0    5000.0
# 2  Снегоходы_(Варианты:_2_снежика_на_1_час,_Бумаж...   9000.0    9000.0
# 3  Подарочный_сертификат_на_12_345_рублей_-_1x123...  12345.0   12345.0
# 4  Квадроциклы_(Варианты:_2_квадрика_на_1_час_без...   9000.0    9000.0
# 8  Вертолет_Robinson_R44_(Варианты:_20_минут_полё...  15500.0   15000.0
#
#   выручка_от_клиента направление_(вид_сертификата)           code  \
# 0               5000                     Снегоходы  VSN1X_2438352
# 2               9000                     Снегоходы  VSN2X_2497270
# 3              12345   Универсальный_Мосвейк_12345   VW&F_2421026
# 4               5000                   Квадроциклы  KVP1X1_138834
# 8              15500                 Авиа_Вертолет    RB20_155687
#
#   корневая_сделка номер_2-го_сертификата сертификат_на_фотографа  \
# 0             NaN                    NaN                     NaN
# 2             NaN                    NaN                     NaN
# 3             NaN                    NaN                     NaN
# 4             NaN      VKV2X1_2415531DIZ                     NaN
# 8             NaN                    NaN                     NaN
#
#   сертификат_на_тренера статус_погашения card_used_date id  prefix   number  \
# 0                   NaN          Погашен     2023-06-02      VSN1X  2438352
# 2                   NaN          Погашен     2023-11-02      VSN2X  2497270
# 3                   NaN          Погашен            NaT       VW&F  2421026
# 4                   NaN          Погашен            NaT     KVP1X1   138834
# 8                   NaN          Погашен     2023-03-07       RB20   155687
#
#   card_type series design_type     status stock_status  sale_price  \
# 0     paper            design1  sold_used                        0
# 2     paper            design1  sold_used                        0
# 3     paper            design1  sold_used                        0
# 4     paper            design1  sold_used                        0
# 8     paper            design1  sold_used                        0
#
#   expiry_date created_at updated_at deleted_at
# 0
# 2
# 3
# 4
# 8

# %% [markdown]
# Обработка **sale_price**

# %%
df_amo_temp['номер_2-го_сертификата'].notna().sum()
# Out:
# 82

# %%
df_amo_temp['сертификат_на_тренера'].notna().sum()
# Out:
# 97

# %%
df_amo_temp['сертификат_на_фотографа'].notna().sum()
# Out:
# 16

# %% [markdown]
# Если в сделке 1 товар и сделка не имеет производных сделок, то использовать значение поля SUBTOTAL

# %%
df_amo_temp.loc[(df_amo_temp['номер_2-го_сертификата'].isna()) & \
                (df_amo_temp['сертификат_на_тренера'].isna()) &\
                (df_amo_temp['сертификат_на_фотографа'].isna()) &\
                (df_amo_temp['корневая_сделка'].isna()),\
                'sale_price'] = df_amo_temp['subtotal']

# %%
df_amo_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2622 entries, 0 to 2621
# Data columns (total 32 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   amo_id                         2622 non-null   int64
#  1   этап_сделки                    2622 non-null   object
#  2   бюджет                         2622 non-null   int64
#  3   дата_создания_сделки           2622 non-null   datetime64[ns]
#  4   sale_date                      2622 non-null   datetime64[ns]
#  5   delivery_price                 1647 non-null   float64
#  6   стоимость_доставки             9 non-null      float64
#  7   products                       2452 non-null   object
#  8   price                          2452 non-null   float64
#  9   subtotal                       2452 non-null   float64
#  10  выручка_от_клиента             2498 non-null   object
#  11  направление_(вид_сертификата)  2622 non-null   object
#  12  code                           2622 non-null   object
#  13  корневая_сделка                135 non-null    object
#  14  номер_2-го_сертификата         82 non-null     object
#  15  сертификат_на_фотографа        16 non-null     object
#  16  сертификат_на_тренера          97 non-null     object
#  17  статус_погашения               1048 non-null   object
#  18  card_used_date                 441 non-null    datetime64[ns]
#  19  id                             2622 non-null   object
#  20  prefix                         2622 non-null   object
#  21  number                         2622 non-null   object
#  22  card_type                      2622 non-null   object
#  23  series                         2622 non-null   object
#  24  design_type                    2622 non-null   object
#  25  status                         2622 non-null   object
#  26  stock_status                   2622 non-null   object
#  27  sale_price                     2585 non-null   float64
#  28  expiry_date                    2622 non-null   object
#  29  created_at                     2622 non-null   object
#  30  updated_at                     2622 non-null   object
#  31  deleted_at                     2622 non-null   object
# dtypes: datetime64[ns](3), float64(5), int64(2), object(22)
# memory usage: 655.6+ KB

# %%
df_amo_temp.head()
# Out:
#      amo_id          этап_сделки  бюджет дата_создания_сделки  \
# 0  23400119  Успешно_реализовано    5000  2023-01-02 16:00:55
# 1  23400461  Успешно_реализовано    4500  2023-01-02 18:01:25
# 2  23400807  Успешно_реализовано    9000  2023-01-02 20:48:09
# 3  23401947  Успешно_реализовано   12345  2023-01-03 11:35:11
# 4  23403789  Успешно_реализовано    5000  2023-01-03 21:56:43
#
#             sale_date  delivery_price  стоимость_доставки  \
# 0 2023-01-02 16:08:00             0.0                 NaN
# 1 2023-01-02 18:10:00             NaN                 NaN
# 2 2023-01-03 10:18:00             0.0                 NaN
# 3 2023-01-03 12:19:00             0.0                 NaN
# 4 2023-01-04 15:19:00             NaN                 NaN
#
#                                             products    price  subtotal  \
# 0  Снегоходы_(Варианты:_1_снежик_на_1_час,_Бумажн...   5000.0    5000.0
# 1  Полет_на_параплане_(Варианты:_1_полет_с_инстру...   4500.0    4500.0
# 2  Снегоходы_(Варианты:_2_снежика_на_1_час,_Бумаж...   9000.0    9000.0
# 3  Подарочный_сертификат_на_12_345_рублей_-_1x123...  12345.0   12345.0
# 4  Квадроциклы_(Варианты:_2_квадрика_на_1_час_без...   9000.0    9000.0
#
#   выручка_от_клиента направление_(вид_сертификата)           code  \
# 0               5000                     Снегоходы  VSN1X_2438352
# 1               4500                      Параплан     P1G_251473
# 2               9000                     Снегоходы  VSN2X_2497270
# 3              12345   Универсальный_Мосвейк_12345   VW&F_2421026
# 4               5000                   Квадроциклы  KVP1X1_138834
#
#   корневая_сделка номер_2-го_сертификата сертификат_на_фотографа  \
# 0             NaN                    NaN                     NaN
# 1             NaN                    NaN                     NaN
# 2             NaN                    NaN                     NaN
# 3             NaN                    NaN                     NaN
# 4             NaN      VKV2X1_2415531DIZ                     NaN
#
#   сертификат_на_тренера статус_погашения card_used_date id  prefix   number  \
# 0                   NaN          Погашен     2023-06-02      VSN1X  2438352
# 1                   NaN              NaN            NaT        P1G   251473
# 2                   NaN          Погашен     2023-11-02      VSN2X  2497270
# 3                   NaN          Погашен            NaT       VW&F  2421026
# 4                   NaN          Погашен            NaT     KVP1X1   138834
#
#   card_type series design_type     status stock_status  sale_price  \
# 0     paper            design1  sold_used                   5000.0
# 1     paper            design1                              4500.0
# 2     paper            design1  sold_used                   9000.0
# 3     paper            design1  sold_used                  12345.0
# 4     paper            design1  sold_used                      0.0
#
#   expiry_date created_at updated_at deleted_at
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# Обработка поля **status**

# %%
df_amo_temp.loc[(df_amo_temp['card_used_date'].notna()) |  \
                (df_amo_temp['статус_погашения'] == 'Погашен'),'status'] = 'sold_used'

# %% [markdown]
# База АМО без prefix

# %%
df_amo_without_prefix = df_amo_temp.loc[df_amo_temp['prefix'] == '']

# %%
df_amo_without_prefix.shape
# Out:
# (7, 32)

# %% [markdown]
# Для дальнейшей работы потребуется наличие prefix

# %%
df_amo_without_prefix.head(10)
# Out:
#         amo_id          этап_сделки  бюджет дата_создания_сделки  \
# 20    23443225  Успешно_реализовано       0  2023-01-10 18:29:34
# 29    23456591  Успешно_реализовано   10500  2023-01-12 17:38:01
# 178   23691835  Успешно_реализовано    5000  2023-02-16 20:33:34
# 464   23959571  Успешно_реализовано    5600  2023-03-28 19:29:43
# 565   24084549  Успешно_реализовано    5700  2023-04-15 21:38:45
# 696   24217649  Успешно_реализовано    2000  2023-05-04 13:54:40
# 1644  24816735  Успешно_реализовано       0  2023-07-15 09:04:30
#
#                sale_date  delivery_price  стоимость_доставки  \
# 20   2023-01-10 18:29:00             NaN                 NaN
# 29   2023-01-14 05:22:00           500.0                 NaN
# 178  2023-02-17 23:16:00           350.0                 NaN
# 464  2023-03-28 22:01:00             NaN                 NaN
# 565  2023-05-01 16:47:00           500.0                 NaN
# 696  2023-05-04 14:24:00             0.0                 NaN
# 1644 2023-07-17 12:46:00             NaN                 NaN
#
#                                                products    price  subtotal  \
# 20                                                  NaN      NaN       NaN
# 29    Подарочный_сертификатв_вейк-парк_(Выберите_тип...  10500.0   10000.0
# 178   Полет_на_параплане_(Варианты:_1_полет_с_инстру...   4850.0    4500.0
# 464   Аэротруба_(Варианты:_6_минут_полёта_(для_1-2_ч...   5600.0    5600.0
# 565   катание_на_картинге_(Варианты:_40_минут_катани...   5700.0    5200.0
# 696   Подарочный_сертификатна_сап-сёрфинг_(Выберите_...   2000.0    2000.0
# 1644                                                NaN      NaN       NaN
#
#      выручка_от_клиента направление_(вид_сертификата)      code  \
# 20                  NaN                     Вейк-парк  VWP62133
# 29                10500                     Вейк-парк  2WP89087
# 178                5000                      Параплан     80688
# 464                5600                     Аэротруба  VAT37112
# 565                 NaN                       Картинг     75453
# 696                2000                      САП-сёрф     29510
# 1644                  0                         Багги     19529
#
#      корневая_сделка номер_2-го_сертификата сертификат_на_фотографа  \
# 20               NaN                    NaN                     NaN
# 29               NaN                    NaN                     NaN
# 178              NaN                    NaN                     NaN
# 464              NaN                    NaN                     NaN
# 565              NaN                    NaN                     NaN
# 696              NaN                    NaN                     NaN
# 1644       #24815607              BG_220721                     NaN
#
#      сертификат_на_тренера статус_погашения card_used_date id prefix number  \
# 20                     NaN              NaN            NaT
# 29                     NaN              NaN            NaT
# 178                    NaN              NaN            NaT
# 464                    NaN              NaN            NaT
# 565                    NaN              NaN            NaT
# 696                    NaN              NaN            NaT
# 1644                   NaN              NaN            NaT
#
#      card_type series design_type status stock_status  sale_price expiry_date  \
# 20       paper            design1                             NaN
# 29       paper            design1                         10000.0
# 178      paper            design1                          4500.0
# 464      paper            design1                          5600.0
# 565      paper            design1                          5200.0
# 696      paper            design1                          2000.0
# 1644     paper            design1                             0.0
#
#      created_at updated_at deleted_at
# 20
# 29
# 178
# 464
# 565
# 696
# 1644

# %% [markdown]
# База АМО c prefix

# %%
df_amo_temp = df_amo_temp.loc[df_amo_temp['prefix'] != '']

# %%
df_amo_temp['card_type'] = df_amo_temp['prefix'].apply(lambda x: 'electronic' if x[0] == 'V' else 'paper')

# %%
df_amo_temp.query('amo_id==26139623').head()
# Out:
#         amo_id          этап_сделки  бюджет дата_создания_сделки  \
# 2611  26139623  Успешно_реализовано   11450  2023-11-28 13:06:38
#
#                sale_date  delivery_price  стоимость_доставки  \
# 2611 2023-12-02 22:29:00           450.0                 NaN
#
#                                                products    price  subtotal  \
# 2611  Снегоходы_(Варианты:_1_снежик_на_1_час,_Бумажн...  11450.0   11000.0
#
#      выручка_от_клиента направление_(вид_сертификата)         code  \
# 2611              11450                     Снегоходы  SN1X_199622
#
#      корневая_сделка номер_2-го_сертификата сертификат_на_фотографа  \
# 2611             NaN            SN1X_191480                     NaN
#
#      сертификат_на_тренера статус_погашения card_used_date id prefix  number  \
# 2611                   NaN              NaN            NaT      SN1X  199622
#
#      card_type series design_type status stock_status  sale_price expiry_date  \
# 2611     paper            design1                             0.0
#
#      created_at updated_at deleted_at
# 2611

# %%
df_amo_temp.query('корневая_сделка.notna()')
# Out:
#         amo_id          этап_сделки  бюджет дата_создания_сделки  \
# 31    23459939  Успешно_реализовано       0  2023-01-13 11:41:15
# 38    23466787  Успешно_реализовано       0  2023-01-14 18:11:28
# 103   23588587  Успешно_реализовано       0  2023-01-31 14:39:58
# 104   23590237  Успешно_реализовано    8000  2023-01-31 18:10:26
# 126   23627015  Успешно_реализовано       0  2023-02-06 16:32:58
# ...        ...                  ...     ...                  ...
# 2505  25885815  Успешно_реализовано       0  2023-11-03 08:49:52
# 2528  25939051  Успешно_реализовано       0  2023-11-09 16:31:32
# 2552  25988317  Успешно_реализовано       0  2023-11-14 17:20:26
# 2580  26042895  Успешно_реализовано       0  2023-11-19 10:36:50
# 2612  26139797  Успешно_реализовано       0  2023-11-28 13:18:52
#
#                sale_date  delivery_price  стоимость_доставки products  price  \
# 31   2023-01-13 11:42:00             NaN                 NaN      NaN    NaN
# 38   2023-01-18 10:48:00             NaN                 NaN      NaN    NaN
# 103  2023-01-31 14:40:00             NaN                 NaN      NaN    NaN
# 104  2023-02-01 00:35:00             NaN                 NaN      NaN    NaN
# 126  2023-02-07 18:19:00             NaN                 NaN      NaN    NaN
# ...                  ...             ...                 ...      ...    ...
# 2505 2023-11-03 11:00:00             NaN                 NaN      NaN    NaN
# 2528 2023-11-09 16:51:00             NaN                 NaN      NaN    NaN
# 2552 2023-11-14 17:29:00             NaN                 NaN      NaN    NaN
# 2580 2023-11-20 12:51:00             NaN                 NaN      NaN    NaN
# 2612 2023-12-02 22:30:00             NaN                 NaN      NaN    NaN
#
#       subtotal выручка_от_клиента    направление_(вид_сертификата)  \
# 31         NaN                NaN              Искусственная_волна
# 38         NaN                NaN                        Снегоходы
# 103        NaN                NaN                   Мото_Мотокросс
# 104        NaN               8000                       Авто_Дрифт
# 126        NaN                NaN                 Мото_Дрифт-трайк
# ...        ...                ...                              ...
# 2505       NaN                NaN  Тир._Стрельба_из_боевого_оружия
# 2528       NaN                  0                            Багги
# 2552       NaN                  0                          Картинг
# 2580       NaN                NaN                          Картинг
# 2612       NaN                  0                        Снегоходы
#
#                 code корневая_сделка номер_2-го_сертификата  \
# 31     VCW1T_2437849       #23459729                    NaN
# 38       S_N2X226233      1715029001                    NaN
# 103       MT2_159461       #23586703                    NaN
# 104   VDRC2H_2598560       #23514709                    NaN
# 126      DT60_282777       #23624295                    NaN
# ...              ...             ...                    ...
# 2505     VGU_4243962       #25885733                    NaN
# 2528     VBG_4327290       #25938825                    NaN
# 2552    VKAT_4319612       #25988183                    NaN
# 2580      KAT_154768       #26042871                    NaN
# 2612     SN1X_184479       #26139623                    NaN
#
#      сертификат_на_фотографа сертификат_на_тренера статус_погашения  \
# 31                       NaN                   NaN          Погашен
# 38                       NaN                   NaN          Погашен
# 103                      NaN                   NaN          Погашен
# 104                      NaN                   NaN              NaN
# 126                      NaN                   NaN          Погашен
# ...                      ...                   ...              ...
# 2505                     NaN                   NaN              NaN
# 2528                     NaN                   NaN              NaN
# 2552                     NaN                   NaN              NaN
# 2580                     NaN                   NaN              NaN
# 2612                     NaN                   NaN              NaN
#
#      card_used_date id  prefix     number   card_type series design_type  \
# 31       2023-05-06      VCW1T    2437849  electronic            design1
# 38       2023-03-03          S  N2X226233       paper            design1
# 103      2023-03-05        MT2     159461       paper            design1
# 104             NaT     VDRC2H    2598560  electronic            design1
# 126             NaT       DT60     282777       paper            design1
# ...             ... ..     ...        ...         ...    ...         ...
# 2505            NaT        VGU    4243962  electronic            design1
# 2528            NaT        VBG    4327290  electronic            design1
# 2552            NaT       VKAT    4319612  electronic            design1
# 2580            NaT        KAT     154768       paper            design1
# 2612            NaT       SN1X     184479       paper            design1
#
#          status stock_status  sale_price expiry_date created_at updated_at  \
# 31    sold_used                      0.0
# 38    sold_used                      0.0
# 103   sold_used                      0.0
# 104                                  0.0
# 126   sold_used                      0.0
# ...         ...          ...         ...         ...        ...        ...
# 2505                                 0.0
# 2528                                 0.0
# 2552                                 0.0
# 2580                                 0.0
# 2612                                 0.0
#
#      deleted_at
# 31
# 38
# 103
# 104
# 126
# ...         ...
# 2505
# 2528
# 2552
# 2580
# 2612
#
# [134 rows x 32 columns]

# %% [markdown]
# Проверка:

# %%
pp = df_amo_temp.query('amo_id == 26139797')

# %%
pp
# Out:
#         amo_id          этап_сделки  бюджет дата_создания_сделки  \
# 2612  26139797  Успешно_реализовано       0  2023-11-28 13:18:52
#
#                sale_date  delivery_price  стоимость_доставки products  price  \
# 2612 2023-12-02 22:30:00             NaN                 NaN      NaN    NaN
#
#       subtotal выручка_от_клиента направление_(вид_сертификата)         code  \
# 2612       NaN                  0                     Снегоходы  SN1X_184479
#
#      корневая_сделка номер_2-го_сертификата сертификат_на_фотографа  \
# 2612       #26139623                    NaN                     NaN
#
#      сертификат_на_тренера статус_погашения card_used_date id prefix  number  \
# 2612                   NaN              NaN            NaT      SN1X  184479
#
#      card_type series design_type status stock_status  sale_price expiry_date  \
# 2612     paper            design1                             0.0
#
#      created_at updated_at deleted_at
# 2612

# %% [markdown]
# Функция для определения sale_price для

# %%
def insert_sale(row):    
    v = row['sale_price']
    #print(v)
    if row['sale_price'] == 0:
        d = row['дата_создания_сделки']
        amo_id = row['amo_id']
        pr = row['prefix']
        #v = 0
        str1 = f'sale_price != 0 & prefix == "{pr}"'
        try:
            #v = df_amo_temp.query(str1).iloc[-1]['sale_price']
            arr = df_amo_temp.query(str1)    
            arr['diff_date'] = arr['дата_создания_сделки'] - d
            arr = arr.sort_values(by='diff_date',ascending=True)
            arr.reset_index(drop= True , inplace= True)
            v = arr.iloc[0]['sale_price']
        except:
            pass
        finally:
            return v
    return v

# %%
null_sale_price = df_amo_temp.query('sale_price == 0')

# %%
null_sale_price
# Out:
#         amo_id          этап_сделки  бюджет дата_создания_сделки  \
# 4     23403789  Успешно_реализовано    5000  2023-01-03 21:56:43
# 31    23459939  Успешно_реализовано       0  2023-01-13 11:41:15
# 32    23460055  Успешно_реализовано   10000  2023-01-13 11:50:38
# 38    23466787  Успешно_реализовано       0  2023-01-14 18:11:28
# 44    23476291  Успешно_реализовано   10000  2023-01-16 14:34:03
# ...        ...                  ...     ...                  ...
# 2580  26042895  Успешно_реализовано       0  2023-11-19 10:36:50
# 2582  25821661  Успешно_реализовано   14200  2023-11-19 21:15:54
# 2594  26095709  Успешно_реализовано   12950  2023-11-23 18:00:18
# 2611  26139623  Успешно_реализовано   11450  2023-11-28 13:06:38
# 2612  26139797  Успешно_реализовано       0  2023-11-28 13:18:52
#
#                sale_date  delivery_price  стоимость_доставки  \
# 4    2023-01-04 15:19:00             NaN                 NaN
# 31   2023-01-13 11:42:00             NaN                 NaN
# 32   2023-01-13 11:59:00             NaN                 NaN
# 38   2023-01-18 10:48:00             NaN                 NaN
# 44   2023-01-16 16:17:00             NaN                 NaN
# ...                  ...             ...                 ...
# 2580 2023-11-20 12:51:00             NaN                 NaN
# 2582 2023-11-22 11:11:00             NaN                 NaN
# 2594 2023-11-25 12:03:00           450.0                 NaN
# 2611 2023-12-02 22:29:00           450.0                 NaN
# 2612 2023-12-02 22:30:00             NaN                 NaN
#
#                                                products    price  subtotal  \
# 4     Квадроциклы_(Варианты:_2_квадрика_на_1_час_без...   9000.0    9000.0
# 31                                                  NaN      NaN       NaN
# 32    Заезд_на_багги_(Варианты:_Занятие_для_одного_1...  10000.0   10000.0
# 38                                                  NaN      NaN       NaN
# 44    Снегоходы_(Варианты:_1_снежик_на_2_часа,_Бумаж...   9000.0    9000.0
# ...                                                 ...      ...       ...
# 2580                                                NaN      NaN       NaN
# 2582  Подарочный_сертификатна_вейкборд_(Выберите_тип...  14200.0   14200.0
# 2594  Искусственная_волна_Flow_Moscow_(Варианты:_1_ч...  12950.0   12500.0
# 2611  Снегоходы_(Варианты:_1_снежик_на_1_час,_Бумажн...  11450.0   11000.0
# 2612                                                NaN      NaN       NaN
#
#      выручка_от_клиента направление_(вид_сертификата)             code  \
# 4                  5000                   Квадроциклы    KVP1X1_138834
# 31                  NaN           Искусственная_волна    VCW1T_2437849
# 32                10000              Мото_Дрифт-трайк     VDTM_3651601
# 38                  NaN                     Снегоходы      S_N2X226233
# 44                 9000                     Снегоходы  VKVP2X1_2696914
# ...                 ...                           ...              ...
# 2580                NaN                       Картинг       KAT_154768
# 2582              14200    Вейксёрф_и_вейк_за_катером      WS60_239527
# 2594              12950           Искусственная_волна       CW2_267873
# 2611              11450                     Снегоходы      SN1X_199622
# 2612                  0                     Снегоходы      SN1X_184479
#
#      корневая_сделка номер_2-го_сертификата сертификат_на_фотографа  \
# 4                NaN      VKV2X1_2415531DIZ                     NaN
# 31         #23459729                    NaN                     NaN
# 32               NaN        VBGH_2415955DIS                     NaN
# 38        1715029001                    NaN                     NaN
# 44               NaN       VSN2X_2416042DIS                     NaN
# ...              ...                    ...                     ...
# 2580       #26042871                    NaN                     NaN
# 2582             NaN                    NaN                     NaN
# 2594             NaN            TR2K_030117                     NaN
# 2611             NaN            SN1X_191480                     NaN
# 2612       #26139623                    NaN                     NaN
#
#      сертификат_на_тренера статус_погашения card_used_date id   prefix  \
# 4                      NaN          Погашен            NaT      KVP1X1
# 31                     NaN          Погашен     2023-05-06       VCW1T
# 32                     NaN              NaN            NaT        VDTM
# 38                     NaN          Погашен     2023-03-03           S
# 44                     NaN              NaN            NaT     VKVP2X1
# ...                    ...              ...            ... ..      ...
# 2580                   NaN              NaN            NaT         KAT
# 2582           TR2K_030782              NaN            NaT        WS60
# 2594                   NaN              NaN            NaT         CW2
# 2611                   NaN              NaN            NaT        SN1X
# 2612                   NaN              NaN            NaT        SN1X
#
#          number   card_type series design_type     status stock_status  \
# 4        138834       paper            design1  sold_used
# 31      2437849  electronic            design1  sold_used
# 32      3651601  electronic            design1
# 38    N2X226233       paper            design1  sold_used
# 44      2696914  electronic            design1
# ...         ...         ...    ...         ...        ...          ...
# 2580     154768       paper            design1
# 2582     239527       paper            design1
# 2594     267873       paper            design1
# 2611     199622       paper            design1
# 2612     184479       paper            design1
#
#       sale_price expiry_date created_at updated_at deleted_at
# 4            0.0
# 31           0.0
# 32           0.0
# 38           0.0
# 44           0.0
# ...          ...         ...        ...        ...        ...
# 2580         0.0
# 2582         0.0
# 2594         0.0
# 2611         0.0
# 2612         0.0
#
# [312 rows x 32 columns]

# %%
idx = list(null_sale_price['amo_id'].values)

# %%
print(idx)
# Out:
# [23403789, 23459939, 23460055, 23466787, 23476291, 23499379, 23502729, 23513149, 23588587, 23590237, 23596239, 23601589, 23611933, 23623467, 23627015, 23627023, 23627035, 23637617, 24913421, 23665131, 23676913, 23680799, 23681563, 23681577, 23692773, 23706009, 23706073, 23710655, 23714709, 22691287, 23716823, 23716881, 23716895, 23717577, 23718677, 23718687, 23718699, 23719323, 23719721, 23720975, 23724387, 23724611, 23727485, 23729299, 23729319, 23729651, 23729655, 23729661, 23732921, 23737613, 23751513, 23751983, 23759977, 23770797, 23788533, 23778849, 23796679, 23801865, 23803433, 23809097, 23810513, 23810559, 23813621, 23842449, 23845273, 23852821, 23869621, 23873785, 23882253, 23885027, 23897495, 23908115, 23908435, 23918655, 23918783, 23924011, 23924021, 23931579, 23931953, 23959347, 23963995, 23967057, 23972905, 23975143, 23990017, 23990845, 24000379, 24013075, 24029665, 24030639, 24048603, 24056111, 24072509, 24083997, 24084061, 24088395, 24092835, 24098587, 24104865, 24108251, 24119097, 24120549, 24108655, 24048077, 24122263, 24124551, 24128423, 24136623, 24177210, 24177776, 24184388, 24206155, 24207425, 24207679, 24207485, 24209199, 24214637, 24283109, 24285861, 24295849, 24295901, 24295929, 24308797, 24308929, 24310757, 24321529, 24323277, 24324573, 24343649, 24350053, 24350347, 24360787, 24362083, 24370199, 24380121, 24386117, 24402985, 24403237, 24403351, 24407045, 24407599, 24413703, 24413747, 24417659, 24433167, 24434737, 24436793, 24437239, 24437483, 24441731, 24450305, 24460403, 24462079, 24463739, 24464305, 24470939, 24486770, 24511935, 24514453, 24521673, 24524175, 24525169, 24526979, 24527773, 24531685, 24544157, 24549375, 24575627, 24578193, 24595337, 24580153, 24580175, 24580183, 24580195, 24560639, 24584857, 24586641, 24592667, 24596539, 24599637, 24604611, 24606011, 24606999, 24608631, 24611547, 24611905, 24614375, 24615849, 24620003, 24640239, 24643097, 24646167, 24649213, 24650609, 24654685, 24655155, 24656289, 24663991, 24664979, 24665969, 24670071, 24672341, 24676537, 24678509, 24678905, 24693099, 24696037, 24696275, 24708927, 24718623, 24716109, 24721963, 24722951, 24734827, 24740295, 24740393, 24746589, 24752957, 24754809, 24754939, 24757207, 24757289, 24757301, 24819125, 24771161, 24774585, 24777563, 24779567, 24785491, 24788049, 24790553, 24791079, 24807245, 24817595, 24818687, 24819965, 24855063, 24854545, 24864919, 24867945, 24874753, 24875347, 24901233, 24901319, 24906491, 24918947, 24930483, 24930499, 24935309, 24949815, 24955933, 24965161, 24975905, 24986247, 24989577, 24992683, 24996401, 25010135, 25010515, 25011655, 25011677, 25011683, 25014895, 25022693, 25030485, 25045555, 25053731, 25053739, 25070705, 25070945, 25078171, 25084293, 25084647, 25090379, 25100731, 25112995, 25126121, 25113117, 25153497, 25153589, 25156509, 25156527, 25183973, 25190897, 25197379, 25228663, 25262447, 25262457, 25269783, 25273975, 25418131, 25449091, 25478241, 25538207, 25538459, 25538463, 25541327, 25698611, 25885815, 25899441, 25934373, 25938825, 25939051, 25956059, 25988317, 26034025, 26036943, 26042895, 25821661, 26095709, 26139623, 26139797]

# %%
df_amo_temp['sale_price'] = df_amo_temp.apply(insert_sale,axis=1)
# Out:
# sale_price != 0 & prefix == "KVP1X1"
# 2023-01-03 21:56:43
#       amo_id          этап_сделки  бюджет дата_создания_сделки  \
# 0   23561917  Успешно_реализовано    5000  2023-01-27 00:28:11
# 1   23665615  Успешно_реализовано    5000  2023-02-12 18:27:04
# 2   23794517  Успешно_реализовано   10000  2023-03-04 12:30:45
# 3   23825623  Успешно_реализовано    5000  2023-03-09 14:26:48
# 4   23902297  Успешно_реализовано    5000  2023-03-20 09:36:32
# 5   23902879  Успешно_реализовано    5500  2023-03-20 10:52:44
# 6   23922623  Успешно_реализовано    5000  2023-03-23 09:19:09
# 7   23973519  Успешно_реализовано    5000  2023-03-30 15:34:39
# 8   24324971  Успешно_реализовано    5350  2023-05-17 20:11:32
# 9   24389017  Успешно_реализовано    5600  2023-05-25 11:05:28
# 10  24479765  Успешно_реализовано    5000  2023-06-06 12:26:12
# 11  24918087  Успешно_реализовано    5000  2023-07-27 16:33:25
# 12  25039649  Успешно_реализовано    5000  2023-08-08 14:48:29
# 13  25044777  Успешно_реализовано    5450  2023-08-09 16:23:34
# 14  25252547  Успешно_реализовано    5450  2023-09-07 00:10:46
# 15  25424339  Успешно_реализовано    5000  2023-09-27 12:32:01
# 16  25527309  Успешно_реализовано    5000  2023-10-03 15:49:06
#
#              sale_date  delivery_price  стоимость_доставки  \
# 0  2023-01-27 09:42:00             0.0                 NaN
# 1  2023-02-16 16:52:00             0.0                 NaN
# 2  2023-03-04 12:40:00             NaN                 NaN
# 3  2023-03-10 19:42:00           500.0                 NaN
# 4  2023-03-22 14:30:00           500.0                 NaN
# 5  2023-03-23 15:54:00           500.0                 NaN
# 6  2023-03-25 18:52:00             NaN                 NaN
# 7  2023-04-01 17:42:00             NaN                 NaN
# 8  2023-05-19 13:59:00             NaN                 NaN
# 9  2023-05-26 08:44:00           600.0                 NaN
# 10 2023-06-06 13:42:00             0.0                 NaN
# 11 2023-07-27 17:49:00             NaN                 NaN
# 12 2023-08-09 11:45:00             NaN                 NaN
# 13 2023-08-11 09:21:00           450.0                 NaN
# 14 2023-09-09 11:46:00           450.0                 NaN
# 15 2023-09-29 12:50:00             NaN                 NaN
# 16 2023-10-05 11:23:00           450.0                 NaN
#
#                                              products    price  subtotal  \
# 0   Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5000.0    5000.0
# 1   Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5000.0    5000.0
# 2   Квадроциклы_(Варианты:_1_квадрик_2_часа_с_пасс...  10000.0   10000.0
# 3   Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5500.0    5000.0
# 4   Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5500.0    5000.0
# 5   Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5500.0    5000.0
# 6   Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5000.0    5000.0
# 7   Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5000.0    5000.0
# 8   Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5000.0    5000.0
# 9   Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5600.0    5000.0
# 10  Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5000.0    5000.0
# 11  Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5000.0    5000.0
# 12  Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5000.0    5000.0
# 13  Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5000.0    5000.0
# 14  Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5450.0    5000.0
# 15  Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5000.0    5000.0
# 16  Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5450.0    5000.0
#
#    выручка_от_клиента направление_(вид_сертификата)           code  \
# 0                5000                   Квадроциклы  KVP1X1_151326
# 1                5000                   Квадроциклы  KVP1X1_150930
# 2               10000                   Квадроциклы   KVP1X1_68697
# 3                5000                   Квадроциклы  KVP1X1_259672
# 4                5000                   Квадроциклы  KVP1X1_145512
# 5                5500                   Квадроциклы  KVP1X1_199463
# 6                5000                   Квадроциклы  KVP1X1_196623
# 7                5000                   Квадроциклы  KVP1X1_193739
# 8                5350                   Квадроциклы  KVP1X1_177017
# 9                5600                   Квадроциклы  KVP1X1_137725
# 10               5000                   Квадроциклы  KVP1X1_165798
# 11               5000                   Квадроциклы  KVP1X1_172502
# 12               5000                   Квадроциклы  KVP1X1_137700
# 13               5450                   Квадроциклы  KVP1X1_158757
# 14               5450                   Квадроциклы  KVP1X1_293302
# 15               5000                   Квадроциклы  KVP1X1_297840
# 16               5000                   Квадроциклы  KVP1X1_199253
#
#    корневая_сделка номер_2-го_сертификата сертификат_на_фотографа  \
# 0              NaN                    NaN                     NaN
# 1              NaN                    NaN                     NaN
# 2              NaN                    NaN                     NaN
# 3              NaN                    NaN                     NaN
# 4              NaN                    NaN                     NaN
# 5              NaN                    NaN                     NaN
# 6              NaN                    NaN                     NaN
# 7              NaN                    NaN                     NaN
# 8              NaN                    NaN                     NaN
# 9              NaN                    NaN                     NaN
# 10             NaN                    NaN                     NaN
# 11             NaN                    NaN                     NaN
# 12             NaN                    NaN                     NaN
# 13             NaN                    NaN                     NaN
# 14             NaN                    NaN                     NaN
# 15             NaN                    NaN                     NaN
# 16             NaN                    NaN                     NaN
#
#    сертификат_на_тренера статус_погашения card_used_date id  prefix  number  \
# 0                    NaN          Погашен     2023-08-10     KVP1X1  151326
# 1                    NaN          Погашен     2023-12-10     KVP1X1  150930
# 2                    NaN              NaN            NaT     KVP1X1   68697
# 3                    NaN          Погашен            NaT     KVP1X1  259672
# 4                    NaN          Погашен            NaT     KVP1X1  145512
# 5                    NaN          Погашен            NaT     KVP1X1  199463
# 6                    NaN          Погашен            NaT     KVP1X1  196623
# 7                    NaN          Погашен            NaT     KVP1X1  193739
# 8                    NaN          Погашен     2023-03-10     KVP1X1  177017
# 9                    NaN          Погашен            NaT     KVP1X1  137725
# 10                   NaN              NaN            NaT     KVP1X1  165798
# 11                   NaN              NaN            NaT     KVP1X1  172502
# 12                   NaN          Погашен            NaT     KVP1X1  137700
# 13                   NaN              NaN            NaT     KVP1X1  158757
# 14                   NaN              NaN            NaT     KVP1X1  293302
# 15                   NaN              NaN            NaT     KVP1X1  297840
# 16                   NaN          Погашен     2023-07-10     KVP1X1  199253
#
#    card_type series design_type     status stock_status  sale_price  \
# 0      paper            design1  sold_used                   5000.0
# 1      paper            design1  sold_used                   5000.0
# 2      paper            design1                             10000.0
# 3      paper            design1  sold_used                   5000.0
# 4      paper            design1  sold_used                   5000.0
# 5      paper            design1  sold_used                   5000.0
# 6      paper            design1  sold_used                   5000.0
# 7      paper            design1  sold_used                   5000.0
# 8      paper            design1  sold_used                   5000.0
# 9      paper            design1  sold_used                   5000.0
# 10     paper            design1                              5000.0
# 11     paper            design1                              5000.0
# 12     paper            design1  sold_used                   5000.0
# 13     paper            design1                              5000.0
# 14     paper            design1                              5000.0
# 15     paper            design1                              5000.0
# 16     paper            design1  sold_used                   5000.0
#
#    expiry_date created_at updated_at deleted_at         diff_date
# 0                                                23 days 02:31:28
# 1                                                39 days 20:30:21
# 2                                                59 days 14:34:02
# 3                                                64 days 16:30:05
# 4                                                75 days 11:39:49
# 5                                                75 days 12:56:01
# 6                                                78 days 11:22:26
# 7                                                85 days 17:37:56
# 8                                               133 days 22:14:49
# 9                                               141 days 13:08:45
# 10                                              153 days 14:29:29
# 11                                              204 days 18:36:42
# 12                                              216 days 16:51:46
# 13                                              217 days 18:26:51
# 14                                              246 days 02:14:03
# 15                                              266 days 14:35:18
# 16                                              272 days 17:52:23
# 5000.0
# sale_price != 0 & prefix == "VCW1T"
# 2023-01-13 11:41:15
#       amo_id          этап_сделки  бюджет дата_создания_сделки  \
# 0   23504011  Успешно_реализовано    6500  2023-01-19 11:31:39
# 1   23559761  Успешно_реализовано    6500  2023-01-26 16:30:15
# 2   23605381  Успешно_реализовано    6500  2023-02-02 17:15:48
# 3   23727619  Успешно_реализовано    6500  2023-02-22 19:09:00
# 4   23887987  Успешно_реализовано    6500  2023-03-17 12:19:10
# 5   23985879  Успешно_реализовано    6500  2023-04-01 16:29:38
# 6   24155929  Успешно_реализовано    6500  2023-04-25 21:59:46
# 7   24217719  Успешно_реализовано    6500  2023-05-04 14:00:23
# 8   24221219  Успешно_реализовано    6500  2023-05-04 18:29:33
# 9   24236895  Успешно_реализовано    6500  2023-05-06 12:55:43
# 10  24930867  Успешно_реализовано    6500  2023-07-28 22:44:20
# 11  25084249  Успешно_реализовано   23777  2023-08-15 14:16:47
# 12  25124397  Успешно_реализовано    6500  2023-08-21 08:36:55
# 13  25263685  Успешно_реализовано    6500  2023-09-08 14:08:20
# 14  25243435  Успешно_реализовано    6500  2023-09-08 15:16:57
# 15  25269083  Успешно_реализовано    6500  2023-09-09 13:32:18
# 16  25301981  Успешно_реализовано    6500  2023-09-13 18:12:53
# 17  25364193  Успешно_реализовано    6500  2023-09-20 22:49:59
# 18  25373599  Успешно_реализовано    6500  2023-09-21 21:39:32
# 19  25394107  Успешно_реализовано    6500  2023-09-25 09:02:34
# 20  25558463  Успешно_реализовано    6500  2023-10-07 08:28:46
# 21  25675113  Успешно_реализовано    6500  2023-10-14 17:27:35
# 22  25822809  Успешно_реализовано    6500  2023-10-27 14:18:00
# 23  25893213  Успешно_реализовано    6500  2023-11-04 00:15:08
# 24  25896241  Успешно_реализовано    6500  2023-11-04 15:45:58
#
#              sale_date  delivery_price  стоимость_доставки  \
# 0  2023-01-19 11:44:00             NaN                 NaN
# 1  2023-01-26 16:44:00             0.0                 NaN
# 2  2023-02-02 17:48:00             0.0                 NaN
# 3  2023-02-22 19:15:00             0.0                 NaN
# 4  2023-03-17 12:29:00             NaN                 NaN
# 5  2023-04-01 14:35:00             0.0                 NaN
# 6  2023-04-26 09:10:00             0.0                 NaN
# 7  2023-05-04 14:32:00             0.0                 NaN
# 8  2023-05-04 18:43:00             0.0                 NaN
# 9  2023-05-06 13:11:00             NaN                 NaN
# 10 2023-07-29 09:15:00             0.0                 NaN
# 11 2023-08-15 14:33:00             0.0                 NaN
# 12 2023-08-21 09:59:00             0.0                 NaN
# 13 2023-09-08 14:23:00             0.0                 NaN
# 14 2023-09-06 14:50:00             NaN                 NaN
# 15 2023-09-09 13:38:00             0.0                 NaN
# 16 2023-09-13 19:15:00             0.0                 NaN
# 17 2023-09-20 23:01:00             0.0                 NaN
# 18 2023-09-21 22:33:00             0.0                 NaN
# 19 2023-09-25 10:00:00             0.0                 NaN
# 20 2023-10-07 08:55:00             0.0                 NaN
# 21 2023-10-14 19:11:00             NaN                 NaN
# 22 2023-10-27 14:58:00             0.0                 NaN
# 23 2023-11-04 09:21:00             0.0                 NaN
# 24 2023-11-04 16:11:00             0.0                 NaN
#
#                                              products    price  subtotal  \
# 0   Искусственная_волна_Flow_Moscow_(Варианты:_1_ч...   6500.0    6500.0
# 1   Искусственная_волна_Flow_Moscow_(Варианты:_1_ч...   6500.0    6500.0
# 2   Искусственная_волна_Flow_Moscow_(Варианты:_1_ч...   6500.0    6500.0
# 3   Искусственная_волна_Flow_Moscow_(Варианты:_1_ч...   6500.0    6500.0
# 4   Искусственная_волна_Flow_Moscow_(Варианты:_1_ч...   6500.0    6500.0
# 5   Искусственная_волна_Flow_Moscow_(Варианты:_1_ч...   6500.0    6500.0
# 6   Искусственная_волна_Flow_Moscow_(Варианты:_1_ч...   6500.0    6500.0
# 7   Искусственная_волна_Flow_Moscow_(Варианты:_1_ч...   6500.0    6500.0
# 8   Искусственная_волна_Flow_Moscow_(Варианты:_1_ч...   6500.0    6500.0
# 9   Искусственная_волна_Flow_Moscow_(Варианты:_1_ч...   6500.0    6500.0
# 10  Искусственная_волна_Flow_Moscow_(Варианты:_1_ч...   6500.0    6500.0
# 11  Искусственная_волна_Flow_Moscow_(Варианты:_1_ч...  23777.0   23777.0
# 12  Искусственная_волна_Flow_Moscow_(Варианты:_1_ч...   6500.0    6500.0
# 13  Искусственная_волна_Flow_Moscow_(Варианты:_1_ч...   6500.0    6500.0
# 14  Искусственная_волна_Flow_Moscow_(Варианты:_1_ч...   6500.0    6500.0
# 15  Искусственная_волна_Flow_Moscow_(Варианты:_1_ч...   6500.0    6500.0
# 16  Искусственная_волна_Flow_Moscow_(Варианты:_1_ч...   6500.0    6500.0
# 17  Искусственная_волна_Flow_Moscow_(Варианты:_1_ч...   6500.0    6500.0
# 18  Искусственная_волна_Flow_Moscow_(Варианты:_1_ч...   6500.0    6500.0
# 19  Искусственная_волна_Flow_Moscow_(Варианты:_1_ч...   6500.0    6500.0
# 20  Искусственная_волна_Flow_Moscow_(Варианты:_1_ч...   6500.0    6500.0
# 21  Искусственная_волна_Flow_Moscow_(Варианты:_1_ч...   6500.0    6500.0
# 22  Искусственная_волна_Flow_Moscow_(Варианты:_1_ч...   6500.0    6500.0
# 23  Искусственная_волна_Flow_Moscow_(Варианты:_1_ч...   6500.0    6500.0
# 24  Искусственная_волна_Flow_Moscow_(Варианты:_1_ч...   6500.0    6500.0
#
#    выручка_от_клиента направление_(вид_сертификата)           code  \
# 0                6500           Искусственная_волна  VCW1T_2439028
# 1                6500           Искусственная_волна  VCW1T_2586646
# 2                6500           Искусственная_волна  VCW1T_2521546
# 3                6500           Искусственная_волна  VCW1T_2684752
# 4                6500           Искусственная_волна  VCW1T_2665328
# 5                6500           Искусственная_волна  VCW1T_2873425
# 6                6500           Искусственная_волна  VCW1T_2997405
# 7                6500           Искусственная_волна  VCW1T_2978650
# 8                6500           Искусственная_волна  VCW1T_2987813
# 9                6500           Искусственная_волна  VCW1T_2925089
# 10               6500           Искусственная_волна  VCW1T_3794486
# 11              23777           Искусственная_волна  VCW1T_3919651
# 12               6500           Искусственная_волна  VCW1T_3946620
# 13               6500           Искусственная_волна  VCW1T_4089972
# 14               6500           Искусственная_волна  VCW1T_4124208
# 15               6500           Искусственная_волна  VCW1T_4114105
# 16               6500           Искусственная_волна  VCW1T_4197499
# 17               6500           Искусственная_волна  VCW1T_4151077
# 18               6500           Искусственная_волна  VCW1T_4174467
# 19               6500           Искусственная_волна  VCW1T_4126826
# 20               6500           Искусственная_волна  VCW1T_4246812
# 21               6500           Искусственная_волна  VCW1T_4235078
# 22               6500           Искусственная_волна  VCW1T_4297035
# 23               6500           Искусственная_волна  VCW1T_4248631
# 24               6500           Искусственная_волна  VCW1T_4251054
#
#    корневая_сделка номер_2-го_сертификата сертификат_на_фотографа  \
# 0              NaN                    NaN                     NaN
# 1              NaN                    NaN                     NaN
# 2              NaN                    NaN                     NaN
# 3              NaN                    NaN                     NaN
# 4              NaN                    NaN                     NaN
# 5              NaN                    NaN                     NaN
# 6              NaN                    NaN                     NaN
# 7              NaN                    NaN                     NaN
# 8              NaN                    NaN                     NaN
# 9              NaN                    NaN                     NaN
# 10             NaN                    NaN                     NaN
# 11             NaN                    NaN                     NaN
# 12             NaN                    NaN                     NaN
# 13             NaN                    NaN                     NaN
# 14             NaN                    NaN                     NaN
# 15             NaN                    NaN                     NaN
# 16             NaN                    NaN                     NaN
# 17             NaN                    NaN                     NaN
# 18             NaN                    NaN                     NaN
# 19             NaN                    NaN                     NaN
# 20             NaN                    NaN                     NaN
# 21             NaN                    NaN                     NaN
# 22             NaN                    NaN                     NaN
# 23             NaN                    NaN                     NaN
# 24             NaN                    NaN                     NaN
#
#    сертификат_на_тренера статус_погашения card_used_date id prefix   number  \
# 0                    NaN          Погашен     2023-10-06     VCW1T  2439028
# 1                    NaN              NaN            NaT     VCW1T  2586646
# 2                    NaN              NaN            NaT     VCW1T  2521546
# 3                    NaN          Погашен            NaT     VCW1T  2684752
# 4                    NaN              NaN            NaT     VCW1T  2665328
# 5                    NaN              NaN            NaT     VCW1T  2873425
# 6                    NaN          Погашен            NaT     VCW1T  2997405
# 7                    NaN          Погашен     2023-01-08     VCW1T  2978650
# 8                    NaN              NaN            NaT     VCW1T  2987813
# 9                    NaN              NaN            NaT     VCW1T  2925089
# 10                   NaN              NaN            NaT     VCW1T  3794486
# 11                   NaN              NaN            NaT     VCW1T  3919651
# 12                   NaN              NaN            NaT     VCW1T  3946620
# 13                   NaN              NaN            NaT     VCW1T  4089972
# 14                   NaN              NaN            NaT     VCW1T  4124208
# 15                   NaN              NaN            NaT     VCW1T  4114105
# 16                   NaN              NaN            NaT     VCW1T  4197499
# 17                   NaN              NaN            NaT     VCW1T  4151077
# 18                   NaN              NaN            NaT     VCW1T  4174467
# 19                   NaN          Погашен            NaT     VCW1T  4126826
# 20                   NaN              NaN            NaT     VCW1T  4246812
# 21                   NaN              NaN            NaT     VCW1T  4235078
# 22                   NaN              NaN            NaT     VCW1T  4297035
# 23                   NaN              NaN            NaT     VCW1T  4248631
# 24                   NaN          Погашен            NaT     VCW1T  4251054
#
#      card_type series design_type     status stock_status  sale_price  \
# 0   electronic            design1  sold_used                   6500.0
# 1   electronic            design1                              6500.0
# 2   electronic            design1                              6500.0
# 3   electronic            design1  sold_used                   6500.0
# 4   electronic            design1                              6500.0
# 5   electronic            design1                              6500.0
# 6   electronic            design1  sold_used                   6500.0
# 7   electronic            design1  sold_used                   6500.0
# 8   electronic            design1                              6500.0
# 9   electronic            design1                              6500.0
# 10  electronic            design1                              6500.0
# 11  electronic            design1                             23777.0
# 12  electronic            design1                              6500.0
# 13  electronic            design1                              6500.0
# 14  electronic            design1                              6500.0
# 15  electronic            design1                              6500.0
# 16  electronic            design1                              6500.0
# 17  electronic            design1                              6500.0
# 18  electronic            design1                              6500.0
# 19  electronic            design1  sold_used                   6500.0
# 20  electronic            design1                              6500.0
# 21  electronic            design1                              6500.0
# 22  electronic            design1                              6500.0
# 23  electronic            design1                              6500.0
# 24  electronic            design1  sold_used                   6500.0
#
#    expiry_date created_at updated_at deleted_at         diff_date
# 0                                                 5 days 23:50:24
# 1                                                13 days 04:49:00
# 2                                                20 days 05:34:33
# 3                                                40 days 07:27:45
# 4                                                63 days 00:37:55
# 5                                                78 days 04:48:23
# 6                                               102 days 10:18:31
# 7                                               111 days 02:19:08
# 8                                               111 days 06:48:18
# 9                                               113 days 01:14:28
# 10                                              196 days 11:03:05
# 11                                              214 days 02:35:32
# 12                                              219 days 20:55:40
# 13                                              238 days 02:27:05
# 14                                              238 days 03:35:42
# 15                                              239 days 01:51:03
# 16                                              243 days 06:31:38
# 17                                              250 days 11:08:44
# 18                                              251 days 09:58:17
# 19                                              254 days 21:21:19
# 20                                              266 days 20:47:31
# 21                                              274 days 05:46:20
# 22                                              287 days 02:36:45
# 23                                              294 days 12:33:53
# 24                                              295 days 04:04:43
# 6500.0
# sale_price != 0 & prefix == "VDTM"
# 2023-01-13 11:50:38
#      amo_id          этап_сделки  бюджет дата_создания_сделки  \
# 0  24107709  Успешно_реализовано   11500  2023-04-19 14:07:05
# 1  24580843  Успешно_реализовано   11500  2023-06-16 20:27:23
#
#             sale_date  delivery_price  стоимость_доставки  \
# 0 2023-04-19 13:56:00             NaN                 NaN
# 1 2023-06-16 20:55:00             NaN                 NaN
#
#                                             products    price  subtotal  \
# 0  Заезд_на_Дрифт_Трайке_(Варианты:_Индивидуально...  11500.0   11500.0
# 1  Заезд_на_Дрифт_Трайке_(Варианты:_Индивидуально...  11500.0   11500.0
#
#   выручка_от_клиента направление_(вид_сертификата)          code  \
# 0              11500              Мото_Дрифт-трайк  VDTM_2852954
# 1              11500              Мото_Дрифт-трайк  VDTM_3328288
#
#   корневая_сделка номер_2-го_сертификата сертификат_на_фотографа  \
# 0             NaN                    NaN                     NaN
# 1             NaN                    NaN                     NaN
#
#   сертификат_на_тренера статус_погашения card_used_date id prefix   number  \
# 0                   NaN          Погашен            NaT      VDTM  2852954
# 1                   NaN          Погашен            NaT      VDTM  3328288
#
#     card_type series design_type     status stock_status  sale_price  \
# 0  electronic            design1  sold_used                  11500.0
# 1  electronic            design1  sold_used                  11500.0
#
#   expiry_date created_at updated_at deleted_at         diff_date
# 0                                               96 days 02:16:27
# 1                                              154 days 08:36:45
# 11500.0
# sale_price != 0 & prefix == "S"
# 2023-01-14 18:11:28
#       amo_id          этап_сделки  бюджет дата_создания_сделки  \
# 0   23443209  Успешно_реализовано       0  2023-01-10 18:26:42
# 1   23464975  Успешно_реализовано    5000  2023-01-14 11:49:31
# 2   23418575  Успешно_реализовано   18450  2023-01-14 17:41:35
# 3   23512497  Успешно_реализовано    3500  2023-01-20 12:41:02
# 4   23510405  Успешно_реализовано    3500  2023-01-21 16:53:43
# 5   23650993  Успешно_реализовано    5000  2023-02-10 09:31:20
# 6   23729673  Успешно_реализовано   18000  2023-02-23 11:06:34
# 7   23869067  Успешно_реализовано    7000  2023-03-15 14:55:56
# 8   23869831  Успешно_реализовано   21800  2023-03-15 16:36:17
# 9   23871179  Успешно_реализовано   18000  2023-03-15 19:21:50
# 10  23962927  Успешно_реализовано    6000  2023-03-29 11:58:03
# 11  22237131  Успешно_реализовано    2000  2023-04-06 11:26:05
# 12  24148027  Успешно_реализовано   18350  2023-04-24 20:20:19
# 13  24253453  Успешно_реализовано   18350  2023-05-09 20:46:12
# 14  24431975  Успешно_реализовано   23100  2023-05-31 10:42:06
# 15  24451687  Успешно_реализовано   22500  2023-06-02 14:49:54
# 16  24481193  Успешно_реализовано   18000  2023-06-06 14:31:28
# 17  24487700  Успешно_реализовано   18450  2023-06-07 10:23:10
# 18  24579679  Успешно_реализовано   20000  2023-06-16 17:13:41
# 19  24612879  Успешно_реализовано   25000  2023-06-21 14:55:47
# 20  24635545  Успешно_реализовано   20450  2023-06-23 16:52:41
# 21  24735211  Успешно_реализовано   25450  2023-07-05 18:51:16
# 22  24887781  Успешно_реализовано   20600  2023-07-24 13:53:16
# 23  24907967  Успешно_реализовано   20000  2023-07-26 13:42:36
# 24  25055469  Успешно_реализовано   20000  2023-08-11 02:00:54
# 25  25055471  Успешно_реализовано   20000  2023-08-11 02:04:25
# 26  25122407  Успешно_реализовано   25000  2023-08-20 18:00:00
# 27  25256543  Успешно_реализовано   20000  2023-09-07 14:19:27
# 28  25348855  Успешно_реализовано   20450  2023-09-19 11:45:57
#
#              sale_date  delivery_price  стоимость_доставки  \
# 0  2023-01-10 18:28:00             NaN                 NaN
# 1  2023-01-14 14:40:00             NaN                 NaN
# 2  2023-01-18 11:03:00           450.0                 NaN
# 3  2023-01-20 12:59:00             0.0                 NaN
# 4  2023-01-20 16:57:00             NaN                 NaN
# 5  2023-02-11 10:10:00             NaN                 NaN
# 6  2023-02-23 11:14:00             0.0                 NaN
# 7  2023-03-16 08:30:00             NaN                 NaN
# 8  2023-03-15 17:25:00             NaN                 NaN
# 9  2023-03-15 19:56:00             NaN                 NaN
# 10 2023-03-29 12:03:00             NaN                 NaN
# 11 2023-04-07 05:59:00             NaN                 NaN
# 12 2023-04-25 13:18:00           350.0                 NaN
# 13 2023-05-11 11:16:00           350.0                 NaN
# 14 2023-05-31 19:40:00           600.0                 NaN
# 15 2023-06-02 15:12:00             NaN                 NaN
# 16 2023-06-10 12:09:00             0.0                 NaN
# 17 2023-06-10 12:16:00           450.0                 NaN
# 18 2023-06-17 14:22:00             NaN                 NaN
# 19 2023-06-21 15:07:00             NaN                 NaN
# 20 2023-06-27 00:35:00           450.0                 NaN
# 21 2023-07-08 18:59:00           450.0                 NaN
# 22 2023-07-25 12:08:00           600.0                 NaN
# 23 2023-07-27 11:29:00             0.0                 NaN
# 24 2023-08-13 09:38:00             NaN                 NaN
# 25 2023-08-13 09:38:00             0.0                 NaN
# 26 2023-08-22 12:15:00             NaN                 NaN
# 27 2023-09-08 12:59:00             NaN                 NaN
# 28 2023-09-20 17:36:00           450.0                 NaN
#
#                                              products    price  subtotal  \
# 0                                                 NaN      NaN       NaN
# 1   Снегоходы_(Варианты:_1_снежик_на_1_час,_Бумажн...   5000.0    5000.0
# 2   Снегоходы_(Варианты:_1_снежик_на_2_часа,_Бумаж...  18450.0   18000.0
# 3   Искусственная_волна_Flow_Ride_(Варианты:_Час_к...   3500.0    3500.0
# 4   Искусственная_волна_Flow_Ride_(Варианты:_Час_к...   3500.0    3500.0
# 5   Снегоходы_(Варианты:_1_снежик_на_1_час,_Бумажн...   5000.0    5000.0
# 6   Прыжок_с_парашютом_(Варианты:_Прыжок_с_инструк...  18000.0   18000.0
# 7   Искусственная_волна_Flow_Ride_(Варианты:_Час_к...   7000.0    7000.0
# 8   Прыжок_с_парашютом_(Варианты:_Прыжок_с_инструк...  21800.0   21800.0
# 9   Прыжок_с_парашютом_(Варианты:_Прыжок_с_инструк...  18000.0   18000.0
# 10  Подарочный_сертификатна_сап-сёрфинг_(Выберите_...   6000.0    6000.0
# 11  Сап-сёрфинг_(Варианты:_1_час_для_двоих,_Бумажн...   2000.0    2000.0
# 12  Прыжок_с_парашютом_(Варианты:_Прыжок_с_инструк...  18350.0   18000.0
# 13  Прыжок_с_парашютом_(Варианты:_Прыжок_с_инструк...  18350.0   18000.0
# 14  Прыжок_с_парашютом_(Варианты:_Прыжок_с_инструк...  23100.0   22500.0
# 15  Прыжок_с_парашютом_(Варианты:_Прыжок_с_инструк...  22500.0   22500.0
# 16  Прыжок_с_парашютом_(Варианты:_Прыжок_с_инструк...  18000.0   18000.0
# 17  Прыжок_с_парашютом_(Варианты:_Прыжок_с_инструк...  18450.0   18000.0
# 18  Прыжок_с_парашютом_(Варианты:_Прыжок_с_инструк...  20000.0   20000.0
# 19  Прыжок_с_парашютом_(Варианты:_Прыжок_с_инструк...  25000.0   25000.0
# 20  Прыжок_с_парашютом_(Варианты:_Прыжок_с_инструк...  20450.0   20000.0
# 21  Прыжок_с_парашютом_(Варианты:_Прыжок_с_инструк...  25450.0   25000.0
# 22  Прыжок_с_парашютом_(Варианты:_Прыжок_с_инструк...  20600.0   20000.0
# 23  Прыжок_с_парашютом_(Варианты:_Прыжок_с_инструк...  20000.0   20000.0
# 24  Прыжок_с_парашютом_(Варианты:_Прыжок_с_инструк...  20000.0   20000.0
# 25  Прыжок_с_парашютом_(Варианты:_Прыжок_с_инструк...  20000.0   20000.0
# 26  Прыжок_с_парашютом_(Варианты:_Прыжок_с_инструк...  25000.0   25000.0
# 27  Прыжок_с_парашютом_(Варианты:_Прыжок_с_инструк...  20000.0   20000.0
# 28  Прыжок_с_парашютом_(Варианты:_Прыжок_с_инструк...  20450.0   20000.0
#
#    выручка_от_клиента направление_(вид_сертификата)          code  \
# 0                 NaN                      САП-сёрф     S_SU75738
# 1                5000                     Снегоходы  S_N1X1173183
# 2               18450                     Снегоходы   S_N2X295778
# 3                3500                     Флоу_Райд   S_SH2412102
# 4                3500                     Флоу_Райд     S_H280977
# 5                5000                     Снегоходы   S_N1X115304
# 6               18000                      Парашюты      S_252659
# 7                7000                     Флоу_Райд    S_H2254284
# 8               21800                      Парашюты  S_SKV2629635
# 9               18000                      Парашюты      S_223242
# 10               6000                      САП-сёрф    S_SU215131
# 11               2000                      САП-сёрф   S_U60146815
# 12              18350                      Парашюты      S_289083
# 13              18350                      Парашюты      S_229627
# 14              23100                      Парашюты    S_KV275543
# 15              22500                      Парашюты    S_KV265992
# 16              18000                      Парашюты      S_267801
# 17              18450                      Парашюты      S_295045
# 18              20000                      Парашюты      S_239266
# 19              25000                      Парашюты     S_KV43465
# 20              20450                      Парашюты      S_239977
# 21              25450                      Парашюты     S_KV58965
# 22              20600                      Парашюты      S_270658
# 23              20000                      Парашюты      S_271298
# 24              20000                      Парашюты      S_273417
# 25              20000                      Парашюты      S_260019
# 26                NaN                      Парашюты    S_KV241693
# 27              20000                      Парашюты      S_256950
# 28              20450                      Парашюты      S_299876
#
#    корневая_сделка номер_2-го_сертификата сертификат_на_фотографа  \
# 0              NaN                    NaN                     NaN
# 1              NaN                    NaN                     NaN
# 2              NaN                    NaN                     NaN
# 3              NaN                    NaN                     NaN
# 4              NaN                    NaN                     NaN
# 5              NaN                    NaN                     NaN
# 6              NaN                    NaN                     NaN
# 7              NaN                    NaN                     NaN
# 8              NaN                    NaN                     NaN
# 9              NaN                    NaN                     NaN
# 10             NaN                    NaN                     NaN
# 11             NaN                    NaN                     NaN
# 12             NaN                    NaN                     NaN
# 13             NaN                    NaN                     NaN
# 14             NaN                    NaN                     NaN
# 15             NaN                    NaN                     NaN
# 16             NaN                    NaN                     NaN
# 17             NaN                    NaN                     NaN
# 18             NaN                    NaN                     NaN
# 19             NaN                    NaN                     NaN
# 20             NaN                    NaN                     NaN
# 21             NaN                    NaN                     NaN
# 22             NaN                    NaN                     NaN
# 23             NaN                    NaN                     NaN
# 24             NaN                    NaN                     NaN
# 25             NaN                    NaN                     NaN
# 26             NaN                    NaN                     NaN
# 27             NaN                    NaN                     NaN
# 28             NaN                    NaN                     NaN
#
#    сертификат_на_тренера статус_погашения card_used_date id prefix  \
# 0                    NaN              NaN            NaT         S
# 1                    NaN          Погашен     2023-10-03         S
# 2                    NaN              NaN            NaT         S
# 3                    NaN              NaN            NaT         S
# 4                    NaN              NaN            NaT         S
# 5                    NaN          Погашен     2023-10-02         S
# 6                    NaN          Погашен            NaT         S
# 7                    NaN              NaN            NaT         S
# 8                    NaN          Погашен            NaT         S
# 9                    NaN              NaN            NaT         S
# 10                   NaN          Погашен     2023-05-08         S
# 11                   NaN              NaN            NaT         S
# 12                   NaN          Погашен     2023-03-08         S
# 13                   NaN              NaN            NaT         S
# 14                   NaN          Погашен     2023-09-06         S
# 15                   NaN          Погашен            NaT         S
# 16                   NaN          Погашен     2023-03-10         S
# 17                   NaN              NaN            NaT         S
# 18                   NaN          Погашен     2023-04-09         S
# 19                   NaN              NaN            NaT         S
# 20                   NaN          Погашен     2023-03-10         S
# 21                   NaN              NaN            NaT         S
# 22                   NaN              NaN            NaT         S
# 23                   NaN          Погашен            NaT         S
# 24                   NaN              NaN            NaT         S
# 25                   NaN              NaN            NaT         S
# 26                   NaN          Погашен            NaT         S
# 27                   NaN          Погашен            NaT         S
# 28                   NaN              NaN            NaT         S
#
#         number card_type series design_type     status stock_status  \
# 0      SU75738     paper            design1
# 1   N1X1173183     paper            design1  sold_used
# 2    N2X295778     paper            design1
# 3    SH2412102     paper            design1
# 4      H280977     paper            design1
# 5    N1X115304     paper            design1  sold_used
# 6       252659     paper            design1  sold_used
# 7     H2254284     paper            design1
# 8   SKV2629635     paper            design1  sold_used
# 9       223242     paper            design1
# 10    SU215131     paper            design1  sold_used
# 11   U60146815     paper            design1
# 12      289083     paper            design1  sold_used
# 13      229627     paper            design1
# 14    KV275543     paper            design1  sold_used
# 15    KV265992     paper            design1  sold_used
# 16      267801     paper            design1  sold_used
# 17      295045     paper            design1
# 18      239266     paper            design1  sold_used
# 19     KV43465     paper            design1
# 20      239977     paper            design1  sold_used
# 21     KV58965     paper            design1
# 22      270658     paper            design1
# 23      271298     paper            design1  sold_used
# 24      273417     paper            design1
# 25      260019     paper            design1
# 26    KV241693     paper            design1  sold_used
# 27      256950     paper            design1  sold_used
# 28      299876     paper            design1
#
#     sale_price expiry_date created_at updated_at deleted_at         diff_date
# 0          NaN                                              -4 days +00:15:14
# 1       5000.0                                              -1 days +17:38:03
# 2      18000.0                                              -1 days +23:30:07
# 3       3500.0                                                5 days 18:29:34
# 4       3500.0                                                6 days 22:42:15
# 5       5000.0                                               26 days 15:19:52
# 6      18000.0                                               39 days 16:55:06
# 7       7000.0                                               59 days 20:44:28
# 8      21800.0                                               59 days 22:24:49
# 9      18000.0                                               60 days 01:10:22
# 10      6000.0                                               73 days 17:46:35
# 11      2000.0                                               81 days 17:14:37
# 12     18000.0                                              100 days 02:08:51
# 13     18000.0                                              115 days 02:34:44
# 14     22500.0                                              136 days 16:30:38
# 15     22500.0                                              138 days 20:38:26
# 16     18000.0                                              142 days 20:20:00
# 17     18000.0                                              143 days 16:11:42
# 18     20000.0                                              152 days 23:02:13
# 19     25000.0                                              157 days 20:44:19
# 20     20000.0                                              159 days 22:41:13
# 21     25000.0                                              172 days 00:39:48
# 22     20000.0                                              190 days 19:41:48
# 23     20000.0                                              192 days 19:31:08
# 24     20000.0                                              208 days 07:49:26
# 25     20000.0                                              208 days 07:52:57
# 26     25000.0                                              217 days 23:48:32
# 27     20000.0                                              235 days 20:07:59
# 28     20000.0                                              247 days 17:34:29
# 5000.0
# sale_price != 0 & prefix == "VKVP2X1"
# 2023-01-16 14:34:03
#       amo_id          этап_сделки  бюджет дата_создания_сделки  \
# 0   23525453  Успешно_реализовано   10000  2023-01-22 16:13:52
# 1   23683171  Успешно_реализовано   10000  2023-02-16 22:17:09
# 2   21795105  Успешно_реализовано   10000  2023-03-18 18:57:55
# 3   24084131  Успешно_реализовано   10000  2023-04-15 19:05:20
# 4   24242307  Успешно_реализовано   10000  2023-05-07 13:18:51
# 5   24324377  Успешно_реализовано   10000  2023-05-17 18:07:13
# 6   24622971  Успешно_реализовано   10000  2023-06-22 14:04:55
# 7   24870503  Успешно_реализовано   10000  2023-07-21 16:10:42
# 8   24873601  Успешно_реализовано   10000  2023-07-22 10:27:40
# 9   25528175  Успешно_реализовано   10000  2023-10-03 17:16:34
# 10  25621807  Успешно_реализовано   10000  2023-10-10 13:12:31
#
#              sale_date  delivery_price  стоимость_доставки  \
# 0  2023-01-22 16:22:00             0.0                 NaN
# 1  2023-02-16 22:32:00             0.0                 NaN
# 2  2022-05-12 18:33:00             NaN                 NaN
# 3  2023-04-15 19:10:00             0.0                 NaN
# 4  2023-05-07 13:46:00             0.0                 NaN
# 5  2023-05-17 18:40:00             0.0                 NaN
# 6  2023-06-22 14:18:00             0.0                 NaN
# 7  2023-07-21 16:32:00             NaN                 NaN
# 8  2023-07-22 10:55:00             0.0                 NaN
# 9  2023-10-03 17:22:00             0.0                 NaN
# 10 2023-10-10 13:18:00             0.0                 NaN
#
#                                              products    price  subtotal  \
# 0   Квадроциклы_(Варианты:_1_квадрик_2_часа_с_пасс...  10000.0   10000.0
# 1   Квадроциклы_(Варианты:_1_квадрик_2_часа_с_пасс...  10000.0   10000.0
# 2   Квадроциклы_(Варианты:_1_квадрик_2_часа_с_пасс...  10000.0   10000.0
# 3   Квадроциклы_(Варианты:_1_квадрик_2_часа_с_пасс...  10000.0   10000.0
# 4   Квадроциклы_(Варианты:_1_квадрик_2_часа_с_пасс...  10000.0   10000.0
# 5   Квадроциклы_(Варианты:_1_квадрик_2_часа_с_пасс...  10000.0   10000.0
# 6   Квадроциклы_(Варианты:_2_квадрика_на_1_час_с_п...  10000.0   10000.0
# 7   Квадроциклы_(Варианты:_1_квадрик_2_часа_с_пасс...  10000.0   10000.0
# 8   Квадроциклы_(Варианты:_2_квадрика_на_1_час_с_п...  10000.0   10000.0
# 9   Квадроциклы_(Варианты:_1_квадрик_2_часа_с_пасс...  10000.0   10000.0
# 10  Квадроциклы_(Варианты:_1_квадрик_2_часа_с_пасс...  10000.0   10000.0
#
#    выручка_от_клиента направление_(вид_сертификата)             code  \
# 0               10000                   Квадроциклы  VKVP2X1_2445541
# 1               10000                   Квадроциклы  VKVP2X1_2554089
# 2               10000                   Квадроциклы  VKVP2X1_2733656
# 3               10000                   Квадроциклы  VKVP2X1_2877313
# 4               10000                   Квадроциклы  VKVP2X1_2970365
# 5               10000                   Квадроциклы  VKVP2X1_3061217
# 6               10000                   Квадроциклы  VKVP2X1_3378915
# 7               10000                   Квадроциклы  VKVP2X1_3790835
# 8               10000                   Квадроциклы  VKVP2X1_3788620
# 9               10000                   Квадроциклы  VKVP2X1_4241943
# 10              10000                   Квадроциклы  VKVP2X1_4271152
#
#    корневая_сделка номер_2-го_сертификата сертификат_на_фотографа  \
# 0              NaN                    NaN                     NaN
# 1              NaN                    NaN                     NaN
# 2              NaN                    NaN                     NaN
# 3              NaN                    NaN                     NaN
# 4              NaN                    NaN                     NaN
# 5              NaN                    NaN                     NaN
# 6              NaN                    NaN                     NaN
# 7              NaN                    NaN                     NaN
# 8              NaN                    NaN                     NaN
# 9              NaN                    NaN                     NaN
# 10             NaN                    NaN                     NaN
#
#    сертификат_на_тренера статус_погашения card_used_date id   prefix   number  \
# 0                    NaN          Погашен            NaT     VKVP2X1  2445541
# ...
# 0  катание_на_картинге_(Варианты:_Разовое_занятие...   6450.0    6000.0
# 1  катание_на_картинге_(Варианты:_Разовое_занятие...  12000.0   12000.0
#
#   выручка_от_клиента направление_(вид_сертификата)        code  \
# 0               6450                       Картинг  KAT_191821
# 1              12000                       Картинг  KAT_140487
#
#   корневая_сделка номер_2-го_сертификата сертификат_на_фотографа  \
# 0             NaN                    NaN                     NaN
# 1             NaN                    NaN                     NaN
#
#   сертификат_на_тренера статус_погашения card_used_date id prefix  number  \
# 0                   NaN          Погашен     2023-03-08       KAT  191821
# 1                   NaN              NaN            NaT       KAT  140487
#
#   card_type series design_type     status stock_status  sale_price  \
# 0     paper            design1  sold_used                   6000.0
# 1     paper            design1                             12000.0
#
#   expiry_date created_at updated_at deleted_at           diff_date
# 0                                              -152 days +04:18:06
# 1                                                -1 days +13:30:30
# 12000.0
# sale_price != 0 & prefix == "WS60"
# 2023-11-19 21:15:54
#       amo_id          этап_сделки  бюджет дата_создания_сделки  \
# 0   23789255  Успешно_реализовано    8500  2023-03-06 10:35:42
# 1   23826923  Успешно_реализовано    8800  2023-03-09 21:11:00
# 2   24372639  Успешно_реализовано    9100  2023-05-24 12:27:55
# 3   24543213  Успешно_реализовано   10050  2023-06-12 15:34:51
# 4   24587353  Успешно_реализовано    9600  2023-06-18 13:01:22
# 5   24807709  Успешно_реализовано    9600  2023-07-13 19:11:10
# 6   24820389  Успешно_реализовано    7680  2023-07-15 23:24:00
# 7   24952423  Успешно_реализовано    8160  2023-07-30 20:06:31
# 8   24975785  Успешно_реализовано   17300  2023-08-02 18:24:52
# 9   25050603  Успешно_реализовано   10050  2023-08-10 13:21:46
# 10  25175493  Успешно_реализовано    7680  2023-08-27 18:59:59
#
#              sale_date  delivery_price  стоимость_доставки  \
# 0  2023-03-03 15:16:00             NaN                 NaN
# 1  2023-03-09 18:10:00             0.0                 NaN
# 2  2023-05-24 16:07:00           600.0                 NaN
# 3  2023-06-14 10:56:00           450.0                 NaN
# 4  2023-06-18 13:10:00             NaN                 NaN
# 5  2023-07-17 17:00:00             0.0                 NaN
# 6  2023-07-15 23:24:00             NaN                 NaN
# 7  2023-07-30 20:06:00             NaN                 NaN
# 8  2023-08-06 09:53:00           600.0                 NaN
# 9  2023-08-10 15:33:00           450.0                 NaN
# 10 2023-08-27 19:01:00             NaN                 NaN
#
#                                              products    price  subtotal  \
# 0   Подарочный_сертификатна_вейк_за_катером_(Выбер...   8500.0    8500.0
# 1   Вейк-сёрфинг_за_катером_(Варианты:_1_час_Maste...   8800.0    8800.0
# 2   Подарочный_сертификатна_вейк_за_катером_(Выбер...   9100.0    8500.0
# 3   Подарочный_сертификатна_вейк_за_катером_(Выбер...  10050.0    9600.0
# 4   Подарочный_сертификатна_вейкборд_(Выберите_тип...   9600.0    9600.0
# 5   Подарочный_сертификатна_вейксёрфинг_(Выберите_...   9600.0    9600.0
# 6                                                 NaN      NaN       NaN
# 7                                                 NaN      NaN       NaN
# 8   Вейк-сёрфинг_за_катером_(Варианты:_1_час_Maste...  17300.0   16700.0
# 9   Подарочный_сертификатна_вейк_за_катером_(Выбер...  10050.0    9600.0
# 10                                                NaN      NaN       NaN
#
#    выручка_от_клиента направление_(вид_сертификата)           code  \
# 0                8500    Вейксёрф_и_вейк_за_катером    WS60_245936
# 1                8800    Вейксёрф_и_вейк_за_катером    WS60_276764
# 2                9100    Вейксёрф_и_вейк_за_катером    WS60_227593
# 3               10050    Вейксёрф_и_вейк_за_катером    WS60_276011
# 4                9600    Вейксёрф_и_вейк_за_катером    WS60_291005
# 5                9600    Вейксёрф_и_вейк_за_катером    WS60_215800
# 6                7680    Вейксёрф_и_вейк_за_катером    WS60_242852
# 7                8160    Вейксёрф_и_вейк_за_катером    WS60_215266
# 8               17300    Вейксёрф_и_вейк_за_катером    WS60_283297
# 9               10050    Вейксёрф_и_вейк_за_катером    WS60_271596
# 10               7680    Вейксёрф_и_вейк_за_катером  WS60_21156334
#
#    корневая_сделка номер_2-го_сертификата сертификат_на_фотографа  \
# 0              NaN                    NaN                     NaN
# 1              NaN                    NaN                     NaN
# 2              NaN                    NaN                     NaN
# 3              NaN                    NaN                     NaN
# 4              NaN                    NaN                     NaN
# 5              NaN                    NaN                     NaN
# 6              NaN                    NaN                     NaN
# 7              NaN                    NaN                     NaN
# 8              NaN                    NaN                     NaN
# 9              NaN                    NaN                     NaN
# 10             NaN                    NaN                     NaN
#
#    сертификат_на_тренера статус_погашения card_used_date id prefix    number  \
# 0                    NaN              NaN            NaT      WS60    245936
# 1                    NaN              NaN            NaT      WS60    276764
# 2                    NaN              NaN            NaT      WS60    227593
# 3                    NaN          Погашен            NaT      WS60    276011
# 4                    NaN          Погашен     2023-12-09      WS60    291005
# 5                    NaN              NaN            NaT      WS60    215800
# 6                    NaN              NaN            NaT      WS60    242852
# 7                    NaN          Погашен     2023-11-09      WS60    215266
# 8                    NaN              NaN            NaT      WS60    283297
# 9                    NaN              NaN            NaT      WS60    271596
# 10                   NaN          Погашен     2023-09-09      WS60  21156334
#
#    card_type series design_type     status stock_status  sale_price  \
# 0      paper            design1                              8500.0
# 1      paper            design1                              8800.0
# 2      paper            design1                              8500.0
# 3      paper            design1  sold_used                   9600.0
# 4      paper            design1  sold_used                   9600.0
# 5      paper            design1                              9600.0
# 6      paper            design1                                 NaN
# 7      paper            design1  sold_used                      NaN
# 8      paper            design1                             16700.0
# 9      paper            design1                              9600.0
# 10     paper            design1  sold_used                      NaN
#
#    expiry_date created_at updated_at deleted_at           diff_date
# 0                                               -259 days +13:19:48
# 1                                               -256 days +23:55:06
# 2                                               -180 days +15:12:01
# 3                                               -161 days +18:18:57
# 4                                               -155 days +15:45:28
# 5                                               -130 days +21:55:16
# 6                                               -127 days +02:08:06
# 7                                               -113 days +22:50:37
# 8                                               -110 days +21:08:58
# 9                                               -102 days +16:05:52
# 10                                               -85 days +21:44:05
# 8800.0
# sale_price != 0 & prefix == "CW2"
# 2023-11-23 18:00:18
#      amo_id          этап_сделки  бюджет дата_создания_сделки  \
# 0  24313681  Успешно_реализовано   12500  2023-05-16 14:54:35
# 1  25052977  Успешно_реализовано    9600  2023-08-10 16:12:59
# 2  26025002  Успешно_реализовано    9000  2023-11-17 00:05:54
#
#             sale_date  delivery_price  стоимость_доставки  \
# 0 2023-05-16 17:44:00             0.0                 NaN
# 1 2023-08-12 14:32:00           600.0                 NaN
# 2 2023-11-18 17:59:00             NaN                 NaN
#
#                                             products    price  subtotal  \
# 0  Искусственная_волна_Flow_Moscow_(Варианты:_1_ч...  12500.0   12500.0
# 1  Искусственная_волна_Flow_Moscow_(Варианты:_1_ч...   9600.0    9000.0
# 2  Искусственная_волна_Flow_Moscow_(Варианты:_1_ч...   9000.0    9000.0
#
#   выручка_от_клиента направление_(вид_сертификата)        code  \
# 0              12500           Искусственная_волна  CW2_147390
# 1               9600           Искусственная_волна  CW2_113169
# 2               9000           Искусственная_волна  CW2_219761
#
#   корневая_сделка номер_2-го_сертификата сертификат_на_фотографа  \
# 0             NaN                    NaN                     NaN
# 1             NaN                    NaN                     NaN
# 2             NaN                    NaN                     NaN
#
#   сертификат_на_тренера статус_погашения card_used_date id prefix  number  \
# 0                   NaN              NaN            NaT       CW2  147390
# 1                   NaN              NaN            NaT       CW2  113169
# 2                   NaN              NaN            NaT       CW2  219761
#
#   card_type series design_type status stock_status  sale_price expiry_date  \
# 0     paper            design1                         12500.0
# 1     paper            design1                          9000.0
# 2     paper            design1                          9000.0
#
#   created_at updated_at deleted_at           diff_date
# 0                                  -192 days +20:54:17
# 1                                  -106 days +22:12:41
# 2                                    -7 days +06:05:36
# 9000.0
# sale_price != 0 & prefix == "SN1X"
# 2023-11-28 13:06:38
#      amo_id          этап_сделки  бюджет дата_создания_сделки  \
# 0  23497421  Успешно_реализовано    5000  2023-01-18 12:56:26
# 1  23665353  Успешно_реализовано    5350  2023-02-12 17:33:25
# 2  23713729  Успешно_реализовано    5000  2023-02-21 18:04:58
# 3  26010147  Успешно_реализовано    5500  2023-11-15 14:41:54
#
#             sale_date  delivery_price  стоимость_доставки  \
# 0 2023-01-19 15:12:00             NaN                 NaN
# 1 2023-02-16 16:52:00           350.0                 NaN
# 2 2023-02-22 20:45:00             NaN                 NaN
# 3 2023-11-16 19:26:00             0.0                 NaN
#
#                                             products   price  subtotal  \
# 0  Снегоходы_(Варианты:_1_снежик_на_1_час,_Бумажн...  5000.0    5000.0
# 1  Снегоходы_(Варианты:_1_снежик_на_1_час,_Бумажн...  5350.0    5000.0
# 2  Снегоходы_(Варианты:_1_снежик_на_1_час,_Бумажн...  5000.0    5000.0
# 3  Снегоходы_(Варианты:_1_снежик_на_1_час,_Бумажн...  5500.0    5500.0
#
#   выручка_от_клиента направление_(вид_сертификата)          code  \
# 0               5000                     Снегоходы  SN1X_1148771
# 1               5350                     Снегоходы   SN1X_171955
# 2               5000                     Снегоходы   SN1X_192640
# 3               5500                     Снегоходы   SN1X_151727
#
#   корневая_сделка номер_2-го_сертификата сертификат_на_фотографа  \
# 0             NaN                    NaN                     NaN
# 1             NaN                    NaN                     NaN
# 2             NaN                    NaN                     NaN
# 3             NaN                    NaN                     NaN
#
#   сертификат_на_тренера статус_погашения card_used_date id prefix   number  \
# 0                   NaN              NaN            NaT      SN1X  1148771
# 1                   NaN              NaN            NaT      SN1X   171955
# 2                   NaN          Погашен     2023-10-03      SN1X   192640
# 3                   NaN              NaN            NaT      SN1X   151727
#
#   card_type series design_type     status stock_status  sale_price  \
# 0     paper            design1                              5000.0
# 1     paper            design1                              5000.0
# 2     paper            design1  sold_used                   5000.0
# 3     paper            design1                              5500.0
#
#   expiry_date created_at updated_at deleted_at           diff_date
# 0                                              -315 days +23:49:48
# 1                                              -289 days +04:26:47
# 2                                              -280 days +04:58:20
# 3                                               -13 days +01:35:16
# 5000.0
# sale_price != 0 & prefix == "SN1X"
# 2023-11-28 13:18:52
#      amo_id          этап_сделки  бюджет дата_создания_сделки  \
# 0  23497421  Успешно_реализовано    5000  2023-01-18 12:56:26
# 1  23665353  Успешно_реализовано    5350  2023-02-12 17:33:25
# 2  23713729  Успешно_реализовано    5000  2023-02-21 18:04:58
# 3  26010147  Успешно_реализовано    5500  2023-11-15 14:41:54
#
#             sale_date  delivery_price  стоимость_доставки  \
# 0 2023-01-19 15:12:00             NaN                 NaN
# 1 2023-02-16 16:52:00           350.0                 NaN
# 2 2023-02-22 20:45:00             NaN                 NaN
# 3 2023-11-16 19:26:00             0.0                 NaN
#
#                                             products   price  subtotal  \
# 0  Снегоходы_(Варианты:_1_снежик_на_1_час,_Бумажн...  5000.0    5000.0
# 1  Снегоходы_(Варианты:_1_снежик_на_1_час,_Бумажн...  5350.0    5000.0
# 2  Снегоходы_(Варианты:_1_снежик_на_1_час,_Бумажн...  5000.0    5000.0
# 3  Снегоходы_(Варианты:_1_снежик_на_1_час,_Бумажн...  5500.0    5500.0
#
#   выручка_от_клиента направление_(вид_сертификата)          code  \
# 0               5000                     Снегоходы  SN1X_1148771
# 1               5350                     Снегоходы   SN1X_171955
# 2               5000                     Снегоходы   SN1X_192640
# 3               5500                     Снегоходы   SN1X_151727
#
#   корневая_сделка номер_2-го_сертификата сертификат_на_фотографа  \
# 0             NaN                    NaN                     NaN
# 1             NaN                    NaN                     NaN
# 2             NaN                    NaN                     NaN
# 3             NaN                    NaN                     NaN
#
#   сертификат_на_тренера статус_погашения card_used_date id prefix   number  \
# 0                   NaN              NaN            NaT      SN1X  1148771
# 1                   NaN              NaN            NaT      SN1X   171955
# 2                   NaN          Погашен     2023-10-03      SN1X   192640
# 3                   NaN              NaN            NaT      SN1X   151727
#
#   card_type series design_type     status stock_status  sale_price  \
# 0     paper            design1                              5000.0
# 1     paper            design1                              5000.0
# 2     paper            design1  sold_used                   5000.0
# 3     paper            design1                              5500.0
#
#   expiry_date created_at updated_at deleted_at           diff_date
# 0                                              -315 days +23:37:34
# 1                                              -289 days +04:14:33
# 2                                              -280 days +04:46:06
# 3                                               -13 days +01:23:02
# 5000.0

# %%
df_amo_temp.head()
# Out:
#      amo_id          этап_сделки  бюджет дата_создания_сделки  \
# 0  23400119  Успешно_реализовано    5000  2023-01-02 16:00:55
# 1  23400461  Успешно_реализовано    4500  2023-01-02 18:01:25
# 2  23400807  Успешно_реализовано    9000  2023-01-02 20:48:09
# 3  23401947  Успешно_реализовано   12345  2023-01-03 11:35:11
# 4  23403789  Успешно_реализовано    5000  2023-01-03 21:56:43
#
#             sale_date  delivery_price  стоимость_доставки  \
# 0 2023-01-02 16:08:00             0.0                 NaN
# 1 2023-01-02 18:10:00             NaN                 NaN
# 2 2023-01-03 10:18:00             0.0                 NaN
# 3 2023-01-03 12:19:00             0.0                 NaN
# 4 2023-01-04 15:19:00             NaN                 NaN
#
#                                             products    price  subtotal  \
# 0  Снегоходы_(Варианты:_1_снежик_на_1_час,_Бумажн...   5000.0    5000.0
# 1  Полет_на_параплане_(Варианты:_1_полет_с_инстру...   4500.0    4500.0
# 2  Снегоходы_(Варианты:_2_снежика_на_1_час,_Бумаж...   9000.0    9000.0
# 3  Подарочный_сертификат_на_12_345_рублей_-_1x123...  12345.0   12345.0
# 4  Квадроциклы_(Варианты:_2_квадрика_на_1_час_без...   9000.0    9000.0
#
#   выручка_от_клиента направление_(вид_сертификата)           code  \
# 0               5000                     Снегоходы  VSN1X_2438352
# 1               4500                      Параплан     P1G_251473
# 2               9000                     Снегоходы  VSN2X_2497270
# 3              12345   Универсальный_Мосвейк_12345   VW&F_2421026
# 4               5000                   Квадроциклы  KVP1X1_138834
#
#   корневая_сделка номер_2-го_сертификата сертификат_на_фотографа  \
# 0             NaN                    NaN                     NaN
# 1             NaN                    NaN                     NaN
# 2             NaN                    NaN                     NaN
# 3             NaN                    NaN                     NaN
# 4             NaN      VKV2X1_2415531DIZ                     NaN
#
#   сертификат_на_тренера статус_погашения card_used_date id  prefix   number  \
# 0                   NaN          Погашен     2023-06-02      VSN1X  2438352
# 1                   NaN              NaN            NaT        P1G   251473
# 2                   NaN          Погашен     2023-11-02      VSN2X  2497270
# 3                   NaN          Погашен            NaT       VW&F  2421026
# 4                   NaN          Погашен            NaT     KVP1X1   138834
#
#     card_type series design_type     status stock_status  sale_price  \
# 0  electronic            design1  sold_used                   5000.0
# 1       paper            design1                              4500.0
# 2  electronic            design1  sold_used                   9000.0
# 3  electronic            design1  sold_used                  12345.0
# 4       paper            design1  sold_used                  11200.0
#
#   expiry_date created_at updated_at deleted_at
# 0
# 1
# 2
# 3
# 4

# %%
null_sale_price_after = df_amo_temp.loc[df_amo_temp['amo_id'].isin(idx)]

# %%
null_sale_price_after
# Out:
#         amo_id          этап_сделки  бюджет дата_создания_сделки  \
# 4     23403789  Успешно_реализовано    5000  2023-01-03 21:56:43
# 31    23459939  Успешно_реализовано       0  2023-01-13 11:41:15
# 32    23460055  Успешно_реализовано   10000  2023-01-13 11:50:38
# 38    23466787  Успешно_реализовано       0  2023-01-14 18:11:28
# 44    23476291  Успешно_реализовано   10000  2023-01-16 14:34:03
# ...        ...                  ...     ...                  ...
# 2580  26042895  Успешно_реализовано       0  2023-11-19 10:36:50
# 2582  25821661  Успешно_реализовано   14200  2023-11-19 21:15:54
# 2594  26095709  Успешно_реализовано   12950  2023-11-23 18:00:18
# 2611  26139623  Успешно_реализовано   11450  2023-11-28 13:06:38
# 2612  26139797  Успешно_реализовано       0  2023-11-28 13:18:52
#
#                sale_date  delivery_price  стоимость_доставки  \
# 4    2023-01-04 15:19:00             NaN                 NaN
# 31   2023-01-13 11:42:00             NaN                 NaN
# 32   2023-01-13 11:59:00             NaN                 NaN
# 38   2023-01-18 10:48:00             NaN                 NaN
# 44   2023-01-16 16:17:00             NaN                 NaN
# ...                  ...             ...                 ...
# 2580 2023-11-20 12:51:00             NaN                 NaN
# 2582 2023-11-22 11:11:00             NaN                 NaN
# 2594 2023-11-25 12:03:00           450.0                 NaN
# 2611 2023-12-02 22:29:00           450.0                 NaN
# 2612 2023-12-02 22:30:00             NaN                 NaN
#
#                                                products    price  subtotal  \
# 4     Квадроциклы_(Варианты:_2_квадрика_на_1_час_без...   9000.0    9000.0
# 31                                                  NaN      NaN       NaN
# 32    Заезд_на_багги_(Варианты:_Занятие_для_одного_1...  10000.0   10000.0
# 38                                                  NaN      NaN       NaN
# 44    Снегоходы_(Варианты:_1_снежик_на_2_часа,_Бумаж...   9000.0    9000.0
# ...                                                 ...      ...       ...
# 2580                                                NaN      NaN       NaN
# 2582  Подарочный_сертификатна_вейкборд_(Выберите_тип...  14200.0   14200.0
# 2594  Искусственная_волна_Flow_Moscow_(Варианты:_1_ч...  12950.0   12500.0
# 2611  Снегоходы_(Варианты:_1_снежик_на_1_час,_Бумажн...  11450.0   11000.0
# 2612                                                NaN      NaN       NaN
#
#      выручка_от_клиента направление_(вид_сертификата)             code  \
# 4                  5000                   Квадроциклы    KVP1X1_138834
# 31                  NaN           Искусственная_волна    VCW1T_2437849
# 32                10000              Мото_Дрифт-трайк     VDTM_3651601
# 38                  NaN                     Снегоходы      S_N2X226233
# 44                 9000                     Снегоходы  VKVP2X1_2696914
# ...                 ...                           ...              ...
# 2580                NaN                       Картинг       KAT_154768
# 2582              14200    Вейксёрф_и_вейк_за_катером      WS60_239527
# 2594              12950           Искусственная_волна       CW2_267873
# 2611              11450                     Снегоходы      SN1X_199622
# 2612                  0                     Снегоходы      SN1X_184479
#
#      корневая_сделка номер_2-го_сертификата сертификат_на_фотографа  \
# 4                NaN      VKV2X1_2415531DIZ                     NaN
# 31         #23459729                    NaN                     NaN
# 32               NaN        VBGH_2415955DIS                     NaN
# 38        1715029001                    NaN                     NaN
# 44               NaN       VSN2X_2416042DIS                     NaN
# ...              ...                    ...                     ...
# 2580       #26042871                    NaN                     NaN
# 2582             NaN                    NaN                     NaN
# 2594             NaN            TR2K_030117                     NaN
# 2611             NaN            SN1X_191480                     NaN
# 2612       #26139623                    NaN                     NaN
#
#      сертификат_на_тренера статус_погашения card_used_date id   prefix  \
# 4                      NaN          Погашен            NaT      KVP1X1
# 31                     NaN          Погашен     2023-05-06       VCW1T
# 32                     NaN              NaN            NaT        VDTM
# 38                     NaN          Погашен     2023-03-03           S
# 44                     NaN              NaN            NaT     VKVP2X1
# ...                    ...              ...            ... ..      ...
# 2580                   NaN              NaN            NaT         KAT
# 2582           TR2K_030782              NaN            NaT        WS60
# 2594                   NaN              NaN            NaT         CW2
# 2611                   NaN              NaN            NaT        SN1X
# 2612                   NaN              NaN            NaT        SN1X
#
#          number   card_type series design_type     status stock_status  \
# 4        138834       paper            design1  sold_used
# 31      2437849  electronic            design1  sold_used
# 32      3651601  electronic            design1
# 38    N2X226233       paper            design1  sold_used
# 44      2696914  electronic            design1
# ...         ...         ...    ...         ...        ...          ...
# 2580     154768       paper            design1
# 2582     239527       paper            design1
# 2594     267873       paper            design1
# 2611     199622       paper            design1
# 2612     184479       paper            design1
#
#       sale_price expiry_date created_at updated_at deleted_at
# 4        11200.0
# 31       11200.0
# 32       11200.0
# 38       11200.0
# 44       11200.0
# ...          ...         ...        ...        ...        ...
# 2580     11200.0
# 2582     11200.0
# 2594     11200.0
# 2611     11200.0
# 2612     11200.0
#
# [312 rows x 32 columns]

# %%
import numpy as np

# %%
matrix = [(22, 16, 23),
          (33, np.NaN, 11),
          (44, 34, 11),
          (55, 35, np.NaN),
          (66, 36, 13)
          ]

# %%
matrix
# Out:
# [(22, 16, 23), (33, nan, 11), (44, 34, 11), (55, 35, nan), (66, 36, 13)]

# %%
str1 = f'sale_price != 0 & prefix == "KVP1X1"'
v = df_amo_temp.query(str1)

# %%
v
# Out:
#         amo_id          этап_сделки  бюджет дата_создания_сделки  \
# 89    23561917  Успешно_реализовано    5000  2023-01-27 00:28:11
# 159   23665615  Успешно_реализовано    5000  2023-02-12 18:27:04
# 353   23794517  Успешно_реализовано   10000  2023-03-04 12:30:45
# 383   23825623  Успешно_реализовано    5000  2023-03-09 14:26:48
# 424   23902297  Успешно_реализовано    5000  2023-03-20 09:36:32
# 425   23902879  Успешно_реализовано    5500  2023-03-20 10:52:44
# 438   23922623  Успешно_реализовано    5000  2023-03-23 09:19:09
# 480   23973519  Успешно_реализовано    5000  2023-03-30 15:34:39
# 813   24324971  Успешно_реализовано    5350  2023-05-17 20:11:32
# 905   24389017  Успешно_реализовано    5600  2023-05-25 11:05:28
# 1067  24479765  Успешно_реализовано    5000  2023-06-06 12:26:12
# 1815  24918087  Успешно_реализовано    5000  2023-07-27 16:33:25
# 1966  25039649  Успешно_реализовано    5000  2023-08-08 14:48:29
# 1980  25044777  Успешно_реализовано    5450  2023-08-09 16:23:34
# 2234  25252547  Успешно_реализовано    5450  2023-09-07 00:10:46
# 2359  25424339  Успешно_реализовано    5000  2023-09-27 12:32:01
# 2391  25527309  Успешно_реализовано    5000  2023-10-03 15:49:06
#
#                sale_date  delivery_price  стоимость_доставки  \
# 89   2023-01-27 09:42:00             0.0                 NaN
# 159  2023-02-16 16:52:00             0.0                 NaN
# 353  2023-03-04 12:40:00             NaN                 NaN
# 383  2023-03-10 19:42:00           500.0                 NaN
# 424  2023-03-22 14:30:00           500.0                 NaN
# 425  2023-03-23 15:54:00           500.0                 NaN
# 438  2023-03-25 18:52:00             NaN                 NaN
# 480  2023-04-01 17:42:00             NaN                 NaN
# 813  2023-05-19 13:59:00             NaN                 NaN
# 905  2023-05-26 08:44:00           600.0                 NaN
# 1067 2023-06-06 13:42:00             0.0                 NaN
# 1815 2023-07-27 17:49:00             NaN                 NaN
# 1966 2023-08-09 11:45:00             NaN                 NaN
# 1980 2023-08-11 09:21:00           450.0                 NaN
# 2234 2023-09-09 11:46:00           450.0                 NaN
# 2359 2023-09-29 12:50:00             NaN                 NaN
# 2391 2023-10-05 11:23:00           450.0                 NaN
#
#                                                products    price  subtotal  \
# 89    Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5000.0    5000.0
# 159   Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5000.0    5000.0
# 353   Квадроциклы_(Варианты:_1_квадрик_2_часа_с_пасс...  10000.0   10000.0
# 383   Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5500.0    5000.0
# 424   Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5500.0    5000.0
# 425   Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5500.0    5000.0
# 438   Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5000.0    5000.0
# 480   Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5000.0    5000.0
# 813   Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5000.0    5000.0
# 905   Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5600.0    5000.0
# 1067  Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5000.0    5000.0
# 1815  Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5000.0    5000.0
# 1966  Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5000.0    5000.0
# 1980  Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5000.0    5000.0
# 2234  Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5450.0    5000.0
# 2359  Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5000.0    5000.0
# 2391  Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5450.0    5000.0
#
#      выручка_от_клиента направление_(вид_сертификата)           code  \
# 89                 5000                   Квадроциклы  KVP1X1_151326
# 159                5000                   Квадроциклы  KVP1X1_150930
# 353               10000                   Квадроциклы   KVP1X1_68697
# 383                5000                   Квадроциклы  KVP1X1_259672
# 424                5000                   Квадроциклы  KVP1X1_145512
# 425                5500                   Квадроциклы  KVP1X1_199463
# 438                5000                   Квадроциклы  KVP1X1_196623
# 480                5000                   Квадроциклы  KVP1X1_193739
# 813                5350                   Квадроциклы  KVP1X1_177017
# 905                5600                   Квадроциклы  KVP1X1_137725
# 1067               5000                   Квадроциклы  KVP1X1_165798
# 1815               5000                   Квадроциклы  KVP1X1_172502
# 1966               5000                   Квадроциклы  KVP1X1_137700
# 1980               5450                   Квадроциклы  KVP1X1_158757
# 2234               5450                   Квадроциклы  KVP1X1_293302
# 2359               5000                   Квадроциклы  KVP1X1_297840
# 2391               5000                   Квадроциклы  KVP1X1_199253
#
#      корневая_сделка номер_2-го_сертификата сертификат_на_фотографа  \
# 89               NaN                    NaN                     NaN
# 159              NaN                    NaN                     NaN
# 353              NaN                    NaN                     NaN
# 383              NaN                    NaN                     NaN
# 424              NaN                    NaN                     NaN
# 425              NaN                    NaN                     NaN
# 438              NaN                    NaN                     NaN
# 480              NaN                    NaN                     NaN
# 813              NaN                    NaN                     NaN
# 905              NaN                    NaN                     NaN
# 1067             NaN                    NaN                     NaN
# 1815             NaN                    NaN                     NaN
# 1966             NaN                    NaN                     NaN
# 1980             NaN                    NaN                     NaN
# 2234             NaN                    NaN                     NaN
# 2359             NaN                    NaN                     NaN
# 2391             NaN                    NaN                     NaN
#
#      сертификат_на_тренера статус_погашения card_used_date id  prefix  number  \
# 89                     NaN          Погашен     2023-08-10     KVP1X1  151326
# 159                    NaN          Погашен     2023-12-10     KVP1X1  150930
# 353                    NaN              NaN            NaT     KVP1X1   68697
# 383                    NaN          Погашен            NaT     KVP1X1  259672
# 424                    NaN          Погашен            NaT     KVP1X1  145512
# 425                    NaN          Погашен            NaT     KVP1X1  199463
# 438                    NaN          Погашен            NaT     KVP1X1  196623
# 480                    NaN          Погашен            NaT     KVP1X1  193739
# 813                    NaN          Погашен     2023-03-10     KVP1X1  177017
# 905                    NaN          Погашен            NaT     KVP1X1  137725
# 1067                   NaN              NaN            NaT     KVP1X1  165798
# 1815                   NaN              NaN            NaT     KVP1X1  172502
# 1966                   NaN          Погашен            NaT     KVP1X1  137700
# 1980                   NaN              NaN            NaT     KVP1X1  158757
# 2234                   NaN              NaN            NaT     KVP1X1  293302
# 2359                   NaN              NaN            NaT     KVP1X1  297840
# 2391                   NaN          Погашен     2023-07-10     KVP1X1  199253
#
#      card_type series design_type     status stock_status  sale_price  \
# 89       paper            design1  sold_used                   5000.0
# 159      paper            design1  sold_used                   5000.0
# 353      paper            design1                             10000.0
# 383      paper            design1  sold_used                   5000.0
# 424      paper            design1  sold_used                   5000.0
# 425      paper            design1  sold_used                   5000.0
# 438      paper            design1  sold_used                   5000.0
# 480      paper            design1  sold_used                   5000.0
# 813      paper            design1  sold_used                   5000.0
# 905      paper            design1  sold_used                   5000.0
# 1067     paper            design1                              5000.0
# 1815     paper            design1                              5000.0
# 1966     paper            design1  sold_used                   5000.0
# 1980     paper            design1                              5000.0
# 2234     paper            design1                              5000.0
# 2359     paper            design1                              5000.0
# 2391     paper            design1  sold_used                   5000.0
#
#      expiry_date created_at updated_at deleted_at
# 89
# 159
# 353
# 383
# 424
# 425
# 438
# 480
# 813
# 905
# 1067
# 1815
# 1966
# 1980
# 2234
# 2359
# 2391

# %%
from datetime import datetime

# Example with the standard date and time format
date_str = '2023-03-20 10:52:44'
date_format = '%Y-%m-%d %H:%M:%S'

date_obj = datetime.strptime(date_str, date_format)
#t = '2023-03-20 10:52:44'
#pd.to_datetime(df['I_DATE'])

# %%
k = df_amo_temp.copy()

# %%
k['diff_date'] = abs(k['дата_создания_сделки'] - date_obj)

# %%
k = k.sort_values(by='diff_date',ascending=True)

# %%
k.reset_index(drop= True , inplace= True)

# %%
k = k.drop(index=0)

# %%
k.head(10)
# Out:
#       amo_id          этап_сделки  бюджет дата_создания_сделки  \
# 1   23902297  Успешно_реализовано    5000  2023-03-20 09:36:32
# 2   23906061  Успешно_реализовано   12100  2023-03-20 16:11:55
# 3   23908115  Успешно_реализовано       0  2023-03-20 21:14:58
# 4   23908435  Успешно_реализовано    4200  2023-03-20 23:20:25
# 5   23899989  Успешно_реализовано    5700  2023-03-19 21:40:53
# 6   23898263  Успешно_реализовано    3300  2023-03-19 16:31:25
# 7   23897495  Успешно_реализовано   13200  2023-03-19 13:38:43
# 8   23896621  Успешно_реализовано    9000  2023-03-19 10:37:56
# 9   23910753  Успешно_реализовано    4500  2023-03-21 11:28:22
# 10  23906549  Успешно_реализовано    5500  2023-03-21 14:06:56
#
#              sale_date  delivery_price  стоимость_доставки  \
# 1  2023-03-22 14:30:00           500.0                 NaN
# 2  2023-03-22 07:50:00             0.0                 NaN
# 3  2023-03-22 07:51:00             NaN                 NaN
# 4  2023-03-22 14:57:00             0.0                 NaN
# 5  2023-03-19 23:36:00             0.0                 NaN
# 6  2023-03-20 21:20:00           700.0                 NaN
# 7  2023-03-21 09:31:00           700.0                 NaN
# 8  2023-03-21 09:30:00             0.0                 NaN
# 9  2023-03-21 11:38:00             0.0                 NaN
# 10 2023-03-25 18:52:00           500.0                 NaN
#
#                                              products    price  subtotal  \
# 1   Квадроциклы_(Варианты:_1_квадрик_1_час_с_пасса...   5500.0    5000.0
# 2   Аэротруба_(Варианты:_6_минут_полёта_(для_1-2_ч...  11200.0   11200.0
# 3                                                 NaN      NaN       NaN
# 4   Подарочный_сертификатна_вейкборд_(Выберите_тип...   4200.0    4200.0
# 5   Подарочный_сертификатна_вейкборд_(Выберите_тип...   5700.0    5700.0
# 6   катание_на_картинге_(Варианты:_20_минут_катани...   3300.0    2600.0
# 7   Искусственная_волна_Flow_Moscow_(Варианты:_1_ч...  13200.0   12500.0
# 8   Квадроциклы_(Варианты:_2_квадрика_на_1_час_без...   9000.0    9000.0
# 9   Квадроциклы_(Варианты:_1_квадрик_1_час_без_пас...   4500.0    4500.0
# 10  Катер_без_капитана_(Варианты:_1_час_проката,_Б...   6000.0    5500.0
#
#    выручка_от_клиента   направление_(вид_сертификата)            code  \
# 1                5000                     Квадроциклы   KVP1X1_145512
# 2               12100                       Аэротруба      AT6_213999
# 3                 NaN                       Аэротруба     AT6K_023008
# 4                4200      Вейксёрф_и_вейк_за_катером     WS20_188511
# 5                5700      Вейксёрф_и_вейк_за_катером  VWS30T_2728643
# 6                3300                         Картинг      KA2_294513
# 7               13200             Искусственная_волна      CW2_020814
# 8                9000                     Квадроциклы    KV2X1_197558
# 9                4500                     Квадроциклы  VKV1X1_2741578
# 10               5500  Катер_без_капитана_(Летолодка)     LL1H_151254
#
#    корневая_сделка номер_2-го_сертификата сертификат_на_фотографа  \
# 1              NaN                    NaN                     NaN
# 2              NaN                    NaN                     NaN
# 3        #23906061                    NaN                     NaN
# 4              NaN                    NaN                     NaN
# 5              NaN                    NaN                     NaN
# 6              NaN                    NaN                     NaN
# 7              NaN                    NaN                     NaN
# 8              NaN                    NaN                     NaN
# 9              NaN                    NaN                     NaN
# 10             NaN                    NaN                     NaN
#
#    сертификат_на_тренера статус_погашения card_used_date id  prefix   number  \
# 1                    NaN          Погашен            NaT     KVP1X1   145512
# 2                    NaN          Погашен            NaT        AT6   213999
# 3                    NaN          Погашен            NaT       AT6K   023008
# 4             TR2_220734          Погашен     2023-12-08       WS20   188511
# 5                    NaN              NaN            NaT     VWS30T  2728643
# 6                    NaN              NaN            NaT        KA2   294513
# 7             TR2_220644          Погашен            NaT        CW2   020814
# 8                    NaN              NaN            NaT      KV2X1   197558
# 9                    NaN          Погашен            NaT     VKV1X1  2741578
# 10                   NaN              NaN            NaT       LL1H   151254
#
#      card_type series design_type     status stock_status  sale_price  \
# 1        paper            design1  sold_used                   5000.0
# 2        paper            design1  sold_used                  11200.0
# 3        paper            design1  sold_used                      0.0
# 4        paper            design1  sold_used                      0.0
# 5   electronic            design1                              5700.0
# 6        paper            design1                              2600.0
# 7        paper            design1  sold_used                      0.0
# 8        paper            design1                              9000.0
# 9   electronic            design1  sold_used                   4500.0
# 10       paper            design1                              5500.0
#
#    expiry_date created_at updated_at deleted_at       diff_date
# 1                                               0 days 01:16:12
# 2                                               0 days 05:19:11
# 3                                               0 days 10:22:14
# 4                                               0 days 12:27:41
# 5                                               0 days 13:11:51
# 6                                               0 days 18:21:19
# 7                                               0 days 21:14:01
# 8                                               1 days 00:14:48
# 9                                               1 days 00:35:38
# 10                                              1 days 03:14:12

# %%
k.iloc[0]['sale_price']
# Out:
# 5000.0
