# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Итак, мои комментарии на этот раз будут зелёными, в заголовке иметь версию V2 (как у этого!) и в них я буду стараться ответить на твои вопросы, если таковые увижу (мелкие/"проходные" изменения/исправления в тексте проекта, каждое из них, не буду с твоего позволения комментировать - только те моменты, где я что-то более-менее не банальное могу сказать. Хорошо? Будем считать, что, если комментария на твое исправление нет - значит я согласен с тобой в этом пункте).
#
# ………………
#
# Я вижу, что все красные комментарии учтены, код исправлен, выводы актуализированы. Соответственно никаких вопросов/моментов/комментариев, мешающих принять твой проект у меня более нет.
#
# ПРОЕКТ ПРИНЯТ!
#
# Я же в свою очередь, ниже попытался ответить на все твои вопросы (если видел, что они есть).
#
# Желаю тебе успехов в учёбе, желаю, чтобы проекты сдавались или сразу, или после первой итерации! Удачи!
#
# p.s. я тебе на твой адрес эл/почты сейчас вышлю некоторые материалы из своей электронной библиотеки - надеюсь они будут тебе полезными в учёбе.</div>

# %% [markdown]
# Приветствую коллега!
#
# Меня зовут Александр Непомнящий и я буду проверять твой проект. Предлагаю общаться на «ты» :))) Но, если это не удобно - мы вполне можем перейти на вы".
#
# Вкратце обо мне: я работаю в сфере информационных технологий, аналитика (анализ) данных - это и мой рабочий функционал и личная, интересная мне область для саморазвития. Используемый стек: python, pandas, графические библиотеки matplotlib/seaborn/plotly. Сфера применения: маркетинговая аналитика в медицинской клинике (Клиника «Кивач», www.kivach.ru, республика Карелия). Если вдруг есть вопрос – что делает аналитик в коммерческой медицине – то вот короткий ответ. Самый главный вопрос, на который мы хотим получить ответ (и который в дальнейшем приведёт к перераспределению рекламного бюджета, плюс напрямую повлияет на разработку и предложению рынку новых лечебных программ) - это КТО ОН, НАШ КЛИЕНТ? Фактически это задача (на нашем внутреннем языке формулируется как построение и анализ «ПОРТРЕТА КЛИЕНТА»). Визуализируем и пытаемся придать смысл половозрастным данным наших клиентов, кто из какого региона и в какие времена года к нам приезжает. Учитываем количество приездов. Учитываем на какую программу этот конкретный клиент приехал в первый раз и как в дальнейшем меняются его предпочтения. Пытаемся построить модель оттока и спрогнозировать, когда клиент уйдёт в отток. Смотрим цифры (суммы трат клиентов на отдельных группах медицинских программ). Анализируем медицинские услуги, которые входят в путёвку, а также что, в каких количествах и на какую сумму клиент покупает дополнительно. Очень вкратце как-то так.
#
# Теперь к сути: основная цель моей проверки - пройти по шагам, по логике твоего решения и обсудить те моменты, которые можно изменить, улучшить, довести до идеала. Такой формат работы двух программистов (аналитиков) ты или уже встречал(а), или встретишь на своей новой работе. Кто-то такой процесс называет "код-ревью", ну а как по мне, так это обмен опытом двух коллег, когда каждый из нас становиться лучше в процессе дискуссии.
#
# Свои мысли, советы, комментарии и вопросы я буду оставлять в текстовых ячейках (markdown) ПОД твоим кодом.
# Для твоего удобства все эти заметки будут "цветными", как на примерах ниже:
#
# "Зелеными" комментариями я буду отмечать твой элегантный ("красивый") код и/или удачные решения, на которые ты можешь смело опираться в будущих проектах.
# <div class="alert alert-success">
# <b>Отлично! 👍</b>
#
# Отличная находка, элегантный код ...</div>
#
# "Жёлтые" комментарии - это мои размышления, предложения, что-то, что на следующей итерации можно сделать по-другому. Твоя реакция на "жёлтые" комментарий необходима и подразумевает или правки, или реакцию или аргументированное согласие/не согласие. Я искренне верю, что наш двусторонний диалог под "желтым" комментарием - это то, от чего твой проект только выиграет. <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Здесь я бы предложил использовать .... Мои аргументы в пользу этого ...</div>
#
# "Красные" комментарий будут появляться, когда что-то пойдёт не так: например, код будет выдавать ошибку. Или, когда в проекте не будет ответов на основные вопросы, ради которых весь анализ и выполнялся. "Красные" комментарии необходимо будет исправить, прежде чем я смогу принять проект.
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# В этой ячейке код работает не так как задумано ...</div>
#
# Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии. Это поможет мне оперативно выполнить повторную проверку твоего проекта.
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом, лучше всего в новой ячейке, сразу под моим комментарием. Если для своих комментариев ты будешь использовать какой-то заметный цвет, то мне будет легче отследить твои изменения, например так:
#
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Текст твоего комментария ...</font>
# </div>
#
# Ну и наконец информируй меня в том случае, если по твоему проекту подходит дедлайн! В таком случае я приложу усилия, чтобы ты сдал(а) его вовремя; буду оперативно, в приоритете проверять итерации ревью, а также отвечать на твои вопросы, если этого будет требовать ситуация.
#
# **Распространенные типичные недочёты в проектах студентов:**
#
# <div class="alert alert-danger" ❌>
# Неработоспособный код. Проверь проект на работоспособность перед отправкой на проверку. Это важный навык, который тебе пригодится как на собеседовании, при выполнении тестового задания, так и перед совещанием у руководства компании.</div>
#
# <div class="alert alert-danger" ❌>
# Проект не структурирован. В проекте должна быть структура, т.е. названия разделов и подразделов должны быть записаны в ячейках Markdown.</div>
#
# <div class="alert alert-warning" 👉 >
# Отсутствие описания, целей проекта, его задач, выводов. В описании должны быть озвучены поставленные задачи, содержание датасета, промежуточные и финальные выводы. Как правило, заказчик читает только финальный вывод, поэтому важно добавить информацию о проведенном исследовании, применить форматирование текста, в общем, сделать красиво, чтобы было понятно, что проведено настоящее исследование и выводу можно верить.</div>
#
# <div class="alert alert-warning" 👉 >
# "Длинный код". Код и и комментарии, которые прячутся за правым концом ячейки нужно переносить на новую строку. Твои будущие коллеги не оценят необходимость постоянного скроллинга. Согласно PEP8: https://www.python.org/dev/peps/pep-0008/ длина строки не должна превышать 79 символов.</div>
#
# <div class="alert alert-warning" 👉 >
# Твои коллеги ценят и твое и своё время, поэтому "подсвечивай" свои комментарии в ячейках Markdown. Подробнее про синтаксис Markdown, с примерами, можно почитать здесь: https://paulradzkov.com/2014/markdown_cheatsheet/?</div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Небольшая вводная перед исследованием даст быстрое понимание о том, чему оно посвящено. Я настоятельно рекомендую тебе оформить введение и добавить цели и задачи.
#
# Например так:
#
# ____
#
# **Название проекта**
# _____
# **Описание исследования.**
#
# _____
# **Цель исследования.**
#
# Суть исследования. Например:
#
# Провести анализ данных при помощи которых предприятие разработает стратегию взаимодействия с клиентами.
#
# _____
# **Задачи исследования.**
#
# Действия, необходимые для достижения поставленной цели.
# _____
# **Исходные данные.**
#
# Здесь описываешь исходные таблицы.
# ______
#
# **Данное исследование разделим на несколько частей.**
#
# ***Часть 1. Изучение общей информации:***
# * [1. Изученеие файлов с данными, получение общей информации, загрузка библиотек.](#1-bullet)
# * [2. Нахождение и ликвидация пропусков.](#2-bullet)
#
# ***Часть 2. Подготовка данных:***
# * [1. Приведение данных к нужным типам.](#3-bullet)
# * [2. Нахождение и исправление аномалий и ошибок.](#4-bullet)
#
# и т.д
#
# Старайся выполнять свой проект в порядке, прописанном в твоем плане. Да, такое оформление займет больше времени, но затем позволит быстро и последовательно идти по шагам выполнения.
# _________________
#
# Обрати внимание, что пункты в частях у меня в виде ссылок. Это очень удобно, когда нужно переходить по разным частям проекта.
# Вот тут почитай, как сделать <a href="https://sebastianraschka.com/Articles/2014_ipython_internal_links.html">кликабельные разделы</a>. Кликабельность сама по себе не обязательна, но план и цели, хотя бы кратко всегда прописывать желательно.
#
# **Почему это важно?** Когда ты будешь в будущем выполнять тестовые задания, просто скопировав присланную тебе задачу и не составив плана, ты можешь этим смутить своего будущего работодателя. А чётко структурированный план покажет тебя как логично и системно думающего аналитика. Также такой подход научит тебя структурировать исследование и не путаться при работе с большими проектами. </div>

# %% [markdown]
# # Исследование продаж игровых платформ

# %% [markdown]
# **Цель исследования**

# %% [markdown]
# Провести анализ данных для построения стратегии деятельности компании в области рекламы на предстоящий год.

# %% [markdown]
# **Задачи исследования:**

# %% [markdown]
# Изучить общую информацию
# Выполнить подготовку данных
# Провести исследование данных
# Сделать вывод

# %% [markdown]
# Часть 1. Изучение общей информации:<br>
#     1. Изученеие файлов с данными, получение общей информации, загрузка библиотек.<br>
#     2. Нахождение и ликвидация пропусков.<br>
# Часть 2. Подготовка данных:<br>
#     1. Приведение данных к нужным типам.<br>
#     2. Нахождение и исправление аномалий и ошибок.<br>
# Часть 3. Исследоваие данных:<br>
#     1. Определение количества игр, выпускаемых в разные годы.<br>
#     2. Выбор платформ с наибольшими суммарными продажами.<br>
#     3. Определение актуального периода<br>
#     4. Вычисление статистик для платформ.<br>
#     5. Определение влияния отзывов пользователей критиков на продажи<br>
#     6. Нахождение самых прибыльных жанров.<br>
# Часть 4. Создание портрета пользователей регионов:<br>
#     1. По платформам<br>
#     2. По жанрам<br>
#     3. По рейтингу ESRB<br>
# Часть 5. Проверка гипотез:<br>
# Часть 6. Написание вывода и рекомендаций:<br>

# %% [markdown]
# **Описание данных**

# %% [markdown]
# •	Name — название игры <br>
# •	Platform — платформа<br>
# •	Year_of_Release — год выпуска<br>
# •	Genre — жанр игры <br>
# •	NA_sales — продажи в Северной Америке (миллионы проданных копий)<br>
# •	EU_sales — продажи в Европе (миллионы проданных копий)<br>
# •	JP_sales — продажи в Японии (миллионы проданных копий)<br>
# •	Other_sales — продажи в других странах (миллионы проданных копий)<br>
# •	Critic_Score — оценка критиков (максимум 100)<br>
# •	User_Score — оценка пользователей (максимум 10)<br>
# •	Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.<br>

# %% [markdown]
# ## Изучение общей информации <a id='dataexp'></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats as st

# %%
df = pd.read_csv('/datasets/games.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
df.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#    NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     41.36     28.96      3.77         8.45          76.0          8      E
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# Имена столбцов необходимо привести к нижнему регистру.<br>
# В столбцах **Year_of_Release** и **User_Score** необходимо изменить тип данных.

# %% [markdown]
# Приводим названия столбцов к нижнему регистру

# %%
df.columns = df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales',
#        'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating'],
#       dtype='object')

# %% [markdown]
# Считаем пропуски

# %%
df.isna().sum()
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# dtype: int64

# %% [markdown]
# Проверяем уникальные значения в столбцах

# %% [markdown]
# **name**

# %%
obj_name = df['name'].unique()

# %%
obj_name
# Out:
# array(['Wii Sports', 'Super Mario Bros.', 'Mario Kart Wii', ...,
#        'Woody Woodpecker in Crazy Castle 5', 'LMA Manager 2007',
#        'Haitaka no Psychedelica'], dtype=object)

# %%
obj_name.shape[0]
# Out:
# 11560

# %% [markdown]
# Строки с пропущенными значениями наименований игр необходимо будет удалить. Пропуски в имени случайны, но восстановить их нет возможности по имеющимся данным.

# %% [markdown]
# **year_of_release**

# %%
obj_yr = df['year_of_release'].unique()

# %%
obj_yr
# Out:
# array([2006., 1985., 2008., 2009., 1996., 1989., 1984., 2005., 1999.,
#        2007., 2010., 2013., 2004., 1990., 1988., 2002., 2001., 2011.,
#        1998., 2015., 2012., 2014., 1992., 1997., 1993., 1994., 1982.,
#        2016., 2003., 1986., 2000.,   nan, 1995., 1991., 1981., 1987.,
#        1980., 1983.])

# %% [markdown]
# Столбец содержит пропуски

# %%
df.query('year_of_release.isna()').head(20)
# Out:
#                                              name platform  year_of_release  \
# 183                               Madden NFL 2004      PS2              NaN
# 377                              FIFA Soccer 2004      PS2              NaN
# 456                    LEGO Batman: The Videogame      Wii              NaN
# 475                    wwe Smackdown vs. Raw 2006      PS2              NaN
# 609                                Space Invaders     2600              NaN
# 627                                     Rock Band     X360              NaN
# 657      Frogger's Adventures: Temple of the Frog      GBA              NaN
# 678   LEGO Indiana Jones: The Original Adventures      Wii              NaN
# 719                                Call of Duty 3      Wii              NaN
# 805                                     Rock Band      Wii              NaN
# 1131                      Call of Duty: Black Ops       PC              NaN
# ...

# %% [markdown]
# Некоторые пропуски в поле **year_of_release** можно восстановить из имени. Остальные оставим без изменений.  Столбец необходимо будет привести к типу **int**

# %% [markdown]
# **Platform**

# %%
obj_pl = df['platform'].unique()

# %%
obj_pl
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        'PS4', '3DS', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne',
#        'WiiU', 'GC', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %% [markdown]
# Дубликатов нет

# %% [markdown]
# **Genre**

# %%
obj_gen = df['genre'].unique()

# %%
obj_gen
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy', nan], dtype=object)

# %%
df.query('genre.isna()').head(20)
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN           1993.0   NaN      1.78      0.53      0.00
# 14244  NaN      GEN           1993.0   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating
# 659           0.08           NaN        NaN    NaN
# 14244         0.00           NaN        NaN    NaN

# %% [markdown]
# Пропуски в тех же строках, где и пропуски в именах, будут удалены вместе с ними

# %% [markdown]
# **Critic_Score**

# %%
df.query('critic_score.isna()').head(20)
# Out:
#                                          name platform  year_of_release  \
# 1                           Super Mario Bros.      NES           1985.0
# 4                    Pokemon Red/Pokemon Blue       GB           1996.0
# 5                                      Tetris       GB           1989.0
# 9                                   Duck Hunt      NES           1984.0
# 10                                 Nintendogs       DS           2005.0
# 12                Pokemon Gold/Pokemon Silver       GB           1999.0
# 18                          Super Mario World     SNES           1990.0
# 20              Pokemon Diamond/Pokemon Pearl       DS           2006.0
# 21                           Super Mario Land       GB           1989.0
# 22                        Super Mario Bros. 3      NES           1988.0
# 25              Pokemon Ruby/Pokemon Sapphire      GBA           2002.0
# 27                Pokemon Black/Pokemon White       DS           2010.0
# ...

# %%
df.query('critic_score.isna()').groupby('year_of_release')['na_sales'].count()
# Out:
# year_of_release
# 1980.0      9
# 1981.0     46
# 1982.0     36
# 1983.0     17
# 1984.0     14
# 1985.0     13
# 1986.0     21
# 1987.0     16
# 1988.0     14
# 1989.0     17
# 1990.0     16
# 1991.0     41
# 1992.0     42
# 1993.0     62
# 1994.0    120
# 1995.0    219
# 1996.0    255
# 1997.0    272
# 1998.0    351
# 1999.0    299
# 2000.0    207
# 2001.0    156
# 2002.0    202
# 2003.0    190
# 2004.0    201
# 2005.0    284
# 2006.0    386
# 2007.0    505
# 2008.0    712
# 2009.0    775
# 2010.0    755
# 2011.0    636
# 2012.0    332
# 2013.0    271
# 2014.0    320
# 2015.0    381
# 2016.0    270
# Name: na_sales, dtype: int64

# %% [markdown]
# Пропуски в данных до 2000 года можно присутствуют по причине неразвитости сообщества критиков, интернета, программного обеспечения для сбора информации. Также игры могли не проходить оценку, не проходить процедуру присвоения рейтинга ESRB

# %% [markdown]
# **User_Score**

# %% [markdown]
# Тип данных *object*, соответственно присутстуют какие-то данные, отличные от числовых

# %%
df['user_score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %% [markdown]
# **tbd** - "to be done" Ожидание оценки.

# %%
df.query('user_score.isna()').head(10)
# Out:
#                              name platform  year_of_release         genre  \
# 1               Super Mario Bros.      NES           1985.0      Platform
# 4        Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                          Tetris       GB           1989.0        Puzzle
# 9                       Duck Hunt      NES           1984.0       Shooter
# 10                     Nintendogs       DS           2005.0    Simulation
# 12    Pokemon Gold/Pokemon Silver       GB           1999.0  Role-Playing
# 18              Super Mario World     SNES           1990.0      Platform
# 20  Pokemon Diamond/Pokemon Pearl       DS           2006.0  Role-Playing
# 21               Super Mario Land       GB           1989.0      Platform
# 22            Super Mario Bros. 3      NES           1988.0      Platform
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score user_score rating
# ...

# %% [markdown]
# Данные, не имеющие пользовательской оценки, но имеющие оценку критиков

# %%
obj_us1 = df.query('user_score.isna() and critic_score>0')
obj_us1.head()
# Out:
#                                  name platform  year_of_release       genre  \
# 182                    Tomb Raider II       PS           1997.0      Action
# 440   Need for Speed III: Hot Pursuit       PS           1998.0      Racing
# 637         Riven: The Sequel to Myst       PC           1997.0   Adventure
# 1981                Monster Rancher 2       PS           1998.0  Simulation
# 2195                MVP Baseball 2005       XB           2005.0      Sports
#
#       na_sales  eu_sales  jp_sales  other_sales  critic_score user_score  \
# 182       2.30      2.46      0.20         0.28          85.0        NaN
# 440       2.14      0.86      0.00         0.13          88.0        NaN
# 637       1.52      0.82      0.00         0.10          83.0        NaN
# 1981      0.19      0.13      0.66         0.07          83.0        NaN
# 2195      0.70      0.20      0.00         0.03          86.0        NaN
#
#      rating
# 182       T
# 440       E
# 637       E
# 1981      E
# ...

# %%
obj_us1.shape[0]
# Out:
# 38

# %% [markdown]
# Оценка пользователей примерно в 9-10 ниже, чем оценка критиков. На этапе подготовки это будет оценено

# %% [markdown]
# Игры, ожидающие оценки пользователей, но имеющие уже оценки критиков:

# %%
obj_us_tbd = df.query('user_score == "tbd" and critic_score>0')
obj_us_tbd.head(40)
# Out:
#                                                name platform  year_of_release  \
# 301                  Namco Museum: 50th Anniversary      PS2           2005.0
# 645                                    uDraw Studio      Wii           2010.0
# 657        Frogger's Adventures: Temple of the Frog      GBA              NaN
# 821                                 The Incredibles      GBA           2004.0
# 1047                                  Tetris Worlds      GBA           2001.0
# 1069                         Personal Trainer: Math       DS           2007.0
# 1070                                   Game Party 3      Wii           2009.0
# 1151              SpongeBob's Atlantis SquarePantis       DS           2007.0
# 1199                                 MySims Kingdom       DS           2008.0
# 1300                        Midway Arcade Treasures      PS2           2003.0
# 1309                                         Wall-E       DS           2008.0
# ...

# %%
obj_us_tbd.shape[0]
# Out:
# 1082

# %% [markdown]
# Пользовательскую оценку можно будет рассчитать от оценки критиков. Чтобы можно было перевести данный столбец к типу данных **float** и выполнять необходимы расчеты, предварительно надо перевести **tbd** в **NaN**

# %% [markdown]
# **Rating**

# %%
df['rating'].unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %% [markdown]
# Рейтинг **K-A** - старое название **E**, поэтому их необходимо будет объединить

# %%
obj_rat = df.query('rating.isna()')
obj_rat.head(10)
# Out:
#                              name platform  year_of_release         genre  \
# 1               Super Mario Bros.      NES           1985.0      Platform
# 4        Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                          Tetris       GB           1989.0        Puzzle
# 9                       Duck Hunt      NES           1984.0       Shooter
# 10                     Nintendogs       DS           2005.0    Simulation
# 12    Pokemon Gold/Pokemon Silver       GB           1999.0  Role-Playing
# 18              Super Mario World     SNES           1990.0      Platform
# 20  Pokemon Diamond/Pokemon Pearl       DS           2006.0  Role-Playing
# 21               Super Mario Land       GB           1989.0      Platform
# 22            Super Mario Bros. 3      NES           1988.0      Platform
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score user_score rating
# ...

# %% [markdown]
# Проверим, как имеющийся рейтинг распеределен по жанрам

# %%
df.groupby(['genre','rating'])['name'].count()
# Out:
# genre         rating
# Action        AO           1
#               E          416
#               E10+       481
#               EC           1
#               M          608
#               T          681
# Adventure     E          162
#               E10+        68
#               EC           2
#               M           99
#               T          115
# Fighting      E            8
#               E10+        19
#               M           49
#               T          362
# Misc          E          457
#               E10+       167
#               EC           5
#               K-A          1
#               M           13
#               T          239
# Platform      E          358
#               E10+       144
#               M            3
#               T           64
# Puzzle        E          289
#               E10+        43
#               T           10
# Racing        E          585
#               E10+        96
#               M           18
# ...

# %% [markdown]
# Количество пропущенных рейтингов для каждого жанра

# %%
obj_rat.groupby('genre')['platform'].count()
# Out:
# genre
# Action          1181
# Adventure        857
# Fighting         411
# Misc             868
# Platform         319
# Puzzle           238
# Racing           377
# Role-Playing     721
# Shooter          304
# Simulation       305
# Sports           839
# Strategy         344
# Name: platform, dtype: int64

# %% [markdown]
# Возможно, игры не проходили процедуру присвоения присвоения рейтинга ESRB. Исходя из распределений рейтингов по жанрам можно с определенной увереностью говорить только о жанрах **Platform**, **Puzzle**, **Sports**. Но так как вопрос возрастных ограничений серьезный, то для уверенности нужно знать контент, а он неизвестен.<br>
# <del>Оставим пропуски так , как есть</del>

# %% [markdown]
#
# <div class="alert alert-info">
# <b>Доработка</b><br>
# Заполним все пропущенные данные значением **U** - unknown <br>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Да, теперь игры без рейтинга из нашего анализа не выпадают, отлично!
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Один из ключевых моментов этого проекта: ты пропуски в 'rating' оставляешь как NaN, без заполнения «заглушкой». Это ОК здесь. Но дальше, когда мы будем строить график для игр в соответствии с их рейтингами - надо будет вспомнить этот момент ... Если не вспомнишь и не обработаешь эти "пропуски", то из анализа игры без рейтинга исчезнут. Ну и соответственно мы сделаем неправильные выводы.
#
# Отметь этот момент - возможно нам придется вернуться сюда.</div>

# %% [markdown]
# ## Подготовка данных <a id='dataprep'></a>

# %%
df.query('name=="Need for Speed: Most Wanted" and platform=="X360"')
# Out:
#                              name platform  year_of_release   genre  na_sales  \
# 1190  Need for Speed: Most Wanted     X360           2012.0  Racing      0.62
# 1591  Need for Speed: Most Wanted     X360           2005.0  Racing      1.00
#
#       eu_sales  jp_sales  other_sales  critic_score user_score rating
# 1190      0.78      0.01         0.15          83.0        8.5      T
# 1591      0.13      0.02         0.10          83.0        8.5      T

# %% [markdown]
# **Создание столбца с итоговыми продажами**

# %%
df['total_sales'] = df['na_sales'] + df['eu_sales'] + df['jp_sales'] + df['other_sales']

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Ещё такой вариант суммирования есть (просто как альтернатива … **псевдокод**): **data[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis='columns')** и "присвоить" этот результат новому столбцу в **data**.</div>

# %% [markdown]
# **Год выпуска**

# %% [markdown]
# <del>df.query('year_of_release.isna()')</del>

# %% [markdown]
# <del>В именах некоторых игр закодирован год выпуска.</del>

# %% [markdown]
# <del>def nan_year(row):
#     """
#     Функция извлечения года релиза игры из имени
#     """
#     #если столбец year_of_release NaN
#     if pd.isna(row.year_of_release) == True:
#         #проверка наличия номера года в имени игры
#         for y in range(1970,2017):
#             if str(y) in row['name']:
#                 return y
#     return row.year_of_release</del>

# %% [markdown]
# <del>df['year_of_release'] = df.apply(nan_year,axis=1)</del>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Я бы после анализа удалил эти записи. Их всего 269 (из 16+ тысяч), меньше 2%. "Погоды" они нам не сделают, а написание такого кода всё равно требует времени на написание и отладку.
#
# p.s. ну и тем более, все 269 пропусков заполнить не удалось, всё равно в итоге 252 записи остались с пропусками в поле года выпуска.</div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# (Немного рассуждений): да, всего 2 записи (из 16 тысяч) с пропусками в жанрах и названиях (плюс в этих же записях нет ни оценок пользователей, ни оценок критиков, ни рейтингов) и 269 записей (менее 2% из 16+ тысяч) с пропусками в годах выпуска. Казалось бы, надо удалять даже не раздумывая … но единого сценария нет на самом деле. С одной стороны - да, говорят, что "данных много не бывает", удалять записи из-за пропусков, когда датасет измеряется всего лишь сотнями-тысячами записей ой как не хочется.
#
# С другой стороны, если запись не спасти, если в ней несколько полей не заполнено или не заполнены ключевые поля, и ты чувствуешь, что заполнение их медианами/средними приведёт к смещению статистик - надо удалять. Да, можно поставить "заглушку", но тогда надо отдавать отчёт, что во всем последующем коде про эту "заглушку" помнить придётся. Т.е. перед построением всех графиков, гистограмм заглушку надо будет удалить. Перед расчетом корреляций - заглушку надо будет удалить. Перед проверкой гипотез заглушку надо будет удалить.
#
# Я бы так определил способ решения такой задачи: если записи с пропусками в ключевых для моего анализа полях составляют 1-3-5-до 10% строк, то я бы их из оригинального датафрейма вырезал (но сохранил бы в некий df, к которому при необходимости мог бы обратиться).
#
# А вообще, в таких случаях, когда нужно решить - заполнять пропуски или удалять строки с ними из df - всегда ищи эксперта в предметной области и советуйся с ним. Как правило это человек из бизнеса, который значит суть бизнес-процесса и вот именно он даст тебе точный и аргументированный совет - что в данной, конкретной задаче делать с "битыми" полями в строках датафрейма.
# </div>

# %% [markdown]
#
# <div class="alert alert-info">
# <b>Доработка</b><br>
# </div>

# %%
df['year_of_release'].isna().sum()
# Out:
# 269

# %%
269/16641
# Out:
# 0.01616489393666246

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Дмитрий, этот код лучше записать вот так (чтобы, в случае, если датафрейм чуть поменяется) твои расчеты остались верны:
#
#     df['year_of_release'].isna().sum() / df.shape[0]
# </div>

# %% [markdown]
# Строки спропущенными гдами выпуска составляют менее 2%<br>
# Восстановить их не представляется возможным, а анализировать данные без этих значений не представляется возможным.<br>
# По этой причине удалим эти записи

# %% [markdown]
# Удаляем строки с отстутствующими годами выпуска

# %%
df.shape[0]
# Out:
# 16715

# %%
df.dropna(subset=['year_of_release'], inplace=True)

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# И ещё небольшой, но жизненный совет: **перед** и **сразу после** удаления строк (и для столбцов тоже будет верно) примени метод .shape к датафрейму. В этом случае наглядно будет видно сколько строк/столбцов было удалено. В некоторых ситуациях может быть ошибка в коде из-за которой удаляется больше чем ожидалось. Но этот способ поможет тебе такую проблему сразу обнаружить.</div>

# %%
df.shape[0]
# Out:
# 16446

# %% [markdown]
# Преобразуем тип данных

# %%
df['year_of_release'] = df['year_of_release'].astype(int)

# %% [markdown]
# ---

# %% [markdown]
# Пропущенные наименования игр

# %%
df.query('name.isna()')
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN             1993   NaN      1.78      0.53      0.00
# 14244  NaN      GEN             1993   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating  total_sales
# 659           0.08           NaN        NaN    NaN         2.39
# 14244         0.00           NaN        NaN    NaN         0.03

# %%
df.dropna(subset=['name'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16444 entries, 0 to 16714
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16444 non-null  object
#  1   platform         16444 non-null  object
#  2   year_of_release  16444 non-null  int64
#  3   genre            16444 non-null  object
#  4   na_sales         16444 non-null  float64
#  5   eu_sales         16444 non-null  float64
#  6   jp_sales         16444 non-null  float64
#  7   other_sales      16444 non-null  float64
#  8   critic_score     7983 non-null   float64
#  9   user_score       9839 non-null   object
#  10  rating           9768 non-null   object
#  11  total_sales      16444 non-null  float64
# dtypes: float64(6), int64(1), object(5)
# memory usage: 1.6+ MB

# %%
df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating  \
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN
#
#    total_sales
# 0        82.54
# 1        40.24
# 2        35.52
# 3        32.77
# ...

# %% [markdown]
# **Пользовательская оценка (user_score)**

# %% [markdown]
# Заменяем tbd на NaN

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# То, что ты tbd меняешь на NaN - это правильно. По сути это и есть пропуски (строки с играми, для которых оценка не проставлена, пропущена по каким-то причинам).</div>

# %%
df.loc[df['user_score'] == "tbd",'user_score'] = np.NaN

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# Дмитрий, оценки зачастую алогичное восторженно-необъяснимая логика человека, нежели строгое математическое правило. Я бы не стал так делать. Ручаться за эти оценки мы не можем.
# </div>

# %% [markdown]
#
# <div class="alert alert-info">
# <b>Доработка</b><br>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Отлично!
# </div>

# %% [markdown]
# Выполнять заполнение пропусков в оценках пользователей не будем

# %% [markdown]
# Приеобразование типа данных

# %%
df['user_score'] = df['user_score'].astype(float)

# %% [markdown]
# **Пропуски в оценках критиков**

# %%
df['critic_score'].isna().sum()
# Out:
# 8461

# %% [markdown]
# Выполнять заполнение пропусков в оценках критиков не будем

# %% [markdown]
# ---

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Код очень длинный (а PEP8 определяет длину строки в 79 символов) - попробуй длинные - переносить, а между строками использовать пустые строки. Ну и желательно код комментировать, хотя бы коротко (что делаешь и каков будет результат - так твоим коллегам будет проще за твоей мыслью следить). Этот комментарий может относиться к нескольким ячейкам этой «тетрадки».
#
# Хороший разработчик форматирует и комментирует свой код, тогда другие разработчики быстрее разберутся в программе. Это важно, ведь код чаще читают, чем пишут: напишет один, а прочтут — сотни или тысячи (если код хороший).
# «Пишите код так, как будто сопровождать его будет склонный к насилию психопат, который знает, где вы живете.» ©1991, John F. Woods, разработчик
#
# ---
# Давай обсудим стиль кодирования (программирования)? Смотри что сейчас происходит в этой ячейке (**возможно не всё применимо к твоему коду здесь, но я попытался вспомнить все часто встречающиеся недочёты**), что "режет" глаз и что можно сделать по-другому, чуть лучше:
#
# 1. Комментарии к строке кода: они должны располагаться выше соответствующей строки кода (выше строки к которой относятся) и должны быть от этой строки отделены пустой строкой. Если же они расположены справа, то для того чтобы увидеть, что там написано приходится пользоваться скроллиногом. Надо добиться того, чтобы ячейку не приходилось прокручивать, т.к. это не добавляет удобства ни при отладке кода, ни для понимания что в этой ячейке "происходит". Как альтернатива – комментарий может размещаться выше, в Markdown-ячейке.
#
# 2. Бывает, что встречаются очень длинные строки кода, которые также уходят за правый край ячейки. Такие строки должны разбиваться разделителем (вот таким: \\). Это best practice, требование PEP8, а именно: PEP8 определяет длину строки в 79 символов.
#
# 3. **В идеале**: одна ячейка - одна строка кода. Почему так? Да как минимум из соображения понятности: будучи выполненной, под этой ячейкой должен отображаться результат трансформации данных. Ты или твой коллега должны видеть, как поменялись данные после выполнения ячейки с кодом. Следующая ячейка - ещё строка кода и соответствующим output'ом. Будешь делать так - коллеги будут тебе благодарны за то, что легко будут следовать за твоей мыслью. И отладку это упрощает. Ну и как противоположность - можно в одну ячейку "положить" результат 3-х последовательных groupby + ещё чего-нибудь. Разобраться с ходу "что происходит" будет очень трудно, придётся всё равно код разносить по ячейкам и смотреть последовательно что происходит. Но ведь логично это делать удобным способом сразу, ведь так?
#
# 4. Неиспользуемые, закомментированные строки выше вынеси в другую ячейку, отдельную, выше. Можешь для удобства своего прокомментировать (на память). И оставь там это код, так, чтобы он не смешивался с рабочим кодом.
# </div>

# %% [markdown]
# Для удобства использования данных и более детального анализа создадим датафрейм с наименованиями платформ и семейств (или "общего предка") с указанием поколений, к которым принадлежат платформы. Это позволит увидеть сменяемость поколений, а тем самым, устойчивость на рынке

# %%
df_fam_plt = pd.DataFrame({'platform':['2600',
                                       '3DO',
                                       '3DS',
                                       'DC',
                                       'DS',
                                       'GB',
                                       'GBA',
                                       'GC',
                                       'GEN',
                                       'GG',
                                       'N64',
                                       'NES',
                                       'PC',
                                       'PCFX',
                                       'PS',                       
                                       'PS2',
                                       'PS3',
                                       'PS4',
                                       'PSP',
                                       'PSV',
                                       'SAT',
                                       'SCD',
                                       'SNES',
                                       'TG16',
                                       'WS',
                                       'Wii',
                                       'WiiU',
                                       'X360',
                                       'XB',
                                       'XOne',
                                       'NG'
                                      ],
                           'family':['Atari 2600',
                                     'LG_05 3DO Interactive Multiplayer',
                                     'GameBoy_08 Nintendo 3DS',
                                     'Dendy Classic',
                                     'GameBoy_07 Nintendo DS',
                                     'GameBoy_04 Game Boy', 
                                     'GameBoy_06 Game Boy Advance',
                                     'ColorTVGame_06 Nintendo GameCube',
                                     'SEGA Retro Genesis',
                                     'Game Gear',
                                     'ColorTVGame_05 Nintendo 64',
                                     'ColorTVGame_03 Nintendo Entertainment System',
                                     'Game PC',
                                     'NEC_05 PC-FX',
                                     'PlayStation_05 PlayStation',
                                     'PlayStation_06 PlayStation',
                                     'PlayStation_07 PlayStation',
                                     'PlayStation_08 PlayStation',
                                     'PSP_07 PlayStation Portable',
                                     'PSP_08 PlayStation Vita',
                                     'SG_05 Sega Saturn',
                                     'unknown',
                                     'ColorTVGame_04 Super NES',
                                     'NEC_04 TurboGrafx-16',
                                     'Bandai_05 WonderSwan',
                                     'ColorTVGame_07 Wii',
                                     'ColorTVGame_08 WiiU',
                                     'Xbox_07 Xbox 360',
                                     'Xbox_06 Xbox',
                                     'Xbox_08 XOne',
                                     'unknown'
                                    ]})

# %% [markdown]
# Объединение исходного датафрейма и датафрейма с наименованиями семейств (предков семейств)

# %%
df = df.merge(df_fam_plt,on='platform')

# %%
df.head()
# Out:
#                         name platform  year_of_release     genre  na_sales  \
# 0                 Wii Sports      Wii             2006    Sports     41.36
# 1             Mario Kart Wii      Wii             2008    Racing     15.68
# 2          Wii Sports Resort      Wii             2009    Sports     15.61
# 3                   Wii Play      Wii             2006      Misc     13.96
# 4  New Super Mario Bros. Wii      Wii             2009  Platform     14.44
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     28.96      3.77         8.45          76.0         8.0      E
# 1     12.76      3.79         3.29          82.0         8.3      E
# 2     10.93      3.28         2.95          80.0         8.0      E
# 3      9.18      2.93         2.84          58.0         6.6      E
# 4      6.94      4.70         2.24          87.0         8.4      E
#
#    total_sales              family
# 0        82.54  ColorTVGame_07 Wii
# ...

# %% [markdown]
# **Вывод:**    <a id='conclusion_2'></a>

# %% [markdown]
# В процессе ознакомления с информацией были определены недочеты в данных, некоторые из которых были испавлены на этапе подготовки данных.<br>
# 1. Названия столбцов были переведены в нижний регистр
# 2. Строки с пропусками в столбце **year_of_release** были удалены.
# 3. Пропуски в названиях и жанрах совпали и были удалены.
# 4. Были обнаружены неявные дубликати в рейтинге ESRB. Рейтинг **K-A** переименован в **E**, а также удален дубликат в наименовании игры и годе выпуска. Бул удален.
#
# 5. Пользовательские оценки имели значения **tbd**, которые были преобразованы в NaN. ПРопуски в пользовательских оценках оставлены без изменений.<br>
# 6. Для удобства пользования данными был добавлен столбец названиями семейств и общих предков различных платформ.
# 7. Был добален столбец с итоговыми продажами для каждой игры
# 8. Изменены типы данных year_of_release на int, user_score на float

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# Любая предобработка данных предполагает поиск и анализ дубликатов. В твоём разделе с предобработкой подобной важной составляющей нет.
#
# Попробуй найти 1. явные и 2. неявные дубликаты (для их поиска нужно использовать параметр **subset**). Конкретно в нашем рабочем проекте пробуй найти дубликаты для пары "Имя - Игровая консоль".
#
# После поиска и обнаружения - опиши как их планируешь и планируешь ли обрабатывать?</div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Доработка</b><br>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Отлично, верно! После анализа дубликатов вполне может быть принято решение их не обрабатывать/не удалять/ещё что-то, но пропускать сам шаг поиска (неявных) дублей не стоит (это один из обязательных шагов в пайплайне EDA).
# </div>

# %% [markdown]
# **Поиск и обработка дубликатов**

# %% [markdown]
# Рейтинг K-A - старое название E, поэтому их необходимо будет объединить

# %%
df['rating'] = df['rating'].replace('K-A', 'E')

# %% [markdown]
# проверка наличия дубликатов в наименованиях игр и игровых консолях

# %%
duplicateRows = df[df.duplicated(['name','platform'])]

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# А если в subset передать ещё параметр keep=False, то можно будет в output'е увидеть все записи, которые Пандас посчитал дублями по выбранному тобой набору столбцов в subset'е.
# </div>

# %%
duplicateRows
# Out:
#                               name platform  year_of_release   genre  \
# 3792   Need for Speed: Most Wanted     X360             2005  Racing
# 6118                 Madden NFL 13      PS3             2012  Sports
# 12889  Need for Speed: Most Wanted       PC             2012  Racing
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 3792        1.0      0.13      0.02         0.10          83.0         8.5
# 6118        0.0      0.01      0.00         0.00          83.0         5.5
# 12889       0.0      0.06      0.00         0.02          82.0         8.5
#
#       rating  total_sales                      family
# 3792       T         1.25            Xbox_07 Xbox 360
# 6118       E         0.01  PlayStation_07 PlayStation
# 12889      T         0.08                     Game PC

# %%
df.query('name=="Need for Speed: Most Wanted" and platform=="X360"')
# Out:
#                              name platform  year_of_release   genre  na_sales  \
# 3749  Need for Speed: Most Wanted     X360             2012  Racing      0.62
# 3792  Need for Speed: Most Wanted     X360             2005  Racing      1.00
#
#       eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 3749      0.78      0.01         0.15          83.0         8.5      T
# 3792      0.13      0.02         0.10          83.0         8.5      T
#
#       total_sales            family
# 3749         1.56  Xbox_07 Xbox 360
# 3792         1.25  Xbox_07 Xbox 360

# %% [markdown]
# Это релиз игры, существующий отдельно, удалять и объединять не будем.

# %%
df.query('name=="Madden NFL 13" and platform=="PS3"')
# Out:
#                name platform  year_of_release   genre  na_sales  eu_sales  \
# 4902  Madden NFL 13      PS3             2012  Sports      2.11      0.22
# 6118  Madden NFL 13      PS3             2012  Sports      0.00      0.01
#
#       jp_sales  other_sales  critic_score  user_score rating  total_sales  \
# 4902       0.0         0.23          83.0         5.5      E         2.56
# 6118       0.0         0.00          83.0         5.5      E         0.01
#
#                           family
# 4902  PlayStation_07 PlayStation
# 6118  PlayStation_07 PlayStation

# %% [markdown]
# Данный дубликат явно сделан случайно и его следует удалить

# %%
df = df.drop(6118)

# %%
df.query('name=="Need for Speed: Most Wanted" and platform=="PC"')
# Out:
#                               name platform  year_of_release   genre  \
# 12701  Need for Speed: Most Wanted       PC             2005  Racing
# 12889  Need for Speed: Most Wanted       PC             2012  Racing
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 12701      0.02      0.23       0.0         0.04          82.0         8.5
# 12889      0.00      0.06       0.0         0.02          82.0         8.5
#
#       rating  total_sales   family
# 12701      T         0.29  Game PC
# 12889      T         0.08  Game PC

# %% [markdown]
# Это релиз игры, существующий отдельно, удалять  и объединять не будем.

# %% [markdown]
# **Создание заглушек для rating**

# %%
df.loc[df['rating'].isna(),'rating'] = 'U'

# %%
df['rating'].isna().sum()
# Out:
# 0

# %% [markdown]
# **Вывод:**    <a id='conclusion_2'></a>

# %% [markdown]
# В процессе ознакомления с информацией были определены недочеты в данных, некоторые из которых были испавлены на этапе подготовки данных.<br>
# 1. Названия столбцов были переведены в нижний регистр
# 2. Строки с пропусками в столбце **year_of_release** были удалены.
# 3. Пропуски в названиях и жанрах совпали и были удалены.
# 4. Были обнаружены неявные дубликати в рейтинге ESRB. Рейтинг **K-A** переименован в **E**, а также удален дубликат в наименовании игры и годе выпуска. Бул удален.
#
# 5. Пользовательские оценки имели значения **tbd**, которые были преобразованы в NaN. ПРопуски в пользовательских оценках оставлены без изменений.<br>
# 6. Для удобства пользования данными был добавлен столбец названиями семейств и общих предков различных платформ.
# 7. Был добален столбец с итоговыми продажами для каждой игры
# 8. Изменены типы данных year_of_release на int, user_score на float

# %% [markdown]
# ___

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Данные загружены, отлично.
#
# Хорошо, что применяешь метод .head()/.sample() таким образом в память не будет загружен весь датасет, объем которого может быть огромным.
#
# Методы .info, .describe, .value_counts(), .unique() как правило часто встречаются и обязательны к применению в задачах по исследованию данных, ведь с их помощью можно получить первые инсайты.
#
# Итак, мы провели предварительный анализ данных, проверили данные на наличие пропусков и затем обработали их (аргументированно заполнили / удалили / оставили как есть). Теперь можно приступать собственно к анализу данных и ответам на вопросы проекта.</div>

# %% [markdown]
# ## Исследование данных

# %% [markdown]
# ### Количество игр выпущенных в разные годы в разные годы

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Агрегация по count() покажет нам число игр, выпущенных на всех платформах, в разрезе лет. Т.е. если одна и та же игра (name) вышла в некоем году на одной платформе, агрегат == 1. Если на 2-х платформах, агрегат == 2, ну и так далее. У меня вопрос к тебе – что в твоем случае, в написанном тобой коде мы считаем выпуском игры (в этом, некоем году)?
#
# Возможно, чтобы получить истинное количество «игр по годам» нам следует поискать дубликаты (используя subset по (Годам - Названиям игр) и затем исключить из полного датафрейма все дубли за исключением одной, «первой», строки? Как ты считаешь?</div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Доработка</b><br>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# В этом вопросе не было подвоха. Этот жёлтый комментарий не про то, чтобы что-то сразу делать с данными, а "про подумать", как и почему мы будем работать с играми, которые в **определенном году** выходят сразу на нескольких платформах. Будем мы их считать разными, уникальными играми. Или мы их будем считать, как одну игру, которая вышла в этом текущем году? Так что, то, что вопрос обдуман, объяснен и реализован - молодец!
# </div>

# %%
game_count_year = df.drop_duplicates(subset=['name', 'year_of_release'], keep='first')\
                        .groupby(['year_of_release']).agg(total_games=('name','count'))
game_count_year.reset_index()
# Out:
#     year_of_release  total_games
# 0              1980            9
# 1              1981           46
# 2              1982           36
# 3              1983           17
# 4              1984           14
# 5              1985           14
# 6              1986           21
# 7              1987           16
# 8              1988           15
# 9              1989           17
# 10             1990           16
# 11             1991           40
# 12             1992           41
# 13             1993           59
# 14             1994          117
# 15             1995          215
# 16             1996          258
# 17             1997          282
# 18             1998          364
# 19             1999          326
# 20             2000          325
# 21             2001          428
# 22             2002          631
# 23             2003          546
# 24             2004          550
# 25             2005          657
# 26             2006          773
# ...

# %%
fig, ax = plt.subplots(figsize=(20, 5));

ax = sns.lineplot(data=game_count_year);
ax.set_ylabel('Количество игр');
ax.set_xlabel('Годы выпуска');

# %% [markdown]
# Бурное развитие игроых приставок и игр начинается с 1994 года. Именно в этот период пявляется рейтинг ESRB. По этой причине исследовать некоторые вопросы (влияние рейтинга) на основе данных ранее 1994 года не имеет смысла.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Этот график, как и все прочие ниже, выиграли бы если бы были подписаны сами (plt.title), а также оси X и Y (plt.xlabel и plt.ylabel, соответственно), а также указаны единицы измерения по осям.
#
# Было бы здорово получить объяснение поведения данного графика (с точки зрения того, что происходило на рынке в соответствующие года). Пытаться понять полученный результат - важная часть работы аналитика.</div>

# %%
data = df.query('year_of_release>1990')
data.head()
# Out:
#                         name platform  year_of_release     genre  na_sales  \
# 0                 Wii Sports      Wii             2006    Sports     41.36
# 1             Mario Kart Wii      Wii             2008    Racing     15.68
# 2          Wii Sports Resort      Wii             2009    Sports     15.61
# 3                   Wii Play      Wii             2006      Misc     13.96
# 4  New Super Mario Bros. Wii      Wii             2009  Platform     14.44
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     28.96      3.77         8.45          76.0         8.0      E
# 1     12.76      3.79         3.29          82.0         8.3      E
# 2     10.93      3.28         2.95          80.0         8.0      E
# 3      9.18      2.93         2.84          58.0         6.6      E
# 4      6.94      4.70         2.24          87.0         8.4      E
#
#    total_sales              family
# 0        82.54  ColorTVGame_07 Wii
# ...

# %% [markdown]
# **Суммарные продажи**

# %%
sum_total = data.groupby('platform').agg(total_sales=('total_sales','sum')).sort_values(by='total_sales', ascending = False)

# %%
sum_total.reset_index()
# Out:
#    platform  total_sales
# 0       PS2      1233.56
# 1      X360       961.24
# 2       PS3       931.33
# 3       Wii       891.18
# 4        DS       802.76
# 5        PS       727.58
# 6       PS4       314.14
# 7       GBA       312.88
# 8       PSP       289.53
# 9       3DS       257.81
# 10       PC       255.69
# 11       XB       251.57
# 12      N64       218.01
# 13       GC       196.73
# 14       GB       183.14
# 15     SNES       173.89
# 16     XOne       159.32
# 17     WiiU        82.19
# 18      PSV        53.81
# 19      SAT        33.59
# 20      GEN        25.75
# 21       DC        15.95
# 22      NES        11.81
# 23      SCD         1.86
# 24       NG         1.44
# 25       WS         1.42
# 26     TG16         0.16
# 27      3DO         0.10
# 28       GG         0.04
# 29     PCFX         0.03

# %% [markdown]
# Из данной группировки видно, что лидерами являются **PlayStation, Xbox и Nintendo**. Но так как одни поколения сменяют другие, то делать вывод о том, какая платформа имеет шанс на дальнейшее развитие нельзя. И нахождение в конце данного списка не означает **"конец карьеры"**, а может наоборт означать её начало.<br>
# Однако, платформы, показавшие результаты продаж ниже 50 удалим.

# %%
#удаление строк, относящимся к платформам, суммарные проажи которых за все время ниже значения 10
for k,v in sum_total.items():
    for kk,kv in v.items():
        if kv < 50:
            filter = df['platform'].str.contains(kk)
            data = data[~filter]
# Out:
# /tmp/ipykernel_67/1198815389.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = data[~filter]

# %% [markdown]
# **Постоение распределения по годам**

# %%
sales_year_distr = data.pivot_table(index=['family'],
                                    columns=['year_of_release'],
                                    values='total_sales',
                                    aggfunc=['sum']).droplevel(level=0,axis=1)
sales_year_distr
# Out:
# year_of_release                   1991   1992   1994   1995   1996    1997  \
# family
# ColorTVGame_05 Nintendo 64         NaN    NaN    NaN    NaN  34.10   39.50
# ColorTVGame_06 Nintendo GameCube   NaN    NaN    NaN    NaN    NaN     NaN
# ColorTVGame_07 Wii                 NaN    NaN    NaN    NaN    NaN     NaN
# ColorTVGame_08 WiiU                NaN    NaN    NaN    NaN    NaN     NaN
# Game PC                            NaN   3.03  12.87   4.22  10.58   11.27
# GameBoy_04 Game Boy               5.57  25.49  12.18   3.60  36.03    6.37
# GameBoy_06 Game Boy Advance        NaN    NaN    NaN    NaN    NaN     NaN
# GameBoy_07 Nintendo DS             NaN    NaN    NaN    NaN    NaN     NaN
# GameBoy_08 Nintendo 3DS            NaN    NaN    NaN    NaN    NaN     NaN
# PSP_07 PlayStation Portable        NaN    NaN    NaN    NaN    NaN     NaN
# PSP_08 PlayStation Vita            NaN    NaN    NaN    NaN    NaN     NaN
# ...

# %% [markdown]
# Дополнительный столбец позволяет видеть **"смену поколений"**

# %% [markdown]
# Был обнаружен факт продажи DS в 1985 году, хотя в свет вышел в 2004. Удалим эти сведения

# %% [markdown]
# Строим график, предварительно транспонировав сводную таблицу

# %%
df1 = sales_year_distr.T

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Попробуй передвинуть "легенду" вправо, **за** график, чтобы она его не перекрывала. Статья на тему: https://devpractice.ru/matplotlib-lesson-3-1-work-with-legend/
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Доработка</b><br>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# +
# </div>

# %%
fig, ax = plt.subplots(figsize=(20, 10));
ax = sns.lineplot(data=df1);

#доработка - сдвиг легенды вправо

plt.legend(bbox_to_anchor=(1, 1));
ax.set_xlabel('Годы выпуска')
ax.set_ylabel('Объемы продаж, млн.шт')
# Out:
# Text(0, 0.5, 'Объемы продаж, млн.шт')

# %%
fig, ax = plt.subplots(figsize=(20, 10));
ax = sns.lineplot(data=df1);

#доработка - сдвиг легенды вправо

plt.legend(bbox_to_anchor=(1, 1));

# %% [markdown]
# <del>Из сводной таблицы и графика видно, что *поколения* меняются примерно каждые 5-6 лет, только **XBox 360** сменил XBox через 8 лет. Старая платформа исчезает примерно через 2 года, после выхода в свет новой. Появления новых платформ разных семейств тоже примерно совпадают по времени, это 2000-2001 г, 2004-2006 г.г, 2011-2013, то есть примерно через каждые 5 лет массово возникают новые платформы разных семейств и производителей.<br>
# В период с 2000 по 2013 годы наблюдается два пика в продажах игр разных платформ.<br>
# Также в районе 2016 года наблюдается *стремление* продаж всех платформ практически до нуля, за исключением **PlayStation8**, **XOne** и **Nintendo 3DS**. Абсолютным долгожителем является платформа **PC**
# Также имеется наблюдение, что если продажи упали примерно в 3-4 раза относительно предыдущего года, то на след год - снятие с продажи (поддержки)</del>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# Нет, не согласен с цифрой. Давай я прокомментирую свой вывод глядя на график ...
#
# Итак, смотрим на платформу PS2: начало продаж - 2000 год, закат - "чуть за" 2010-м. 10+ лет. Платформа PS: начало продаж - 1994 год, закат - в районе 2004-го. 10 лет.
#
# Когда после 5-6 лет подъёма платформа катится к закату она разве денег не приносит? И когда платформа растет (до пика) или когда она (падает с пика) эти этапы не вместе, не одновременно, входят в её жизненный цикл?
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Доработка</b><br>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Подтверждаю 10 лет, как корректный интервал, описывающий средний срок жизни игровой платформы.
# </div>

# %% [markdown]
# **Рассчитаем срок жизни каждой платформы**

# %% [markdown]
# Получаем список платформ

# %%
cc = list(data['platform'].unique())

# %%
#создание пустого списка для хранения срока жизни каждой платформы

life_cicle = []

# %% [markdown]
# Для каждой платформы получаем срез и находим разницу между максимальным годом в столбце year_of_release и минимальным

# %%
for i in cc:
    k = data.query('platform ==@i')
    year_min = k['year_of_release'].max() - k['year_of_release'].min() + 1
    life_cicle.append(year_min)

# %% [markdown]
# Создаем датафрейм для платформ и сроков их жизни

# %%
 life_platform = pd.DataFrame({'platform':cc,
                               'year_of_life':life_cicle
                              })

# %% [markdown]
# Объединяем список платформ с суммарными продажами и сроками их жизни

# %%
sum_total = sum_total.merge(life_platform,on='platform')

# %%
sum_total
# Out:
#    platform  total_sales  year_of_life
# 0       PS2      1233.56            12
# 1      X360       961.24            12
# 2       PS3       931.33            11
# 3       Wii       891.18            11
# 4        DS       802.76            10
# 5        PS       727.58            10
# 6       PS4       314.14             4
# 7       GBA       312.88             8
# 8       PSP       289.53            12
# 9       3DS       257.81             6
# 10       PC       255.69            25
# 11       XB       251.57             9
# 12      N64       218.01             7
# 13       GC       196.73             7
# 14       GB       183.14            11
# 15     XOne       159.32             4
# 16     WiiU        82.19             5
# 17      PSV        53.81             6

# %%
sum_total.year_of_life.mean()
# Out:
# 9.444444444444445

# %% [markdown]
# Из таблицы и графика видно, что характерный срок жизни платформ составляет от **9 ло 12** лет. Старая платформа исчезает примерно через 4 года, после выхода в свет новой. Появления новых платформ разных семейств тоже примерно совпадают по времени.<br>
# В период с 2000 по 2013 годы наблюдается два пика в продажах игр разных платформ.<br>
# Также в районе 2016 года наблюдается *стремление* продаж всех платформ практически до нуля, за исключением **PlayStation8**, **XOne** и **Nintendo 3DS**. Абсолютным долгожителем является платформа **PC**
# Также имеется наблюдение, что если продажи упали примерно в 3-4 раза относительно предыдущего года, то через год-два - снятие с продажи (поддержки)</del>

# %% [markdown]
# ---

# %% [markdown]
# **Актуальный период**

# %% [markdown]
# Таким образом, для построения прогноза на 2017 год отобразим данные за период с 2013 по 2016 годы

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Правильный выбор диапазона!
#
# Это на самом деле один из подводных камней этого проекта!
#
# Студенты могут выбирать для анализа очень большой интервал данных, но для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-4 года. И в такой динамично меняющейся индустрии, как компьютерные игры также не стоит брать слишком большой временной интервал - иначе обязательно захватишь уже отжившие тренды. В нашем учебном проекте, я с тобой соглашусь, что 4 года: 2013 - 2015 + неполный 2016 - ОК.</div>

# %%
act_data = data.query('year_of_release>2012')

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Очень хорошо, что результат запроса/’среза’ ты присваиваешь новому датафрейму. Таким образом оригинальный датафрейм ты оставляешь нетронутым, не перезаписываешь (вдруг нам опять понадобятся данные из него чуть ниже). Это верное решение. Best practice. Молодец!</div>

# %%
sales_total=act_data.pivot_table(index='year_of_release', columns = 'platform', values='total_sales', aggfunc='sum')
sales_total
# Out:
# platform           3DS    DS     PC     PS3     PS4   PSP    PSV   Wii   WiiU  \
# year_of_release
# 2013             56.57  1.54  12.38  113.25   25.99  3.14  10.59  8.59  21.65
# 2014             43.76   NaN  13.28   47.76  100.00  0.24  11.90  3.75  22.03
# 2015             27.78   NaN   8.52   16.82  118.90  0.12   6.25  1.14  16.35
# 2016             15.14   NaN   5.25    3.60   69.25   NaN   4.25  0.18   4.60
#
# platform          X360   XOne
# year_of_release
# 2013             88.58  18.96
# 2014             34.74  54.07
# 2015             11.96  60.14
# 2016              1.52  26.15

# %%
#sales_total.plot(figsize=(20, 10), xlim=(2015,2016))
fig, ax = plt.subplots(figsize=(20, 10));
ax = sns.lineplot(data=sales_total);

# %% [markdown]
# Из графиков видно, что в 2016 году наблюдается общее падение рынка, начавшееся с 2010 для всех платформ, кроме **PS4** и **XOne**. А с 2015 года падение продаж происходит для всех игровых платформ. Исходя из наблюдений, сделанных для сроков жизни, возникновения новых версий и данных из сводных таблиц, можно сделать следующий предварительный прогноз для рынка игровых платформ:
#
# Прдажи прекратятся:<br>
# **Wii** - Платформа 11 лет на рынке. Продажи упали практически до 0. В 2017 году продажи прекратятся<br>
# **X360** -  Платформа 12 лет на рынке. Относительно 2015 года продажи упали в 10 раз. В 2017 году продажи упадут практически до нуля<br><br>
#
# Продажи продолжатся:<br>
# **PS3** - В 2017 году продажи этого продукта будут осуществляться последний год<br>
# **PSV** - Платформа уже 7 лет на рынке, продажи постоянно падают. В 2017 продажи будут также сокращаться <br>
# **WiiU** - Продажи упали в 2016 году почти в в 4 раза, несмотря на недолгий срок жизненного цикла. В 2017 году продажи будут падать. Если не появится новая модель, то продажи снизятся но нуля<br>
# **PC** - Продажи будут снижаться, но продолжатся<br>
# **3DS** - Платформа 6 лет на рынке. Продажи снижаются, но не критично и нет резких скачков. Продажи снизятся примерно в 1.5 -2 раза. Исходя из выводов, сделанных ранее, в перспективе 1-2 года должна появиться новая платформа. <br>
#
# Для платформ **XOne** и **PS4** в 2017 году может наблюдаться либо *небольшой* рост продаж по причине падения конкурентов и отсутствия у них новых платформ, либо *плавное* снижение. Несмотря на то, что продажи упали примернов 2 раза, это снижение не является критическим. Платформы появились на рынке одновременно и для них еще замены скорее всего нет. Новые платформы скорее всего не появятся. <br>

# %% [markdown]
# ### Исследование данных

# %%
act_platform = ['PS3','PS4','XOne','PC','3DS','WiiU','PSV']
act_data = data.query('platform in  @act_platform and year_of_release>2012')

# %%
act_data.shape[0]
# Out:
# 1949

# %%
act_data.groupby('platform')['total_sales'].describe()
# Out:
#           count      mean       std   min   25%   50%    75%    max
# platform
# 3DS       303.0  0.472772  1.381347  0.01  0.04  0.09  0.280  14.60
# PC        189.0  0.208624  0.352304  0.01  0.03  0.08  0.230   3.05
# PS3       345.0  0.525884  1.451939  0.01  0.04  0.15  0.510  21.05
# PS4       392.0  0.801378  1.609456  0.01  0.06  0.20  0.730  14.63
# PSV       358.0  0.092151  0.153816  0.01  0.02  0.04  0.110   1.96
# WiiU      115.0  0.562000  1.038778  0.01  0.06  0.20  0.595   7.09
# XOne      247.0  0.645020  1.036139  0.01  0.06  0.22  0.685   7.39

# %%
fig, ax = plt.subplots(figsize=(20, 10));
ax = sns.boxplot(y=act_data["total_sales"], x=act_data['platform']);
plt.ylim(0,1.75)
ax.grid()

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# К сожалению, на этом графике **уверенно** сравнивать квартили (медиану, 25ый и 75ый) у части платформ не получается. Велика вероятность ошибки. Для более обоснованных выводов на основе **только графика** (иначе зачем такой **неговорящий график нужен**) нужно сделать дополнительный график, где будет отображена только нижняя часть boxplot-ов. Этого можно добиться, например, задав параметр ylim
#
# То есть, я бы предложил после этого графика ещё один построить, в котором бы сами "ящики" были лучше видны. На том, что выше выбросы их фактически "забили". Попробуй использовать в параметре ylim, значение, которое ещё больше ограничит значение по OY "сверху" (например, ylim(0, 0.85). Ну и «строй» график большего размера (попробуй использовать: figsize=[20, 10].
#
# Ну а в твоем случае, из-за того, что на графике не разобрать квартили - для точного сравнения "ящиков" мы вынуждены будем использовать describe().</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Да, теперь здорово! Теперь «ящики» платформ можно визуально сравнивать между собой прямо на графике.
# </div>

# %%
cc
# Out:
# ['Wii',
#  'GB',
#  'DS',
#  'X360',
#  'PS3',
#  'PS2',
#  'GBA',
#  'PS4',
#  '3DS',
#  'N64',
#  'PS',
#  'XB',
#  'PC',
#  'PSP',
#  'XOne',
#  'WiiU',
#  'GC',
#  'PSV']

# %% [markdown]
# Все платформы имеют выбросы за Q3, что говорит о том, что имеются игры, пользующиеся особым спросом. PS4 и 3DS имеют одиночные выбросы в районе 12 и 15 млн о наличии особоенно удачных игр

# %% [markdown]
# Видно,что платформы **XOne** и **PS4** имеют ящики примерно одинаковых размеров, но гораздо больше, чем у конкурентов. Медианное значение у XOne и PS4 практически одинаковое 0.22 и 0.20 соответственно. Среднее значение PS4 немного выше 0,8 против 0,64. А вот стандартное отклонение у XOne существенно ниже. Учитывая, что PS4 имеет в 1,6 раза больше выпущенных игр, то можно сделать вывод, что Xone в целом создает более качественный продукт.
#
# **WiiU** имеет показатели поскромнее и самое малое количество наименований продаваемых игр. Но медианные и средние значения продаж, однако,  приблизительно такие же, что и  XOne и PS4. Малое количество выбросов означает, что данная платформа не может похвастаться суперуспешными продуктами, которые были присущи ее предшественнику **Wii**. Отсутствие таких продуктов и приводит к ситуации, что продажи упали в 4 раза, по сравнению с предудущим периодом.
#
# Медианные показатели **PS3** на уровне, 0.15, а средние 0.52, что почти на 30% ниже, чем у конкурентов PS4 и XOne. Платформа 11 лет на рынке и имеет некоторые суперуспешные продукты, которые позволят еще некоторе время иметь продажи.
#
#
# **3DS** имеет некоторое количество очень хороших игр, которые обеспечивает данной платформе возможность оставаться на плаву. По всей видимости данная платформа за счет этих игр еще некоторе время будет существовать, но, так как в целом ее деятельность почти в 2 раза менее эффективна, чем, скажем у XOne при большем количестве выпущенной продукции, то это продлится недолго.
#
#
# **PC** имеет самые скромные показатели, но тем не менее, существует продукция, конкурирующая с новыми платформами и имеющая свою аудиторию. Вся история данной платформы показывает, что она занимает свою нишу по праву.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Дмитрий, обрати внимание на красный комментарий выше. Не стоит в проекте отсавлять "не говорящие графики". Нужно доводить их до такого состояния, чтобы по нимможно было бы выводы делать.
# </div>

# %% [markdown]
# ### Влияние пользователей и критиков

# %%
act_data.groupby('platform')['critic_score'].count()
# Out:
# platform
# 3DS      71
# PC      149
# PS3     121
# PS4     252
# PSV      77
# WiiU     70
# XOne    169
# Name: critic_score, dtype: int64

# %%
act_data.groupby('platform')['user_score'].count()
# Out:
# platform
# 3DS      80
# PC      155
# PS3     186
# PS4     257
# PSV      99
# WiiU     80
# XOne    182
# Name: user_score, dtype: int64

# %% [markdown]
# Отзывов больше в платформе PS4

# %%
#диаграмма рассеивания по платформе PS4, отобразив отзывы критиков
data[data['platform']=='PS4'].plot(x='critic_score', y='total_sales', kind='scatter', alpha=0.3, figsize=(8,8), grid=True)
plt.show()

# %%
data_ps4 = act_data.query('platform=="PS4"')
data_ps4_cor = data_ps4['critic_score'].corr(data_ps4['total_sales'])
display('Корреляция: {}'.format(round(data_ps4_cor,2)))
# Out:
# 'Корреляция: 0.41'

# %% [markdown]
# Между озывами критиков и глобальными продажами **корреляция слабо положительная**

# %%
#диаграмма рассеивания по платформе PS4, отобразив отзывы пользователей
data[data['platform']=='PS4'].plot(x='user_score', y='total_sales', kind='scatter', alpha=0.3, figsize=(8,8), grid=True)
plt.show()

# %%
data_ps4_cor_user = data_ps4['user_score'].corr(data_ps4['total_sales'])
print('Корреляция : {}'.format(round(data_ps4_cor_user,2)))
# Out:
# Корреляция : -0.03

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# Если бы в 'user_score' мы оставили бы NaN (не заполняли «заглушкой»), то .corr бы их при расчете корреляций не стал использовать (и мы получили бы коэффициенты для **реальных** оценок). Сейчас же своё влияние на значения коэффициентов корреляции имеют и искусственно сгенерированные нами оценки, за фактическую корректность которых мы ручаться совсем не можем.
#
# ![image.png](attachment:image.png)</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Да, теперь пропуски мы "заглушками" не заполняем.
# </div>

# %% [markdown]
# Между озывами пользователей и глобальными продажами **корреляция слабо отрицательная**

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Здорово! Ты понимаешь, что формулировать, что якобы коэффициент корреляции (Пирсона) между 2 переменными (в нашем случае между "total_sales" и "critic_score") есть показатель того, что **на количество продаж влияет оценка критиков** - неверно. А ведь примерно в 70% студенческих работ именно такое и встречается.
#
# Действительно, коэффициент свидетельствует **о наличии или отсутствии линейной связи** между переменными, и **измеряет выраженность** этой связи. Другими словами, коэффициент корреляции - это инструмент, с помощью которого можно проверить гипотезу о **линейной** зависимости и измерить степень этой зависимости.
#
# Например, в нашем случае, связь между продажами и оценками экспертов для всех платформ является **прямой, слабой** степени выраженности (во всех случаях коэффициент около 0,3-0,4).
#
# То есть, влияния оценок на продажи нет. Коэффициент корреляции Пирсона не про это. Он про линейную зависимость 2-х переменных. И ещё, это коэффициент **НЕ ОБЪЯСНЯЕТ** зависимость, он **НЕ ГОВОРИТ** почему наблюдается такой эффект, но просто констатирует факт, что корреляция наблюдается (например, "мы видим, что те игры, которым наши эксперты дают высокие оценки - продаются лучше". А вот почему они продаются лучше - можно только предполагать ... разные причины могут быть).</div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# По условию задачи надо сравнить результаты PS4 (то, что сделано выше) с результатами на других консолях. Рассмотри ещё пару консолей отдельно друг от друга. Выводы, сделанные на основе расчетов по нескольким платформам, выглядят "весомей" и убедительней.</div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Доработка</b><br>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Отлично, вижу ниже отработку ещё 2х платформ
# </div>

# %% [markdown]
# Функция для определения типа корреляции

# %%
def corr_type(corr):
    if abs(corr)<0.5:
        c1 = 'слабо'
    elif 0.5<=abs(corr)<0.7:
        c1 = "средне "
    else:
        c1 = "сильно "
    
    if corr>0:
        c2 = 'положительная'
    else:
        c2 = "отрицательная"
    return c1+c2

# %% [markdown]
# Функция для расчета значения корреляции

# %%
def research_score(pl):
    """
    Функция для расчета значений корреляций отзывов критиков и пользователей с итоговыми продажами
    """
    print(f'Платформа {pl}')
    data[data['platform']==pl].plot(x='critic_score', 
                                    y='total_sales', 
                                    kind='scatter', 
                                    alpha=0.3, 
                                    figsize=(8,8), 
                                    grid=True)
    plt.show()
    
    #получение среза для платформы
    data_plt = act_data.query('platform==@pl')
    
    #расчет и вывод знаяения корреляции
    data_plt_cor = data_plt['critic_score'].corr(data_plt['total_sales'])
    display('Корреляция critic_score-total_sales: {} {}'.format(round(data_plt_cor,2),corr_type(data_plt_cor)))
    
    data_plt_cor2 = data_plt['user_score'].corr(data_plt['total_sales'])
    display('Корреляция user_score-total_sales: {} {}'.format(round(data_plt_cor2,2),corr_type(data_plt_cor2)))

# %% [markdown]
# **Платформа XOne**

# %%
research_score('XOne')
# Out:
# Платформа XOne
# 'Корреляция critic_score-total_sales: 0.42 слабоположительная'
# 'Корреляция user_score-total_sales: -0.07 слабоотрицательная'

# %% [markdown]
# **Платформа PC**

# %%
research_score('PC')
# Out:
# Платформа PC
# 'Корреляция critic_score-total_sales: 0.2 слабоположительная'
# 'Корреляция user_score-total_sales: -0.09 слабоотрицательная'

# %% [markdown]
# При рассмотрении влияния отзывов критиков и пользователей на продажи обнаружилась **слабо полоижительная** корреляция между отзывами критиков и продажами и **слабо отрицательная** корреляция между отзывами пользователей и продажами

# %% [markdown]
# ### Распределение игр по жанрам

# %%
act_data.groupby('genre').agg({'name':'count','total_sales':'sum'}).sort_values(by='total_sales',ascending=False)
# Out:
#               name  total_sales
# genre
# Action         682       270.10
# Shooter        153       197.50
# Role-Playing   277       140.43
# Sports         174       123.02
# Misc           130        43.02
# Platform        64        37.55
# Racing          73        36.82
# Fighting        72        32.74
# Adventure      198        20.80
# Simulation      56        20.52
# Strategy        53         9.52
# Puzzle          17         3.17

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# Здесь у нас возникла проблема: по суммарным (sum, count) объемам продаж у тебя получилось, что явный лидер - игры в жанре Экшн. Если же ты рассмотришь медианные или средние (mean) значения, то результат поменяется в пользу Шуттеров. Учти тот факт, что игр в жанре Экшн выпускается значительно больше, чем других (в 1,5-2 раза). Доля количества игр в жанре «стрелялок» - всего лишь 8%. Очевидно, что в жанре Экшн присутствует большое количество непопулярных игр с низкими объёмами продаж, в результате чего общий объём продаж жанра "раздут" и берётся количеством, а не качеством. Медиана учитывает не только слишком большие\маленькие значения относительно среднего, но и их количество. Поэтому брать итоговые результаты медианы или среднего более корректно.
#
# В сухом остатке: попробуй рассмотреть не общие продажи, а медианные (или средние). Общие продажи - плохая метрика для поиска наиболее прибыльного жанра. За высокими показателями общих продаж может скрываться множество мелких игр с низкими продажами. Или 2-3 звезды и куча провалов. Лучше найти жанр, где игры стабильно приносят высокий доход - для этого стоит рассмотреть средние (или медианные продажи). Я думаю, что анализ медианных показателей позволит тебе найти жанр, который приносит высокий доход.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Доработка</b><br>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Да, отлично, теперь самый прибыльный жанр (Шуттеры) определен верно!
# </div>

# %%
act_data.groupby('genre').agg({'name':'count','total_sales':'median'}).sort_values(by='total_sales',ascending=False)
# Out:
#               name  total_sales
# genre
# Shooter        153        0.480
# Platform        64        0.245
# Sports         174        0.235
# Fighting        72        0.125
# Role-Playing   277        0.120
# Racing          73        0.110
# Misc           130        0.105
# Action         682        0.100
# Simulation      56        0.090
# Strategy        53        0.080
# Puzzle          17        0.060
# Adventure      198        0.030

# %% [markdown]
# <del>Среди жанров игр различных платформ имеются лидеры и аутсайдеры. Четверку лидеров составляют **Action**, **Shooter**, **Role-Playing** и **Sports**. Аутсайдерами являются **Puzzle** и **Strategy**</del>

# %% [markdown]
# Среди жанров игр различных платформ имеются лидеры и аутсайдеры. Четверку лидеров прибыльных жанров составляют Shooter, Platform, Sports,  Fighting, Role-Playing Аутсайдерами являются Puzzle и Adventure. Жанр Action показывает самое большое количество выпущенных игр, но продаются они в основном не очень хорошо.

# %% [markdown]
# **Вывод:** <a id='conclusion_3'></a>

# %% [markdown]
# В ходе проведения исследований были выявлено следующее:
#
# 1. Бурное развитие игроых приставок и игр начинается с 1994 года. Именно в этот период пявляется рейтинг ESRB. По этой причине в исследованиях за первоначальное приближение были взяты данные, начиная с 1994 года.<br>
# 2. Поколения меняются примерно каждые 5-6 лет, только XBox 360 сменил XBox через 8 лет. Старая платформа исчезает примерно через 2 года, после выхода в свет новой. Появления новых платформ разных семейств тоже примерно совпадают по времени, это 2000-2001 г, 2004-2006 г.г, 2011-2013, то есть примерно через каждые 5 лет массово возникают новые платформы разных семейств и производителей. В период с 2000 по 2013 годы наблюдается два пика в продажах игр разных платформ.<br>
# Также в районе 2016 года наблюдается стремление продаж всех платформ практически до нуля, за исключением PlayStation8, XOne и Nintendo 3DS. Абсолютным долгожителем является платформа PC<br>
# Также имеется наблюдение, что если продажи упали примерно в 3-4 раза относительно предыдущего года, то на след год - отсутствие сведений о продажах.<br>
# 3. В 2016 году наблюдается общее падение рынка, начавшееся с 2010 для всех платформ, кроме PS4 и XOne. А с 2015 года падение продаж происходит для всех игровых платформ. Новых платформ после 2013 года не появлялось. За актуальный период был взят 2013 - 2016 годы. <br>
#
# PSV - Платформа уже 7 лет на рынке, продажи сильно упали. Скорее всего в 2017 продажи прекратятся
# Wii - В 2017 году продажи прекратятся
# PS3 - В 2017 году продажи это долгожителя прекратятся
# X360 - Платформа 12 лет на рынке. В 2017 году продажи прекратятся
#
# Платформы XOne и PS4 имеют самые внушительные показатели. Медианное значение продаж у XOne и PS4 практически одинаковое. Среднее значение PS4 немного выше , а вот стандартное отклонение у XOne существенно ниже. Учитывая, что PS4 имеет в 1,6 раза больше выпущенных игр, то можно сделать вывод, что Xone в целом создает более качественный продукт.
#
# 3DS имеет некоторое количество очень хороших игр, которые обеспечивает данной платформе возможность оставаться на плаву. По всей видимости данная платформа за счет этих игр еще некоторе время будет существовать, но, так как в целом ее деятельность почти в 2 раза менее эффективна, чем, скажем у XOne при большем количестве выпущенной продукции, то это продлится недолго.
#
# WiiU не может похвастаться суперуспешными продуктами, которые были присущи ее предшественнику Wii. Отсутствие таких продуктов и приводит к ситуации, что продажи упали в 4 раза, по сравнению с предудущим периодом.
#
# PC имеет самые скромные показатели, но тем не менее, существует продукция, конкурирующая с новыми платформами и имеющая свою аудиторию. Вся история данной платформы показывает, что она занимает свою нишу по праву.
#
#
# Исходя из наблюдений, сделанных для сроков жизни, возникновения новых версий и данных из сводных таблиц, можно сделать следующий предварительный прогноз для рынка игровых платформ:
# Продажи продолжатся:
#
# WiiU - Продажи упали в 2016 году почти в в 4 раза, несмотря на недолгий срок жизненного цикла. В 2017 году продажи будут падать. Если не появится новая модель, то продажи снизятся но нуля
# PC - Продажи будут снижаться, но продолжатся
# 3DS - Платформа 6 лет на рынке. Продажи снижаются, но не критично и нет резких скачков. Продажи снизятся примерно в 1.5 -2 раза. Исходя из выводов, сделанных ранее, в перспективе 1-2 года должна появиться новая платформа.
#
# Для платформ XOne и PS4 в 2017 году может наблюдаться либо небольшой рост продаж по причине падения конкурентов и отсутствия у них новых платформ, либо плавное снижение. Несмотря на то, что продажи упали примернов 2 раза, это снижение не является критическим. Платформы появились на рынке одновременно и для них еще замены скорее всего нет. Новые платформы скорее всего не появятся.
#
# 5. Между отзывами критиков и глобальными продажами корреляция слабо положительная
# 6. Между отзывами пользователей и глобальными продажами корреляция слабо отрицательная
# Таким образом, нельзя утверждать, что отзывы имеют какое-то влияние на продажи
#
# 7. Среди жанров игр различных платформ имеются лидеры и аутсайдеры. Четверку лидеров прибыльных жанров составляют Shooter, Platform, Sports,  Fighting. Аутсайдерами являются Puzzle и Adventure. Жанр Action показывает самое большое количество выпущенных игр, но продаются они в основном не очень хорошо.

# %% [markdown]
# ## Портрет пользователя <a id='user_portrait'></a>

# %% [markdown]
# ### Самые популярные платформы <a id='popular_platforms'></a>

# %%
def user_port(reg,base,total_count,d):
    """
    Функция вычисления продаж различных платформ в заданном регионе и доли от общей суммы продаж
    Input - имя столбца с продажами в нужном регионе, имя столбца для группировки, общая сумма количества продаж, датафрейм
    Output - датасет с группировкой
    """
    print(reg)
    up = d[[base,reg]]
    up_gr = up.groupby(base).agg(count=(reg,'sum')).sort_values(by='count',ascending=False)
    
    up_gr['perc_all'] = round(up_gr['count'] / total_count,3) 
    
    up_gr['region'] = reg
    up_gr['total_pl_reg'] = up_gr.groupby('region')['count'].transform('sum')
    up_gr['perc_plat_reg'] = up_gr['count']/up_gr['total_pl_reg']
    return(up_gr.reset_index())

# %%
# форимирование датаврейма с данными о продажах разлиных платформ в разных регионах
reg = ['na_sales', 'eu_sales','jp_sales']
# датафрейм с данными
d = act_data
total_count =  d['total_sales'].sum()
frames = []
for r in reg:
    result = user_port(r,'platform',total_count,d )
    frames.append(result)
    print(result)
# Out:
# na_sales
#   platform   count  perc_all    region  total_pl_reg  perc_plat_reg
# 0      PS4  108.74     0.116  na_sales        348.92       0.311647
# 1     XOne   93.12     0.100  na_sales        348.92       0.266881
# 2      PS3   63.50     0.068  na_sales        348.92       0.181990
# 3      3DS   38.20     0.041  na_sales        348.92       0.109481
# 4     WiiU   29.21     0.031  na_sales        348.92       0.083715
# 5       PC   11.11     0.012  na_sales        348.92       0.031841
# 6      PSV    5.04     0.005  na_sales        348.92       0.014445
# eu_sales
#   platform   count  perc_all    region  total_pl_reg  perc_plat_reg
# 0      PS4  141.09     0.151  eu_sales        342.76       0.411629
# 1      PS3   67.81     0.073  eu_sales        342.76       0.197835
# 2     XOne   51.59     0.055  eu_sales        342.76       0.150513
# 3      3DS   30.96     0.033  eu_sales        342.76       0.090326
# ...

# %%
#собираем все вместе
rr = pd.concat(frames)
rr
# Out:
#   platform   count  perc_all    region  total_pl_reg  perc_plat_reg
# 0      PS4  108.74     0.116  na_sales        348.92       0.311647
# 1     XOne   93.12     0.100  na_sales        348.92       0.266881
# 2      PS3   63.50     0.068  na_sales        348.92       0.181990
# 3      3DS   38.20     0.041  na_sales        348.92       0.109481
# 4     WiiU   29.21     0.031  na_sales        348.92       0.083715
# 5       PC   11.11     0.012  na_sales        348.92       0.031841
# 6      PSV    5.04     0.005  na_sales        348.92       0.014445
# 0      PS4  141.09     0.151  eu_sales        342.76       0.411629
# 1      PS3   67.81     0.073  eu_sales        342.76       0.197835
# 2     XOne   51.59     0.055  eu_sales        342.76       0.150513
# 3      3DS   30.96     0.033  eu_sales        342.76       0.090326
# 4       PC   25.36     0.027  eu_sales        342.76       0.073988
# 5     WiiU   19.85     0.021  eu_sales        342.76       0.057912
# ...

# %% [markdown]
# Строим график

# %%
fig, ax = plt.subplots(figsize=(20, 10));
ax = sns.barplot(data=rr,y=rr['count'],x=rr['region'],hue='platform')

# %% [markdown]
# Из данных и графиков можно сделать заключение, что в NA следят за новинками, появляющимися на рынке и продажи японских PS4 популярны не менее, чем американские XOne. Доля продаж этих продаж сопоставимы 43% - PS4, 37% - XOne. XOne - ползьзуется наибольшей популярностью именно в NA (14.2% продаж от общемирового показателя). Старые платформы 3DS и PC менее популярны, но имеют своего покупателя.<br>
#
# В EU за явным преимуществом лидирует платформа, PS4 (56%), а вот XOne всего лишь 21%. Платформы 3DS и  WiiU имеют практическую такую же популярность, что и в NA. А вот старая платформа PC здесь в 2 раза популярнее.
#
# Пользователь JP являеетя самым консервативным и патриотичным. Здесь популярны исключительно японские платформы, причем 3DS почти в 3.5 раза популярнее, чем новая PS4. ПОльзователь JP не даст платформе в 2017 упасть в продажах до нуля.

# %% [markdown]
# ПОстроим графики за период с 1994 года

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Достаточно и актуального периода (выше)
# </div>

# %% [markdown]
# Видно, что "профили" na и eu несколько схожи, а вот jp - отличается

# %% [markdown]
# ### Самые популярные жанры <a id='popular_genre'></a>

# %%
# форимирование датаврейма с данными о продажах разлиных платформ в разных регионах
reg = ['na_sales', 'eu_sales','jp_sales']
# датафрейм с данными
d = act_data
total_count =  d['total_sales'].sum()
frames = []
for r in reg:
    result = user_port(r,'genre',total_count,d )
    frames.append(result[0:5])
    print(result[0:5])
# Out:
# na_sales
#           genre  count  perc_all    region  total_pl_reg  perc_plat_reg
# 0        Action  97.08     0.104  na_sales        348.92       0.278230
# 1       Shooter  87.63     0.094  na_sales        348.92       0.251146
# 2        Sports  49.49     0.053  na_sales        348.92       0.141838
# 3  Role-Playing  43.63     0.047  na_sales        348.92       0.125043
# 4          Misc  15.94     0.017  na_sales        348.92       0.045684
# eu_sales
#           genre   count  perc_all    region  total_pl_reg  perc_plat_reg
# 0        Action  100.77     0.108  eu_sales        342.76       0.293996
# 1       Shooter   77.86     0.083  eu_sales        342.76       0.227156
# 2        Sports   51.62     0.055  eu_sales        342.76       0.150601
# 3  Role-Playing   35.73     0.038  eu_sales        342.76       0.104242
# 4        Racing   18.65     0.020  eu_sales        342.76       0.054411
# jp_sales
# ...

# %%
#собираем все вместе
rr2 = pd.concat(frames)
rr2
# Out:
#           genre   count  perc_all    region  total_pl_reg  perc_plat_reg
# 0        Action   97.08     0.104  na_sales        348.92       0.278230
# 1       Shooter   87.63     0.094  na_sales        348.92       0.251146
# 2        Sports   49.49     0.053  na_sales        348.92       0.141838
# 3  Role-Playing   43.63     0.047  na_sales        348.92       0.125043
# 4          Misc   15.94     0.017  na_sales        348.92       0.045684
# 0        Action  100.77     0.108  eu_sales        342.76       0.293996
# 1       Shooter   77.86     0.083  eu_sales        342.76       0.227156
# 2        Sports   51.62     0.055  eu_sales        342.76       0.150601
# 3  Role-Playing   35.73     0.038  eu_sales        342.76       0.104242
# 4        Racing   18.65     0.020  eu_sales        342.76       0.054411
# 0  Role-Playing   49.98     0.053  jp_sales        136.93       0.365004
# 1        Action   39.47     0.042  jp_sales        136.93       0.288249
# ...

# %%
fig, ax = plt.subplots(figsize=(20, 5));
ax = sns.barplot(data=rr2,y=rr2['count'],x=rr2['region'],hue='genre')
ax.grid()

# %% [markdown]
# На предавленных графиках предствдены предпочтения игроков разных регионов. Из них видно, что американский **NA** и европейский игроки **EU** практически на "одно лицо". За явным преимущество лидируют **Shooter** и **Action**. В два раза отcтают жанры **Sports** и **Role-Playing**. Единственным отличием является то, что в NA в пятерку входит Platform, а в EU - Racing. Из этого можно сделать вывод, что европейский игрок более аггресивен. Ему нужно больше "острых" ощущений, чем американскому.
#
# Японский игрок кардинально отличается от европейского и американского. Он абсолютно равнодушен к жанру **Sports**. Ему больше по душе более размеренные игровые жанры **Role-Playing**, **Action**. Жанры Misc и Figting входят в пятерку популярных тоже только JP. Японский геймер более спокойный.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# В этих 2х подразделах всё отлично! Предпочтения геймеров 3х регионов в отношении игровых платформ и жанров определены. Ну и вывод соответственно описывает эти отличия.</div>

# %% [markdown]
# Для сравнения проверим рейтинг жанров за время наблюдений с 1994 года

# %%
# форимирование датаврейма с данными о продажах разлиных платформ в разных регионах
reg = ['na_sales', 'eu_sales','jp_sales']
# датафрейм с данными
d = data
total_count =  d['total_sales'].sum()
frames = []
for r in reg:
    result = user_port(r,'genre',total_count,d )
    frames.append(result[0:5])
    print(result[0:5])
# Out:
# na_sales
#      genre   count  perc_all    region  total_pl_reg  perc_plat_reg
# 0   Action  815.87     0.100  na_sales       4004.18       0.203755
# 1   Sports  652.42     0.080  na_sales       4004.18       0.162935
# 2  Shooter  531.32     0.065  na_sales       4004.18       0.132691
# 3     Misc  394.79     0.049  na_sales       4004.18       0.098594
# 4   Racing  342.09     0.042  na_sales       4004.18       0.085433
# eu_sales
#      genre   count  perc_all    region  total_pl_reg  perc_plat_reg
# 0   Action  504.07     0.062  eu_sales       2337.74       0.215623
# 1   Sports  367.37     0.045  eu_sales       2337.74       0.157148
# 2  Shooter  310.80     0.038  eu_sales       2337.74       0.132949
# 3   Racing  230.02     0.028  eu_sales       2337.74       0.098394
# 4     Misc  209.86     0.026  eu_sales       2337.74       0.089770
# jp_sales
#           genre   count  perc_all    region  total_pl_reg  perc_plat_reg
# ...

# %% [markdown]
# Из полученных данных можно увидеть, что предпочтения пользователей практически не изменились, за исключением того, что Sports пропал из "пятерки" в JP, Misc исчез в NA и EU, на его место пришел жанр Role-Playing. Жанры Action, Shooter, Sports в NA и EU остались на своих местах

# %% [markdown]
# В общем и целом рейтинги не изменились.

# %% [markdown]
#  Посчитаем рейтинг каждой платформы в продажах каждого жанра.
#
#  Извлечем наименования самых популярных жанров:

# %%
genre_name = list(set(rr2['genre']))
genre_name
# Out:
# ['Role-Playing', 'Racing', 'Action', 'Misc', 'Sports', 'Shooter', 'Fighting']

# %% [markdown]
# <div class="alert alert-info">
# <b>Доработка</b><br>
# </div>

# %%
genre_name = ['Shooter','Sports', 'Fighting','Role-Playing', 'Action','Misc','Platform','Racing']

# %% [markdown]
# Выведем медианные продажи каждой платформы, популярной у пользователей в наиболее прибыльных и востребованных жанрах:

# %%
for g in genre_name:
    rol_pl = act_data.query('genre == @g').groupby('platform')\
                        .agg(count_na = ('na_sales','count'),sum_na=('na_sales','mean'),\
                             count_eu = ('eu_sales','count'),sum_eu=('eu_sales','mean'),\
                             count_jp = ('jp_sales','count'),sum_jp=('jp_sales','mean'))\
                        .sort_values(by='sum_na',ascending=False)
    print('Жанр - ', g)
    print(rol_pl)
    print('*'*30)
# Out:
# Жанр -  Shooter
#           count_na    sum_na  count_eu    sum_eu  count_jp    sum_jp
# platform
# XOne            38  0.970000        38  0.468421        38  0.004211
# PS4             41  0.796585        41  0.955122        41  0.068537
# PS3             31  0.395484        31  0.418387        31  0.058710
# PSV              2  0.260000         2  0.275000         2  0.025000
# WiiU             8  0.260000         8  0.190000         8  0.192500
# PC              32  0.101562        32  0.181250        32  0.000000
# 3DS              1  0.000000         1  0.060000         1  0.000000
# ******************************
# Жанр -  Sports
#           count_na    sum_na  count_eu    sum_eu  count_jp    sum_jp
# platform
# PS4             46  0.430000        46  0.564783        46  0.021522
# XOne            38  0.410263        38  0.229737        38  0.000526
# PS3             47  0.263830        47  0.276383        47  0.039362
# ...

# %% [markdown]
# Суммарные продажи в жанре **Shooter** в NA и EU

# %%
rol_pl = act_data.query('genre == "Shooter"').groupby('platform')\
                .agg(count_na = ('na_sales','sum'),count_eu = ('eu_sales','sum'))\
                .sort_values(by='count_na',ascending=False)
rol_pl
# Out:
#           count_na  count_eu
# platform
# XOne         36.86     17.80
# PS4          32.66     39.16
# PS3          12.26     12.97
# PC            3.25      5.80
# WiiU          2.08      1.52
# PSV           0.52      0.55
# 3DS           0.00      0.06

# %% [markdown]
# Суммарные продажи в жанре **Action** в NA и EU

# %%
rol_pl = act_data.query('genre == "Action"').groupby('platform')\
                .agg(count_na = ('na_sales','sum'),count_eu = ('eu_sales','sum'))\
                .sort_values(by='count_na',ascending=False)
rol_pl
# Out:
#           count_na  count_eu
# platform
# PS4          32.83     42.71
# PS3          23.65     26.81
# XOne         21.37     12.58
# 3DS           8.60      6.97
# WiiU          7.37      5.22
# PC            2.26      4.50
# PSV           1.00      1.98

# %% [markdown]
# Из приведенных расчетов становится более понятно лидерство PS4. Эта платформа является первой в продажах различных игр в 4-х из семи представленных жанров. Что касается 3DS, то так как жанры Role-Playing и Action входят в пятерку популярных во всех регионах, особенно в JP, а в лидерах по продажам того жанра является 3DS, то этим и объясняется его "долгожительство". Несмотря на то, что  XOne и PS4 продают практически одинаковое количество наименований различных игр в жанрах   Shooter и Action (41 и 38) , количество проданных экземпляров этих игр в EU в этих жанрах от 2 до 4 раз больше, этим объясняется отставание XOne в Европе.
#
# Так же средние показатели продаж по каждой платформе в разрезе жанров показывают, что в общем и целом наиболее перспективными являются

# %% [markdown]
# ### Влияние рейтинга ESRB <a id='raiting_esrb'></a>

# %% [markdown]
# Группируем данные по рейтингу ESRB за период наблюдений за период 2013 - 2016 годыы (1994 - год появления ESRB). Аггрегационная функция - суммирование

# %%
raiting_esrb = act_data.groupby('rating').agg(NA=('na_sales','sum'),EU=('eu_sales','sum'),JP=('jp_sales','sum')).sort_values(by='NA',ascending=False)

# %%
raiting_esrb.reset_index()
# Out:
#   rating      NA      EU     JP
# 0      M  126.80  126.26  13.74
# 1      U   77.09   72.20  81.93
# 2      E   64.39   73.39  14.99
# 3      T   42.60   38.60  20.39
# 4   E10+   38.04   32.31   5.88

# %% [markdown]
# <div class="alert alert-info">
# <b>Доработка</b><br>
# </div>

# %% [markdown]
# Здесь рейтинг **U** - unknown. "Заглушка", поставленная на этапе предобработки.<br>
# Предварительно видно, что игры с отсутсвием рейтинга занимают ощутимую доолю в продажах

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Да, теперь игры без рейтинга из нашего анализа не выпадают, отлично!
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# Здесь мы потеряли игры без рейтинга (в самом начале тетрадки у меня был комментарий про то, что мы не должны забыть обработать NaN в 'rating'). Если выполнить (**псевдокод!**): **df_actual['rating'].value_counts(dropna=False)**, то получим, что кроме игр с явными рейтингами (которые ты ниже и анализируешь) есть ещё около тысячи игр без рейтинга. Но продажи именно таких игр могут указать на ключевое различие в регионах.
# Исправь пожалуйста эту ошибку и посмотри - не поменялись ли твои выводы.</div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Доработка</b><br>
# </div>

# %% [markdown]
# Считаем долю продаж игр каждого рейтинга в отдельно взятом регионе

# %%
raiting_esrb['na_sum'] = raiting_esrb['NA'].sum()
raiting_esrb['eu_sum'] = raiting_esrb['EU'].sum()
raiting_esrb['jp_sum'] = raiting_esrb['JP'].sum()
raiting_esrb['na_perc'] = round(raiting_esrb['NA']/raiting_esrb['na_sum'],2)
raiting_esrb['eu_perc'] = round(raiting_esrb['EU']/raiting_esrb['eu_sum'],2)
raiting_esrb['jp_perc'] = round(raiting_esrb['JP']/raiting_esrb['jp_sum'],2)

# %%
raiting_esrb = raiting_esrb[['na_perc','eu_perc','jp_perc']]
raiting_esrb
# Out:
#         na_perc  eu_perc  jp_perc
# rating
# M          0.36     0.37     0.10
# U          0.22     0.21     0.60
# E          0.18     0.21     0.11
# T          0.12     0.11     0.15
# E10+       0.11     0.09     0.04

# %% [markdown]
# Из расчетной таблицы видно, что значимые отличия наблюдаются в регионе **JP** в части рейтингов **M**, **E**, **E10+** и **U**. В Японии 60% игр не имеют рейтинга. Игры для взрослых продаются в три раза меньше, чем в EU и NA, а без рейтинга игр в 3 раза больше, чем в тех же регионах. Возможно, это попытка продать игры для взрослых при законодательных ограничениях. **Рейтинг ESRB существенно влияет на продажи в отдельном регионе.**

# %% [markdown]
# Группируем данные по рейтингу ESRB за период наблюдений за период 1994 - 2016 годы (1994 - год появления ESRB). Аггрегационная функция - суммирование

# %%
raiting_esrb = data.groupby('rating').agg(NA=('na_sales','sum'),EU=('eu_sales','sum'),JP=('jp_sales','sum')).sort_values(by='NA',ascending=False)

# %%
raiting_esrb.reset_index()
# Out:
#   rating       NA      EU      JP
# 0      E  1275.78  704.08  199.17
# 1      U   890.14  548.06  559.21
# 2      T   747.08  421.52  148.34
# 3      M   742.89  480.00   63.53
# 4   E10+   345.50  183.33   40.20
# 5     EC     1.53    0.11    0.00
# 6     AO     1.26    0.61    0.00
# 7     RP     0.00    0.03    0.00

# %%
raiting_esrb['na_sum'] = raiting_esrb['NA'].sum()
raiting_esrb['eu_sum'] = raiting_esrb['EU'].sum()
raiting_esrb['jp_sum'] = raiting_esrb['JP'].sum()
raiting_esrb['na_perc'] = round(raiting_esrb['NA']/raiting_esrb['na_sum'],2)
raiting_esrb['eu_perc'] = round(raiting_esrb['EU']/raiting_esrb['eu_sum'],2)
raiting_esrb['jp_perc'] = round(raiting_esrb['JP']/raiting_esrb['jp_sum'],2)

# %%
raiting_esrb = raiting_esrb[['na_perc','eu_perc','jp_perc']]
raiting_esrb
# Out:
#         na_perc  eu_perc  jp_perc
# rating
# E          0.32     0.30     0.20
# U          0.22     0.23     0.55
# T          0.19     0.18     0.15
# M          0.19     0.21     0.06
# E10+       0.09     0.08     0.04
# EC         0.00     0.00     0.00
# AO         0.00     0.00     0.00
# RP         0.00     0.00     0.00

# %% [markdown]
# Данные расчеты подтверждают, что предпочтения геймеров региона JP ощутимо отличаются от европейских и американских

# %% [markdown]
# **Вывод:** <a id='conclusion_4'></a>

# %% [markdown]
# При составлении портрета пользователя регионов обнаружилось следующее:
#
# 1. В **NA** у геймеров  японские PS4 популярны не менее, чем американские XOne. Доля продаж этих продаж сопоставимы 43% - PS4, 37% - XOne. XOne - пользуется наибольшей популярностью именно в NA. Старые платформы 3DS и PC менее популярны, но имеют своего покупателя в силу того, что в пятерку самых популярных входит жанр **Role-Playing**, наиболее широко представленный именно 3DS. Основные предпочтения американского геймера - это **Shooter**, **Action**, **Sports**, **Role-Playing** и **Platform**<br>
#
# 2. В EU геймер явно предпочитает игры платформы PS4 (56%), а вот XOne всего лишь 21%. Связано это скорее всего, что к играм жанров **Shooter** и **Action** (наиболее популярных в этом регионе) от **XOne** здесь относятся "прохладнее". Платформы 3DS и  WiiU имеют практическую такую же популярность, что и в NA. А вот старая платформа PC пользуется спросом в 2 раза чаще, возможно это связано с тем, что PC входит в тройку по продажам игр жанров **Sports**, **Role-Playing**, имеющих немало поклонников в данном регоне.  Создается впечатление , что пользователь EU более динамичен, аггресивен, поскольку практически все жанры, на которые имеется спрос в данном регионе, связаны со стрельбой, спортом, гонками и экшеном. <br>
#
# 3. Пользователь JP являеетя самым консервативным и патриотичным. Здесь популярны исключительно японские платформы, причем 3DS покупается почти в 3.5 раза чаще, чем новая PS4. Это связано с популярностью жанров **Role-Playing** и **Action**, в которых 3DS и PS4 - лидеры. Так же PS4 является лидером продаж в жанре **Fighting**, популярным именно в **JP**. Геймер из JP предпочитает более спокойные жанры, такие как **Platform** и **Misc**. Абсолютно не интересуется жанром **Shooter**. Интерес к жанру **Figting** можно объяснить наличием культуры самураев). <br>
#
# 4. Если в регионах **NA** и **EU** прождажа игр рейтинга ESRB **M(для взрослых)** составляет практически половину, то в JP лишь пятую часть. Основная часть игр в Японии <del>относится к категории E(для всех) и Т(подростки)</del> **не имеет рейтинга**. Таким образом рейтинг ESRB влияет на продажи в отдельном регионе.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# (После исправления красного комментария выше) А чем на твой взгляд можно объяснить то, что в Японии лидерами продаж (в количестве копий) являются игры без рейтинга ESRB?</div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Ответ</b><br>
#    Игры для взрослых продаются в три раза меньше, чем в EU и NA, а без рейтинга игр в 3 раза больше, чем в тех же регионах. Возможно, это попытка продать игры для взрослых при законодательных ограничениях. Также в Японии существует своя рейтинговая политика, отличная от ESRB
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Да, верно! Рейтинг ESRB - это американский рейтинг, а в Японии есть своё рейтинговое агентство (CERO). Получается, что Япония страна со своим менталитетом. И твой анализ показывает, что Японцы в игры-то играют не такие, как весь прочий мир и жанры игр там популярны совсем другие, нежели в остальном мире, да и на рейтинги (не своего агентства) не очень-то внимание обращают.
# </div>

# %% [markdown]
# ## Гипотезы <a id='hypothesis'></a>

# %% [markdown]
# <div class="alert alert-info">
# <b>Доработка</b><br>
#    Импорты перенесены в начало тетради
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# +
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Все импорты лучше собрать в самой первой ячейке "тетрадки" с кодом - так твои коллеги с первого взгляда смогут понять и оценить какие библиотеки ты используешь в своём проекте.</div>

# %% [markdown]
# В данном блоке будут проверяться гипотезы о равенстве средних рейтингов, каждый из которых которые будет выбираться из своей совокупности. Поэтому будем проводить t-тест для двух совокупностей, используя метод **st.ttest_ind**

# %% [markdown]
# Создадим функцию для вычисления значения p-value для двух совокупностей

# %%
def hypothesis_testing(df1,df2):
    """
    Функция, возвращающая значение p-value t-теста
    Вход - два датафрейма
    Выход - p-value для t-теста двух совокупностей
    """
    #Выравниваем датафреймы по длине
    if df1.shape[0]>df2.shape[0]:
        df1 = df1.sample(n=df2.shape[0])
    elif df1.shape[0]<df2.shape[0]:
        df2 = df2.sample(n=df1.shape[0])
    #вычисляем p-value
    results = st.ttest_ind(
        df1, 
        df2,
        equal_var = False)
    return results.pvalue

# %% [markdown]
# ### Средние пользовательские рейтинги платформ Xbox One и PC  <a id='hypothesis_1'></a>

# %% [markdown]
# hyp_xone - датафрейм c пользовательскими рейтингами XOne<br>
# hyp_pc - датафрейм c пользовательскими рейтингами PC

# %%
hyp_xone = act_data.query('platform=="XOne" and not(user_score.isna())')['user_score']

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# У тебя в 'user_score' есть искусственно внесенные туда значения-«заглушки». Теория же нам говорит, что перед проверкой гипотез и пропуски и «заглушки» должны быть удалены.</div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Доработка</b><br>
#     Заглушки были удалены. Значения NaN отсекаются условием в срезе
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Да, всё теперь верно, молодец!
# </div>

# %%
hyp_xone.head()
# Out:
# 14797    7.9
# 14798    5.4
# 14799    6.4
# 14800    6.2
# 14802    4.1
# Name: user_score, dtype: float64

# %%
hyp_xone.shape[0]
# Out:
# 182

# %%
hyp_xone.describe()
# Out:
# count    182.000000
# mean       6.521429
# std        1.380941
# min        1.600000
# 25%        5.800000
# 50%        6.800000
# 75%        7.500000
# max        9.200000
# Name: user_score, dtype: float64

# %%
hyp_pc = act_data.query('platform=="PC" and not(user_score.isna())')['user_score']

# %%
hyp_pc.head()
# Out:
# 12542    3.9
# 12568    7.9
# 12576    2.2
# 12577    6.0
# 12580    5.4
# Name: user_score, dtype: float64

# %%
hyp_pc.describe()
# Out:
# count    155.000000
# mean       6.269677
# std        1.742381
# min        1.400000
# 25%        5.300000
# 50%        6.800000
# 75%        7.600000
# max        9.300000
# Name: user_score, dtype: float64

# %% [markdown]
# Гипотеза H0 - средние пользовательские рейтинги ировых платформ Xone и PC одинаковые<BR>
# Гипотеза H1 - средние пользовательские рейтинги ировых платформ Xone и PC различаются

# %%
alpha = .05 # критический уровень статистической значимости

# %%
pv = hypothesis_testing(hyp_xone,hyp_pc)
print('pvalue =',pv)
if pv < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# pvalue = 0.21199621509350325
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# ### Средние пользовательские рейтинги жанров Action и Sports  <a id='hypothesis_2'></a>

# %%
hyp_act = act_data.query('genre=="Action" and not(user_score.isna())')['user_score']
print(hyp_act.shape[0])
# Out:
# 341

# %% [markdown]
# Средний пользовательсвктй рейтинг Action

# %%
hyp_act.mean()
# Out:
# 6.868621700879765

# %%
hyp_act.shape[0]
# Out:
# 341

# %%
hyp_sports = act_data.query('genre=="Sports" and not(user_score.isna())')['user_score']
print(hyp_sports.shape[0])
# Out:
# 130

# %% [markdown]
# Средний пользовательсвкий рейтинг Sports

# %%
hyp_sports.mean()
# Out:
# 5.385384615384616

# %% [markdown]
# Видно что рейтинг Action значительно выше, чем Sports. Выполним проверку односторонней гипотезы

# %% [markdown]
# Гипотеза H0 - рейтинги жанров Action и Sports одинаковые<br>
# Гипотеза H1 - рейтинги жанра Action больше, чем Sports

# %%
alpha = 0.05

# %%
pv = hypothesis_testing(hyp_act,hyp_sports)
print('pvalue =',pv)
if pv/2 < alpha and hyp_sports.mean()<hyp_act.mean():
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# pvalue = 3.784804013553847e-12
# Отвергаем нулевую гипотезу

# %% [markdown]
# **Вывод**: <a id='conclusion_5'></a>

# %% [markdown]
# Были выдвинуты две гипотезы о равенстве ползовательских рейтингов платформ XONE и PC, а также жанров Action и Sports.<br>
# Первая гипотеза подтвердилась, вторая была отвергнута. <br>
# Нулевые гипотезы были выдвинуты о равенстве рейтингов.<br>
# Альтернативная гипотеза о равенстве рейтингов платформ была двусторонней и предполагала неравенство рейтингов.<br>
# Альтернативная гипотеза о равенстве рейтингов жанров была односторонней в пользу жанра Action.<br>
# В силу того, что выборки не являются большими, можно было сделать выводы и не прибегая к t-тесту

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Очень хорошо, что ты не забываешь отфильтровать «заглушки» / NaN значения.
#
# Также верно и то, что мы используем здесь двусторонний тест.
#
# Ну и отлично, что ты понимаешь, что нельзя сделать вывод, что тест "подтвердил" одну из гипотез (в статистике гипотезы подтвердить невозможно) или "подтвердил" равенство/неравенство (можно говорить только о статистически (не)значимом различии). Например так: «У нас нет оснований утверждать, что средние пользовательские рейтинги платформ Xbox One и PC значимо различаются».
#
# И ещё на эту же тему: никакие экспериментально полученные данные никогда не подтвердят какую-либо гипотезу. Это наше фундаментальное ограничение. Данные могут лишь не противоречить ей или, наоборот, показывать крайне маловероятные результаты (при условии, что гипотеза верна). Но и в том, и в другом случае нет оснований утверждать, что выдвинутая гипотеза доказана. Допустим, данные гипотезе не противоречат, тогда мы её не отвергаем. Если же мы приходим к выводу, что получить такие данные в рамках этой гипотезы вряд ли возможно, у нас появляется основание отбросить эту гипотезу.
#
# Статья на эту тему: https://allatambov.github.io/psms/pdf/hypo-test.pdf
# </div>

# %% [markdown]
# **Общий вывод:** <a id='conclusion_6'></a>

# %% [markdown]
# Для работы были предоставлены данные, содержащие некоторое количество пропущенной информации.
# В процессе ознакомления с информацией были определены недочеты в данных, некоторые из которых были испавлены на этапе подготовки данных.<br>
# 1. Названия столбцов были переведены в нижний регистр
# 2. Некоторые пропуски в столбце **year_of_release** были восстановлены из наименования игр, остальные удалены.
# 3. Пропуски в названиях и жанрах совпали и были удалены.
# 4. Были обнаружены неявные дубликати в рейтинге ESRB. Рейтинг **K-A** переименован в **E**
# 5. Пользовательские оценки имели значения **tbd**, которые были преобразованы в NaN. Пропуски в оценках пользователей оставлены без изменений. Оценки критиков были оставлены без изменений.<br>
# 6. Для удобства пользования данными был добавлен столбец названиями семейств и общих предков различных платформ.
# 7. Был добален столбец с итоговыми продажами для каждой игры
# 8. Изменены типы данных year_of_release на int, user_score на float
#
# Для выполнения исследований и получения прогнозов были взяты данные за период 2013-2016 годы. Это обусловлено тем, что некоторые платформы уже закончили свой жизненный цикл и не имеют продаж, либо срок жизни уже велик.  а также тот факт, что последние новые платформы появились в 2013 годы.
#
# Средняя продолжительность жизни игровой платформы составляет от 9 до 12 лет. Абсолютным долгожителем является платформа PC. Было замечено, что если продажи упали примерно в 3-4 раза относительно предыдущего года, то на след год - отсутствие сведений о продажах.<br>
# В 2016 году наблюдается общее падение рынка, начавшееся с 2010 для всех платформ, кроме PS4 и XOne. А с 2015 года падение продаж происходит для всех игровых платформ. Новых платформ после 2013 года не появлялось. За актуальный период был взят 2013 - 2016 годы.
#
# 3DS имеет некоторое количество очень хороших игр, которые обеспечивает данной платформе возможность оставаться на плаву. По всей видимости данная платформа за счет этих игр еще некоторе время будет существовать, но, так как в целом ее деятельность почти в 2 раза менее эффективна, чем, скажем у XOne при большем количестве выпущенной продукции, то это продлится недолго. Долгожительство 3DS поддерживается в основном геймерами из Японии и теме, кто любит жанры **Role-Playing** и **Action**
#
# WiiU является крепким "середнячком" и имеет качественный продукт, позволяющий при меньше количестве выпускаемой продукции показывать средние показатели на уровне PS4 и XOne. Однако, продажи упали в 2016 году почти в 4 раза, несмотря на недолгий срок жизненного цикла. В 2017 году продажи будут падать. Если не появится новая модель, то продажи снизятся но нуля.
#
# PC имеет самые скромные показатели, но тем не менее, существует продукция, конкурирующая с новыми платформами и имеющая свою аудиторию. Вся история данной платформы показывает, что она занимает свою нишу по праву. В 2017 продажи будут снижаться, но продолжатся
#
#
# Платформы XOne и PS4 имеют самые внушительные показатели. Медианное значение продаж у XOne и PS4 практически одинаковое. Среднее значение PS4 немного выше , а вот стандартное отклонение у XOne существенно ниже. Учитывая, что PS4 имеет в 1,6 раза больше выпущенных игр, то можно сделать вывод, что Xone в целом создает более качественный продукт.<br>
# Обе платформы имеют самые высокие продажи в **NA**, но вот в **EU** больше популярна **PS4**. Разработчикам Xone необходимо уделить внимание жанрам **Shooter** и **Action**, потому что именно эти жанры от XOne у европейцев не конкурируют с PS4.
#
# Для платформ XOne и PS4 в 2017 году может наблюдаться либо небольшой рост продаж по причине падения конкурентов и отсутствия у них новых платформ, либо плавное снижение. Несмотря на то, что продажи упали примернов 2 раза, это снижение не является критическим. Платформы появились на рынке одновременно и для них еще замены скорее всего нет. Новые платформы скорее всего не появятся.
#
# Между отзывами критиков и глобальными продажами корреляция **слабо положительная**, а между отзывами пользователей и глобальными продажами корреляция **слабо отрицательная** Таким образом, нельзя утверждать, что отзывы имеют какое-то влияние на продажи. Геймеры - народ консервативный, особенно японский геймер.
#
# Самыми прибыльными жанрами являются **Shooter, Platform, Sports,  Fighting**. Аутсайдерами являются **Puzzle и Adventure**. Жанр **Action** хоть и является одним из предпочитаемых пользователями и показывает самое большое количество выпущенных игр, но продаются они в основном не очень хорошо.
#
# При составлении портрета пользователя регионов обнаружилось следующее:
#
# 1. В **NA** у геймеров  японские PS4 и американские XOne популярны одинаково. Это платформы новые. Американский геймер более склонен к экспериментам. Доля продаж этих продаж сопоставимы 43% - PS4, 37% - XOne. XOne - пользуется наибольшей популярностью именно в NA. Старые платформы 3DS и PC менее популярны, но имеют своего покупателя в силу того, что в пятерку самых популярных входит жанр **Role-Playing**, наиболее широко представленный именно 3DS. Основные предпочтения американского геймера - это **Shooter**, **Action**, **Sports**, **Role-Playing** и **Platform**<br>
#
# 2. В EU геймер явно предпочитает игры платформы PS4 (56%), а вот XOne всего лишь 21%. Связано это скорее всего, что к играм жанров **Shooter** и **Action** (наиболее популярных в этом регионе) от **XOne** здесь относятся "прохладнее". Платформы 3DS и  WiiU имеют практическую такую же популярность, что и в NA. А вот старая платформа PC пользуется спросом в 2 раза чаще, возможно это связано с тем, что PC входит в тройку по продажам игр жанров **Sports**, **Role-Playing**, имеющих немало поклонников в данном регоне.  Создается впечатление , что пользователь EU более динамичен, аггресивен, поскольку практически все жанры, на которые имеется спрос в данном регионе, связаны со стрельбой, спортом, гонками и экшеном. <br>
#
# 3. Пользователь JP являеетя самым консервативным и патриотичным. Здесь популярны исключительно японские платформы, причем 3DS покупается почти в 3.5 раза чаще, чем новая PS4. Это связано с популярностью жанров **Role-Playing** и **Action**, в которых 3DS и PS4 - лидеры. Так же PS4 является лидером продаж в жанре **Fighting**, популярным именно в **JP**. Геймер из JP предпочитает более спокойные жанры, такие как **Platform** и **Misc**. Абсолютно не интересуется жанром **Shooter**. Интерес к жанру **Figting** можно объяснить наличием культуры самураев).<br>
#
# Портреты пользователей подтверждают тот факт, что в 2017 году старые платформы 3DS, PC будут продаваться.
#
# Значимые отличия наблюдаются в регионе JP в части рейтингов M, E, E10+ и U. В Японии 60% игр не имеют рейтинга. Игры для взрослых продаются в три раза меньше, чем в EU и NA, а без рейтинга игр в 3 раза больше, чем в тех же регионах. Рейтинг ESRB существенно влияет на продажи в отдельном регионе.
#
# В конце были выдвинуты две гипотезы, касаемо средних рейтингов пользователей: равенстве пользовательских рейтингов платформ XONE и PC, а также жанров Action и Sports.
#
# Первая гипотеза подтвердилась, вторая была отвергнута.
# Нулевые гипотезы были выдвинуты о равенстве рейтингов.
# Альтернативная гипотеза о равенстве рейтингов платформ была двусторонней и предполагала неравенство рейтингов.
# Альтернативная гипотеза о равенстве рейтингов жанров была односторонней в пользу жанра Action.
# Выборки не являются большими, можно было сделать выводы и не прибегая к t-тесту.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# Нам, нашей компании "Стримчик"-то что делать? Мы не разработчики, мы не критики, мы обычные продавцы. Нам нужно спланировать рекламную компанию на 2017 год. На что мы должны ставку делать? Конкретика нужна от тебя, как от аналитика.
#
# Другими словами, в нашем исследовании мы проанализировали игры «с разных точек зрения». Логично, что рекламный отдел от нас ждет на какие платформы (1-2 штуки, на большее у нас не хватит рекламного бюджета), с каким жанром, с каким рейтингом ESRB и в каком регионе рекламировать. Стоит ли обращать внимание на отзывы или нет. К финальному выводу вся эта информация у нас уже есть, надо просто акцентировать на какие игры тратить рекламный бюджет.</div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Доработка</b><br>
#
# </div>

# %% [markdown]
# Таким образом, компании "Стримчик" в 2017 году необходимо:
# 1. Сконцентрироваться на продажаж игровых платформ PS4, XOne в регионах NA и EU. В регионе JP платформу XOne в силу менталитета геймеров продавать бессмысленно. Здесь иммеет смысл усилить позиции PS4.
# 2. В силу прибыльности платформ Shooter и Sports и предпочтений геймеров в регионах необходимо провести рекламную кампанию со ставкой на следующие игровые платформы:<br>
#
#     1) XOne в регионе EU  в жанрах **shooter,sports** c рейтингами **E**, **M**<br>
#     Пояснение: XOne занимает лидирующие позиции в NA наряду c PS4, а вот в EU данная платформа отстает. Надо усилить позиции.
#
#     2) PS4 в регионе JP в жанре **shooter** без рейтинга<br>
#     Пояснение: **shooter** является наиболее перспективым и прибыльным жанром, но платформа, которая популярна во всех регионах - это PS4.
#
# 3. Продажу игровой платформы 3DS продолжить в прежних объемах, особенно в жанре **Role-Playing**
# 4. ПРодажи WiiU,PC,PS3 продолжить в меньших объемах в связи с их постепенной утратой спроса на рынке.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# После исправления красных комментариев надо будет ещё раз пересмотреть выводы в этом финальном разделе, я уверен, что некоторые акценты сместятся и твой вывод поменяется.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Спасибо за качественный, детальный, структурированный финальный вывод! Отдельное спасибо – за **рекомендации аналитика**, которые должны помочь менеджменту компании «Стримчик» в определении потенциально выигрышных в 2017 году продуктов и проектов.
# </div>

# %% [markdown]
# # Результат ревью:
#
# Я отмечаю адекватный уровень твоей программистской подготовки. Ты используешь продвинутые концепции языка Python и библиотеки pandas. Всё это в целом упрощает твой код и одновременно показывает твой уровень владения инструментами.
#
# Ты умело применяешь графические библиотеки (matplotlib / seaborn / plotly), выбираешь для визуализации ровно те типы графиков, которые нужны. Если ещё поработать над тем, чтобы все оси были подписаны и графики имели понятные названия, то будет просто отлично. Очень хорошо, что оси на графиках (в большинстве графиков!) подписаны и сами они имеют понятные названия.
#
# В некоторых местах, как мне показалось, всё-таки были бы уместны короткие комментарии. Как пример: применение функций groupby на мой взгляд можно было бы сопроводить описанием того - для чего делается группировка/объединение и что мы получим в результате.
#
# С комментированием никаких проблем нет. Твоих объяснений достаточно для понимания твоими коллегами хода мыслей. Ссылки из брифа проекта в нужных местах также помогают следовать за развитием событий и дают полную информацию касаемо того, что будет происходить в том или ином разделе проекта.
#
# Зелёным цветом я отметил и прокомментировал удачные и элегантные решения, на которые ты можешь опираться в будущих проектах.
#
# Жёлтым цветом я выделил то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас.
#
# Однако есть принципиальные моменты, которые не позволяют мне принять твой проект в его нынешнем состоянии:
#
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# 1. Небольшая вводная перед исследованием даст быстрое понимание о том, чему оно посвящено. Я настоятельно рекомендую тебе оформить введение и добавить цели и задачи проекта.
#
# 2. Заполнять пропуски в оценках пользователей и экспертов вычисленными значениями по соответствующим столбцам датасета в этой задаче нельзя. Оцени пожалуйста корректность такого решения и рассмотри другой вариант работы с пропусками.
#
# 3. Любая предобработка данных предполагает поиск и анализ дубликатов. В твоём разделе EDA (== Exploratory Data Analysis) подобной важной составляющей нет. После поиска и обнаружения - опиши как их планируешь и планируешь ли обрабатывать?
#
# 4. В разделе построения «ящика с усами» по глобальным продажам игр в разбивке по платформам необходимо построить график так, чтобы квартили соответствующих «ящиков» позволяли визуально сравнивать платформы между собой. **Все боксплоты** нужно построить на одном графике.
#
# 5. В разделе расчета корреляций между оценками (пользователей/экспертов) и продажами, «на расчет» передаются данные, содержащие «заглушки» (заполненные руками значения).
#
# 6. По условию задачи надо сравнить результаты PS4 с результатами на других консолях.
#
# 7. Попробуй рассмотреть не общие продажи, а медианные (или средние). Общие продажи - плохая метрика для поиска наиболее прибыльного жанра. Анализ медианных показателей позволит тебе найти жанр, который приносит высокий доход.
#
# 8. Мы "потеряли" игры без рейтинга. Кроме игр с явными рейтингами (которые ты анализируешь) есть ещё около тысячи игр без рейтинга. Но продажи именно таких игр могут указать на ключевое различие в регионах.
#
# 9. В разделе проверки гипотез, ты на проверку передаешь кроме "реальных оценок пользователей" ещё и данные содержащие NaN и заполненные руками значения.
#
# 10.  В финальном выводе требуется максимально подробно описать что ты предлагаешь сделать в 2017 году, для того, чтобы твоя компания победила конкурентов.</div>
#
# Эти 10 моментов требуют твоего внимания. Комментарии по ним помечены красным цветом.
#
# Подводя итог: хорошая работа на самом-то деле, молодец! Есть несколько моментов к исправлению, но уверен, что они не вызовут у тебя сложностей. После доработки обязательно проверь комментарии и выводы. Их нужно будет скорректировать. Жду доработанную версию проекта на повторное ревью.
