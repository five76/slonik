# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Дмитрий, привет!👋</b>
#
# Меня зовут Алексей Гриб, и я буду ревьюером твоего проекта.
#
# Сразу хочу предложить в дальнейшем общаться на "ты" - надеюсь, так будет комфортнее:) Но если это неудобно, обязательно дай знать, и мы придумаем что-нибудь ещё!
#
# Цель ревью - не искать ошибки в твоём проекте, а помочь тебе сделать твою работу ещё лучше, устранив недочёты и приблизив её к реальным задачам аналитика. Поэтому не расстраивайся, если что-то не получилось с первого раза - это нормально, и это поможет тебе вырасти!
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> похвала, рекомендации «со звёздочкой», полезные лайфхаки, которые сделают и без того красивое решение ещё более элегантным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> некритичные ошибки или развивающие рекомендации на будущее.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Критичные ошибки, которые обязательно нужно исправить.
# </div>
#
# Я не смогу принять проект, если в нём будет хотя бы одна критичная ошибка или несколько некритичных ошибок - тогда проект нужно будет немного доработать. Но это нестрашно - я обязательно дам тебе подсказку или укажу верное направление.
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь задавать свои вопросы, реагировать на мои комментарии, делать пометки и пояснения - полная творческая свобода! Но маленькая просьба - пускай они будут отличаться от моих комментариев, это поможет избежать путаницы в нашем общении:)
# Например, вот так:
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *твой текст*
# </div>
#
# Давай посмотрим на твой проект!

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Изучение-данных" data-toc-modified-id="Изучение-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Изучение данных</a></span></li><li><span><a href="#Проверка-расчета-эффективности-обогащения" data-toc-modified-id="Проверка-расчета-эффективности-обогащения-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Проверка расчета эффективности обогащения</a></span></li><li><span><a href="#Признаки,-отсутствующие-в-тестовой-выборке" data-toc-modified-id="Признаки,-отсутствующие-в-тестовой-выборке-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Признаки, отсутствующие в тестовой выборке</a></span></li><li><span><a href="#Проверка-на-дубликаты" data-toc-modified-id="Проверка-на-дубликаты-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Проверка на дубликаты</a></span></li><li><span><a href="#Заполнение-пропусков" data-toc-modified-id="Заполнение-пропусков-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Заполнение пропусков</a></span></li><li><span><a href="#Проверка-тестовой-выборки-на-мультиколлинеарность" data-toc-modified-id="Проверка-тестовой-выборки-на-мультиколлинеарность-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Проверка тестовой выборки на мультиколлинеарность</a></span></li><li><span><a href="#Добаление-целевых-признаков-в-тестовую-выборку" data-toc-modified-id="Добаление-целевых-признаков-в-тестовую-выборку-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Добаление целевых признаков в тестовую выборку</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки" data-toc-modified-id="Концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Концентрация металлов (Au, Ag, Pb) на различных этапах очистки</a></span><ul class="toc-item"><li><span><a href="#Свинец-(Pb)" data-toc-modified-id="Свинец-(Pb)-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Свинец (Pb)</a></span></li><li><span><a href="#Серебро(Ag)" data-toc-modified-id="Серебро(Ag)-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Серебро(Ag)</a></span></li><li><span><a href="#Золото-(Au)" data-toc-modified-id="Золото-(Au)-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Золото (Au)</a></span></li></ul></li><li><span><a href="#Размеры-гранул-сырья" data-toc-modified-id="Размеры-гранул-сырья-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Размеры гранул сырья</a></span></li><li><span><a href="#Суммарная-концентрация-веществ-на-разных-стадиях" data-toc-modified-id="Суммарная-концентрация-веществ-на-разных-стадиях-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Суммарная концентрация веществ на разных стадиях</a></span></li><li><span><a href="#Создание-выборок-для-обучения" data-toc-modified-id="Создание-выборок-для-обучения-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Создание выборок для обучения</a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Линейная-регрессия" data-toc-modified-id="Линейная-регрессия-3.0.1"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>Линейная регрессия</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-3.0.2"><span class="toc-item-num">3.0.2&nbsp;&nbsp;</span>Случайный лес</a></span><ul class="toc-item"><li><span><a href="#Подбор-параметров-для-этапа-rougher" data-toc-modified-id="Подбор-параметров-для-этапа-rougher-3.0.2.1"><span class="toc-item-num">3.0.2.1&nbsp;&nbsp;</span>Подбор параметров для этапа rougher</a></span></li><li><span><a href="#Подбор-параметров-для-этапа-final" data-toc-modified-id="Подбор-параметров-для-этапа-final-3.0.2.2"><span class="toc-item-num">3.0.2.2&nbsp;&nbsp;</span>Подбор параметров для этапа final</a></span></li></ul></li><li><span><a href="#Проверка-модели-на-тестовой-выборке" data-toc-modified-id="Проверка-модели-на-тестовой-выборке-3.0.3"><span class="toc-item-num">3.0.3&nbsp;&nbsp;</span>Проверка модели на тестовой выборке</a></span></li><li><span><a href="#Проверка-на-адекватность" data-toc-modified-id="Проверка-на-адекватность-3.0.4"><span class="toc-item-num">3.0.4&nbsp;&nbsp;</span>Проверка на адекватность</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %% [markdown]
# **Описание данных**<br>
# Технологический процесс<br>
#
# Rougher feed — исходное сырье<br>
# Rougher additions (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant<br>
# Xanthate — ксантогенат (промотер, или активатор флотации);<br>
# Sulphate — сульфат (на данном производстве сульфид натрия);<br>
# Depressant — депрессант (силикат натрия).<br>
# Rougher process (англ. «грубый процесс») — флотация<br>
# Rougher tails — отвальные хвосты<br>
# Float banks — флотационная установка<br>
# Cleaner process — очистка<br>
# Rougher Au — черновой концентрат золота<br>
# Final Au — финальный концентрат золота<br>
# Параметры этапов<br>
#
# air amount — объём воздуха<br>
# fluid levels — уровень жидкости<br>
# feed size — размер гранул сырья<br>
# feed rate — скорость подачи<br>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Прекрасное вступление!
#
# В нём есть всё, что необходимо, чтобы понять суть проекта с первых строк отчёта!
#
# Спасибо, что есть оглавление в плагине toc и в виде гиперссылок - по проекту удобно перемещаться:)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from numpy.random import RandomState
from statsmodels.stats.outliers_influence import variance_inflation_factor  
from statsmodels.tools.tools import add_constant 
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score
from sklearn.dummy import DummyRegressor
from sklearn.model_selection import GridSearchCV
pd.set_option('display.max_columns', None)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Библиотеки импортировали - отлично!

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Я вижу, исполнение твоего кода начинается в ячейке с номером, который отличается от единицы. Перед отправкой проекта стоит проверять работоспособность кода — это можно сделать, нажав на панели Jupiter Hub ``Kernel`` и ``Restart & Run All`` (см скриншот ниже).
#
# ![](https://i.postimg.cc/yd19rYf6/Screenshot-428.png)
#
# Важно также убедиться, что все ячейки проекта исполнились - можно просто пролистать работу до конца и убедиться, что последняя ячейка исполнена. Такая проверка поможет тебе убедиться, что твоё решение будет должным образом воспроизведено во время ревью или во время передачи его заказчику - это очень важный этап, пренебрегать которым не стоит:)

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Долго выполнялись расчеты. ПОэтому, так как некоторые детали были добавлены в начало проекта после расчетов, то было принято решение не перезапускать код, потому что не влияло на результаты, а влияло только на нумерацию ячеек
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Может повлиять и на результаты, если в ходе эксперимента удалишь какие-то переменные в одном месте, а в другом - оставишь:)

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Изучение данных

# %%
df_train = pd.read_csv('/datasets/gold_recovery_train_new.csv')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Данные загрузили.
#
# При считывании данных из файла здорово перестраховывать себя от ошибок, связанных, например, с неверным указанием пути к файлу. А иногда бывает, что работаешь с файлом локально, выгружаешь его на сервер, ожидая, что он будет принимать данные, которые лежат на том же сервере, а код падает с ошибкой, потому что путь к файлу не поменялся с локального на серверный.
#
# Для этого, например, можно использовать конструкцию `try-except`: сначала пробуешь локальный путь, при возникновении ошибки используется серверный путь (подробнее можешь почитать тут: https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html).
#
# Но еще лучше использовать библиотеку `os` - её использование позволит тебе проверять существование указанных директорий (что может быть актуально при одновременной работа на локальном и сетевом окружении) и загружать данные из существующей директории, избегая ошибок. Как пример:
#
#     import os
#
#     pth1 = '/folder_1/data.csv'
#     pth2 = '/folder_2/data.csv'
#
#     if os.path.exists(pth1):
#         query_1 = pd.read_csv(pth1)
#     elif os.path.exists(pth2):
#         query_1 = pd.read_csv(pth2)
#     else:
#         print('Something is wrong')
#
# Ещё на этапе считывания данных можно спарсить дату: за это действие отвечает параметр `parse_dates` метода `read_csv()`, в него нужно передать список с названием полей-дат, и в большинстве случаев дата будет корректно преобразована в нужный формат сразу:)
# Также на этапе считывания данных задать индекс-столбец- за это действие отвечает параметр `index_col`.

# %%
df_train.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %%
df_test = pd.read_csv('/datasets/gold_recovery_test_new.csv')

# %%
df_test.head()
# Out:
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# ...

# %%
df_full = pd.read_csv('/datasets/gold_recovery_full_new.csv')

# %%
df_full.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14149 non-null  object
#  1   final.output.concentrate_ag                         14148 non-null  float64
#  2   final.output.concentrate_pb                         14148 non-null  float64
#  3   final.output.concentrate_sol                        13938 non-null  float64
#  4   final.output.concentrate_au                         14149 non-null  float64
#  5   final.output.recovery                               14149 non-null  float64
#  6   final.output.tail_ag                                14149 non-null  float64
#  7   final.output.tail_pb                                14049 non-null  float64
# ...

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   final.output.concentrate_ag                         19438 non-null  float64
#  2   final.output.concentrate_pb                         19438 non-null  float64
#  3   final.output.concentrate_sol                        19228 non-null  float64
#  4   final.output.concentrate_au                         19439 non-null  float64
#  5   final.output.recovery                               19439 non-null  float64
#  6   final.output.tail_ag                                19438 non-null  float64
#  7   final.output.tail_pb                                19338 non-null  float64
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5290 entries, 0 to 5289
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        5290 non-null   object
#  1   primary_cleaner.input.sulfate               5286 non-null   float64
#  2   primary_cleaner.input.depressant            5285 non-null   float64
#  3   primary_cleaner.input.feed_size             5290 non-null   float64
#  4   primary_cleaner.input.xanthate              5286 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_air      5290 non-null   float64
#  6   primary_cleaner.state.floatbank8_a_level    5290 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_air      5290 non-null   float64
#  8   primary_cleaner.state.floatbank8_b_level    5290 non-null   float64
# ...

# %% [markdown]
# ### Проверка расчета эффективности обогащения

# %% [markdown]
# Формула для расчета

# %% [markdown]
# $$
# Recovery = {C x (F-T)\over F x (C-T)}
# $$

# %% [markdown]
# В обучающей выборке роль переменных будут выполнять следующие столбцы:<br><br>
# **Recovery** - *rougher.output.recovery*<br>
# **C** - *rougher.output.concentrate_au*<br>
# **F** - *rougher.input.feed_au*<br>
# **T** - *rougher.output.tail_au*<br>

# %%
df_train['calc_recovery'] =\
(df_train['rougher.output.concentrate_au'] * (df_train['rougher.input.feed_au'] - df_train['rougher.output.tail_au']))/\
(df_train['rougher.input.feed_au'] * (df_train['rougher.output.concentrate_au'] - df_train['rougher.output.tail_au']))*100

# %%
#df_train.head()

# %%
mae_recovery = mean_absolute_error(df_train['rougher.output.recovery'],df_train['calc_recovery']) 
print(f'MAE = {mae_recovery:.5f}')
# Out:
# MAE = 0.00000

# %% [markdown]
# Вывод: **Значения расчета эффективности** обогащения в исходных данных **совпадают** с расчетами, выполненными дополнительно.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Оценили `MAE` между исходным и расчётным значением эффективности обогащения и убедились, что эффективность обогащения рассчитана правильно - отлично!
# </div>

# %% [markdown]
# ### Признаки, отсутствующие в тестовой выборке

# %%
train_col = set(df_train.columns)
test_col = set(df_test.columns)
diff_columns = train_col - test_col 
diff_columns
# Out:
# {'calc_recovery',
#  'final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.recovery',
# ...

# %% [markdown]
# **Вывод**: В тестовой выборке отсутсвуют признаки, характеризующие значения содержания металлов в концентратах на выходе технологических процессов.<br>
# Все признаки относятся к типу данных **float**<br>
# Эти же признаки нужно будет удалить из обучающей выборки при построении модели<br>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Проанализировали разницу в признаках между выборками.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Исходя из понимания, что тестовая выборка имитирует работу модели в реальных условиях протекания технологического процесса, давай подумаем, почему в `train` есть признаки, которые недоступны в `test`?

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Возможно, по той причине, что если не будет доступен **full**, то можно выполнить соответствующие проверки на **train**
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Скорее, разница в том, что в `train` собраны исторические данные о состоянии техпроцесса, в том числе промежуточные и финальные его показатели. В `test` же есть только те признаки, которые доступны на старте техпроцесса - именно с ними может работать модель, потому что на старте техпроцесса других признаков мы не можем знать заранее.
# </div>

# %% [markdown]
# ### Проверка на дубликаты

# %%
df_test['date'].duplicated().sum()
# Out:
# 0

# %%
df_train['date'].duplicated().sum()
# Out:
# 0

# %%
df_full['date'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Дубликаты отсутствуют**

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Дубликатов нет - отлично!

# %% [markdown]
# ### Заполнение пропусков

# %% [markdown]
# Вывод количества пропусков

# %%
df_full.isna().sum()
# Out:
# date                                            0
# final.output.concentrate_ag                     1
# final.output.concentrate_pb                     1
# final.output.concentrate_sol                  211
# final.output.concentrate_au                     0
#                                              ...
# secondary_cleaner.state.floatbank5_a_level      1
# secondary_cleaner.state.floatbank5_b_air        1
# secondary_cleaner.state.floatbank5_b_level      1
# secondary_cleaner.state.floatbank6_a_air        2
# secondary_cleaner.state.floatbank6_a_level      1
# Length: 87, dtype: int64

# %% [markdown]
# Заполнение пропусков

# %%
df_full = df_full.fillna(method='bfill')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Обработали пропуски с помощью стратегии заполнения `backward fill` - отлично!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# В комментариях важно пояснить, почему была выбрана именно эта стратегия работы с пропусками.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Была выбрана такая стратегия работы с пропусками, потому что в условии сказано, что близкие данные похожи
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Верно.

# %%
df_train.isna().sum().sum()
# Out:
# 4100

# %%
df_test.isna().sum().sum()
# Out:
# 90

# %% [markdown]
# Заполнение пропущенных значений в валидационной и тестовой выборке значениями из общего датафрейма

# %%
#df_train.set_index('date', inplace=True)
#df_train.update(df_full.set_index('date'))
#df_train = df_train.reset_index()

# %%
df_train.isna().sum().sum()
# Out:
# 4100

# %%
#df_test.set_index('date', inplace=True)
#df_test.update(df_full.set_index('date'))
#df_test = df_test.reset_index()

# %%
#df_test.isna().sum().sum()

# %% [markdown]
# Пропуски отсутствуют

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Важно понимать, что в реальной работе модели `full` выборки у нас не будет, поэтому восстановить таким образом пропуски в реальном проекте мы не сможем - вполне можно использовать `bfill` для `train` и `test`.
#
# </div>

# %% [markdown]
#  <div class="alert alert-info">
# <h2> Доработка <a class="tocSkip"> </h2>
#
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
df_train = df_train.fillna(method='bfill')

# %%
df_train.isna().sum().sum()
# Out:
# 0

# %%
df_test = df_test.fillna(method='bfill')

# %%
df_test.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# ### Проверка тестовой выборки на мультиколлинеарность

# %%
plt.figure(figsize=(20, 15)) 
sns.heatmap(df_test.corr());
plt.title('Мультиколлинеарность признаков');

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Нужно подписать название графика.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Доработка <a class="tocSkip"> </h2>
#
# График подписан
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# Из графика видно, что есть достаточное количество зависимых столбцов

# %% [markdown]
# Расчет коэффициент инфляции дисперсии для признаков

# %%
def calc_vif(df_f,drop_param):
    """
    Расчет корреляции признаков
    """
    #Удаление признака с высокой корреляцей
    df_f = df_f.drop([drop_param],axis=1)
    pp = df_f
    X = add_constant(pp)  
    #Построение нового Series с новыми корреляциями
    ds=pd.Series([variance_inflation_factor(X.values, i) for i in range(X.shape[1])], index=X.columns)  
    return ds,df_f

# %% [markdown]
# Преобразование Series в Dataframe

# %%
def conv_ser_to_df(ser):
    t = ser.to_frame().reset_index()
    t = t.rename(columns= {0: 'coef'})
    #Удаление строки 0 c количеством расчетов
    t = t.drop(index=0)
    return t

# %%
df_f = df_test.drop(['date'],axis=1)

# %% [markdown]
# Расчет начальных значений для удаления коррелированных признаков

# %%
pp = df_f
X = add_constant(pp)  
#Построение нового Series с новыми корреляциями
ds=pd.Series([variance_inflation_factor(X.values, i) for i in range(X.shape[1])], index=X.columns)

# %%
tind = conv_ser_to_df(ds)

# %%
tind = tind.sort_values(by='coef',ascending=False)

# %% [markdown]
# Высоколкоррелированными являются признаки, у которых показаьель vif > 10, но ограничимся значением 13<br>
# Расчет коррелированных признаков и удаление их из тестовой выборки до тех, пока vif больше 13.

# %%
while tind.iloc[0,1]>13:
    print(tind.iloc[0,1])
    print(tind.iloc[0,0])
    ds,df_f = calc_vif(df_f,tind.iloc[0,0])
    #удаление столбца с высокой корреляцией из тестовой выборки
    df_test = df_test.drop([tind.iloc[0,0]],axis=1)
    tind = conv_ser_to_df(ds)
    tind = tind.sort_values(by='coef',ascending=False)
# Out:
# 63.139855012406755
# rougher.state.floatbank10_c_level
# 47.38838068836824
# rougher.state.floatbank10_c_air
# 41.82023835468299
# primary_cleaner.state.floatbank8_b_air
# 35.32486872513111
# rougher.state.floatbank10_e_level
# 28.724075288595177
# rougher.state.floatbank10_e_air
# 28.216269149246017
# rougher.input.floatbank10_sulfate
# 22.114044741318278
# secondary_cleaner.state.floatbank2_b_air
# 19.558618216312293
# primary_cleaner.state.floatbank8_d_air
# 19.066747304596255
# rougher.state.floatbank10_b_level
# 16.775590518858305
# secondary_cleaner.state.floatbank3_b_air
# 15.096830460277388
# rougher.state.floatbank10_d_air
# 13.900469741488436
# secondary_cleaner.state.floatbank4_a_air

# %%
df_test.head()
# Out:
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# ...

# %%
df_test.columns
# Out:
# Index(['date', 'primary_cleaner.input.sulfate',
#        'primary_cleaner.input.depressant', 'primary_cleaner.input.feed_size',
#        'primary_cleaner.input.xanthate',
#        'primary_cleaner.state.floatbank8_a_air',
#        'primary_cleaner.state.floatbank8_a_level',
#        'primary_cleaner.state.floatbank8_b_level',
#        'primary_cleaner.state.floatbank8_c_air',
#        'primary_cleaner.state.floatbank8_c_level',
#        'primary_cleaner.state.floatbank8_d_level', 'rougher.input.feed_ag',
#        'rougher.input.feed_pb', 'rougher.input.feed_rate',
#        'rougher.input.feed_size', 'rougher.input.feed_sol',
#        'rougher.input.feed_au', 'rougher.input.floatbank10_xanthate',
#        'rougher.input.floatbank11_sulfate',
#        'rougher.input.floatbank11_xanthate', 'rougher.state.floatbank10_a_air',
#        'rougher.state.floatbank10_a_level', 'rougher.state.floatbank10_b_air',
#        'rougher.state.floatbank10_d_level', 'rougher.state.floatbank10_f_air',
# ...

# %% [markdown]
# Сырье на входе осталось на месте

# %%
plt.figure(figsize=(20, 15))
sns.heatmap(df_test.corr());
plt.title('Мультиколлинеарность признаков');

# %% [markdown]
# ### Добаление целевых признаков в тестовую выборку

# %%
dff_test = df_test.copy()

# %%
df_test = df_test.merge(df_full[['final.output.recovery', 'rougher.output.recovery', 'date']], how='left', on='date')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В `test` добавили целевые признаки из `full`, используя дату как ключ при соединении - отлично!

# %% [markdown]
# **Вывод:**<br>
# В данном разделе открыты файлы и изучены основные данные.
#
# Проверен расчёт эффективности обогащения. Вычислено значение MAE между данными и расчётными значениями эффективности. Полученные значения МАЕ близки к 0. Это означаем, что эффективность обогащения рассчитана правильно.<br>
# В тестовой выборке отсутствуют целевые признаки для моделей 'rougher.output.recovery', 'final.output.recovery', а также значения output по всем операциям технологического процесса. Они являются фактическими даными, которые могут быть получены только попосле проведения работ. Так будет построена модель предсказаний, то результаты работ нам не нужны.<br>
# Проведена проверка на дубликаты.<br>
# Пропуски заполнены<br>.
#
# В тестовой выборке выявлена сильная корреляция между признаками. С помощью расчета коэффициент инфляции дисперсии для признаков были удалены некоторые признаки. В основном это признаки, характеризующие состояние этапов (state).<br>
# Столбцы 'rougher.output.recovery', 'final.output.recovery' добавлены в тестовую выборку<br>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть промежуточный вывод - отлично!

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Концентрация металлов (Au, Ag, Pb) на различных этапах очистки

# %% [markdown]
# #### Свинец (Pb)

# %%
plt.figure(figsize=(15,5))

df_full['rougher.input.feed_pb'].hist(bins=25, label='rougher.input.feed', alpha=0.5)
df_full['rougher.output.concentrate_pb'].hist(bins=25, label='rougher.output.concentrate', alpha=0.5)
df_full['primary_cleaner.output.concentrate_pb'].hist(bins=25, label='primary_cleaner.output', alpha=0.5)
df_full['final.output.concentrate_pb'].hist(bins=25, label='final_output.output', alpha=0.5)
plt.title('Диаграмма концентрации свинца pb')
plt.legend(loc='upper left')
plt.xlabel('Значения')
plt.ylabel('Количество')
plt.show()

# %% [markdown]
# **Средняя концентрация Pb в сырье**

# %%
df_full[['rougher.output.concentrate_pb', 'primary_cleaner.output.concentrate_pb', 'final.output.concentrate_pb']].mean()
# Out:
# rougher.output.concentrate_pb            7.606272
# primary_cleaner.output.concentrate_pb    9.810430
# final.output.concentrate_pb              9.978817
# dtype: float64

# %% [markdown]
# **Средняя концентрация Pb в хвостах**

# %%
df_full[['rougher.output.tail_pb', 'primary_cleaner.output.tail_pb', 'secondary_cleaner.output.tail_pb']].mean()
# Out:
# rougher.output.tail_pb              0.645782
# primary_cleaner.output.tail_pb      3.433834
# secondary_cleaner.output.tail_pb    5.776394
# dtype: float64

# %% [markdown]
# В концентрате свинец практически не изменяется, в отвалах концентрация сильно увеличивается

# %% [markdown]
# #### Серебро(Ag)

# %%
plt.figure(figsize=(15,5))

df_full['rougher.input.feed_ag'].hist(bins=25, label='rougher.input.feed', alpha=0.5)
df_full['rougher.output.concentrate_ag'].hist(bins=25, label='rougher.output.concentrate', alpha=0.5)
df_full['primary_cleaner.output.concentrate_ag'].hist(bins=25, label='primary_cleaner.output', alpha=0.5)
df_full['final.output.concentrate_ag'].hist(bins=25, label='final_output.output', alpha=0.5)
plt.title('Диаграмма концентрации серебра ag')
plt.legend(loc='upper right')
plt.xlabel('Значения')
plt.ylabel('Количество')
plt.show()

# %% [markdown]
# **Средняя концентрация Ag в сырье**

# %%
df_full[['rougher.output.concentrate_ag', 'primary_cleaner.output.concentrate_ag', 'final.output.concentrate_ag']].mean()
# Out:
# rougher.output.concentrate_ag            11.994759
# primary_cleaner.output.concentrate_ag     8.442408
# final.output.concentrate_ag               5.168382
# dtype: float64

# %% [markdown]
# **Средняя концентрация Ag в хвостах**

# %%
df_full[['rougher.output.tail_ag', 'primary_cleaner.output.tail_ag', 'secondary_cleaner.output.tail_ag']].mean()
# Out:
# rougher.output.tail_ag               5.589070
# primary_cleaner.output.tail_ag      16.145110
# secondary_cleaner.output.tail_ag    14.586431
# dtype: float64

# %% [markdown]
# В концентрате серебро практически уменьшается, в отвалах концентрация увеличивается после флотации в три раза, а после очистки не изменяется

# %% [markdown]
# #### Золото (Au)

# %%
plt.figure(figsize=(15,5))

df_full['rougher.input.feed_au'].hist(bins=25, label='rougher.input.feed', alpha=0.5)
df_full['rougher.output.concentrate_au'].hist(bins=25, label='rougher.output.concentrate', alpha=0.5)
df_full['primary_cleaner.output.concentrate_au'].hist(bins=25, label='primary_cleaner.output', alpha=0.5)
df_full['final.output.concentrate_au'].hist(bins=25, label='secondary_cleaner.output', alpha=0.5)
plt.title('Диаграмма концентрации золота au')
plt.legend(loc='upper left')
plt.xlabel('Значения')
plt.ylabel('Количество')
plt.show()

# %% [markdown]
# **Средняя концентрация Au в сырье**

# %%
df_full[['rougher.output.concentrate_au', 'primary_cleaner.output.concentrate_au', 'final.output.concentrate_au']].mean()
# Out:
# rougher.output.concentrate_au            19.772000
# primary_cleaner.output.concentrate_au    32.119400
# final.output.concentrate_au              44.076513
# dtype: float64

# %% [markdown]
# **Средняя концентрация Ag в хвостах**

# %%
df_full[['rougher.output.tail_au', 'primary_cleaner.output.tail_au', 'secondary_cleaner.output.tail_au']].mean()
# Out:
# rougher.output.tail_au              1.816391
# primary_cleaner.output.tail_au      3.914179
# secondary_cleaner.output.tail_au    4.339625
# dtype: float64

# %% [markdown]
# Концентрация золота увеличивается на каждом этапе, в хвостах золото присутствует, но его в десять раз меньше, чем в концентрате.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Исследована концентрация металлов на разных стадиях обработки, проанализирована динамика концентрации в зависимости от этапа техпроцесса - отлично, тут всё верно.

# %% [markdown]
# ### Размеры гранул сырья

# %%
df_train['rougher.input.feed_size'].describe()
# Out:
# count    14149.000000
# mean        59.955950
# std         23.286534
# min          9.659576
# 25%         48.920770
# 50%         55.301596
# 75%         65.941463
# max        484.967466
# Name: rougher.input.feed_size, dtype: float64

# %%
df_test['rougher.input.feed_size'].describe()
# Out:
# count    5290.000000
# mean       55.952917
# std        19.080412
# min         0.046369
# 25%        43.906504
# 50%        50.846843
# 75%        62.451165
# max       392.494040
# Name: rougher.input.feed_size, dtype: float64

# %%
plt.figure(figsize=(15, 5))
sns.kdeplot(df_train['rougher.input.feed_size'], label='train rougher.input.feed_size', alpha=0.5, shade=True)
sns.kdeplot(df_test['rougher.input.feed_size'], label='test rougher.input.feed_size', alpha=0.7, shade=True)
plt.xlim([0, 200])
plt.xlabel('Размер зерна')
plt.ylabel('Плотность распределения ')
plt.title('Плотность распределения гранул зерна перед флотацией')
plt.legend(loc='upper right')
plt.show()

# %%
plt.figure(figsize=(15, 5))
sns.kdeplot(df_train['primary_cleaner.input.feed_size'], label='train_primary.input.feed_size', alpha=0.5, shade=True)
sns.kdeplot(df_test['primary_cleaner.input.feed_size'], label='test_primary.input.feed_size', alpha=0.7, shade=True)
plt.xlim([5, 10])
plt.xlabel('Размер зерна')
plt.ylabel('Плотность распределения ')
plt.legend(loc='upper right')
plt.title('Плотность распределения гранул зерна перед первой очисткой');
plt.show()

# %% [markdown]
# Нет сильных отличий на графиках распределений размеров гранул сырья на входе в технологические процессы флотации и очистки. Это означает, что роспределения однородны

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Сравнили размеры гранул сырья на обучающей и тестовой выборках для этапов `rougher.input.feed_size` и `primary_cleaner.input.feed_size` - отлично, распределения между выборками действительно схожи, следовательно модель будет корректно работать.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# На графиках нужно подписать название.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Доработка <a class="tocSkip"> </h2>
#
# Графики подписаны
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ### Суммарная концентрация веществ на разных стадиях

# %% [markdown]
# Cуммарная концентрация на выходе флотации

# %%
df_full['rougher.output.sum_concentrate'] = \
                df_full['rougher.output.concentrate_ag']\
              + df_full['rougher.output.concentrate_pb']\
              + df_full['rougher.output.concentrate_sol']\
              + df_full['rougher.output.concentrate_au']

# %% [markdown]
# Cуммарная концентрация на выходе первой очистки

# %%
df_full['primary_cleaner.output.sum_concentrate'] = \
                df_full['primary_cleaner.output.concentrate_ag']\
              + df_full['primary_cleaner.output.concentrate_pb']\
              + df_full['primary_cleaner.output.concentrate_sol']\
              + df_full['primary_cleaner.output.concentrate_au']

# %% [markdown]
# Cуммарная концентрация на выходе финальной очистки

# %%
df_full['final.output.sum_concentrate'] = \
                df_full['final.output.concentrate_ag']\
              + df_full['final.output.concentrate_pb']\
              + df_full['final.output.concentrate_sol']\
              + df_full['final.output.concentrate_au']

# %%
df_full.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %%
plt.figure(figsize=(15,5))
df_full['rougher.output.sum_concentrate'].hist(bins=25, label='rougher_sum_concentrate', alpha=0.8)
df_full['primary_cleaner.output.sum_concentrate'].hist(bins=25, label='primary_sum_concentrate', alpha=0.8)
df_full['final.output.sum_concentrate'].hist(bins=25, label='final_sum_concentrate', alpha=0.8)
plt.title('Cуммарная концентрация на выходе производственных процессов')
plt.xlabel('Значения')
plt.ylabel('Количество')
plt.legend(loc='upper left')

plt.show()

# %% [markdown]
# Суммарная концентрация металлов растёт по мере продвижения по техпроцессу
#
# Имеются значения около нуля с итоговыми суммами концентратов металлов

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Исследована суммарная концентрация металлов на разных стадиях техпроцесса - отлично! Также отмечено наличие нулевых значений и необходимость их удаления - тут всё круто!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Суммарную концентрацию металлов также нужно исследовать на этапе `rougher.input.feed_`.
#
# Стоит сделать вывод о динамике суммарной концентрации металлов.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Доработка <a class="tocSkip"> </h2>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
df_full['rougher.input.sum_concentrate'] = \
                df_full['rougher.input.feed_ag']\
              + df_full['rougher.input.feed_pb']\
              + df_full['rougher.input.feed_sol']\
              + df_full['rougher.input.feed_au']

# %%
plt.figure(figsize=(15,5))
df_full['rougher.input.sum_concentrate'].hist(bins=25, label='rougher_input_sum_concentrate', alpha=0.8)
df_full['rougher.output.sum_concentrate'].hist(bins=25, label='rougher_output_sum_concentrate', alpha=0.8)
df_full['primary_cleaner.output.sum_concentrate'].hist(bins=25, label='primary_output_sum_concentrate', alpha=0.8)
df_full['final.output.sum_concentrate'].hist(bins=25, label='final_output_sum_concentrate', alpha=0.8)
plt.title('Cуммарная концентрация на выходе производственных процессов')
plt.xlabel('Значения')
plt.ylabel('Количество')
plt.legend(loc='upper left')
#plt.xlim([0, 4])
plt.show()

# %%
plt.figure(figsize=(15, 5))
sns.kdeplot(df_full['rougher.input.sum_concentrate'], label='train_primary.input.feed_size', alpha=0.5, shade=True)
sns.kdeplot(df_full['rougher.output.sum_concentrate'], label='train_primary.input.feed_size', alpha=0.5, shade=True)
sns.kdeplot(df_full['primary_cleaner.output.sum_concentrate'], label='train_primary.input.feed_size', alpha=0.5, shade=True)
sns.kdeplot(df_full['final.output.sum_concentrate'], label='train_primary.input.feed_size', alpha=0.5, shade=True)
#sns.kdeplot(df_test['primary_cleaner.input.feed_size'], label='test_primary.input.feed_size', alpha=0.7, shade=True)
#plt.xlim([5, 10])
plt.xlabel('Концентрация')
plt.ylabel('Плотность распределения')
plt.legend(loc='upper right')
plt.title('Плотность распределения суммарной концентрации металлов ');
plt.show()

# %% [markdown]
# Суммарная концентрация металлов на выходе каждого из производственных процессор изменяется. На входе самая низкая, после флотации увеличивается, после первой очистки уменьшается, но увеличивается плотность концентрации. После второй очистки наблюдается резкий скачок и в концентрации и в плотности распределения. На всех этапах распределение концентрации близко к нормальному

# %%
plt.figure(figsize=(15,5))
df_full['rougher.output.sum_concentrate'].hist(bins=25, label='rougher_sum_concentrate', alpha=0.8)
df_full['primary_cleaner.output.sum_concentrate'].hist(bins=25, label='primary_sum_concentrate', alpha=0.8)
df_full['final.output.sum_concentrate'].hist(bins=25, label='final_sum_concentrate', alpha=0.8)
plt.title('Cуммарная концентрация на выходе производственных процессов')
plt.xlabel('Значения')
plt.ylabel('Количество')
plt.legend(loc='upper left')
plt.xlim([0, 4])
plt.show()

# %%
temp_rougher = df_full[df_full['rougher.output.sum_concentrate']==0]

# %%
temp_rougher.head()
# Out:
#                    date  final.output.concentrate_ag  \
# 45  2016-01-16 21:00:00                     4.566664
# 46  2016-01-16 22:00:00                     4.577832
# 47  2016-01-16 23:00:00                     4.591462
# 48  2016-01-17 00:00:00                     5.296830
# 49  2016-01-17 02:00:00                     8.162896
#
#     final.output.concentrate_pb  final.output.concentrate_sol  \
# 45                    10.406178                      4.588698
# 46                    10.691605                      5.274175
# 47                    10.628846                      5.688961
# 48                    10.597469                      3.997737
# 49                     8.877528                      3.997737
#
#     final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 45                    46.614456              68.403877             10.705777
# 46                    46.250638              70.675633             10.728531
# ...

# %%
temp_primary = df_full[df_full['primary_cleaner.output.sum_concentrate']==0]

# %%
temp_primary.head()
# Out:
#                    date  final.output.concentrate_ag  \
# 19  2016-01-15 19:00:00                     5.658943
# 22  2016-01-15 22:00:00                     6.118749
# 30  2016-01-16 06:00:00                     5.322681
# 71  2016-01-18 01:00:00                     4.677499
# 74  2016-01-18 04:00:00                     4.821388
#
#     final.output.concentrate_pb  final.output.concentrate_sol  \
# 19                    10.436002                      5.942418
# 22                    10.483007                      6.546983
# 30                     9.577672                      4.805490
# 71                    11.304745                      4.655438
# 74                    10.235502                      1.581066
#
#     final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 19                    42.509402              70.348300             10.232392
# 22                    41.406172              69.823900             10.322077
# ...

# %%
temp_final = df_full[df_full['final.output.sum_concentrate']==0]

# %%
temp_final.head()
# Out:
#                      date  final.output.concentrate_ag  \
# 644   2016-02-13 11:00:00                          0.0
# 1193  2016-03-11 10:00:00                          0.0
# 1194  2016-03-11 11:00:00                          0.0
# 1195  2016-03-11 12:00:00                          0.0
# 1196  2016-03-11 13:00:00                          0.0
#
#       final.output.concentrate_pb  final.output.concentrate_sol  \
# 644                           0.0                           0.0
# 1193                          0.0                           0.0
# 1194                          0.0                           0.0
# 1195                          0.0                           0.0
# 1196                          0.0                           0.0
#
#       final.output.concentrate_au  final.output.recovery  \
# 644                           0.0                    0.0
# 1193                          0.0                    0.0
# 1194                          0.0                    0.0
# ...

# %% [markdown]
# Нулевые значения появились скорее всего в результате неправильного ввода данных вручную, либо ошибке при автоматическом вводе

# %% [markdown]
# Удаление строк из валидационной и тестовой выборок, для которых в итоговый таблице имеются нулевые значения в суммарных значениях концентратов

# %%
#список индексов
drop_list=[]

# %%
drop_list.extend(temp_rougher['date'].to_list())

# %%
drop_list.extend(temp_primary['date'].to_list())

# %%
drop_list.extend(temp_final['date'].to_list())

# %%
len(drop_list)
# Out:
# 600

# %% [markdown]
# Всего таких записей насчитывается 600

# %%
df_train.drop(df_train[df_train.date.isin(drop_list)].index, axis = 0, inplace = True)

# %%
df_train.shape
# Out:
# (13725, 88)

# %%
df_test_clean = df_test.copy()

# %%
df_test.shape
# Out:
# (5290, 43)

# %%
df_test.drop(df_test[df_test.date.isin(drop_list)].index, axis = 0, inplace = True)

# %%
df_test.shape
# Out:
# (5123, 43)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Отбросили строки с нулевым значением суммарной концентрации - супер!
# </div>

# %% [markdown]
# ### Создание выборок для обучения

# %% [markdown]
# Берем для обучения только те столбцы, которые остались в df_test после этапа проверки на мультиколлинеарность. Исключаем **data** и целевые столбцы **rougher.output.recovery, final.output.recovery**

# %%
features_columns = list(df_test.columns)[1:-2]

# %%
target_columns = ['rougher.output.recovery', 'final.output.recovery']

# %%
# формируем необходимые для обучения и оценки датафреймы
features_train = df_train[features_columns]
target_train = df_train[target_columns]
features_test = df_test[features_columns]
target_test = df_test[target_columns]

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Синхронизировали тренировочную и тестовую выборки по набору признаков, выделили признаки для обучения и целевые признаки - отлично!
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
# Дополнительно можно было бы выполнить стандартизацию непрерывных переменных - это важно для линейной регрессии, которую ты используешь.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Доработка <a class="tocSkip"> </h2>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
scaler = StandardScaler()
scaler.fit(features_train) 
features_train = scaler.transform(features_train)
features_test = scaler.transform(features_test)

# %% [markdown]
# **Вывод**<br>
# Концентрация золота значительно увеличивается на каждом этапе обработки сырья. Концентрация золота в отвалах тоже увеличивается, но при этом на порядок ниже чем в сырье.
#
# Построены графики распределения плотности вероятности значений размеров гранул на входе в этапы флотации и финальной очистки выборок train и test. Схожесть графиков свидетельствует об однородности данных размеров сырья в выборках train и test<br>
# Суммарная концентрация металлов на выходе каждого из производственных процессор изменяется. На входе самая низкая, после флотации увеличивается, после первой очистки уменьшается, но увеличивается плотность концентрации. После второй очистки наблюдается резкий скачок и в концентрации и в плотности распределения. На всех этапах распределение концентрации близко к нормальном<br>
#
# Из выборок удалены строки, для которых в таблице full были рассчитаные нулевые значения суммарной концентрации металлов после технологических процессов.<br>
#
# Подготовлены датафреймы для прогнозирования features, target

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть вывод - отлично!

# %% [markdown]
# ## Модель

# %% [markdown]
# **Функция для вычисления итоговой sMAPE**

# %%
def smape_func(target, pred):
    '''
    Метод получения sMape для одного этапа
    '''
    
    smape = abs(target-pred)/((abs(target)+abs(pred))/2)*100
    #smape = smape.fillna(value=0)

    smape = np.mean(smape)
    return smape

# %%
def summary_smape(smape_rouger, smape_final):
    
    '''
    Вычисление итоговой sMAPE для smape_rouger и smape_final
    '''
    
    # итоговый smape
    summary_smape = 0.25 * smape_rouger + 0.75 * smape_final
    
    return summary_smape

# %% [markdown]
# #### Линейная регрессия

# %%
smape_scorer = make_scorer(smape_func, greater_is_better=False)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть функции для частного и взвешенного `sMAPE`, а также пользовательский скорринг для кросс-валидации - супер!
# </div>

# %%
model_line_reg_rougher = LinearRegression()

# %% [markdown]
# Оценка модели с помощью кроссвалидации features_train, target_train. Вычисление sMape_rougher

# %%
scores_line_reg_rougher = cross_val_score(model_line_reg_rougher,  
                                          features_train, 
                                          target_train['rougher.output.recovery'], 
                                          scoring = smape_scorer,
                                          cv = 5)
smape_rougher = np.mean(abs(scores_line_reg_rougher))
print('Средняя оценка качества sMape_rougher', round(smape_rougher, 4))
# Out:
# Средняя оценка качества sMape_rougher 6.8521

# %% [markdown]
# Оценка модели с помощью кроссвалидации features_train, target_train. Вычисление sMape_final

# %%
scores_line_reg_final = cross_val_score(model_line_reg_rougher,  
                                          features_train, 
                                          target_train['final.output.recovery'], 
                                          scoring = smape_scorer,
                                          cv = 5)
smape_final = np.mean(abs(scores_line_reg_final))
print('Средняя оценка качества sMape_final', round(smape_final, 4))
# Out:
# Средняя оценка качества sMape_final 10.321

# %% [markdown]
# **Итоговая sMape**

# %%
smape_total = summary_smape(smape_rougher, smape_final)
print('Средняя итоговая оценка качества модели sMape ', round(smape_total, 4))
# Out:
# Средняя итоговая оценка качества модели sMape  9.4538

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Линейную регрессию оценили на кросс-валидации - отлично!
#
# При работе с `cross_val_score`, а также с `GridSearchCV` или `RandomizedSearchCV` есть несколько полезных действий, которые сделают нашу жизнь проще и лучше:)
#
# 1. Можно настроить параметр `n_jobs=-1`, чтобы для вычислений использовались все доступные ядра - это ускорит процесс.
# 2. Можно настроить параметр `verbose=10`, чтобы инструмент взаимодействовал с логом и выдавал сообщения о прогрессе обучения - так мы будем понимать, что процесс идёт, а не что, например, у нас упало ядро, и процесс завис.
# 3. Для кросс-валидации (параметр `cv`) вполне можно использовать и 3 фолда: мы немного потеряем в качестве, но процесс будет происходить гораздо быстрее. Для учебного проекта более чем достаточно:)
# </div>

# %% [markdown]
# #### Случайный лес

# %% [markdown]
# **Оценка модели случайного леса для этапа rougher**

# %% [markdown]
# <s>
# model_rf_rougher = RandomForestRegressor(random_state=12345, max_depth = 10, n_estimators=20)
#
# # оценка модели с помощью кроссвалидации features_train, target_train
# scores_rf_rougher = cross_val_score(model_rf_rougher,
#                                     features_train,
#                                     target_train['rougher.output.recovery'],
#                                     scoring=smape_scorer,
#                                     cv = 5)
# smape_rf_rougher = np.mean(abs(scores_rf_rougher))
# print('Средняя оценка качества модели final_score_rf_rougher', round(smape_rf_rougher, 4))
# </s>

# %% [markdown]
# <s>**Этап final**</s>

# %% [markdown]
# <s>%%time
# model_rf_final = RandomForestRegressor(random_state=12345, max_depth = 10, n_estimators=20)
#
# scores_rf_final = cross_val_score(model_rf_final,
#                                     features_train,
#                                     target_train['final.output.recovery'],
#                                     scoring=smape_scorer,
#                                     cv = 5)
# smape_rf_final = np.mean(abs(scores_rf_final))
# print('Средняя оценка качества модели final_score_rf_rougher', round(smape_rf_final, 4))
#     </s>

# %% [markdown]
# <s>**Итоговая sMape**</s>

# %% [markdown]
# <s>smape_rf_total = summary_smape(smape_rf_rougher, smape_rf_final)
# print('Средняя итоговая оценка качества модели smape_rf_total', round(smape_rf_total, 4))
# </s>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Нет смысла тратить время и ресурсы на оценку базовой модели, если далее выполняется оптимизация гиперпараметров.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Доработка <a class="tocSkip"> </h2>
#     Оценка базовой модели удалена
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ##### Подбор параметров для этапа rougher

# %%
# %%time
model_rf_rougher = RandomForestRegressor(random_state=12345)

# подбор лучших параметров для дерева
parameters = { 'max_depth': [x for x in range(2, 12, 3)],
               'n_estimators': [x for x in range(100, 250, 50)]
             }

grid_rf_rougher = GridSearchCV(model_rf_rougher, 
                               parameters, 
                               cv=5, 
                               scoring=smape_scorer
                              )
grid_rf_rougher.fit(features_train, target_train['rougher.output.recovery'])
# Out:
# CPU times: user 22min 15s, sys: 11.5 s, total: 22min 27s
# Wall time: 22min 30s
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=12345),
#              param_grid={'max_depth': [2, 5, 8, 11],
#                          'n_estimators': [100, 150, 200]},
#              scoring=make_scorer(smape_func, greater_is_better=False))

# %%
print('Оптимальные параметры: ', grid_rf_rougher.best_params_)
print('smape_rougher', abs(round(grid_rf_rougher.best_score_, 3)))
# Out:
# Оптимальные параметры:  {'max_depth': 8, 'n_estimators': 200}
# smape_rougher 6.645

# %% [markdown]
# ##### Подбор параметров для этапа final

# %%
# %%time
model_rf_final = RandomForestRegressor(random_state=12345)
parameters = { 'max_depth': [x for x in range(2, 12, 3)],
               'n_estimators': [x for x in range(100, 250, 50)]
             }

grid_rf_final = GridSearchCV(model_rf_final, 
                               parameters, 
                               cv=3, 
                               scoring=smape_scorer,
                               verbose=10
                              )
grid_rf_final.fit(features_train, target_train['final.output.recovery'])
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV 1/3; 1/12] START max_depth=2, n_estimators=100..............................
# [CV 1/3; 1/12] END ............max_depth=2, n_estimators=100; total time=   4.4s
# [CV 2/3; 1/12] START max_depth=2, n_estimators=100..............................
# [CV 2/3; 1/12] END ............max_depth=2, n_estimators=100; total time=   4.4s
# [CV 3/3; 1/12] START max_depth=2, n_estimators=100..............................
# [CV 3/3; 1/12] END ............max_depth=2, n_estimators=100; total time=   4.5s
# [CV 1/3; 2/12] START max_depth=2, n_estimators=150..............................
# [CV 1/3; 2/12] END ............max_depth=2, n_estimators=150; total time=   6.4s
# [CV 2/3; 2/12] START max_depth=2, n_estimators=150..............................
# [CV 2/3; 2/12] END ............max_depth=2, n_estimators=150; total time=   7.0s
# [CV 3/3; 2/12] START max_depth=2, n_estimators=150..............................
# ...

# %%
print('Лучшие параметры: ', grid_rf_final.best_params_)
print('smape_final', round(abs(grid_rf_final.best_score_), 3))
# Out:
# Лучшие параметры:  {'max_depth': 2, 'n_estimators': 100}
# smape_final 10.039

# %% [markdown]
# **Итоговое sMAPE**

# %%
smape_rf_itog = summary_smape(abs(round(grid_rf_rougher.best_score_, 3)), abs(round(grid_rf_final.best_score_, 3)))
print('sMAPE для случайного леса = ', round(smape_rf_itog, 4))
# Out:
# sMAPE для случайного леса =  9.1905

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Для случайного леса оптимизировали гиперпараметры и оценили модель на кросс-валидации - отлично!

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Нужно сделать вывод о том, какая модель и с какой метрикой оказалась лучшей на кросс-валидации.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Доработка <a class="tocSkip"> </h2>
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# Вывод: Модель случайного леса показала лучший результат sMAPE 9.19 против 9.4538 от модели Линейной регрессии<br>
# Таким образом, дальше проходит модель от Случайного леса!

# %% [markdown]
# #### Проверка модели на тестовой выборке

# %%
def best_model(features_train, target_train, features_test, depth, estimators):
    # метод прогнозирования целевого признаки на случайном лесе

    # инициируем модель с лучшими параметрами
    model = RandomForestRegressor(random_state=12345, max_depth = depth, n_estimators=estimators)
    # обучим модель
    model.fit(features_train, target_train)
    # подготовим прогноз целевого признака
    pred_test_rf = model.predict(features_test)

    return pred_test_rf

# %% [markdown]
# **Прогноз эффективности для rougher:**

# %% [markdown]
# Параметры для rougher:

# %%
r_depth,r_estimators = grid_rf_rougher.best_params_['max_depth'],grid_rf_rougher.best_params_['n_estimators']

# %%
print(r_depth,r_estimators)
# Out:
# 8 200

# %%
# %time
rougher_test = best_model(features_train, target_train['rougher.output.recovery'], features_test, r_depth, r_estimators)
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.72 µs

# %%
f_depth,f_estimators = grid_rf_final.best_params_['max_depth'],grid_rf_final.best_params_['n_estimators']

# %%
print(f_depth,f_estimators)
# Out:
# 2 100

# %%
final_test = best_model(features_train, target_train['final.output.recovery'], features_test, f_depth, f_estimators)

# %%
smape_rouger = smape_func(target_test['rougher.output.recovery'], rougher_test)

# %%
smape_rouger
# Out:
# 4.453590088021694

# %%
smape_final = smape_func(target_test['final.output.recovery'], final_test)

# %%
smape_final
# Out:
# 7.723269935505243

# %%
smape_total_test = summary_smape(smape_rouger,smape_final)

# %%
print('Итоговая оценка smape на тестовой выборке = ', round(smape_total_test, 3))
# Out:
# Итоговая оценка smape на тестовой выборке =  6.906

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Выполнили оценку модели на тестовой выборке - отличный результат!

# %% [markdown]
# #### Проверка на адекватность

# %% [markdown]
# Расчет целевого признака на константной модели

# %%
def dumm_model(features_train, target_train, features_test):
    """
    метод прогнозирования целевого признаки на константной модели 
    """
    # инициируем модель с лучшими параметрами
    model_dummy = DummyRegressor(strategy="mean")
    model_dummy.fit(features_train, target_train)
    #прогноз целевого признака
    pred_test = model_dummy.predict(features_test)
    return pred_test

# %%
#прогноз константной модели для этапа rougher
pred_test_rougher_const = dumm_model(features_train, target_train['rougher.output.recovery'], features_test)

# %%
#прогноз константной модели для этапа final
pred_test_final_const = dumm_model(features_train, target_train['final.output.recovery'], features_test)

# %%
smape_rouger_const = smape_func(target_test['rougher.output.recovery'], pred_test_rougher_const)

# %%
smape_final_const = smape_func(target_test['final.output.recovery'], pred_test_final_const)

# %%
smape_total_const = summary_smape(smape_rouger_const,smape_final_const)

# %%
print('Итоговая оценка smape на константной модели = ', round(smape_total_const, 3))
# Out:
# Итоговая оценка smape на константной модели =  7.778

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть сравнение с константной моделью - отлично!

# %% [markdown]
# **Вывод:**
# В ходе исследования были выполнено несколько этапов.<br>
# На этапе предобработки были загружены данные, изучена информация исходных датафреймов. Дубликатов обнаружено не было, пропуски в full были дменены ближайщими значениями. После этого были обновлены значения в тренировочной и тестовой выборках.<br>
# Вычислено значение MAE между данными и расчётными значениями эффективности. Полученные значения МАЕ близки к 0. Это означаем, что эффективность обогащения рассчитана верно.
#
# Проанализированы столбцы, имеющиеся в тестовой выборке. В них отсутствуют целевые признаки и поля с результатами работ технологических процессов. Целевые признаки были добавлены из общего датафрейма full.
#
# Было проведено исследование мультиколлинеарности полей тестовой выборки и удалены столбцы с высокой корреляцией.
#
# Анализ концентрации металлов показал, что концентрация золота значительно увеличивается на каждом этапе обработки сырья. В отвалах (хвостах) концентрациях тоже увеличивается, но значение в 10 раз ниже, чем в сырье. Исследована суммарная концентрация всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах. Были обнаружены нулевые значения сумм. Это, вероятнее всего, ошибка данных, поэтому из тренировочной и тестовой выборки строки были удалены. Потери составили менее 2%.
#
# Распределение плотности вероятности значений размеров гранул на входе в этапы флотации и финальной очистки выборок train и test похожи. Наблюдается однородность данных размеров сырья в выборках train и test.
#
# Подготовлены датафреймы для прогнозирования features, target. В тренировочной выборке столбцы приведены в соотвествие со столбцами тестовой выборки.
#
# На тренировочной выборке обучены модели линейной регрессии и случайного леса. Проведена оценка каждой модели. В результате для дальнешего прогнозирования выбирана модель случайного леса с лучшими параметрами, найденными с помощью **GridSearchCV**.<br>
#
# На тренировочных данных показатель smape равен 9.0715
#
# На тестовых данных выбранной модели случайного леса получен smape равный 6.906
#
# Итоговая оценка smape на константной модели =  7.778

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Отличный итоговый вывод по проекту!

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту.
#
# Дмитрий, проект получился на довольно хорошем уровне - отличная работа над проектом, молодец!
#
# Мне нравится твой аналитический подход к выполнению проекта, ты соблюдаешь структуру работы, выполняешь её последовательно - это очень хорошо! Шаги проекта выполнены по порядку согласно плану проекта, нет смысловых и структурных ям. Важно, что не забываешь про выводы.
#
# Работа с моделями также выполнена отлично: исследовано несколько алгоритмов, проведён подбор гиперпараметров с помощью `GridSearchCV`, выполнена промежуточная оценка моделей на кросс-валидации - молодец!
#
# Над проектом ещё стоит поработать - есть рекомендации по дополнению некоторых твоих шагов проекта. Такие рекомендации я отметил жёлтыми комментариями. Будет здорово, если ты учтёшь их - так проект станет структурно и содержательно более совершенным.
#
# Также в работе есть критические замечания. К этим замечаниям я оставил пояснительные комментарии красного цвета, в которых перечислил возможные варианты дальнейших действий. Уверен, ты быстро с этим управишься:)
#
# Если о том, что нужно сделать в рамках комментариев, будут возникать вопросы - оставь их, пожалуйста, в комментариях, и я отвечу на них во время следующего ревью.
#
# Также буду рад ответить на любые твои вопросы по проекту или на какие-либо другие, если они у тебя имеются - оставь их в комментариях, и я постараюсь ответить:)
#
# Жду твой проект на повторном ревью. До встречи:)

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту v.2.
#
# Дмитрий, все замечания учтены - проект принят!
#
# Спасибо за работу над проектом, желаю успехов в дальнейшем обучении:)
